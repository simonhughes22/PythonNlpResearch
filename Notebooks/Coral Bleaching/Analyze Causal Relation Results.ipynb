# %%
import pandas as pd

#fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions.txt"
fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions-causal_relations.txt"

data = pd.read_csv(fname, sep="|")

# %%
data.head()
# Out:
#                             Essay  Sent Number  \
# 0  EBA1415_AEKD_4_CB_ES-05568.ann            1
# 1  EBA1415_AEKD_4_CB_ES-05568.ann            2
# 2  EBA1415_AEKD_4_CB_ES-05568.ann            3
# 3  EBA1415_AEKD_4_CB_ES-05568.ann            4
# 4  EBA1415_AEKD_4_CB_ES-05572.ann            1
#
#                                   Processed Sentence Concept Codes Predictions
# 0  What leads to differences in the rates of cora...            50          50
# 1  Coral is often mistaken for a rock but it is m...           NaN         NaN
# 2  Coral bleaching shows bleaching and healthy bl...            50          50
# 3  Coral bleaching is almost noticeable in the pa...            50          50
# 4  The part of coral called zooanthellae are not ...             5         NaN

# %%
data["Concept Codes"] = data["Concept Codes"].apply(str)
data["Predictions"] = data["Predictions"].apply(str)

# %%
code = "Causer:5->Result:50"

#with_ys = data["Concept Codes"].str.contains(code)
#without = with_ys[not data["Concept Codes"].str.contains(code)]
df = data[data["Concept Codes"].str.contains(code) & ~data["Predictions"].str.contains(code)]
def filter_causal(s):
    splt = s.split(",")
    return "\t".join(filter(lambda st: "->" in st and "_" not in st, splt)).\
        replace("Causer:","C:").replace("Result:","R:")

print code, len(df)
for i in range(len(df)):
    row = df.iloc[i]
    ix = df.iloc[[i]].index.tolist()[0] + 2
    #print dir(row)
    print "Line:  ", str(ix), "Essay:", row["Essay"]
    print "Sent:  ", row["Processed Sentence"]
    print "Codes: ", row["Concept Codes"]
    print "Preds: ", row["Predictions"]
    print "CCodes:", filter_causal(row["Concept Codes"])
    print "CPreds:", filter_causal(row["Predictions"])
    print
# Out:
# Causer:5->Result:50 44
# Line:   7 Essay: EBA1415_AEKD_4_CB_ES-05572.ann
# Sent:   And if they get or much sunlight they start to loses their color
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  50
# CCodes: C:5->R:50
# CPreds:
#
# Line:   233 Essay: EBA1415_BLHT_5_CB_ES-05205.ann
# Sent:   There are many factors that can cause coral bleaching
# Codes:  50,Result,Causer:1->Result:50,Causer:5->Result:50,Causer:6->Result:50
# Preds:  50,Causer
# CCodes: C:1->R:50	C:5->R:50	C:6->R:50
# CPreds:
#
# Line:   234 Essay: EBA1415_BLHT_5_CB_ES-05205.ann
# Sent:   Some happen naturally like shifting trade winds and photosynthesis but others are caused by humans and the stress we INFREQUENT INFREQUENT on them
# Codes:  1,5,6,_CRel,Causer,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:6->Result:50
# Preds:  1,6
# CCodes: C:1->R:50	C:5->R:50	C:6->R:50
# CPreds:
#
# Line:   544 Essay: EBA1415_BLRW_3_CB_ES-05177.ann
# Sent:   Then the temperature is INFREQUENT is to not for photosynthesis to take places and coral bleaching takes place because the coral get the energy it needs to survive
# Codes:  3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:5,Causer:5->Result:50,Causer:5b->Result:50
# Preds:  5,50,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:3->R:5	C:5->R:50	C:5b->R:50
# CPreds:
#
# Line:   566 Essay: EBA1415_BLRW_3_CB_ES-05178.ann
# Sent:   The rate of bleaching is also affected by photosynthesis
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  50,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   1560 Essay: EBA1415_KNKC_1_CB_ES-05419.ann
# Sent:   Some of those INFREQUENT may not be INFREQUENT however the winds shifting the temperature photosynthesis process and the threat of human brings are causing the differences in the rates of coral bleaching
# Codes:  1,3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50,Causer:5->Result:50
# Preds:  1,5,50,_CRel,Causer,explicit
# CCodes: C:1->R:50	C:3->R:50	C:5->R:50
# CPreds:
#
# Line:   3261 Essay: EBA1415_LZBA_4_CB_ES-05516.ann
# Sent:   If the algae is doing an excessive amount of INFREQUENT then the polyps will create the color INFREQUENT and the coral will be bleached INFREQUENT
# Codes:  _C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  7,50,Causer:7->Result:50
# CCodes: C:5->R:50
# CPreds: C:7->R:50
#
# Line:   3372 Essay: EBA1415_LZBA_4_CB_ES-05531.ann
# Sent:   Another thing that leads to coral bleaching would be ocean salinity and INFREQUENT INFREQUENT photosynthesis
# Codes:  5,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50,Causer:13->Result:50
# Preds:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# CCodes: C:5->R:50	C:13->R:50
# CPreds: C:13->R:50
#
# Line:   3472 Essay: EBA1415_RCGJ_4a_CB_ES-04687.ann
# Sent:   Next the increased stress loses the color because not getting any photosynthesis
# Codes:  5,6,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50,Causer:6->Result:50
# Preds:  5,_CRel,Causer,Result
# CCodes: C:5->R:50	C:6->R:50
# CPreds:
#
# Line:   3843 Essay: EBA1415_RHSG_2_CB_ES-05074.ann
# Sent:   What leads to differences in the rates of coral bleaching are Shifting trade Winds photosynthesis and zooxanthellae
# Codes:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:7->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50	C:7->R:50
# CPreds: C:1->R:50
#
# Line:   4011 Essay: EBA1415_RHSGa_3_CB_ES-05089.ann
# Sent:   Because of the relationship coral algae have if the algae go through photosynthesis they will be in danger
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5,_C->R,_CRel,_RRel,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   4187 Essay: EBA1415_SDLC_2_CB_ES-04745.ann
# Sent:   If there is change in the environment the zooxanthellae cannot go through its photosynthesis and the coral can not go through its photosynthesis and the coral will become INFREQUENT and white
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5,7,50,_C->R,_CRel,_RRel,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   4204 Essay: EBA1415_SDLC_2_CB_ES-06284.ann
# Sent:   INFREQUENT photosynthesis trade winds all lead to differences in the rates of coral bleaching
# Codes:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:7->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50	C:7->R:50
# CPreds: C:1->R:50
#
# Line:   4311 Essay: EBA1415_SDLC_8_CB-06288.ann
# Sent:   Another way this happens is when the algae in the coral stops photosynthesis and the reef dies or the salinity levels drops because of heavy INFREQUENT storms
# Codes:  5,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  7,11,13,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   4675 Essay: EBA1415_SDMK_6_CB_ES-05454.ann
# Sent:   In what I read I learned of 0 factors in nature that affect rates of coral bleaching they which are changing trade winds photosynthesis of algae in coral and the INFREQUENT of coral and INFREQUENT
# Codes:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50
# Preds:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50
# CPreds: C:1->R:50
#
# Line:   4730 Essay: EBA1415_SDMK_6_CB_ES-06293.ann
# Sent:   The coral bleaching has a lot to do with the INFREQUENT INFREQUENT H20 CO2
# Codes:  4,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:4->Result:50,Causer:5->Result:50
# Preds:  50
# CCodes: C:4->R:50	C:5->R:50
# CPreds:
#
# Line:   5023 Essay: EBA1415_SEAL_78_CB_ES-04803.ann
# Sent:   The coral give the algae a protected nutrient rich enviroment while the algae give the coral food by INFREQUENT the energy to food to give some to the coral which gives them their color
# Codes:  _C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  nan
# CCodes: C:5->R:50
# CPreds:
#
# Line:   5030 Essay: EBA1415_SEAL_78_CB_ES-04804.ann
# Sent:   One rate leading to coral bleaching is the Trade Winds and Photosynthesis and also the algae
# Codes:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:7->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50	C:7->R:50
# CPreds: C:1->R:50
#
# Line:   5154 Essay: EBA1415_SEKL_1_CB_ES-04812.ann
# Sent:   Without being able to perform Photosynthesis the algae help the coral so it will die and in turn the Algae will die
# Codes:  5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50,Causer:7->Result:50
# Preds:  50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5b->Result:50
# CCodes: C:5->R:50	C:7->R:50
# CPreds: C:5b->R:50
#
# Line:   5354 Essay: EBA1415_SERS_1314_CB-05100.ann
# Sent:   This shows stress from the environment kills the algae that uses photosynthesis to give the coral food and color
# Codes:  6,7,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:6->Result:7,Causer:5->Result:50
# Preds:  6,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:6->Result:7
# CCodes: C:6->R:7	C:5->R:50
# CPreds: C:6->R:7
#
# Line:   5467 Essay: EBA1415_SERS_1314_CB_ES-05102.ann
# Sent:   Another reason for the rates of coral bleaching go up or down is photosynthesis
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5,50
# CCodes: C:5->R:50
# CPreds:
#
# Line:   5581 Essay: EBA1415_SERS_1516_CB-05123.ann
# Sent:   It get the right amount of photosynthesis they change color if they do they grow coral reefs
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5
# CCodes: C:5->R:50
# CPreds:
#
# Line:   6111 Essay: EBA1415_SWCT_6_CB_ES-04871.ann
# Sent:   There are various reasons to why coral bleaching has been occuring a lot that include shifting trade winds photosynthesis and zooxanthallae
# Codes:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:7->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50	C:7->R:50
# CPreds: C:1->R:50
#
# Line:   6334 Essay: EBA1415_SWCT_7_CB_ES-04897.ann
# Sent:   If the temperature is too hot or too cold the the coral cannot feed on the light properly Photosynthesis and will become white
# Codes:  3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:5,Causer:5->Result:50
# Preds:  3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50
# CCodes: C:3->R:5	C:5->R:50
# CPreds: C:3->R:50
#
# Line:   6413 Essay: EBA1415_SWSP_1_CB_ES-04850.ann
# Sent:   Coral bleaching is when coral loose their color and turn white What causes this is heat photosynthesis and extreme storms
# Codes:  5,11,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  11,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   6469 Essay: EBA1415_SWSP_4_CB_ES-04857.ann
# Sent:   Zooxanthellae and Photosynthesis use energy from the sunlight to more CO2 in the ocean with water which cause some of the difference in the rate of coral bleaching
# Codes:  50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  50
# CCodes: C:5->R:50
# CPreds:
#
# Line:   6474 Essay: EBA1415_SWSP_4_CB_ES-04859.ann
# Sent:   Other ways as when the CO2 is lowered in the ocean it will change the coral because the chemicals there not going to be able to use photosynthesis and the coral want get all the energy
# Codes:  4,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:4->Result:5,Causer:5->Result:50
# Preds:  50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:4->R:5	C:5->R:50
# CPreds:
#
# Line:   6525 Essay: EBA1415_SYMS_3_CB_ES-05563.ann
# Sent:   What leads to differences in the coral bleaching is depending on the algae weather or if the coral photosynthesis
# Codes:  5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50,Causer:7->Result:50
# Preds:  5,50
# CCodes: C:5->R:50	C:7->R:50
# CPreds:
#
# Line:   6596 Essay: EBA1415_SYMS_4_CB_ES-05982.ann
# Sent:   The things that lead to differences in the rates of coral bleaching are locations climate trade winds benefits from other animals physical damage and photosynthesis
# Codes:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50
# Preds:  1,50
# CCodes: C:1->R:50	C:5->R:50
# CPreds:
#
# Line:   6731 Essay: EBA1415_TFBM_2_CB_ES-05448.ann
# Sent:   The process is very important but it is also very sensitive to changes in the environment which is why corals become bleached when the algae cannot perform photosynthesis because the water changes during INFREQUENT trade winds
# Codes:  1,3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:3,Causer:5->Result:50
# Preds:  1,3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:3	C:5->R:50
# CPreds: C:1->R:50
#
# Line:   7058 Essay: EBA1415_TFHC_1_CB_ES-05965.ann
# Sent:   So therefore the biggest INFREQUENT in bleaching coral would be the trade winds because they make the environment very INFREQUENT up messing up the photosynthesis process for the coral which will not give them their normal color the algae provides them with because they can not create energy
# Codes:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50
# Preds:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:1->R:50	C:5->R:50
# CPreds:
#
# Line:   7339 Essay: EBA1415_TRDJ_11_CB_ES-05720.ann
# Sent:   Coral needs their color and in order get that they need light for the process of photosynthesis
# Codes:  _C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  nan
# CCodes: C:5->R:50
# CPreds:
#
# Line:   7435 Essay: EBA1415_TRDJ_2_CB_ES-06131.ann
# Sent:   Something that may cause the differences in rates of coral bleaching are when the water becomes warmer that stops photosynthesis for zooxanthellae and changes in enviroment
# Codes:  3,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:5,Causer:3->Result:7,Causer:5->Result:50,Causer:7->Result:50
# Preds:  3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50
# CCodes: C:3->R:5	C:3->R:7	C:5->R:50	C:7->R:50
# CPreds: C:3->R:50
#
# Line:   8261 Essay: EBA1415_TTFW_1_CB_ES-06175.ann
# Sent:   The things that leads to the difference in the rates of coral bleaching is shifting trade winds zooxanthallae and photosynthesis
# Codes:  1,5,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50,Causer:7->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50	C:7->R:50
# CPreds: C:1->R:50
#
# Line:   8551 Essay: EBA1415_TTKP_78_CB_ES-04917.ann
# Sent:   These warmer waters make the coral not do photosynthesis INFREQUENT making them die from not being able to make their own food and then losing color INFREQUENT after death
# Codes:  3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:5,Causer:5->Result:50,Causer:5b->Result:50
# Preds:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:3->R:5	C:5->R:50	C:5b->R:50
# CPreds:
#
# Line:   9059 Essay: EBA1415_WSAL_1_CB_ES-05350.ann
# Sent:   Shifting Trade winds photosynthesis and environmental stressors leads to differences in the rates or coral bleaching
# Codes:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50
# Preds:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:1->R:50	C:5->R:50
# CPreds:
#
# Line:   9340 Essay: EBA1415_WSKT_6_CB_ES-05343.ann
# Sent:   The high temps cause the Carbon Dioxide in the water to decrease and CO2 is needed to complete the process called Photosynthesis which helps the coral to maintain healthy
# Codes:  3,4,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:4,Causer:4->Result:5,Causer:5->Result:50
# Preds:  3,4,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:4
# CCodes: C:3->R:4	C:4->R:5	C:5->R:50
# CPreds: C:3->R:4
#
# Line:   9429 Essay: EBA1415post_TWDG_1_CB_ES-04936.ann
# Sent:   What leads to the differences in the rates of coral bleaching is trade winds photosynthesis polyps and zooxanthallae
# Codes:  1,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:5->Result:50
# Preds:  1,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:5->R:50
# CPreds: C:1->R:50
#
# Line:   9551 Essay: EBA1415post_TWMD_4-5_CB_ES-05466.ann
# Sent:   If they do not complete this process the coral will turn white which is known as coral bleaching
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   9706 Essay: EBA1415post_TWNB_3_CB_ES-04981.ann
# Sent:   Another reason why the rates of coral bleaching are different is because of photosynthesis
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5,50,_RRel,Result
# CCodes: C:5->R:50
# CPreds:
#
# Line:   9811 Essay: EBA1415post_TWNB_3_CB_ES-04991.ann
# Sent:   In conclusion coral bleaching is caused by trade winds photosynthesis and water temperature
# Codes:  1,3,5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50,Causer:5->Result:50
# Preds:  1,3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50
# CCodes: C:1->R:50	C:3->R:50	C:5->R:50
# CPreds: C:1->R:50
#
# Line:   9816 Essay: EBA1415post_TWNB_3_CB_ES-05893.ann
# Sent:   Coral need photosynthesis because without it the coral will die
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  Result
# CCodes: C:5->R:50
# CPreds:
#
# Line:   10114 Essay: EBA1415post_WSKT_1_CB_ES-05326.ann
# Sent:   The thing that leads to less or more differences in coral bleaching is the amount of photosynthesis
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:5->R:50
# CPreds:
#
# Line:   10165 Essay: EBA1415post_WSKT_6_CB_ES-05335.ann
# Sent:   Coral bleaching is because algae give them color through photosynthesis
# Codes:  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:5->Result:50
# Preds:  50
# CCodes: C:5->R:50
# CPreds:

# %%
row = df.iloc[0]
type(row)
# Out:
# pandas.core.series.Series

# %%
dir(row)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_align_frame',
#  '_align_series',
#  '_allow_index_ops',
#  '_at',
#  '_binop',
#  '_box_item_values',
#  '_can_hold_na',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_for_slice',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_create_indexer',
#  '_dir_additions',
#  '_dir_deletions',
#  '_expand_axes',
#  '_from_axes',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_numeric_data',
#  '_get_repr',
#  '_get_val_at',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_iat',
#  '_iget_item_cache',
#  '_iloc',
#  '_index',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_datelike_mixed_type',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_loc',
#  '_make_cat_accessor',
#  '_make_dt_accessor',
#  '_make_str_accessor',
#  '_maybe_box',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_axis',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_footer',
#  '_reset_cache',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_is_copy',
#  '_set_item',
#  '_set_labels',
#  '_set_subtyp',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_typ',
#  '_unpickle_series_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'as_blocks',
#  'as_matrix',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'autocorr',
#  'axes',
#  'base',
#  'between',
#  'between_time',
#  'bfill',
#  'blocks',
#  'bool',
#  'clip',
#  'clip_lower',
#  'clip_upper',
#  'combine',
#  'combine_first',
#  'compound',
#  'compress',
#  'consolidate',
#  'convert_objects',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'data',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_array',
#  'from_csv',
#  'ftype',
#  'ftypes',
#  'ge',
#  'get',
#  'get_dtype_counts',
#  'get_ftype_counts',
#  'get_value',
#  'get_values',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iget',
#  'iget_value',
#  'iloc',
#  'imag',
#  'index',
#  'interpolate',
#  'irow',
#  'is_copy',
#  'is_time_series',
#  'isin',
#  'isnull',
#  'item',
#  'itemsize',
#  'iteritems',
#  'iterkv',
#  'ix',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'load',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'nonzero',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'order',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'ptp',
#  'put',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'real',
#  'reindex',
#  'reindex_axis',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'reshape',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'save',
#  'searchsorted',
#  'select',
#  'sem',
#  'set_axis',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort',
#  'sort_index',
#  'sortlevel',
#  'squeeze',
#  'std',
#  'str',
#  'strides',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dense',
#  'to_dict',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_msgpack',
#  'to_period',
#  'to_pickle',
#  'to_sparse',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'tolist',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'valid',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %%
df.iloc[[0]].index.tolist()
# Out:
# [73]
