# %%
#top 5k dice keywords
NUM_CLUSTERS         = 100 
NUM_CLUSTER_SYNONYMS = 5
# number of cluster synonyms to map to
ROOT_FOLDER = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/PhraseExtractionAnalysis"

KEY_WORDS_FILE       = None
SYNONYMS_QRY_FILE    = None
SYNONYMS_INDEX_FILE  = None
PHRASES_FILE         = "%s/Phrases.txt" % ROOT_FOLDER
MODEL_FILE           = "%s/model.w2v" % ROOT_FOLDER

AP_CLUSTERS_FILE = "%s/Ap_Clusters.txt" % ROOT_FOLDER
KM_CLUSTERS_FILE = "%s/KMeans_Clusters.txt" % ROOT_FOLDER

# %%
#Shared
#just used to load phrases file
def load_stop_words(stop_words_file):
    stop_words = set()
    with open(stop_words_file) as f:
            for line in f:
                word = line.strip()
                if word[0] != "#":
                    word = word.lower()
                    stop_words.add(word)
    return stop_words

# %%
import time
grand_start = time.time()

# %%
import numpy as np
from collections import defaultdict

#functions
def is_valid_search_keyword(kw):
    q_kw = " " + kw + " "
    for wd in "(,), and , or , not , true , TRUE , false , FALSE ".split(","):
        if wd in q_kw:
            return False
    # remove queries with negations in them
    tokens = kw.split(" ")
    
    # remove single char keywords
    if len(tokens) == 1 and len(tokens[0]) == 1:
        return False
    
    if any(map(lambda t: t.strip().startswith("-"), tokens)):
        return False
    return True

def map_keyword(kw):
    return kw.replace(" ", "_")

def get_vector(item, model):
    if item not in model.vocab:
        return None
    vocab = model.vocab[item]
    vector = model.syn0[vocab.index]
    return vector

def get_norm_vector(item, model):
    if item not in model.vocab:
        return None
    # for deserialized models, the norm vectors are not stored
    vec = get_vector(item, model)
    norm = np.linalg.norm(vec)
    if norm != 0:
        return vec / norm
    return vec

def extract_clusters(ids, id2kwd):
    clusters = defaultdict(set)
    for kw_id, label in enumerate(ids):
        kw = id2kwd[kw_id]
        clusters[label].add(kw)
    return clusters

def extract_centroids(km_clusterer):
    lbl2centroid = dict()
    for i in range(len(km_clusterer.cluster_centers_)):
        centroid = km_clusterer.cluster_centers_[i]
        c_norm = np.linalg.norm(centroid)
        if c_norm > 0.0:
            n_centroid = centroid / c_norm
        else:
            n_centroid = centroid
        lbl2centroid[i] = n_centroid
    return lbl2centroid

def compute_cluster_similarities(kwds, kwd2id, vectors, lbl2centroid):
    kwd2cluster_sims = dict()
    for kwd in kwds:
        ix = kwd2id[kwd]
        nvec = vectors[ix]
        sims = []

        for lbl, centroid in lbl2centroid.items():
            cosine_sim = np.inner(nvec, centroid)
            sims.append((lbl,cosine_sim))
        sims = sorted(sims, key = lambda (lbl,sim): -sim)
        kwd2cluster_sims[kwd] = sims
        if len(kwd2cluster_sims) % 1000 == 0:
            print("%i computed out of %i" % (len(kwd2cluster_sims), len(all_kwds)))
    return kwd2cluster_sims

# expand at query time
# use with tfidf (on cluster labels) at index time by just mapping to cluster label
def write_most_similar_clusters(topn, kwd2cluster_sims, synonym_qry_fname, synonyn_index_fname):
    kwords = sorted(kwd2cluster_sims.keys())
    cluster_label = lambda lbl: "cluster_" + str(lbl)
    
    with open(synonym_qry_fname, "w+") as qry_f:
        for kword in kwords:
            cl_sims = kwd2cluster_sims[kword]
            # unlike the other methods, we DO want to include the first cluster here
            # as it's a cluster rather than the top 10 or top 30 keyword method
            top_clusters = cl_sims[:topn]                
            if len(top_clusters) > 0:
                qry_f.write("%s=>" % kword)
                for lbl, sim in top_clusters:                    
                    qry_f.write("%s|%f " %(cluster_label(lbl),sim))
                qry_f.write("\n")
                
    with open(synonyn_index_fname, "w+") as f:
        for kword in kwords:
            # get top cluster label
            lbl, sim = kwd2cluster_sims[kword][0]
            f.write("%s=>%s\n" % (kword, cluster_label(lbl)))

# %%
import gensim, time
from gensim.models.word2vec import Word2Vec

model = Word2Vec.load(MODEL_FILE)

# %%
phrases = load_stop_words(PHRASES_FILE)
len(phrases)
# Out:
# 1194

# %%
keywords = []
un_keywords = set()
if KEY_WORDS_FILE is not None:
    with open(KEY_WORDS_FILE) as f:
        for line in f:
            kw = line.strip()
            if len(kw) > 0 and is_valid_search_keyword(kw):
                keywords.append(kw)
print("%i keywords loaded from %s" % (len(keywords), KEY_WORDS_FILE))
# Out:
# 0 keywords loaded from None

# %%
#get all keywords
# remove any not in the model
all_kwds = phrases.union(keywords)
#all_kwds = set(keywords)
for kwd in list(all_kwds):
    if kwd not in model.vocab:
        all_kwds.remove(kwd)
    splt = kwd.split(" ")
    # add in single word tokens from keywords
    if splt and len(splt) > 1:
        for wd in splt:
            if wd.strip() and wd in model.vocab:
                all_kwds.add(wd)

id2kwd = dict()
kwd2id = dict()
vectors = []
for term in all_kwds:
    id2kwd[len(vectors)] = term
    kwd2id[term] = len(vectors)
    vec = get_norm_vector(term, model)
    vectors.append(vec)

len(all_kwds), len(vectors)
# Out:
# (1176, 1176)

# %% [markdown]
# # Cluster the Vectors

# %% [markdown]
# ## Affinity Propagation

# %%
from sklearn import cluster
from sklearn.cluster import AffinityPropagation
import time
start = time.time()

# don't parallelize (n_jobs = -1), doesn't seem to work
print("Clustering vectors into clusters via AP")
ap_clusterer = AffinityPropagation()
ap_ids = ap_clusterer.fit_predict(vectors)

end = time.time()
print("Creating %i clusters took %i seconds" % (len(set(ap_ids)), end - start))
# Out:
# Clustering vectors into clusters via AP
# Creating 82 clusters took 0 seconds

# %%
ap_lbl2cluster = extract_clusters(ap_ids, id2kwd)
ap_lbl2centroid = extract_centroids(ap_clusterer)

len(ap_lbl2cluster), len(ap_lbl2centroid)
# Out:
# (82, 82)

# %% [markdown]
# ## Examine the AP Clusters

# %%
ap_lbl2cluster.values()
# Out:
# [{'affect',
#   'affects',
#   'another',
#   'another reason',
#   'certain',
#   'effect',
#   'effects',
#   'example',
#   'final',
#   'finally',
#   'main reason',
#   'major',
#   'negative',
#   'one',
#   'one way',
#   'stressors',
#   'unbalanced',
#   'weather'},
#  {'central',
#   'climate',
#   'eastern pacific regions',
#   'equatorial',
#   'especially',
#   'greatly',
#   'int',
#   'major shifts',
#   'movement',
#   'pacific regions',
#   'swell',
#   'warm water eastward',
#   'water levels',
#   'worlds'},
#  {'caused',
#   'environment',
#   'health',
#   'increased stress',
#   'most dangerous threat',
#   'most dangerous threats',
#   'put stress',
#   'those',
#   'threats'},
#  {'coral polyps range',
#   'diameter',
#   'foot',
#   'pinhead',
#   'range',
#   'size',
#   'tiny',
#   'tiny up',
#   'up'},
#  {'10of',
#   '3of',
#   '5of',
#   'above',
#   'even',
#   'increase over',
#   'normal',
#   'ocean water temperatures increase',
#   'places',
#   'say',
#   'waters shift eastward ocean water'},
#  {'big problem',
#   'bleaching',
#   'conclusion coral',
#   'coral bleach',
#   'coral reef',
#   'happen',
#   'loss',
#   'population',
#   'problems',
#   'thats',
#   'why coral'},
#  {'alive',
#   'grow',
#   'healthy',
#   'help',
#   'keep',
#   'need',
#   'pretty',
#   'right amount'},
#  {'areas',
#   'background',
#   'coastal regions',
#   'costal',
#   'land',
#   'location',
#   'mainly',
#   'most affected',
#   'near'},
#  {'few', 'goes', 'likely', 'might', 'much', 'seems', 'through', 'well'},
#  {'carbon',
#   'combination',
#   'combination results',
#   'during',
#   'form',
#   'formation',
#   'glucose',
#   'happening',
#   'makes',
#   'o2',
#   'oxygen',
#   'passed',
#   'resulting',
#   'sugar',
#   'sugars'},
#  {'algae gives',
#   'coral gets',
#   'ejects',
#   'food',
#   'give',
#   'helps',
#   'itself',
#   'kills',
#   'make',
#   'nutrient rich environment',
#   'off',
#   'pass',
#   'passes',
#   'protection',
#   'provided',
#   'reason why coral',
#   'source',
#   'through photosynthesis',
#   'zooxanthalle',
#   'zooxanthellae',
#   'zooxanthellae pass'},
#  {'according',
#   'background what',
#   'coral photosynthesis',
#   'document',
#   'paragraph',
#   'second'},
#  {'actually',
#   'always',
#   'animal',
#   'animals called polyps',
#   'called',
#   'called polyps',
#   'made',
#   'made up',
#   'mistaken',
#   'often mistaken',
#   'one thing',
#   'plant',
#   'plants',
#   'really made',
#   'really made up',
#   'rock',
#   'rocks',
#   'small',
#   'sometimes',
#   'though',
#   'tiny animals',
#   'tiny animals called polyps'},
#  {'called upwelling',
#   'colder',
#   'cooler',
#   'deeper',
#   'hotter',
#   'moves',
#   'than',
#   'warmer',
#   'water gets',
#   'water rises',
#   'western',
#   'westward'},
#  {'article', 'corals receive', 'estimate', 'recieve', 'scientists'},
#  {'away',
#   'become',
#   'become bleached',
#   'become unhealthy',
#   'becomes',
#   'bleached',
#   'comes',
#   'coral becomes',
#   'coral bleaching happens',
#   'gets',
#   'heat',
#   'less',
#   'sick',
#   'therefore',
#   'underwater',
#   'unhealthy'},
#  {'bottom',
#   'bring',
#   'cold',
#   'cold water',
#   'common',
#   'eastern',
#   'everything',
#   'hot',
#   'move',
#   'moving',
#   'warm water',
#   'warmer water'},
#  {'coral bleaching',
#   'coral bleaching would',
#   'depends',
#   'difference',
#   'differences',
#   'different',
#   'every year',
#   'lead',
#   'leads',
#   'rate',
#   'rates',
#   'what leads'},
#  {'benefit',
#   'benefits',
#   'both',
#   'both benefit',
#   'means',
#   'relationship',
#   'symbiotic',
#   'symbiotic relationship',
#   'zooxanthallae'},
#  {'big',
#   'conditions',
#   'natural',
#   'occurs',
#   'ocean',
#   'overall',
#   'phenomena',
#   'reason why coral bleaching',
#   'something',
#   'too much',
#   'tropical'},
#  {'coral bleaching could',
#   'coral bleaching rates',
#   'different rates',
#   'different things',
#   'different ways',
#   'environmental',
#   'factors',
#   'get bleached',
#   'many different',
#   'many factors',
#   'many reasons',
#   'many things',
#   'many ways',
#   'multiple',
#   'several',
#   'things',
#   'two',
#   'various',
#   'ways'},
#  {'anywhere',
#   'higher water',
#   'inches',
#   'rise',
#   'rises',
#   'sea level',
#   'sea levels'},
#  {'affects coral',
#   'another thing',
#   'another way',
#   'balance',
#   'dangerous',
#   'extreme storms',
#   'increase',
#   'increasing',
#   'much salt',
#   'occur',
#   'threat',
#   'threaten',
#   'threatened',
#   'very sensitive'},
#  {'change',
#   'degree',
#   'huge',
#   'least',
#   'temperature',
#   'trade wind strength',
#   'trade winds',
#   'trade winds shift',
#   'water temperature',
#   'water temperatures'},
#  {'clear shallow tropical',
#   'clear shallow tropical waters',
#   'coral reefs',
#   'found',
#   'only found',
#   'shallow tropical waters'},
#  {'after',
#   'alot',
#   'bad',
#   'being bleached',
#   'come',
#   'having',
#   'information',
#   'large',
#   'like',
#   'lot',
#   'often',
#   'probably',
#   'stop'},
#  {'considered',
#   'considered one',
#   'coral bleaching event',
#   'died',
#   'event',
#   'event resulted',
#   'ever',
#   'happened',
#   'killed',
#   'massive',
#   'massive coral bleaching',
#   'massive coral bleaching event',
#   'observed',
#   'resulted',
#   'very serious',
#   'worlds coral',
#   'worlds coral reefs',
#   'worst',
#   'worst coral bleaching',
#   'worst ever',
#   'worst ever observed'},
#  {'animals live together',
#   'colonies',
#   'coral live',
#   'coral lives',
#   'corals live',
#   'invertebrate',
#   'invertebrate animals',
#   'invertebrate animals live together',
#   'live together',
#   'many polyps',
#   'one place',
#   'stay',
#   'tend',
#   'together'},
#  {'add',
#   'amounts',
#   'corals health',
#   'decreases',
#   'decreasing',
#   'during storms',
#   'excessive',
#   'extreme',
#   'fresh water',
#   'hurricane',
#   'level',
#   'levels',
#   'like hurricanes',
#   'messes',
#   'more fresh',
#   'more fresh water',
#   'produces',
#   'rain',
#   'rainfall',
#   'salt',
#   'salt water',
#   'storm',
#   'storms'},
#  {'algae cannot',
#   'algae needs',
#   'clear',
#   'clear shallow',
#   'clear tropical',
#   'go through',
#   'light',
#   'live',
#   'only',
#   'perform photosynthesis',
#   'shallow',
#   'shallow water',
#   'shallow waters',
#   'thrive',
#   'tropical water',
#   'tropical waters',
#   'warm',
#   'waters'},
#  {'affecting',
#   'anchor',
#   'anchors',
#   'blast',
#   'blast fishing',
#   'blast fishing tourists who',
#   'blast fishing tourists who drop anchors',
#   'damage',
#   'damaged',
#   'damaging',
#   'drop anchors',
#   'dropped',
#   'dropping',
#   'dropping anchors',
#   'drops',
#   'etc',
#   'examples',
#   'fishing',
#   'harm',
#   'human',
#   'humans',
#   'include',
#   'kill',
#   'like blast fishing',
#   'people',
#   'physical',
#   'physical damage',
#   'reef',
#   'reefs',
#   'stepping',
#   'things like',
#   'tourist',
#   'tourist who',
#   'tourists',
#   'tourists who drop anchors',
#   'walk',
#   'walking',
#   'who drop anchors'},
#  {'coral turn white',
#   'coral turns white',
#   'coral turns white due',
#   'corals turn white',
#   'corals turn white due',
#   'death',
#   'during bleaching',
#   'during bleaching corals turn white due',
#   'ejected',
#   'ejecting',
#   'ejection',
#   'leaves',
#   'turns white due',
#   'white due',
#   'zooxanthallae algae',
#   'zooxanthellae algae'},
#  {'amount',
#   'balance required',
#   'carbon dioxide',
#   'carbon dioxide co2',
#   'carbon dioxide decreases',
#   'co2 decreases',
#   'co2 threaten',
#   'coral healthy',
#   'corals healthy',
#   'delicate balance',
#   'delicate balance required',
#   'increases',
#   'keep coral',
#   'keep corals healthy',
#   'needed',
#   'required',
#   'temp',
#   'temperature increases',
#   'threatens',
#   'water decreases',
#   'water increases',
#   'water temp',
#   'water temperature changes',
#   'water temperature increase',
#   'water temperature increases',
#   'water temperatures increase'},
#  {'articles',
#   'believe',
#   'explain',
#   'first off',
#   'know what',
#   'my',
#   'now',
#   'what',
#   'what coral bleaching',
#   'why',
#   'you'},
#  {'biggest', 'creatures', 'fish', 'ones', 'our', 'sea', 'take', 'who'},
#  {'bleached coral',
#   'bright',
#   'colorful',
#   'corals lose',
#   'figure',
#   'healthy coral'},
#  {'do',
#   'just',
#   'let',
#   'look',
#   'maybe',
#   'nature',
#   'nothing',
#   'place',
#   'thing',
#   'until',
#   'we'},
#  {'allow photosynthesis',
#   'animals',
#   'cannot live',
#   'cannot live outside',
#   'cant',
#   'coral body',
#   'enough nutrients',
#   'fact',
#   'live outside',
#   'most zooxanthellae',
#   'outside',
#   'tropical ocean',
#   'work',
#   'zooanthellae',
#   'zooxanthellae cannot',
#   'zooxanthellae cannot live outside'},
#  {'based',
#   'changing',
#   'climate change',
#   'conclude',
#   'conclusion',
#   'depending',
#   'factor',
#   'main',
#   'one reason',
#   'part',
#   'reason',
#   'reasons',
#   'reasons why',
#   'temperature change',
#   'temperature changes',
#   'trade winds photosynthesis',
#   'why coral bleaching'},
#  {'chart',
#   'charts',
#   'coral bleaching increases',
#   'coral bleaching reports',
#   'data',
#   'given',
#   'graph',
#   'graphs',
#   'high water',
#   'high water temperatures',
#   'higher',
#   'higher water temperature',
#   'higher water temperatures',
#   'higher water temps',
#   'low',
#   'more coral bleaching',
#   'show',
#   'shown',
#   'shows',
#   'temperature rises',
#   'versus trade winds',
#   'water temps',
#   'weak',
#   'weak trade winds',
#   'weaker trade winds',
#   'wind trades'},
#  {'play', 'plays', 'role'},
#  {'becoming',
#   'bleaching event',
#   'bleaching makes',
#   'coral vulnerable',
#   'corals vulnerable',
#   'disease',
#   'disease starvation',
#   'diseases',
#   'due',
#   'happens',
#   'makes coral vulnerable',
#   'makes corals',
#   'makes corals vulnerable',
#   'result',
#   'results',
#   'starvation',
#   'vulnerable'},
#  {'events leading',
#   'impact',
#   'impacts',
#   'serious',
#   'serious impact',
#   'serious problem',
#   'world'},
#  {'australia',
#   'australia near',
#   'just north',
#   'new guinea',
#   'north',
#   'occuring',
#   'papua',
#   'papua new guinea',
#   'pool',
#   'side',
#   'trade winds drag warm',
#   'trading',
#   'warm waters',
#   'waters westward',
#   'winds drag warm surface waters westward'},
#  {'algae relies',
#   'algae rely',
#   'destructive',
#   'destructive practices',
#   'stay healthy',
#   'sustain physical damage'},
#  {'85f',
#   '85of',
#   'building',
#   'certain temperature',
#   'changes',
#   'coral need',
#   'coral needs',
#   'coral reefs need',
#   'corals need water',
#   'corals need water temperatures',
#   'do photosynthesis',
#   'keeps',
#   'need water',
#   'needs water',
#   'order',
#   'photosynthesis',
#   'process',
#   'receive',
#   'reef building',
#   'reef building corals',
#   'reef building corals need',
#   'reef building corals need water temperature',
#   'reef building corals need water temperatures',
#   'sensitive',
#   'temps',
#   'water changes',
#   'way coral'},
#  {'better',
#   'bleach',
#   'cannot',
#   'die',
#   'dies',
#   'eat',
#   'eventually',
#   'find',
#   'leaving',
#   'left',
#   'meaning',
#   'out',
#   'possibly',
#   'produce',
#   'producing',
#   'start',
#   'starve',
#   'without'},
#  {'algae living',
#   'algae living within',
#   'colors',
#   'coral polyps',
#   'coral polyps give',
#   'corals',
#   'corals get',
#   'different colors',
#   'different types',
#   'give corals',
#   'gives',
#   'inside',
#   'living within',
#   'many types',
#   'own',
#   'polyps give',
#   'types',
#   'varying',
#   'varying colors',
#   'within'},
#  {'algae make',
#   'algae make provide',
#   'algae makes',
#   'chemicals',
#   'important',
#   'needs',
#   'provide',
#   'survive'},
#  {'although',
#   'being important',
#   'boat navigation',
#   'boats',
#   'deeper colder',
#   'guide',
#   'guide boat navigation',
#   'later',
#   'later recognized',
#   'leading',
#   'merchant',
#   'merchant trading',
#   'much more',
#   'navigation',
#   'originally',
#   'originally used',
#   'purpose',
#   'recognized',
#   'seen',
#   'trade',
#   'used'},
#  {'any',
#   'danger',
#   'delicate',
#   'else',
#   'get stressed',
#   'harmful',
#   'hurt',
#   'puts',
#   'should',
#   'wrong'},
#  {'alter',
#   'altered',
#   'direction',
#   'directions',
#   'drag warm',
#   'drastically',
#   'every few years',
#   'normally',
#   'shifting',
#   'strong',
#   'trade winds change',
#   'tradewinds',
#   'wind'},
#  {'go down',
#   'goes up',
#   'got',
#   'lower',
#   'strength',
#   'trade wind',
#   'trades',
#   'versa',
#   'water goes',
#   'water temperature rises',
#   'weak trade',
#   'weakened',
#   'weaker',
#   'wind strength',
#   'winds'},
#  {'atlantic',
#   'atlantic ocean',
#   'back',
#   'bleaching corals',
#   'contains',
#   'contains double',
#   'covers',
#   'covers about',
#   'double',
#   'entire',
#   'entire globe',
#   'globe',
#   'issue',
#   'ocean covers',
#   'ocean covers about',
#   'pacific ocean covers',
#   'surface',
#   'water found',
#   'way'},
#  {'algae zooxanthallae',
#   'coral ejects',
#   'eject',
#   'enviroment',
#   'enviromental',
#   'environment changes',
#   'environment forces',
#   'food producing algae',
#   'forced',
#   'forces',
#   'killing',
#   'most dangerous',
#   'put',
#   'puts stress',
#   'risk',
#   'stress',
#   'stressed',
#   'sudden',
#   'undergo'},
#  {'being',
#   'coral',
#   'could',
#   'does',
#   'get',
#   'getting',
#   'go',
#   'good',
#   'life',
#   'making',
#   'more',
#   'must',
#   'really',
#   'since',
#   'since coral',
#   'so',
#   'very',
#   'water',
#   'would'},
#  {'been',
#   'changed',
#   'down',
#   'every',
#   'going',
#   'gone',
#   'last',
#   'same',
#   'throughout',
#   'worse',
#   'years'},
#  {'balance necessary',
#   'coral health',
#   'drop',
#   'necessary',
#   'ocean salinity',
#   'salinity drops',
#   'salinity upsets',
#   'storms increase',
#   'upset',
#   'upsets'},
#  {'co2',
#   'enough sunlight',
#   'long',
#   'lower than normal',
#   'normal amount',
#   'undergo photosynthesis'},
#  {'allow',
#   'build',
#   'build up',
#   'create',
#   'delicate body',
#   'feed',
#   'form coral reefs',
#   'hard',
#   'hard skeleton',
#   'hard skeleton protects',
#   'hard skeletons',
#   'limestone',
#   'over time',
#   'polyp',
#   'polyps',
#   'protect',
#   'protects',
#   'seawater',
#   'self',
#   'skeleton'},
#  {'beautiful',
#   'been bleached',
#   'coral bleaching occurs',
#   'coral starts',
#   'dead',
#   'loses',
#   'loses color',
#   'lost',
#   'plain white',
#   'red',
#   'starts',
#   'turn',
#   'turning',
#   'turns',
#   'white',
#   'white color'},
#  {'algae',
#   'algae provides',
#   'coral provides',
#   'coral so',
#   'depend',
#   'eachother',
#   'giving',
#   'home',
#   'nutrient',
#   'nutrients',
#   'protected',
#   'protected nutrient rich',
#   'protected nutrient rich environment',
#   'provides',
#   'relies',
#   'rely',
#   'survival',
#   'sustain',
#   'very important'},
#  {'color',
#   'coral looses',
#   'coral lose',
#   'coral loses',
#   'coral loses color',
#   'looses',
#   'phenomenon',
#   'takes place',
#   'turns white',
#   'where coral'},
#  {'body',
#   'coral polyp',
#   'mouth',
#   'mouth surrounded',
#   'stinging tentacles',
#   'surrounded',
#   'tentacles'},
#  {'asia',
#   'located',
#   'most coral bleaching',
#   'most noticeable',
#   'mostly',
#   'mostly found',
#   'north america',
#   'noticable',
#   'noticeable',
#   'noticed',
#   'pacific',
#   'pacific ocean',
#   'where'},
#  {'article coral', 'passage', 'said', 'says', 'stated', 'states', 'text'},
#  {'80of',
#   'degree f',
#   'degrees',
#   'degrees f',
#   'eastward ocean water',
#   'however',
#   'need water temperature',
#   'normal water',
#   'normal water temperature',
#   'region',
#   'regions',
#   'shift',
#   'shift eastward ocean water temperatures',
#   'shifts',
#   'surface water',
#   'surface waters shift eastward',
#   'surface waters shift eastward ocean water',
#   'temp increases',
#   'temperature increase',
#   'temperatures',
#   'temperatures increase'},
#  {'algae dies',
#   'begin',
#   'bleaching coral',
#   'coral dies',
#   'die off',
#   'enviromental changes',
#   'leave',
#   'loose',
#   'lose',
#   'losing',
#   'makes coral',
#   'once',
#   'reason why',
#   'turn white',
#   'turning white',
#   'zooxanthellae dies'},
#  {'algae lives',
#   'combine',
#   'combine carbon dioxide',
#   'combine co2',
#   'during photosynthesis',
#   'during photosynthesis zooxanthellae',
#   'energy',
#   'h2o',
#   'ocean water',
#   'photosynthesis zooxanthellae',
#   'sun',
#   'sunlight',
#   'takes'},
#  {'about',
#   'almost',
#   'cases',
#   'coral bleached',
#   'coral bleaching reports per',
#   'countries',
#   'countries reported',
#   'countries reported coral bleaching',
#   'countries reporting',
#   'decreased',
#   'higher than',
#   'increased',
#   'more severe',
#   'number',
#   'over',
#   'report',
#   'reported',
#   'reported coral bleaching',
#   'reporting coral bleaching',
#   'rose',
#   'same year',
#   'severe coral bleaching',
#   'started',
#   'very weak',
#   'weakest',
#   'went',
#   'went up'},
#  {'decrease',
#   'excessive rainfall',
#   'excessive rainfall like hurricanes',
#   'hurricanes',
#   'lots',
#   'regions during storms',
#   'salinity',
#   'salty',
#   'shallow coastal regions',
#   'shallow coastal regions during storms',
#   'tropical storms'},
#  {'biologists',
#   'called coral bleaching',
#   'coral living',
#   'corals living',
#   'deal',
#   'discovered',
#   'discovered many',
#   'discovered many different types',
#   'living',
#   'many different types',
#   'marine',
#   'marine biologist',
#   'marine biologists',
#   'oceans',
#   'still'},
#  {'about coral',
#   'about coral bleaching',
#   'before',
#   'close',
#   'did',
#   'documents',
#   'done',
#   'finish',
#   'first',
#   'know',
#   'learned',
#   'little',
#   'matter',
#   'mean',
#   'ran out',
#   'read',
#   'reading',
#   'see',
#   'seem',
#   'think',
#   'time',
#   'times'},
#  {'case',
#   'coral bleaching happened',
#   'coral bleaching reports per year',
#   'countries reporting coral bleaching',
#   'deaths',
#   'end',
#   'extremely',
#   'had',
#   'high',
#   'highest',
#   'lowest',
#   'mild',
#   'moderate',
#   'more than',
#   'most coral',
#   'most severe',
#   'occured',
#   'per year',
#   'reporting',
#   'reports',
#   'severe',
#   'showed',
#   'water temperature versus trade winds',
#   'year',
#   'you look'},
#  {'blow',
#   'change direction',
#   'completely',
#   'couple',
#   'drag warm surface',
#   'east',
#   'every few years trade winds',
#   'instead',
#   'pacific trade winds',
#   'reverse',
#   'reverse direction',
#   'reverse direction completely',
#   'trade winds weaken',
#   'travel',
#   'weaken',
#   'west',
#   'winds go',
#   'winds weaken'},
#  {'dying',
#   'events',
#   'many',
#   'many do',
#   'others',
#   'recover',
#   'reefs recover',
#   'while'},
#  {'balanced',
#   'balanced relationship',
#   'coral zooxanthellae',
#   'enviromental stressors',
#   'environmental stressors',
#   'negatively',
#   'negatively affect',
#   'one example',
#   'zooxanthelle'},
#  {'america',
#   'circumstances',
#   'drag',
#   'dragged',
#   'dragged eastward',
#   'eastward',
#   'eastward towards south',
#   'shifting trade winds',
#   'south america',
#   'towards',
#   'towards south',
#   'towards south america',
#   'trade winds travel',
#   'under',
#   'usually',
#   'warm surface water',
#   'warm surface waters',
#   'warm surface waters westward',
#   'winds change',
#   'winds shift'},
#  {'article shifting trade winds',
#   'colder than',
#   'colder than those',
#   'deeper colder waters',
#   'drag warm surface waters westward',
#   'eastern pacific',
#   'eastern pacific rise',
#   'known',
#   'surface waters',
#   'trade winds affect',
#   'upwelling',
#   'western pacific'},
#  {'able',
#   'another factor',
#   'area',
#   'co2 levels',
#   'coral does',
#   'coral get',
#   'coral would',
#   'corals need',
#   'enough',
#   'get enough',
#   'lack',
#   'lastly',
#   'lose color',
#   'lower than',
#   'may',
#   'photosynthesis process',
#   'possible',
#   'problem',
#   'right',
#   'specific',
#   'too'},
#  {'algae called',
#   'algae called zooxanthellae',
#   'algae called zooxanthellae live',
#   'algae live',
#   'algae zooxanthellae',
#   'basically',
#   'called zooxanthellae',
#   'coral tissues',
#   'go through photosynthesis',
#   'lives',
#   'need light',
#   'partly',
#   'tissue',
#   'tissues',
#   'type',
#   'wich',
#   'zooxanthellae live'},
#  {'affected', 'around', 'effected', 'most', 'most common', 'new', 'next'}]

# %%
from sklearn import cluster
from sklearn.cluster import KMeans
import time
start = time.time()

# don't parallelize (n_jobs = -1), doesn't seem to work
print("Clustering vectors into %i clusters" % NUM_CLUSTERS)
km_clusterer = KMeans(n_clusters=NUM_CLUSTERS, n_jobs=1, verbose=1, n_init=5)
ids = km_clusterer.fit_predict(vectors)

end = time.time()
print("Creating %i clusters took %i seconds" % (NUM_CLUSTERS, end - start))
# Out:
# Clustering vectors into 100 clusters
# Initialization complete
# Iteration  0, inertia 337.257
# Iteration  1, inertia 237.088
# Iteration  2, inertia 231.604
# Iteration  3, inertia 229.067
# Iteration  4, inertia 227.822
# Iteration  5, inertia 227.560
# Iteration  6, inertia 227.396
# Iteration  7, inertia 227.321
# Converged at iteration 7
# Initialization complete
# Iteration  0, inertia 334.312
# Iteration  1, inertia 235.941
# Iteration  2, inertia 230.795
# Iteration  3, inertia 229.187
# Iteration  4, inertia 228.479
# Iteration  5, inertia 228.339
# Iteration  6, inertia 228.273
# Iteration  7, inertia 228.227
# Iteration  8, inertia 228.191
# Converged at iteration 8
# Initialization complete
# Iteration  0, inertia 340.482
# Iteration  1, inertia 238.389
# Iteration  2, inertia 233.003
# Iteration  3, inertia 231.386
# Iteration  4, inertia 230.706
# Iteration  5, inertia 230.220
# Iteration  6, inertia 230.152
# Converged at iteration 6
# Initialization complete
# Iteration  0, inertia 340.290
# Iteration  1, inertia 238.158
# Iteration  2, inertia 231.810
# Iteration  3, inertia 228.953
# Iteration  4, inertia 227.951
# Iteration  5, inertia 227.471
# Iteration  6, inertia 227.303
# Iteration  7, inertia 227.269
# Iteration  8, inertia 227.193
# Converged at iteration 8
# Initialization complete
# Iteration  0, inertia 337.815
# Iteration  1, inertia 235.081
# Iteration  2, inertia 229.789
# Iteration  3, inertia 228.086
# Iteration  4, inertia 227.383
# Iteration  5, inertia 226.877
# Iteration  6, inertia 226.660
# Iteration  7, inertia 226.644
# Converged at iteration 7
# Creating 100 clusters took 0 seconds

# %%
lbl2cluster = extract_clusters(ids, id2kwd)
lbl2centroid = extract_centroids(km_clusterer)

len(lbl2cluster), len(lbl2centroid)
# Out:
# (100, 100)

# %% [markdown]
# ## Examine the k-Means Clusters

# %%
lbl2cluster.values()
# Out:
# [{'believe',
#   'get bleached',
#   'many different',
#   'reasons',
#   'two',
#   'various',
#   'ways'},
#  {'back',
#   'deeper colder',
#   'deeper colder waters',
#   'drag warm surface waters westward',
#   'eastern pacific rise',
#   'pacific',
#   'surface'},
#  {'big problem',
#   'bleaching',
#   'conclusion coral',
#   'coral bleach',
#   'coral reef',
#   'loss',
#   'population',
#   'why coral'},
#  {'algae', 'coral', 'coral gets', 'corals', 'off', 'produces'},
#  {'alive',
#   'carbon dioxide',
#   'carbon dioxide decreases',
#   'co2 decreases',
#   'co2 levels',
#   'healthy',
#   'keep coral',
#   'keeps',
#   'needed',
#   'temperature increases',
#   'water increases'},
#  {'algae living',
#   'basically',
#   'colors',
#   'give',
#   'gives',
#   'giving',
#   'inside',
#   'lives',
#   'own',
#   'tissues',
#   'type',
#   'wich'},
#  {'alter',
#   'changed',
#   'couple',
#   'depending',
#   'direction',
#   'drastically',
#   'every',
#   'normally',
#   'shift',
#   'shifting',
#   'shifting trade winds',
#   'temperatures',
#   'trade winds change',
#   'trade winds shift',
#   'tradewinds',
#   'water goes',
#   'weakened',
#   'wind'},
#  {'animals live together',
#   'colonies',
#   'coral live',
#   'coral lives',
#   'corals live',
#   'invertebrate',
#   'invertebrate animals',
#   'invertebrate animals live together',
#   'live together',
#   'living',
#   'many polyps',
#   'one place',
#   'stay',
#   'tend',
#   'together'},
#  {'algae provides',
#   'coral provides',
#   'food',
#   'help',
#   'kills',
#   'nutrient',
#   'nutrient rich environment',
#   'nutrients',
#   'pass',
#   'passes',
#   'protected',
#   'protected nutrient rich',
#   'protected nutrient rich environment',
#   'protection',
#   'survival',
#   'through photosynthesis',
#   'zooxanthellae',
#   'zooxanthellae pass'},
#  {'coral bleaching reports',
#   'graphs',
#   'high water temperatures',
#   'higher water temperature',
#   'higher water temperatures',
#   'higher water temps',
#   'more coral bleaching',
#   'more severe',
#   'shown',
#   'very weak',
#   'weak trade',
#   'weak trade winds',
#   'weaker trade winds'},
#  {'build',
#   'build up',
#   'delicate body',
#   'form coral reefs',
#   'hard skeleton',
#   'hard skeleton protects',
#   'hard skeletons',
#   'limestone',
#   'over time',
#   'polyp',
#   'polyps',
#   'protect',
#   'protects',
#   'sea',
#   'seawater',
#   'self',
#   'skeleton'},
#  {'about',
#   'almost',
#   'been',
#   'case',
#   'cases',
#   'coral bleached',
#   'coral bleaching happened',
#   'countries',
#   'countries reported',
#   'countries reported coral bleaching',
#   'countries reporting',
#   'countries reporting coral bleaching',
#   'deaths',
#   'gone',
#   'had',
#   'highest',
#   'least',
#   'lowest',
#   'mild',
#   'moderate',
#   'more than',
#   'most coral',
#   'most severe',
#   'number',
#   'occured',
#   'report',
#   'reported',
#   'reported coral bleaching',
#   'reporting',
#   'reporting coral bleaching',
#   'reports',
#   'same year',
#   'severe',
#   'severe coral bleaching',
#   'throughout',
#   'went',
#   'went up',
#   'year',
#   'years'},
#  {'central',
#   'climate',
#   'eastern',
#   'eastern pacific regions',
#   'major shifts',
#   'movement',
#   'pacific regions',
#   'region',
#   'swell',
#   'warm water eastward',
#   'worlds'},
#  {'affect',
#   'another',
#   'another factor',
#   'another reason',
#   'another thing',
#   'certain',
#   'final',
#   'finally',
#   'may',
#   'one reason',
#   'photosynthesis process',
#   'well',
#   'why coral bleaching'},
#  {'decrease',
#   'during storms',
#   'excessive',
#   'excessive rainfall',
#   'excessive rainfall like hurricanes',
#   'hurricane',
#   'hurricanes',
#   'like hurricanes',
#   'lots',
#   'rain',
#   'rainfall',
#   'regions during storms',
#   'shallow coastal regions',
#   'shallow coastal regions during storms',
#   'storm',
#   'tropical',
#   'tropical storms'},
#  {'damaging', 'harm', 'life', 'nature', 'physical'},
#  {'algae dies',
#   'begin',
#   'bleach',
#   'bleaching coral',
#   'coral dies',
#   'coral so',
#   'die',
#   'die off',
#   'dies',
#   'eat',
#   'ejected',
#   'ejecting',
#   'ejects',
#   'eventually',
#   'kill',
#   'lack',
#   'leave',
#   'leaving',
#   'left',
#   'meaning',
#   'possibly',
#   'start',
#   'starve',
#   'sustain',
#   'zooxanthellae dies'},
#  {'clear shallow',
#   'clear shallow tropical',
#   'clear shallow tropical waters',
#   'clear tropical',
#   'found',
#   'only',
#   'only found',
#   'shallow',
#   'shallow tropical waters',
#   'where'},
#  {'balanced relationship',
#   'coral zooxanthellae',
#   'enviromental stressors',
#   'environmental stressors',
#   'negatively',
#   'negatively affect',
#   'one example',
#   'stressors',
#   'zooanthellae',
#   'zooxanthelle'},
#  {'80of',
#   'degree',
#   'degree f',
#   'degrees',
#   'degrees f',
#   'eastward ocean water',
#   'however',
#   'increase',
#   'need water temperature',
#   'normal water',
#   'normal water temperature',
#   'regions',
#   'shift eastward ocean water temperatures',
#   'shifts',
#   'surface water',
#   'surface waters shift eastward',
#   'surface waters shift eastward ocean water',
#   'temp',
#   'temp increases',
#   'temperature increase',
#   'temperatures increase',
#   'waters shift eastward ocean water'},
#  {'85f',
#   '85of',
#   'building',
#   'certain temperature',
#   'corals need water',
#   'corals need water temperatures',
#   'need water',
#   'needs water',
#   'process',
#   'reef building',
#   'reef building corals',
#   'reef building corals need',
#   'reef building corals need water temperature',
#   'reef building corals need water temperatures',
#   'sensitive',
#   'water temperature'},
#  {'combine',
#   'combine carbon dioxide',
#   'combine co2',
#   'during photosynthesis',
#   'during photosynthesis zooxanthellae',
#   'h2o',
#   'ocean',
#   'ocean water',
#   'photosynthesis zooxanthellae',
#   'sunlight'},
#  {'although',
#   'being important',
#   'boat navigation',
#   'boats',
#   'guide',
#   'guide boat navigation',
#   'important',
#   'later',
#   'later recognized',
#   'merchant',
#   'merchant trading',
#   'much more',
#   'navigation',
#   'now',
#   'originally',
#   'originally used',
#   'purpose',
#   'recognized',
#   'trade',
#   'trade winds',
#   'used'},
#  {'considered',
#   'considered one',
#   'coral bleaching event',
#   'died',
#   'event',
#   'event resulted',
#   'ever',
#   'happened',
#   'killed',
#   'massive',
#   'massive coral bleaching',
#   'massive coral bleaching event',
#   'observed',
#   'resulted',
#   'very serious',
#   'worlds coral',
#   'worse',
#   'worst',
#   'worst coral bleaching',
#   'worst ever',
#   'worst ever observed'},
#  {'before',
#   'did',
#   'know',
#   'know what',
#   'look',
#   'nothing',
#   'place',
#   'probably',
#   'really',
#   'think',
#   'until',
#   'you'},
#  {'effected',
#   'located',
#   'mainly',
#   'most',
#   'most coral bleaching',
#   'most noticeable',
#   'mostly',
#   'mostly found',
#   'north america',
#   'noticable',
#   'noticeable',
#   'noticed',
#   'pacific ocean',
#   'seen'},
#  {'algae living within',
#   'coral polyps',
#   'coral polyps give',
#   'different colors',
#   'different types',
#   'give corals',
#   'living within',
#   'many types',
#   'polyps give',
#   'types',
#   'varying',
#   'varying colors',
#   'within'},
#  {'coral turn white',
#   'coral turns white',
#   'coral turns white due',
#   'corals turn white',
#   'corals turn white due',
#   'death',
#   'during bleaching',
#   'during bleaching corals turn white due',
#   'ejection',
#   'leaves',
#   'turns white due',
#   'white due',
#   'zooxanthellae algae'},
#  {'add',
#   'balance',
#   'balance necessary',
#   'become unhealthy',
#   'coral health',
#   'corals health',
#   'decreases',
#   'drop',
#   'drops',
#   'extreme storms',
#   'fresh water',
#   'level',
#   'levels',
#   'messes',
#   'more fresh',
#   'more fresh water',
#   'necessary',
#   'ocean salinity',
#   'salinity',
#   'salinity drops',
#   'salinity upsets',
#   'salt',
#   'salt water',
#   'salty',
#   'storms',
#   'storms increase',
#   'upset',
#   'upsets'},
#  {'biologists',
#   'coral living',
#   'corals living',
#   'discovered',
#   'discovered many',
#   'discovered many different types',
#   'many different types',
#   'marine',
#   'marine biologist',
#   'marine biologists',
#   'oceans'},
#  {'algae called',
#   'algae called zooxanthellae',
#   'algae called zooxanthellae live',
#   'algae live',
#   'algae lives',
#   'algae zooxanthellae',
#   'called zooxanthellae',
#   'coral tissues',
#   'go through photosynthesis',
#   'light',
#   'live',
#   'need light',
#   'partly',
#   'tissue',
#   'tropical waters',
#   'zooxanthellae live'},
#  {'becoming',
#   'bleaching event',
#   'bleaching makes',
#   'coral vulnerable',
#   'corals vulnerable',
#   'disease',
#   'disease starvation',
#   'diseases',
#   'makes coral vulnerable',
#   'makes corals',
#   'makes corals vulnerable',
#   'result',
#   'results',
#   'starvation',
#   'vulnerable'},
#  {'drag', 'instead', 'move', 'usually', 'westward', 'winds shift'},
#  {'body',
#   'coral polyp',
#   'mouth',
#   'mouth surrounded',
#   'stinging tentacles',
#   'surrounded',
#   'tentacles'},
#  {'any', 'danger', 'delicate', 'else', 'harmful', 'hurt', 'lot', 'puts'},
#  {'big', 'part', 'play', 'plays', 'role'},
#  {'based',
#   'coral bleaching rates',
#   'depends',
#   'difference',
#   'different',
#   'different rates',
#   'effects',
#   'every year',
#   'factor',
#   'increasing',
#   'last',
#   'main',
#   'one',
#   'rate',
#   'started'},
#  {'anchor',
#   'anchors',
#   'blast',
#   'blast fishing',
#   'damage',
#   'damaged',
#   'dropped',
#   'dropping',
#   'dropping anchors',
#   'etc',
#   'human',
#   'humans',
#   'outside',
#   'people',
#   'stepping',
#   'tourist',
#   'tourists',
#   'walking',
#   'who drop anchors'},
#  {'better',
#   'colder',
#   'cooler',
#   'coral would',
#   'deeper',
#   'hotter',
#   'lose color',
#   'than',
#   'warmer',
#   'water gets',
#   'water rises'},
#  {'biggest',
#   'caused',
#   'destructive',
#   'environment',
#   'health',
#   'most dangerous',
#   'most dangerous threat',
#   'most dangerous threats',
#   'put stress',
#   'puts stress',
#   'those',
#   'threat',
#   'threats'},
#  {'coral bleaching happens',
#   'coral bleaching occurs',
#   'enviromental changes',
#   'one way',
#   'reasons why'},
#  {'bleached coral', 'bright', 'colorful', 'figure', 'healthy coral'},
#  {'affecting',
#   'blast fishing tourists who',
#   'blast fishing tourists who drop anchors',
#   'drop anchors',
#   'examples',
#   'fishing',
#   'include',
#   'like blast fishing',
#   'most common',
#   'physical damage',
#   'reef',
#   'reefs',
#   'things like',
#   'tourist who',
#   'tourists who drop anchors',
#   'walk'},
#  {'co2',
#   'enough sunlight',
#   'long',
#   'lower than normal',
#   'normal amount',
#   'problem',
#   'undergo photosynthesis'},
#  {'away',
#   'become',
#   'become bleached',
#   'becomes',
#   'being bleached',
#   'bleached',
#   'comes',
#   'coral becomes',
#   'gets',
#   'getting',
#   'heat',
#   'less',
#   'making',
#   'sick',
#   'starts',
#   'therefore',
#   'underwater',
#   'unhealthy'},
#  {'get stressed', 'producing', 'should', 'stop', 'we'},
#  {'area',
#   'explain',
#   'given',
#   'good',
#   'lastly',
#   'mean',
#   'must',
#   'my',
#   'possible',
#   'right',
#   'specific',
#   'thats',
#   'too',
#   'why'},
#  {'coral polyps range',
#   'diameter',
#   'foot',
#   'pinhead',
#   'size',
#   'tiny',
#   'tiny up',
#   'up'},
#  {'close', 'fact'},
#  {'cannot live',
#   'cant',
#   'out',
#   'zooxanthallae algae',
#   'zooxanthellae cannot',
#   'zooxanthellae cannot live outside'},
#  {'about coral',
#   'about coral bleaching',
#   'background',
#   'documents',
#   'finish',
#   'learned',
#   'read',
#   'reading',
#   'what',
#   'what coral bleaching'},
#  {'actually',
#   'always',
#   'mistaken',
#   'often mistaken',
#   'plant',
#   'really made',
#   'really made up',
#   'rock',
#   'sometimes',
#   'though',
#   'tiny animals called polyps'},
#  {'anywhere',
#   'few',
#   'higher water',
#   'inches',
#   'much',
#   'rise',
#   'rises',
#   'sea level',
#   'sea levels',
#   'seems',
#   'strong'},
#  {'carbon',
#   'combination',
#   'combination results',
#   'during',
#   'form',
#   'formation',
#   'glucose',
#   'makes',
#   'o2',
#   'oxygen',
#   'passed',
#   'resulting',
#   'sugar',
#   'sugars',
#   'takes'},
#  {'corals receive', 'estimate', 'recieve', 'scientists'},
#  {'above', 'over', 'water temperature increase'},
#  {'article shifting trade winds',
#   'colder than',
#   'colder than those',
#   'eastern pacific',
#   'known',
#   'surface waters',
#   'trade winds affect',
#   'upwelling',
#   'western pacific',
#   'winds drag warm surface waters westward'},
#  {'corals get',
#   'eject',
#   'enviroment',
#   'environment forces',
#   'food producing algae',
#   'forces',
#   'increased stress'},
#  {'allow',
#   'create',
#   'feed',
#   'get',
#   'hard',
#   'helps',
#   'itself',
#   'make',
#   'produce',
#   'sun'},
#  {'been bleached',
#   'called coral bleaching',
#   'color',
#   'coral starts',
#   'dead',
#   'loose',
#   'looses',
#   'lose',
#   'loses color',
#   'losing',
#   'lost',
#   'once',
#   'plain white',
#   'reason why',
#   'red',
#   'turn',
#   'turn white',
#   'turning',
#   'turning white',
#   'turns',
#   'where coral',
#   'white',
#   'white color'},
#  {'coral bleaching increases',
#   'location',
#   'show',
#   'shows',
#   'temperature rises',
#   'trade wind',
#   'water temperature rises'},
#  {'amount',
#   'balance required',
#   'balanced',
#   'carbon dioxide co2',
#   'changes',
#   'co2 threaten',
#   'coral healthy',
#   'corals healthy',
#   'dangerous',
#   'delicate balance',
#   'delicate balance required',
#   'increases',
#   'keep corals healthy',
#   'required',
#   'threaten',
#   'threatened',
#   'threatens',
#   'water decreases',
#   'water temperature changes',
#   'water temperature increases',
#   'water temperatures increase'},
#  {'atlantic',
#   'atlantic ocean',
#   'bleaching corals',
#   'contains',
#   'contains double',
#   'covers',
#   'covers about',
#   'double',
#   'entire',
#   'entire globe',
#   'globe',
#   'issue',
#   'ocean covers',
#   'ocean covers about',
#   'pacific ocean covers',
#   'water found'},
#  {'being',
#   'come',
#   'could',
#   'do',
#   'down',
#   'everything',
#   'go',
#   'going',
#   'just',
#   'like',
#   'likely',
#   'might',
#   'more',
#   'next',
#   'often',
#   'others',
#   'through',
#   'way',
#   'would'},
#  {'altered',
#   'blow',
#   'change direction',
#   'completely',
#   'directions',
#   'drag warm',
#   'drag warm surface',
#   'east',
#   'every few years',
#   'every few years trade winds',
#   'reverse',
#   'reverse direction',
#   'reverse direction completely',
#   'trade winds weaken',
#   'weaken',
#   'west',
#   'winds go',
#   'winds weaken'},
#  {'able', 'coral does', 'get enough', 'grow', 'lower than'},
#  {'decreased',
#   'go down',
#   'high',
#   'high water',
#   'higher',
#   'higher than',
#   'increased',
#   'low',
#   'lower',
#   'rose',
#   'strength',
#   'temperature',
#   'temps',
#   'trade wind strength',
#   'versus trade winds',
#   'water temp',
#   'water temperatures',
#   'water temps',
#   'weak',
#   'weaker',
#   'wind strength',
#   'wind trades'},
#  {'allow photosynthesis',
#   'cannot live outside',
#   'coral body',
#   'enough nutrients',
#   'live outside',
#   'most zooxanthellae',
#   'tropical ocean'},
#  {'affected',
#   'areas',
#   'around',
#   'coastal regions',
#   'costal',
#   'land',
#   'most affected',
#   'near'},
#  {'10of',
#   '3of',
#   '5of',
#   'even',
#   'increase over',
#   'normal',
#   'ocean water temperatures increase',
#   'places',
#   'range',
#   'say',
#   'water changes'},
#  {'algae gives',
#   'algae make',
#   'algae make provide',
#   'algae makes',
#   'chemicals',
#   'energy',
#   'needs',
#   'provide',
#   'provided',
#   'provides',
#   'survive'},
#  {'articles',
#   'conclude',
#   'happens',
#   'information',
#   'reason',
#   'source',
#   'temperature change',
#   'temperature changes'},
#  {'circumstances',
#   'dragged',
#   'dragged eastward',
#   'south america',
#   'towards south',
#   'towards south america',
#   'under',
#   'warm surface waters',
#   'winds change'},
#  {'coral reefs',
#   'events leading',
#   'serious',
#   'serious impact',
#   'serious problem',
#   'world',
#   'worlds coral reefs'},
#  {'australia',
#   'australia near',
#   'called upwelling',
#   'just north',
#   'new guinea',
#   'north',
#   'papua',
#   'papua new guinea',
#   'pool',
#   'trade winds drag warm',
#   'trading',
#   'warm waters'},
#  {'both', 'cannot', 'enough', 'versa', 'without', 'work', 'zooxanthalle'},
#  {'another way',
#   'due',
#   'effect',
#   'example',
#   'greatly',
#   'huge',
#   'impacts',
#   'leading',
#   'major',
#   'negative',
#   'occurs',
#   'unbalanced',
#   'water levels',
#   'weather'},
#  {'benefit',
#   'benefits',
#   'both benefit',
#   'depend',
#   'eachother',
#   'means',
#   'relationship',
#   'symbiotic',
#   'symbiotic relationship',
#   'zooxanthallae'},
#  {'chart',
#   'charts',
#   'coral bleaching reports per',
#   'coral bleaching reports per year',
#   'data',
#   'extremely',
#   'first',
#   'goes up',
#   'got',
#   'graph',
#   'per year',
#   'ran out',
#   'same',
#   'see',
#   'seem',
#   'showed',
#   'time',
#   'water temperature versus trade winds',
#   'weakest',
#   'you look'},
#  {'bad',
#   'conditions',
#   'extreme',
#   'having',
#   'maybe',
#   'much salt',
#   'reason why coral bleaching',
#   'second',
#   'shallow waters',
#   'something',
#   'thing',
#   'too much'},
#  {'algae needs', 'corals need', 'need', 'order'},
#  {'creatures', 'find', 'fish', 'home', 'ones', 'our', 'still', 'take', 'who'},
#  {'equatorial', 'especially', 'impact'},
#  {'amounts',
#   'climate change',
#   'coral bleaching could',
#   'decreasing',
#   'happen',
#   'large',
#   'natural',
#   'occur',
#   'overall',
#   'problems'},
#  {'algae cannot',
#   'clear',
#   'coral need',
#   'coral needs',
#   'coral reefs need',
#   'do photosynthesis',
#   'go through',
#   'perform photosynthesis',
#   'photosynthesis',
#   'reason why coral',
#   'receive',
#   'shallow water',
#   'thrive',
#   'tropical water'},
#  {'happening', 'occuring'},
#  {'algae relies',
#   'algae rely',
#   'destructive practices',
#   'relies',
#   'rely',
#   'stay healthy',
#   'sustain physical damage'},
#  {'article coral', 'paragraph', 'passage', 'says', 'stated', 'states', 'text'},
#  {'coral get',
#   'does',
#   'keep',
#   'let',
#   'pretty',
#   'right amount',
#   'since',
#   'since coral',
#   'so'},
#  {'beautiful',
#   'coral looses',
#   'coral lose',
#   'coral loses',
#   'coral loses color',
#   'corals lose',
#   'first off',
#   'loses',
#   'phenomenon',
#   'takes place',
#   'turns white'},
#  {'after',
#   'alot',
#   'done',
#   'end',
#   'little',
#   'matter',
#   'times',
#   'very',
#   'wrong'},
#  {'america',
#   'bottom',
#   'bring',
#   'cold',
#   'cold water',
#   'common',
#   'eastward',
#   'eastward towards south',
#   'goes',
#   'hot',
#   'moves',
#   'moving',
#   'trades',
#   'warm',
#   'warm water',
#   'warmer water',
#   'water',
#   'waters',
#   'western',
#   'winds'},
#  {'algae zooxanthallae',
#   'coral ejects',
#   'enviromental',
#   'environment changes',
#   'environmental',
#   'forced',
#   'killing',
#   'makes coral',
#   'put',
#   'risk',
#   'stress',
#   'stressed',
#   'sudden',
#   'undergo'},
#  {'new'},
#  {'dying', 'events', 'many do', 'recover', 'reefs recover', 'while'},
#  {'asia',
#   'pacific trade winds',
#   'side',
#   'towards',
#   'trade winds travel',
#   'travel',
#   'warm surface water',
#   'warm surface waters westward',
#   'waters westward'},
#  {'animal',
#   'animals',
#   'animals called polyps',
#   'called',
#   'called polyps',
#   'made',
#   'made up',
#   'one thing',
#   'plants',
#   'rocks',
#   'small',
#   'tiny animals'},
#  {'according',
#   'article',
#   'background what',
#   'coral photosynthesis',
#   'document',
#   'said'},
#  {'affects',
#   'affects coral',
#   'change',
#   'changing',
#   'int',
#   'very important',
#   'very sensitive',
#   'way coral'},
#  {'conclusion',
#   'coral bleaching',
#   'coral bleaching would',
#   'deal',
#   'differences',
#   'different things',
#   'different ways',
#   'factors',
#   'lead',
#   'leads',
#   'main reason',
#   'many',
#   'many factors',
#   'many reasons',
#   'many things',
#   'many ways',
#   'multiple',
#   'phenomena',
#   'rates',
#   'several',
#   'things',
#   'trade winds photosynthesis',
#   'what leads'}]

# %% [markdown]
# # Dump Clusters to File

# %%
def clusters_to_file(fname, lbl2Clusters):
    with open(fname, "w+") as f:
        for lbl, phrases in lbl2Clusters.items():
            f.write(str(lbl).rjust(4,' '))
            f.write("|")
            f.write(str(len(phrases)).rjust(5,' '))
            f.write("|")
            line = ",".join(sorted(phrases, key = lambda s: (len(s.split(" ")), s)))
            f.write(line)
            f.write("\n")

# %%
clusters_to_file(AP_CLUSTERS_FILE, ap_lbl2cluster)
clusters_to_file(KM_CLUSTERS_FILE, lbl2cluster)

# %% [markdown]
# # Conceptual Search Output Files

# %%
import time
start = time.time()

kwd2cluster_sims = compute_cluster_similarities(all_kwds, kwd2id, vectors, lbl2centroid)
end = time.time()
print("Sorting the clusters for each of the %i keywords took %i seconds" % (len(all_kwds),end - start))
# Out:
# 1000 computed out of 1176
# Sorting the clusters for each of the 1176 keywords took 0 seconds

# %%
if SYNONYMS_QRY_FILE is not None and SYNONYMS_INDEX_FILE is not None:
    write_most_similar_clusters(NUM_CLUSTER_SYNONYMS, kwd2cluster_sims, SYNONYMS_QRY_FILE, SYNONYMS_INDEX_FILE)

# %%
grand_end = time.time()
print("Cluster generation and processing took %i seconds" % (grand_end - grand_start))
# Out:
# Cluster generation and processing took 13 seconds
