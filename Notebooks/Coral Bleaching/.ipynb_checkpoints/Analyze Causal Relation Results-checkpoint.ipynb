# %%
import pandas as pd

#fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions.txt"
fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions-causal_relations.txt"

data = pd.read_csv(fname, sep="|")

# %%
data.head()
# Out:
#                             Essay  Sent Number  \
# 0  EBA1415_AEKD_4_CB_ES-05568.ann            1
# 1  EBA1415_AEKD_4_CB_ES-05568.ann            2
# 2  EBA1415_AEKD_4_CB_ES-05568.ann            3
# 3  EBA1415_AEKD_4_CB_ES-05568.ann            4
# 4  EBA1415_AEKD_4_CB_ES-05572.ann            1
#
#                                   Processed Sentence Concept Codes Predictions
# 0  What leads to differences in the rates of cora...            50          50
# 1  Coral is often mistaken for a rock but it is m...           NaN         NaN
# 2  Coral bleaching shows bleaching and healthy bl...            50          50
# 3  Coral bleaching is almost noticeable in the pa...            50          50
# 4  The part of coral called zooanthellae are not ...             5         NaN

# %%
data["Concept Codes"] = data["Concept Codes"].apply(str)
data["Predictions"] = data["Predictions"].apply(str)

# %%
code = "Causer:13->Result:50"

#with_ys = data["Concept Codes"].str.contains(code)
#without = with_ys[not data["Concept Codes"].str.contains(code)]
df = data[data["Concept Codes"].str.contains(code) & ~data["Predictions"].str.contains(code)]
def filter_causal(s):
    splt = s.split(",")
    return "\t".join(filter(lambda st: "->" in st and "_" not in st, splt)).\
        replace("Causer:","C:").replace("Result:","R:")

print code, len(df)
for i in range(len(df)):
    row = df.iloc[i]
    ix = df.iloc[[i]].index.tolist()[0] + 2
    #print dir(row)
    print "Line:  ", str(ix), "Essay:", row["Essay"]
    print "Sent:  ", row["Processed Sentence"]
    print "Codes: ", row["Concept Codes"]
    print "Preds: ", row["Predictions"]
    print "CCodes:", filter_causal(row["Concept Codes"])
    print "CPreds:", filter_causal(row["Predictions"])
    print
# Out:
# Causer:13->Result:50 59
# Line:   75 Essay: EBA1415_BGJD_1_CB_ES-05727.ann
# Sent:   The things that lead to coral bleaching could be salt that near there trade winds and Tropical storms
# Codes:  1,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:11->Result:50,Causer:13->Result:50
# Preds:  1,11,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:11->Result:50
# CCodes: C:1->R:50	C:11->R:50	C:13->R:50
# CPreds: C:1->R:50	C:11->R:50
#
# Line:   138 Essay: EBA1415_BGJD_2_CB_ES-05740.ann
# Sent:   INFREQUENT off temperature causes change in the coral because of the salinity which have coral change colors
# Codes:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:13->Result:50
# Preds:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50
# CCodes: C:3->R:50	C:13->R:50
# CPreds: C:3->R:50
#
# Line:   158 Essay: EBA1415_BGJD_2_CB_ES-05752.ann
# Sent:   If it drops alot then it can really affect the coral
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  _CRel
# CCodes: C:13->R:50
# CPreds:
#
# Line:   206 Essay: EBA1415_BLHT_5_CB_ES-05202.ann
# Sent:   When it storms the storms increase the amount of fresh water from the rain which causes the salt level to drop which INFREQUENT off the corals health
# Codes:  11,12,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:12->Result:13,Causer:13->Result:50
# Preds:  11,12,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:12->Result:13
# CCodes: C:11->R:12	C:12->R:13	C:13->R:50
# CPreds: C:11->R:12	C:12->R:13
#
# Line:   455 Essay: EBA1415_BLRW_3_CB_ES-05169.ann
# Sent:   There are many ways corals can be bleached
# Codes:  50,Result,Causer:1->Result:50,Causer:13->Result:50
# Preds:  50
# CCodes: C:1->R:50	C:13->R:50
# CPreds:
#
# Line:   456 Essay: EBA1415_BLRW_3_CB_ES-05169.ann
# Sent:   INFREQUENT trade winds salty water
# Codes:  1,13,Causer,Causer:1->Result:50,Causer:13->Result:50
# Preds:  nan
# CCodes: C:1->R:50	C:13->R:50
# CPreds:
#
# Line:   1131 Essay: EBA1415_ERSK_1_CB_ES-05785.ann
# Sent:   This shows a healthy colored coral can be affected by extreme storms humans INFREQUENT the ocean and ocean salinity
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:50,Causer:13->Result:50
# Preds:  11,12,13,_C->R,_CRel,_RRel,Result,explicit
# CCodes: C:11->R:50	C:13->R:50
# CPreds:
#
# Line:   1574 Essay: EBA1415_KNKC_1_CB_ES-05420.ann
# Sent:   Corals need to be in a seawater that is salty if the winds happen more often then the salinity decreases which INFREQUENT the coral in danger if bleaching
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:14
# CCodes: C:13->R:50
# CPreds: C:13->R:14
#
# Line:   1963 Essay: EBA1415_KYLS_5_CB_ES-05647.ann
# Sent:   The reason why coral reefs are because when the water temperature or salt level is low it depends much on the algae called zooxanthellae
# Codes:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:13->Result:50
# Preds:  3,13,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:3->R:50	C:13->R:50
# CPreds:
#
# Line:   2385 Essay: EBA1415_KYNS_3_CB_ES-05373.ann
# Sent:   Coral bleaching also happen because of the salinity of the water
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   2396 Essay: EBA1415_KYNS_3_CB_ES-05374.ann
# Sent:   And now much the water is salinity of temperature in the water is the number I reason corals bleaching
# Codes:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:13->Result:50
# Preds:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50
# CCodes: C:3->R:50	C:13->R:50
# CPreds: C:3->R:50
#
# Line:   2505 Essay: EBA1415_KYNS_3_CB_ES-06001.ann
# Sent:   The amount of salt INFREQUENT the rate differences necessary for coral bleaching
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50
# CCodes: C:13->R:50
# CPreds:
#
# Line:   2641 Essay: EBA1415_KYNS_4_CB_ES-05401.ann
# Sent:   This means when storms occur such as hurricanes or tropical storms more water is INFREQUENT meaning less salt
# Codes:  11,12,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:12->Result:13,Causer:13->Result:50
# Preds:  11,_C->R,Causer,Causer:11->Result:50
# CCodes: C:11->R:12	C:12->R:13	C:13->R:50
# CPreds: C:11->R:50
#
# Line:   2642 Essay: EBA1415_KYNS_4_CB_ES-05401.ann
# Sent:   As a result the corals start to bleach and die off
# Codes:  50,_RRel,Result,explicit,Causer:13->Result:50
# Preds:  7,50,Causer
# CCodes: C:13->R:50
# CPreds:
#
# Line:   2696 Essay: EBA1415_KYNS_4_CB_ES-05406.ann
# Sent:   What leads to differences in the rates of coral bleaching to the place the corals are and it could also probably be the wind or how salty is the water
# Codes:  1,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:13->Result:50
# Preds:  1,50,_C->R,_RRel,Causer,Result,Causer:1->Result:50
# CCodes: C:1->R:50	C:13->R:50
# CPreds: C:1->R:50
#
# Line:   2781 Essay: EBA1415_LRBL_3_CB_ES-05150.ann
# Sent:   Another way to have the coral reefs healthy is to have ocean salinity
# Codes:  _C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13
# CCodes: C:13->R:50
# CPreds:
#
# Line:   2822 Essay: EBA1415_LRBL_3_CB_ES-05157.ann
# Sent:   Salinity is how salty the water is so too much fresh water from excessive rainfall like hurricanes or tropical storms will upset the balance of fresh to salty water which in return will effect the corals health
# Codes:  11,12,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:12->Result:13,Causer:13->Result:50
# Preds:  11,12,13,14,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12
# CCodes: C:11->R:12	C:12->R:13	C:13->R:50
# CPreds: C:11->R:12
#
# Line:   2824 Essay: EBA1415_LRBL_3_CB_ES-05157.ann
# Sent:   So to answer the question the causes of coral bleaching are dead algae the salinity of water and the water temperature
# Codes:  3,7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:7->Result:50,Causer:13->Result:50
# Preds:  3,7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:3->R:50	C:7->R:50	C:13->R:50
# CPreds:
#
# Line:   2863 Essay: EBA1415_LRBL_3_CB_ES-05478.ann
# Sent:   Coral also are very sensitive to ocean salinity which is how salty the water is so when INFREQUENT storms and the salinity drops can be very bad for the corals health and that might be another reason
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:50,Causer:13->Result:50
# Preds:  11,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13
# CCodes: C:11->R:50	C:13->R:50
# CPreds: C:11->R:13
#
# Line:   3186 Essay: EBA1415_LZBA_3_CB_ES-05498.ann
# Sent:   INFREQUENT affects coral bleaching too
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  50
# CCodes: C:13->R:50
# CPreds:
#
# Line:   3664 Essay: EBA1415_RDCSa_1_CB_ES-04701.ann
# Sent:   When the balance is threatened by an extreme storm coral bleaching is sensitive to how much salt is in the water
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  11,13,14,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   3739 Essay: EBA1415_RDJK_5_CB_ES-04720.ann
# Sent:   What leads to differences in the rates of coral bleaching are shifting trade winds changes in the amount CO2 and how salty the water is to how balanced out the zooxanthellae is
# Codes:  1,4,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:4->Result:50,Causer:13->Result:50
# Preds:  1,4,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:1->R:50	C:4->R:50	C:13->R:50
# CPreds:
#
# Line:   3763 Essay: EBA1415_RDJK_5_CB_ES-04722.ann
# Sent:   INFREQUENT salt can hurt the coral
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13
# CCodes: C:13->R:50
# CPreds:
#
# Line:   3839 Essay: EBA1415_RHSG_1_CB_ES-05073.ann
# Sent:   Storms water levels salinity carbon dioxide clear water sunlight are many things that have to do with coral bleaching weather it be good or bad
# Codes:  4,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:4->Result:50,Causer:11->Result:50,Causer:13->Result:50
# Preds:  13,50,_C->R,_RRel,Causer
# CCodes: C:4->R:50	C:11->R:50	C:13->R:50
# CPreds:
#
# Line:   4118 Essay: EBA1415_SDLC_2_CB_ES-04738.ann
# Sent:   Something that effect the coral are extreme storms changes in water temperature amount of CO2 salinity death of zooxanthellae algae trade winds
# Codes:  1,3,4,7,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50,Causer:4->Result:50,Causer:7->Result:50,Causer:11->Result:50,Causer:13->Result:50
# Preds:  1,3,4,7,11,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:1->R:50	C:3->R:50	C:4->R:50	C:7->R:50	C:11->R:50	C:13->R:50
# CPreds:
#
# Line:   5141 Essay: EBA1415_SEKL_1_CB_ES-04811.ann
# Sent:   Coral Bleaching is done by the wrong salt and the different in temp
# Codes:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:13->Result:50
# Preds:  50
# CCodes: C:3->R:50	C:13->R:50
# CPreds:
#
# Line:   5518 Essay: EBA1415_SERS_1516_CB-05115.ann
# Sent:   The problem that makes coral bleach is the shifting trade winds temperature and salinity
# Codes:  1,3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50,Causer:13->Result:50
# Preds:  1,3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50
# CCodes: C:1->R:50	C:3->R:50	C:13->R:50
# CPreds: C:1->R:50	C:3->R:50
#
# Line:   5543 Essay: EBA1415_SERS_1516_CB-05117.ann
# Sent:   The more fresh water there is the less salinity the ocean has this upset in salinity in the water can cause the coral to die or become so sick that algae cannot live on it any more
# Codes:  12,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:12->Result:13,Causer:13->Result:50
# Preds:  7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:12->R:13	C:13->R:50
# CPreds:
#
# Line:   5690 Essay: EBA1415_SVJJ_1_CB_ES-05629.ann
# Sent:   If there is excessive rainfall it causes the salinity of ocean water to drop and corals need salt water
# Codes:  11,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  11,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13
# CCodes: C:11->R:13	C:13->R:50
# CPreds: C:11->R:13
#
# Line:   5691 Essay: EBA1415_SVJJ_1_CB_ES-05629.ann
# Sent:   Because of these enviromental changes it causes corals to bleach
# Codes:  50,_RRel,Result,explicit,Causer:13->Result:50
# Preds:  50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   5761 Essay: EBA1415_SVJJ_4_CB_ES-05625.ann
# Sent:   Some of the causes of the coral bleaching is due to the fact that INFREQUENT from the ocean is lost because of storms that cause excessive INFREQUENT like hurricanes or tropical storms
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  11,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:11->R:13	C:13->R:50
# CPreds:
#
# Line:   5773 Essay: EBA1415_SVJJ_4_CB_ES-05625.ann
# Sent:   I think the trade winds causes INFREQUENT oceans which leads to increase ocean temperatures and the INFREQUENT of the ocean will cause a change in INFREQUENT and that can affect the corals
# Codes:  1,3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  1,3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:3
# CCodes: C:13->R:50
# CPreds: C:1->R:3
#
# Line:   6317 Essay: EBA1415_SWCT_7_CB_ES-04892.ann
# Sent:   Salinity will decrease in hurricanes and tropical storms making more corals bleached
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13
# CCodes: C:11->R:13	C:13->R:50
# CPreds: C:11->R:13
#
# Line:   6428 Essay: EBA1415_SWSP_1_CB_ES-04851.ann
# Sent:   The corals are also sensitive to the INFREQUENT of the water and extreme storms like hurricanes can throw off the temperature and INFREQUENT of the water which can lead to large amounts of coral bleaching
# Codes:  3,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  3,11,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:11->Result:50
# CCodes: C:11->R:13	C:13->R:50
# CPreds: C:3->R:50	C:11->R:50
#
# Line:   6632 Essay: EBA1415_TFBM_1_CB_ES-05439.ann
# Sent:   One way bleach is because when there is big storms the level of salt needed for the coral goes down and is INFREQUENT with water
# Codes:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:11->Result:50
# CCodes: C:11->R:13	C:13->R:50
# CPreds: C:11->R:13	C:11->R:50
#
# Line:   6722 Essay: EBA1415_TFBM_2_CB_ES-05448.ann
# Sent:   Many things lead to the differences in the rates of coral bleaching
# Codes:  50,Result,Causer:1->Result:50,Causer:13->Result:50
# Preds:  50
# CCodes: C:1->R:50	C:13->R:50
# CPreds:
#
# Line:   6723 Essay: EBA1415_TFBM_2_CB_ES-05448.ann
# Sent:   Like shifting trade winds low salinity and blast fishing or other INFREQUENT related things
# Codes:  1,13,_CRel,Causer,explicit,Causer:1->Result:50,Causer:13->Result:50
# Preds:  1,13
# CCodes: C:1->R:50	C:13->R:50
# CPreds:
#
# Line:   6861 Essay: EBA1415_TFBM_2_CB_ES-05559.ann
# Sent:   So the lack of salt in the water may weaken or INFREQUENT the coral turning them white
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7021 Essay: EBA1415_TFHC_1_CB_ES-05945.ann
# Sent:   Finally the waters salinity effects coral and bleached its surface
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_CRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7202 Essay: EBA1415_TFHC_4_CB_ES-05838.ann
# Sent:   Some of the main causes of coral bleaching are changes in the waters INFREQUENT and how rain and the enviroment its self plays a role in the coral and water
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  3,50,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7286 Essay: EBA1415_TFMV_3_CB_ES-05952.ann
# Sent:   So the coral reefs need zooxanthellae and the process of photosynthesis also the salinity has to be a normal amount so the coral reefs can be healthy and live and also have a pretty color to them
# Codes:  _C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  nan
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7556 Essay: EBA1415_TRJB_1_CB_ES-05017.ann
# Sent:   As the water temperature increases the Co2 decreases which can cause coral bleaching
# Codes:  3,4,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:4,Causer:4->Result:50,Causer:13->Result:50
# Preds:  3,4,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:4,Causer:4->Result:50
# CCodes: C:3->R:4	C:4->R:50	C:13->R:50
# CPreds: C:3->R:4	C:4->R:50
#
# Line:   7557 Essay: EBA1415_TRJB_1_CB_ES-05017.ann
# Sent:   Not only the decrease of co2 but also salinity in the water
# Codes:  4,13,_CRel,Causer,explicit,Causer:13->Result:50
# Preds:  13
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7689 Essay: EBA1415_TRKM_1_CB_ES-05029.ann
# Sent:   The things that lead to coral bleaching and the difference of it is that the coral bleaching is caused because the Salinity upsets the balance necessary for coral health
# Codes:  13,14,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:14,Causer:13->Result:50
# Preds:  14,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:14
# CCodes: C:13->R:14	C:13->R:50
# CPreds: C:13->R:14
#
# Line:   7690 Essay: EBA1415_TRKM_1_CB_ES-05029.ann
# Sent:   And the difference is that the water temperature changes because of Trade Winds and when a trade wind is weak is effects the coral and also the water and salt because then the salt move INFREQUENT else which is bad because that INFREQUENT coral bleaching if INFREQUENT to much salt in one spot in water then that messes up the good health that the coral life needs To survive
# Codes:  1,3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:3,Causer:13->Result:50
# Preds:  1,3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:3
# CCodes: C:1->R:3	C:13->R:50
# CPreds: C:1->R:3
#
# Line:   7721 Essay: EBA1415_TRKM_2_CB_ES-05032.ann
# Sent:   If the photosynthesis is not right do to low salinity level the coral will become bleached and lose its color due to dead algae
# Codes:  5,7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:7->Result:50,Causer:13->Result:50
# Preds:  5,7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:7->Result:50
# CCodes: C:7->R:50	C:13->R:50
# CPreds: C:7->R:50
#
# Line:   7818 Essay: EBA1415_TRWH_1_CB_ES-05536.ann
# Sent:   Also if salt or other INFREQUENT water INFREQUENT on coral it can also make the corals become bleach
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  50
# CCodes: C:13->R:50
# CPreds:
#
# Line:   7820 Essay: EBA1415_TRWH_1_CB_ES-06054.ann
# Sent:   The differences in the rates of coral bleaching has more to do with water temp and how salty the water is
# Codes:  3,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50,Causer:13->Result:50
# Preds:  50,_CRel,Result,explicit
# CCodes: C:3->R:50	C:13->R:50
# CPreds:
#
# Line:   7854 Essay: EBA1415_TRWH_1_CB_ES-06067.ann
# Sent:   The difference in rates of coral INFREQUENT is that corals are sensitive to ocean salinity salty water
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13
# CCodes: C:13->R:50
# CPreds:
#
# Line:   8037 Essay: EBA1415_TTCM_2_CB_ES-04928.ann
# Sent:   After reading about coral and coral bleaching I think salinity level water temperature trade winds algae zooxanthallae and sunlight leads to the differences in the rates of coral bleaching
# Codes:  1,3,7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:1->Result:50,Causer:3->Result:50,Causer:7->Result:50,Causer:13->Result:50
# Preds:  1,7,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:1->R:50	C:3->R:50	C:7->R:50	C:13->R:50
# CPreds:
#
# Line:   8148 Essay: EBA1415_TTCM_910_CB_ES-06146.ann
# Sent:   When the salt in water decreases coral bleaching can occur
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   8222 Essay: EBA1415_TTFW_1_CB_ES-04901.ann
# Sent:   the things that lead to coral bleaching is how salty the ocean water is coral also turns white due to the ejection or death of the zooxanthellae
# Codes:  7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:7->Result:50,Causer:13->Result:50
# Preds:  7,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:7->Result:50
# CCodes: C:7->R:50	C:13->R:50
# CPreds: C:7->R:50
#
# Line:   8466 Essay: EBA1415_TTKP_45_CB_ES-04924.ann
# Sent:   There are not a lot of things that cause coral bleaching but there are a few like the oceans salinity
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,Causer
# CCodes: C:13->R:50
# CPreds:
#
# Line:   8653 Essay: EBA1415_TWJB_56_CB_ES-06219.ann
# Sent:   The amount of rainfall and temperature that goes into the ocean affects the INFREQUENT water which causes coral bleaching
# Codes:  3,11,13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:13,Causer:13->Result:50
# Preds:  3,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:3->Result:50
# CCodes: C:11->R:13	C:13->R:50
# CPreds: C:3->R:50
#
# Line:   8988 Essay: EBA1415_TWPK_3_CB_ES-05049.ann
# Sent:   The coral was also sensitive like if the water was to get salty that would hurt the coral
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  Causer
# CCodes: C:13->R:50
# CPreds:
#
# Line:   9370 Essay: EBA1415post_TWDG_11_CB_ES-05461.ann
# Sent:   If a lot of salt drops all the way to the bottom where the coral is it is harmful to the coral and then bleached self
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit
# CCodes: C:13->R:50
# CPreds:
#
# Line:   10059 Essay: EBA1415post_WSAL_2_CB_ES-05962.ann
# Sent:   Corals have to live in water with certain salinity but a storm can bring large amount of fresh water to the ocean and upset the INFREQUENT in the water This drop in salinity upsets the balance of necessary for coral health
# Codes:  11,12,13,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:12->Result:13,Causer:13->Result:50
# Preds:  11,12,13,14,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:11->Result:12,Causer:11->Result:13,Causer:12->Result:13,Causer:13->Result:14
# CCodes: C:11->R:12	C:12->R:13	C:13->R:50
# CPreds: C:11->R:12	C:11->R:13	C:12->R:13	C:13->R:14
#
# Line:   10060 Essay: EBA1415post_WSAL_2_CB_ES-05962.ann
# Sent:   corals then will end up being sick and die
# Codes:  50,_RRel,Result,explicit,Causer:13->Result:50
# Preds:  nan
# CCodes: C:13->R:50
# CPreds:
#
# Line:   10135 Essay: EBA1415post_WSKT_1_CB_ES-05331.ann
# Sent:   The salinity is also another factor that leads to differences in the rates of coral bleaching
# Codes:  13,50,_C->R,_CRel,_RRel,Causer,Result,explicit,Causer:13->Result:50
# Preds:  13,50,_C->R,_CRel,_RRel,Causer,explicit
# CCodes: C:13->R:50
# CPreds:

# %%
row = df.iloc[0]
type(row)
# Out:
# pandas.core.series.Series

# %%
dir(row)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_align_frame',
#  '_align_series',
#  '_allow_index_ops',
#  '_at',
#  '_binop',
#  '_box_item_values',
#  '_can_hold_na',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_for_slice',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_create_indexer',
#  '_dir_additions',
#  '_dir_deletions',
#  '_expand_axes',
#  '_from_axes',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_numeric_data',
#  '_get_repr',
#  '_get_val_at',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_iat',
#  '_iget_item_cache',
#  '_iloc',
#  '_index',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_datelike_mixed_type',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_loc',
#  '_make_cat_accessor',
#  '_make_dt_accessor',
#  '_make_str_accessor',
#  '_maybe_box',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_axis',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_footer',
#  '_reset_cache',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_is_copy',
#  '_set_item',
#  '_set_labels',
#  '_set_subtyp',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_typ',
#  '_unpickle_series_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'as_blocks',
#  'as_matrix',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'autocorr',
#  'axes',
#  'base',
#  'between',
#  'between_time',
#  'bfill',
#  'blocks',
#  'bool',
#  'clip',
#  'clip_lower',
#  'clip_upper',
#  'combine',
#  'combine_first',
#  'compound',
#  'compress',
#  'consolidate',
#  'convert_objects',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'data',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_array',
#  'from_csv',
#  'ftype',
#  'ftypes',
#  'ge',
#  'get',
#  'get_dtype_counts',
#  'get_ftype_counts',
#  'get_value',
#  'get_values',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iget',
#  'iget_value',
#  'iloc',
#  'imag',
#  'index',
#  'interpolate',
#  'irow',
#  'is_copy',
#  'is_time_series',
#  'isin',
#  'isnull',
#  'item',
#  'itemsize',
#  'iteritems',
#  'iterkv',
#  'ix',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'load',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'nonzero',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'order',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'ptp',
#  'put',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'real',
#  'reindex',
#  'reindex_axis',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'reshape',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'save',
#  'searchsorted',
#  'select',
#  'sem',
#  'set_axis',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort',
#  'sort_index',
#  'sortlevel',
#  'squeeze',
#  'std',
#  'str',
#  'strides',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dense',
#  'to_dict',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_msgpack',
#  'to_period',
#  'to_pickle',
#  'to_sparse',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'tolist',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'valid',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %%
df.iloc[[0]].index.tolist()
# Out:
# [73]
