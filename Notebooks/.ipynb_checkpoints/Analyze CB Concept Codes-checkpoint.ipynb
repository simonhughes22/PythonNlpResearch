# %%
from BrattEssay import load_bratt_essays
from collections import defaultdict

essays = load_bratt_essays("/Users/simon.hughes/Dropbox/Phd/Data/CoralBleaching/BrattData/Merged/")
wd_sent_freq = defaultdict(int)
all_codes = set()
#Stores all words for the spelling corrector
words = []
all_sentences = []
sentencesForCode = defaultdict(list)
for essay in essays:
    for sentence in essay.tagged_sentences:
        wdsInSent = set()
        codes4sentence = set()
        sent = []
        for w, tags in sentence:
            words.append(w)
            all_codes.update(tags)
            codes4sentence.update(tags)
            if w not in wdsInSent:
                wdsInSent.add(w)
                wd_sent_freq[w] += 1
            sent.append(w)
        all_sentences.append(sent)
        for code in codes4sentence:
            sentencesForCode[code].append(sentence)
# Out:
# 235 files found
# 235 essays processed

# %%
def print_window(win):
    def set2str(st):
        return "{" + str(t)[5:-2] + "}"
    
    w, tg = zip(*win)
    lens = [max(len(wd),len(set2str(t))) for wd,t in win]
    
    for i, wd in enumerate(w):
        print wd.ljust(lens[i]) , "|",
    print ""
    
    for i, t in enumerate(tg):
        print set2str(t).ljust(lens[i]), "|",
    print ""

def print_code(sentence, code):
    wds, tags = zip(*sentence)
    tagged = []
    for i, (w,t) in enumerate(sentence):
        if code in t:
            if i > 0 and len(tagged) > 0 and code not in sentence[i-1][1]:
                tagged.append("|")
            tagged.append(w)
    print " ".join(tagged).ljust(60)#, " ".join(wds)

""" Prints a unique string for each set of consecutive tags """
def print_unique_strings_for_code(sentences, code):
    tally = defaultdict(int)
    cnt = 0 
    for sentence in sentences:
        wds, tags = zip(*sentence)
        tagged = []
        for i, (wd,t) in enumerate(sentence):
            if code in t:
                if i > 0 and len(tagged) > 0 and code not in sentence[i-1][1]:
                    tagged.append("|")
                tagged.append(wd)
                
        if len(tagged) > 0:
            for phrase in " ".join(tagged).split("|"):
                tally[phrase.strip().replace("  ", " ")] +=1
            cnt += 1
    
    s = sorted(tally.items(), key = lambda (k,v): -v)
    print "Total Sentences for code:".ljust(30), cnt
    print ""
    for k,v in s:
        print k.ljust(30), v

""" Prints a single pattern per sentence """
def print_unique_patterns_for_code(sentences, code):
    tally = defaultdict(int)
    cnt = 0 
    for sentence in sentences:
        wds, tags = zip(*sentence)
        tagged = []
        for i, (wd,t) in enumerate(sentence):
            if code in t:
                if i > 0 and len(tagged) > 0 and code not in sentence[i-1][1]:
                    tagged.append("|")
                tagged.append(wd)
                
        if len(tagged) > 0:
            tally[" ".join(tagged)] +=1
            cnt += 1
    
    s = sorted(tally.items(), key = lambda (k,v): -v)
    print "Total Sentences for code:".ljust(30), cnt
    print ""
    for k,v in s:
        print k.ljust(30), v

# %% [markdown]
# Look at Concept Codes
# ---------------------

# %%
code = "explicit"
sentences = sentencesForCode[code]
#for sentence in sentences:
#    print_code(sentence, code)

print_unique_strings_for_code(sentences, code)
# Out:
# Total Sentences for code:      505
#
# because                        34
# due to                         27
# because of                     24
# when                           23
# causes                         16
# when | ,                       16
# if | ,                         11
# if                             11
# if | then                      8
# can cause                      7
# causing                        7
# affects                        6
# cause                          6
# threatens                      6
# ,                              5
# then                           5
# happens when                   5
# caused by                      5
# occurs                         4
# can                            4
# depending on                   3
# during                         3
# bring                          3
# the more                       3
# makes                          3
# disrupts                       3
# will                           3
# when | drop                    3
# when | drop | ,                3
# more                           3
# another reason                 3
# because when                   2
# affect                         2
# occurs when                    2
# increases                      2
# force                          2
# happen                         2
# creates                        2
# is why                         2
# from                           2
# would                          2
# as | , | creates               2
# if | , then                    2
# can affect                     2
# depends on                     2
# result in                      2
# is                             2
# as                             2
# drop                           2
# so                             2
# can be what the rates          1
# forced to                      1
# which | if | causing           1
# caused                         1
# many force the coral           1
# because | wich                 1
# vary                           1
# results                        1
# leads                          1
# it can | ,                     1
# is more                        1
# when | , | because of          1
# dropped | there is             1
# which causes                   1
# cause | and then               1
# if | could lead                1
# resulting in                   1
# when | it                      1
# to | effect | because          1
# to                             1
# what caused                    1
# with | the | thats why         1
# as | meaning                   1
# due to | because of            1
# as | come in                   1
# lowering | threathens          1
# this to happen                 1
# if | , | disrupting            1
# , making | , causing           1
# affected                       1
# which                          1
# reasons on why                 1
# that's how                     1
# occurs when | witch means      1
# caused by | disrupts | threatening 1
# if | then | without it         1
# effect on how                  1
# it increase                    1
# if | , | ,                     1
# if | the | which may           1
# will also cause                1
# results in                     1
# behind all                     1
# happens when | makes           1
# happens by                     1
# under these | ,                1
# if | become                    1
# a cause of                     1
# cause | causes                 1
# happens because                1
# when | is | causes             1
# as | , the                     1
# as like                        1
# cause by                       1
# become                         1
# when | water                   1
# that's when                    1
# has an effect on               1
# causing | causes               1
# the thing that | are           1
# because | caused               1
# if | can cause                 1
# affected by                    1
# having such                    1
# when it                        1
# are | is                       1
# of why                         1
# result                         1
# would be                       1
# cause | ;                      1
# effect the cause               1
# happens because of             1
# will be                        1
# because when | , the           1
# both results                   1
# happens most when              1
# the stuff that | are           1
# the higher | the higher        1
# because if | the               1
# disrupts | leads to            1
# the | can cause                1
# the higher | , | which creates 1
# when | then                    1
# take place                     1
# from | which gets              1
# will effect                    1
# because | sensitive to         1
# offset when                    1
# caused | causing               1
# due to | ,                     1
# resulted in                    1
# because | as the               1
# ends up going through          1
# threates                       1
# when | threatens               1
# by                             1
# change                         1
# occurs when | changes          1
# could cause                    1
# if | can make                  1
# could                          1
# bring | changes                1
# whenever | causes              1
# occurs when | to | when | if   1
# may force                      1
# because of when                1
# contribute of                  1
# is because                     1
# the weaker | the higher        1
# caused by | because            1
# if | start                     1
# creates | ,                    1
# due to | force to              1
# so did                         1
# there are | why                1
# if | than                      1
# cause of                       1
# blows                          1
# mess up                        1
# causal                         1
# cause | when                   1
# changes | when                 1
# due to | from                  1
# causing to                     1
# one reason | bring | causes    1
# when | it is                   1
# due                            1
# the | threatening              1
# many causes                    1
# many reasons                   1
# the higher | the lower | the lower | the higher 1
# because of | cause             1
# because | when                 1
# that affects                   1
# is when                        1
# means they don't               1
# change due                     1
# disturbs | and                 1
# from | if                      1
# because | will make            1
# might aid                      1
# cause | could                  1
# cause | because when           1
# may cause                      1
# so does                        1
# when | , | which results in    1
# are | is why                   1
# when | because of              1
# which is                       1
# that also | because of | makes 1
# same year                      1
# wich makes                     1
# depends of                     1
# arrive                         1
# is a big factor                1
# , the                          1
# add | putting                  1
# because of | ,                 1
# , | ,                          1
# lead to                        1
# when | and                     1
# if there is | witch            1
# caused when                    1
# if | will | will occur         1
# can lead to                    1
# depending                      1
# provide                        1
# make                           1
# means                          1
# when | than                    1
# for                            1
# how                            1
# may face                       1
# becomes                        1
# during | because               1
# =                              1
# shocked | lead to | , | ,      1
# can happen                     1
# happens                        1
# why the rates                  1
# resalt of                      1
# completely to                  1
# vary when                      1
# when | drop | the              1
# makes | damages                1
# effect                         1
# based off                      1
# another factor | is            1
# changing                       1
# during | when | , | which | affect 1
# why                            1
# it causes                      1
# when | forces | which results in 1
# as | ,                         1
# as | threatening               1
# as | which                     1
# when | causing                 1
# can occur if                   1
# because | may force            1
# without                        1
# can start causing | can start  1
# happen for                     1
# if | it will                   1
# increase when                  1

# %% [markdown]
# Train and Test Spelling Corrector
# =================================

# %%
from SpellingCorrector import SpellingCorrector 
corrector = SpellingCorrector(words)

# %%
corrections = defaultdict(int)
for sentence in all_sentences:
    for word in sentence:
        wc = corrector.correct(word)
        if word != wc:
            corrections[(word,wc)] +=1

# %%
from DictionaryHelper import *
sort_by_value(corrections, reverse = True)[0:25]
# Out:
# [(("it's", 'its'), 46),
#  (("don't", 'dont'), 30),
#  (("that's", 'thats'), 28),
#  (('algea', 'algae'), 20),
#  (('zox', 'zo'), 20),
#  (("world's", 'worlds'), 17),
#  (("can't", 'cant'), 14),
#  (('bleaches', 'bleached'), 12),
#  (('cloral', 'coral'), 10),
#  (("coral's", 'corals'), 9),
#  (("won't", 'wont'), 9),
#  (("they're", 'there'), 9),
#  (("isn't", 'isn'), 9),
#  (('tempature', 'temperature'), 8),
#  (('tempeture', 'temperature'), 7),
#  (('varys', 'vary'), 6),
#  (('saclike', 'saline'), 6),
#  (("aren't", 'arendt'), 5),
#  (("there's", 'there'), 5),
#  (("i'm", 'iam'), 5),
#  (('alge', 'algae'), 5),
#  (('temprature', 'temperature'), 5),
#  (('bleching', 'bleaching'), 4),
#  (("sun's", 'suns'), 4),
#  (('bleeching', 'bleaching'), 4)]

# %% [markdown]
# Extract Wordnet Synonyms
# ========================

# %%
import nltk
from nltk.corpus import wordnet as wn

def convert2wn_pos(pos):
    if pos.startswith("NN"):
        return wn.NOUN
    elif pos.startswith("VB"):
        return wn.VERB
    elif pos.startswith("JJ"):
        return wn.ADJ
    elif pos.startswith("RB"):
        return wn.ADV
    else:
        return None

memoized = defaultdict(list)
def __get_words_from_synset__(word, pos):
    synsets = wn.synsets(word, pos=pos)
    if len(synsets) == 0:
        return [word]
    
    words = set()
    for syn in synsets:
        for lemma in syn.lemmas:
            words.add(lemma.name)
    return list(words)

def get_word_synonyms(word, pos):
    pair =  (word, pos)
    if pair in memoized:
        return memoized[pair]
    
    words = __get_words_from_synset__(word, pos)
    memoized[pair] = words
    return words
    
def get_synonyms(word, pos):
    if pos is None:
        return [word]
    wn_pos = convert2wn_pos(pos)
    if not wn_pos:
        return [word]
    return get_word_synonyms(word, wn_pos)

# %%
syn_map2 = {}
mapped = set()
for sentence in all_sentences:
    tags = nltk.pos_tag(sentence)
    for wd, tag in tags:
        pair = (wd, tag)
        if pair in mapped:
            continue
        synonyms = [(s,tag) for s in get_synonyms(wd, tag) if s in wd_sent_freq]
        if len(synonyms) >= 1:
            matches = []
            for spair in synonyms:
                if spair in syn_map2:
                    matches.append(syn_map2[spair])
            if len(matches) == 0:
                synset = set(synonyms)
                synset.add(pair)
                for p in synset:
                    syn_map2[p] = synset                
            elif len(matches) == 1:
                matches[0].add(pair)
                syn_map2[pair] = matches[0]
            else:
                #merge existing synonym lists
                new_synset = set()
                for m in matches:
                    new_synset.update(m)
                #update mapping to map to new larger set
                for s in new_synset:
                    syn_map2[s] = new_synset
            mapped.add(pair)

# %%
syn_map2.items()
# Out:
# [(('link', 'VBN'),
#   {('combine', 'VBN'),
#    ('link', 'VBN'),
#    ('linked', 'VBN'),
#    ('mix', 'VBN'),
#    ('mixed', 'VBN'),
#    ('relate', 'VBN'),
#    ('tie', 'VBN')}),
#  (('course', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('showing', 'VBG'),
#   {('order', 'VBG'),
#    ('putting', 'VBG'),
#    ('read', 'VBG'),
#    ('say', 'VBG'),
#    ('saying', 'VBG'),
#    ('showing', 'VBG'),
#    ('state', 'VBG'),
#    ('tell', 'VBG')}),
#  (('we', 'PRP'), {('we', 'PRP')}),
#  (('spilles', 'NNS'), {('spilles', 'NNS')}),
#  (('ot', 'NN'), {('ot', 'NN')}),
#  (('usual', 'JJ'), {('common', 'JJ'), ('usual', 'JJ')}),
#  (('find', 'VBN'), {('detected', 'VBN'), ('find', 'VBN'), ('notice', 'VBN')}),
#  (('slight', 'JJ'),
#   {('delicate', 'JJ'), ('little', 'JJ'), ('slight', 'JJ'), ('soft', 'JJ')}),
#  (('stop', 'NNS'), {('stay', 'NNS'), ('stop', 'NNS'), ('stops', 'NNS')}),
#  (('down', 'JJR'),
#   {('blue', 'JJR'),
#    ('broken', 'JJR'),
#    ('down', 'JJR'),
#    ('low', 'JJR'),
#    ('lower', 'JJR')}),
#  (('pall', 'VBN'),
#   {('act', 'VBN'),
#    ('affect', 'VBN'),
#    ('affected', 'VBN'),
#    ('amazed', 'VBN'),
#    ('answer', 'VBN'),
#    ('bar', 'VBN'),
#    ('be', 'VBN'),
#    ('been', 'VBN'),
#    ('blocked', 'VBN'),
#    ('break', 'VBN'),
#    ('called', 'VBN'),
#    ('cause', 'VBN'),
#    ('caused', 'VBN'),
#    ('come', 'VBN'),
#    ('controlled', 'VBN'),
#    ('course', 'VBN'),
#    ('depend', 'VBN'),
#    ('destroy', 'VBN'),
#    ('destroyed', 'VBN'),
#    ('die', 'VBN'),
#    ('died', 'VBN'),
#    ('do', 'VBN'),
#    ('done', 'VBN'),
#    ('drop', 'VBN'),
#    ('droped', 'VBN'),
#    ('eat', 'VBN'),
#    ('evidence', 'VBN'),
#    ('exist', 'VBN'),
#    ('exposed', 'VBN'),
#    ('face', 'VBN'),
#    ('feed', 'VBN'),
#    ('filled', 'VBN'),
#    ('flow', 'VBN'),
#    ('freeze', 'VBN'),
#    ('get', 'VBN'),
#    ('give', 'VBN'),
#    ('go', 'VBN'),
#    ('guess', 'VBN'),
#    ('happen', 'VBN'),
#    ('happened', 'VBN'),
#    ('hurt', 'VBN'),
#    ('impact', 'VBN'),
#    ('involve', 'VBN'),
#    ('known', 'VBN'),
#    ('lead', 'VBN'),
#    ('leave', 'VBN'),
#    ('live', 'VBN'),
#    ('located', 'VBN'),
#    ('look', 'VBN'),
#    ('looked', 'VBN'),
#    ('lose', 'VBN'),
#    ('lost', 'VBN'),
#    ('made', 'VBN'),
#    ('make', 'VBN'),
#    ('mentioned', 'VBN'),
#    ('move', 'VBN'),
#    ('name', 'VBN'),
#    ('pall', 'VBN'),
#    ('pass', 'VBN'),
#    ('picture', 'VBN'),
#    ('place', 'VBN'),
#    ('pose', 'VBN'),
#    ('predict', 'VBN'),
#    ('present', 'VBN'),
#    ('prey', 'VBN'),
#    ('read', 'VBN'),
#    ('removed', 'VBN'),
#    ('required', 'VBN'),
#    ('result', 'VBN'),
#    ('resulted', 'VBN'),
#    ('ruin', 'VBN'),
#    ('run', 'VBN'),
#    ('say', 'VBN'),
#    ('see', 'VBN'),
#    ('set', 'VBN'),
#    ('show', 'VBN'),
#    ('showed', 'VBN'),
#    ('speculate', 'VBN'),
#    ('stated', 'VBN'),
#    ('stop', 'VBN'),
#    ('stuff', 'VBN'),
#    ('suffer', 'VBN'),
#    ('supposed', 'VBN'),
#    ('take', 'VBN'),
#    ('think', 'VBN'),
#    ('throw', 'VBN'),
#    ('weaken', 'VBN')}),
#  (('young', 'JJ'),
#   {('clean', 'JJ'),
#    ('fresh', 'JJ'),
#    ('light', 'JJ'),
#    ('loose', 'JJ'),
#    ('new', 'JJ'),
#    ('weak', 'JJ'),
#    ('white', 'JJ'),
#    ('young', 'JJ')}),
#  (("'87", '-NONE-'), {("'87", '-NONE-')}),
#  (('humans', 'NNS'),
#   {('human', 'NNS'), ('humans', 'NNS'), ('man', 'NNS'), ('world', 'NNS')}),
#  (('use', 'NNS'),
#   {('function', 'NNS'), ('role', 'NNS'), ('use', 'NNS'), ('uses', 'NNS')}),
#  (('rock', 'NNS'), {('rock', 'NNS'), ('rocks', 'NNS')}),
#  (('level', 'NN'), {('degree', 'NN'), ('level', 'NN'), ('stage', 'NN')}),
#  (('west', 'NNS'),
#   {('west', 'NNS'), ('westward', 'NNS'), ('westwards', 'NNS')}),
#  (('close', 'VB'), {('close', 'VB'), ('conclude', 'VB')}),
#  (('drops', 'NNS'), {('drop', 'NNS'), ('drops', 'NNS'), ('fall', 'NNS')}),
#  (('guess', 'VBP'),
#   {('believe', 'VBP'), ('guess', 'VBP'), ('mean', 'VBP'), ('think', 'VBP')}),
#  (('complex', 'JJ'), {('complex', 'JJ')}),
#  (('already', 'RB'), {('already', 'RB')}),
#  (('evidence', 'VBZ'),
#   {('act', 'VBZ'),
#    ('affects', 'VBZ'),
#    ('allow', 'VBZ'),
#    ('answer', 'VBZ'),
#    ('be', 'VBZ'),
#    ('become', 'VBZ'),
#    ('becomes', 'VBZ'),
#    ('begins', 'VBZ'),
#    ('break', 'VBZ'),
#    ('cause', 'VBZ'),
#    ('chance', 'VBZ'),
#    ('come', 'VBZ'),
#    ('contains', 'VBZ'),
#    ('course', 'VBZ'),
#    ('creates', 'VBZ'),
#    ('decrease', 'VBZ'),
#    ('decreases', 'VBZ'),
#    ('destroy', 'VBZ'),
#    ('do', 'VBZ'),
#    ('does', 'VBZ'),
#    ('eat', 'VBZ'),
#    ('essay', 'VBZ'),
#    ('evidence', 'VBZ'),
#    ('examine', 'VBZ'),
#    ('exist', 'VBZ'),
#    ('fall', 'VBZ'),
#    ('feed', 'VBZ'),
#    ('feeds', 'VBZ'),
#    ('find', 'VBZ'),
#    ('flow', 'VBZ'),
#    ('gain', 'VBZ'),
#    ('get', 'VBZ'),
#    ('give', 'VBZ'),
#    ('gives', 'VBZ'),
#    ('go', 'VBZ'),
#    ('happen', 'VBZ'),
#    ('happens', 'VBZ'),
#    ('has', 'VBZ'),
#    ('involve', 'VBZ'),
#    ('is', 'VBZ'),
#    ('knows', 'VBZ'),
#    ('leave', 'VBZ'),
#    ('live', 'VBZ'),
#    ('make', 'VBZ'),
#    ('need', 'VBZ'),
#    ('occur', 'VBZ'),
#    ('order', 'VBZ'),
#    ('pass', 'VBZ'),
#    ('prey', 'VBZ'),
#    ('proves', 'VBZ'),
#    ('provide', 'VBZ'),
#    ('provides', 'VBZ'),
#    ('rates', 'VBZ'),
#    ('read', 'VBZ'),
#    ('requires', 'VBZ'),
#    ('rise', 'VBZ'),
#    ('rises', 'VBZ'),
#    ('ruin', 'VBZ'),
#    ('ruins', 'VBZ'),
#    ('run', 'VBZ'),
#    ('say', 'VBZ'),
#    ('says', 'VBZ'),
#    ('set', 'VBZ'),
#    ('show', 'VBZ'),
#    ('shows', 'VBZ'),
#    ('smash', 'VBZ'),
#    ('state', 'VBZ'),
#    ('take', 'VBZ'),
#    ('tell', 'VBZ'),
#    ('travels', 'VBZ'),
#    ('turn', 'VBZ'),
#    ('want', 'VBZ'),
#    ('weakens', 'VBZ'),
#    ('win', 'VBZ'),
#    ('wins', 'VBZ')}),
#  (('bleach', 'NNS'), {('bleach', 'NNS'), ('bleaches', 'NNS')}),
#  (('beginning', 'JJ'), {('beginning', 'JJ'), ('first', 'JJ')}),
#  (('walk', 'NNS'),
#   {('act', 'NNS'),
#    ('bit', 'NNS'),
#    ('go', 'NNS'),
#    ('home', 'NNS'),
#    ('number', 'NNS'),
#    ('pass', 'NNS'),
#    ('passes', 'NNS'),
#    ('place', 'NNS'),
#    ('places', 'NNS'),
#    ('routine', 'NNS'),
#    ('s', 'NNS'),
#    ('second', 'NNS'),
#    ('sites', 'NNS'),
#    ('situation', 'NNS'),
#    ('south', 'NNS'),
#    ('space', 'NNS'),
#    ('spot', 'NNS'),
#    ('turn', 'NNS'),
#    ('turning', 'NNS'),
#    ('turns', 'NNS'),
#    ('walk', 'NNS'),
#    ('walking', 'NNS'),
#    ('walks', 'NNS')}),
#  (('feed', 'VBD'), {('eat', 'VBD'), ('feed', 'VBD')}),
#  (('glucose', 'VB'), {('glucose', 'VB')}),
#  (('lot', 'NNS'),
#   {('circles', 'NNS'),
#    ('circumstance', 'NNS'),
#    ('circumstances', 'NNS'),
#    ('condition', 'NNS'),
#    ('lot', 'NNS'),
#    ('setting', 'NNS')}),
#  (('\\', 'CD'), {('\\', 'CD')}),
#  (('temperature', 'VB'), {('temperature', 'VB')}),
#  (('dioxide', 'NN'), {('dioxide', 'NN')}),
#  (('anchor', 'NN'), {('anchor', 'NN')}),
#  (('disease', 'VB'), {('disease', 'VB')}),
#  (('agree', 'VBP'), {('agree', 'VBP')}),
#  (('therefore', 'RB'),
#   {('consequently', 'RB'),
#    ('hence', 'RB'),
#    ('so', 'RB'),
#    ('then', 'RB'),
#    ('therefore', 'RB')}),
#  (('variety', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('couple', 'NN'), {('couple', 'NN')}),
#  (('oral', 'JJ'), {('oral', 'JJ')}),
#  (('vary', 'VBP'),
#   {('alter', 'VBP'), ('change', 'VBP'), ('shift', 'VBP'), ('vary', 'VBP')}),
#  (('case', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('lead', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (('called', 'VBN'),
#   {('act', 'VBN'),
#    ('affect', 'VBN'),
#    ('affected', 'VBN'),
#    ('amazed', 'VBN'),
#    ('answer', 'VBN'),
#    ('bar', 'VBN'),
#    ('be', 'VBN'),
#    ('been', 'VBN'),
#    ('blocked', 'VBN'),
#    ('break', 'VBN'),
#    ('called', 'VBN'),
#    ('cause', 'VBN'),
#    ('caused', 'VBN'),
#    ('come', 'VBN'),
#    ('controlled', 'VBN'),
#    ('course', 'VBN'),
#    ('depend', 'VBN'),
#    ('destroy', 'VBN'),
#    ('destroyed', 'VBN'),
#    ('die', 'VBN'),
#    ('died', 'VBN'),
#    ('do', 'VBN'),
#    ('done', 'VBN'),
#    ('drop', 'VBN'),
#    ('droped', 'VBN'),
#    ('eat', 'VBN'),
#    ('evidence', 'VBN'),
#    ('exist', 'VBN'),
#    ('exposed', 'VBN'),
#    ('face', 'VBN'),
#    ('feed', 'VBN'),
#    ('filled', 'VBN'),
#    ('flow', 'VBN'),
#    ('freeze', 'VBN'),
#    ('get', 'VBN'),
#    ('give', 'VBN'),
#    ('go', 'VBN'),
#    ('guess', 'VBN'),
#    ('happen', 'VBN'),
#    ('happened', 'VBN'),
#    ('hurt', 'VBN'),
#    ('impact', 'VBN'),
#    ('involve', 'VBN'),
#    ('known', 'VBN'),
#    ('lead', 'VBN'),
#    ('leave', 'VBN'),
#    ('live', 'VBN'),
#    ('located', 'VBN'),
#    ('look', 'VBN'),
#    ('looked', 'VBN'),
#    ('lose', 'VBN'),
#    ('lost', 'VBN'),
#    ('made', 'VBN'),
#    ('make', 'VBN'),
#    ('mentioned', 'VBN'),
#    ('move', 'VBN'),
#    ('name', 'VBN'),
#    ('pall', 'VBN'),
#    ('pass', 'VBN'),
#    ('picture', 'VBN'),
#    ('place', 'VBN'),
#    ('pose', 'VBN'),
#    ('predict', 'VBN'),
#    ('present', 'VBN'),
#    ('prey', 'VBN'),
#    ('read', 'VBN'),
#    ('removed', 'VBN'),
#    ('required', 'VBN'),
#    ('result', 'VBN'),
#    ('resulted', 'VBN'),
#    ('ruin', 'VBN'),
#    ('run', 'VBN'),
#    ('say', 'VBN'),
#    ('see', 'VBN'),
#    ('set', 'VBN'),
#    ('show', 'VBN'),
#    ('showed', 'VBN'),
#    ('speculate', 'VBN'),
#    ('stated', 'VBN'),
#    ('stop', 'VBN'),
#    ('stuff', 'VBN'),
#    ('suffer', 'VBN'),
#    ('supposed', 'VBN'),
#    ('take', 'VBN'),
#    ('think', 'VBN'),
#    ('throw', 'VBN'),
#    ('weaken', 'VBN')}),
#  (('pass', 'VBZ'),
#   {('act', 'VBZ'),
#    ('affects', 'VBZ'),
#    ('allow', 'VBZ'),
#    ('answer', 'VBZ'),
#    ('be', 'VBZ'),
#    ('become', 'VBZ'),
#    ('becomes', 'VBZ'),
#    ('begins', 'VBZ'),
#    ('break', 'VBZ'),
#    ('cause', 'VBZ'),
#    ('chance', 'VBZ'),
#    ('come', 'VBZ'),
#    ('contains', 'VBZ'),
#    ('course', 'VBZ'),
#    ('creates', 'VBZ'),
#    ('decrease', 'VBZ'),
#    ('decreases', 'VBZ'),
#    ('destroy', 'VBZ'),
#    ('do', 'VBZ'),
#    ('does', 'VBZ'),
#    ('eat', 'VBZ'),
#    ('essay', 'VBZ'),
#    ('evidence', 'VBZ'),
#    ('examine', 'VBZ'),
#    ('exist', 'VBZ'),
#    ('fall', 'VBZ'),
#    ('feed', 'VBZ'),
#    ('feeds', 'VBZ'),
#    ('find', 'VBZ'),
#    ('flow', 'VBZ'),
#    ('gain', 'VBZ'),
#    ('get', 'VBZ'),
#    ('give', 'VBZ'),
#    ('gives', 'VBZ'),
#    ('go', 'VBZ'),
#    ('happen', 'VBZ'),
#    ('happens', 'VBZ'),
#    ('has', 'VBZ'),
#    ('involve', 'VBZ'),
#    ('is', 'VBZ'),
#    ('knows', 'VBZ'),
#    ('leave', 'VBZ'),
#    ('live', 'VBZ'),
#    ('make', 'VBZ'),
#    ('need', 'VBZ'),
#    ('occur', 'VBZ'),
#    ('order', 'VBZ'),
#    ('pass', 'VBZ'),
#    ('prey', 'VBZ'),
#    ('proves', 'VBZ'),
#    ('provide', 'VBZ'),
#    ('provides', 'VBZ'),
#    ('rates', 'VBZ'),
#    ('read', 'VBZ'),
#    ('requires', 'VBZ'),
#    ('rise', 'VBZ'),
#    ('rises', 'VBZ'),
#    ('ruin', 'VBZ'),
#    ('ruins', 'VBZ'),
#    ('run', 'VBZ'),
#    ('say', 'VBZ'),
#    ('says', 'VBZ'),
#    ('set', 'VBZ'),
#    ('show', 'VBZ'),
#    ('shows', 'VBZ'),
#    ('smash', 'VBZ'),
#    ('state', 'VBZ'),
#    ('take', 'VBZ'),
#    ('tell', 'VBZ'),
#    ('travels', 'VBZ'),
#    ('turn', 'VBZ'),
#    ('want', 'VBZ'),
#    ('weakens', 'VBZ'),
#    ('win', 'VBZ'),
#    ('wins', 'VBZ')}),
#  (('feed', 'NNS'), {('feed', 'NNS'), ('feeds', 'NNS')}),
#  (('second', 'JJ'), {('second', 'JJ')}),
#  (('swell', 'VBG'), {('swell', 'VBG'), ('well', 'VBG'), ('welling', 'VBG')}),
#  (('say', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (("would've", 'VBP'), {("would've", 'VBP')}),
#  (('starvation', 'NN'), {('starvation', 'NN')}),
#  (('spill', 'VBD'), {('mouth', 'VBD'), ('spill', 'VBD'), ('talked', 'VBD')}),
#  (('higher', 'JJR'), {('high', 'JJR'), ('higher', 'JJR')}),
#  (('salty', 'NN'), {('salty', 'NN')}),
#  (('link', 'VBP'), {('link', 'VBP'), ('relate', 'VBP'), ('tie', 'VBP')}),
#  (('auincidentally', 'RB'), {('auincidentally', 'RB')}),
#  (('random', 'NN'), {('random', 'NN')}),
#  (('relies', 'NNS'), {('relies', 'NNS')}),
#  (('plant', 'VBD'),
#   {('essay', 'VBD'),
#    ('evidence', 'VBD'),
#    ('examine', 'VBD'),
#    ('order', 'VBD'),
#    ('place', 'VBD'),
#    ('plant', 'VBD'),
#    ('pose', 'VBD'),
#    ('proved', 'VBD'),
#    ('put', 'VBD'),
#    ('rise', 'VBD'),
#    ('rose', 'VBD'),
#    ('say', 'VBD'),
#    ('set', 'VBD'),
#    ('show', 'VBD'),
#    ('state', 'VBD'),
#    ('stated', 'VBD'),
#    ('tell', 'VBD')}),
#  (('graphs', 'NNS'), {('graph', 'NNS'), ('graphs', 'NNS')}),
#  (('ability', 'NN'), {('ability', 'NN')}),
#  (('weak', 'JJ'),
#   {('clean', 'JJ'),
#    ('fresh', 'JJ'),
#    ('light', 'JJ'),
#    ('loose', 'JJ'),
#    ('new', 'JJ'),
#    ('weak', 'JJ'),
#    ('white', 'JJ'),
#    ('young', 'JJ')}),
#  (('pressure', 'VB'),
#   {('force', 'VB'), ('pressure', 'VB'), ('push', 'VB'), ('storm', 'VB')}),
#  (('phonosinthisis', 'NN'), {('phonosinthisis', 'NN')}),
#  (('beings', 'NNS'),
#   {('being', 'NNS'), ('beings', 'NNS'), ('organism', 'NNS')}),
#  (('zooanthlallae', 'NN'), {('zooanthlallae', 'NN')}),
#  (('fishing', 'NN'), {('fishing', 'NN')}),
#  (('zoozanthellas', 'NNS'), {('zoozanthellas', 'NNS')}),
#  (('win', 'VBD'), {('gain', 'VBD'), ('win', 'VBD'), ('won', 'VBD')}),
#  (('0', '-NONE-'), {('0', '-NONE-')}),
#  (('collide', 'VB'), {('collide', 'VB')}),
#  (('bleaching', 'VBG'), {('bleach', 'VBG'), ('bleaching', 'VBG')}),
#  (('\x80', ':'), {('\x80', ':')}),
#  (('peak', 'NN'), {('peak', 'NN')}),
#  (('last', 'JJS'),
#   {('blue', 'JJS'),
#    ('broken', 'JJS'),
#    ('down', 'JJS'),
#    ('last', 'JJS'),
#    ('low', 'JJS'),
#    ('lowest', 'JJS'),
#    ('smallest', 'JJS')}),
#  (('gives', 'VBZ'),
#   {('act', 'VBZ'),
#    ('affects', 'VBZ'),
#    ('allow', 'VBZ'),
#    ('answer', 'VBZ'),
#    ('be', 'VBZ'),
#    ('become', 'VBZ'),
#    ('becomes', 'VBZ'),
#    ('begins', 'VBZ'),
#    ('break', 'VBZ'),
#    ('cause', 'VBZ'),
#    ('chance', 'VBZ'),
#    ('come', 'VBZ'),
#    ('contains', 'VBZ'),
#    ('course', 'VBZ'),
#    ('creates', 'VBZ'),
#    ('decrease', 'VBZ'),
#    ('decreases', 'VBZ'),
#    ('destroy', 'VBZ'),
#    ('do', 'VBZ'),
#    ('does', 'VBZ'),
#    ('eat', 'VBZ'),
#    ('essay', 'VBZ'),
#    ('evidence', 'VBZ'),
#    ('examine', 'VBZ'),
#    ('exist', 'VBZ'),
#    ('fall', 'VBZ'),
#    ('feed', 'VBZ'),
#    ('feeds', 'VBZ'),
#    ('find', 'VBZ'),
#    ('flow', 'VBZ'),
#    ('gain', 'VBZ'),
#    ('get', 'VBZ'),
#    ('give', 'VBZ'),
#    ('gives', 'VBZ'),
#    ('go', 'VBZ'),
#    ('happen', 'VBZ'),
#    ('happens', 'VBZ'),
#    ('has', 'VBZ'),
#    ('involve', 'VBZ'),
#    ('is', 'VBZ'),
#    ('knows', 'VBZ'),
#    ('leave', 'VBZ'),
#    ('live', 'VBZ'),
#    ('make', 'VBZ'),
#    ('need', 'VBZ'),
#    ('occur', 'VBZ'),
#    ('order', 'VBZ'),
#    ('pass', 'VBZ'),
#    ('prey', 'VBZ'),
#    ('proves', 'VBZ'),
#    ('provide', 'VBZ'),
#    ('provides', 'VBZ'),
#    ('rates', 'VBZ'),
#    ('read', 'VBZ'),
#    ('requires', 'VBZ'),
#    ('rise', 'VBZ'),
#    ('rises', 'VBZ'),
#    ('ruin', 'VBZ'),
#    ('ruins', 'VBZ'),
#    ('run', 'VBZ'),
#    ('say', 'VBZ'),
#    ('says', 'VBZ'),
#    ('set', 'VBZ'),
#    ('show', 'VBZ'),
#    ('shows', 'VBZ'),
#    ('smash', 'VBZ'),
#    ('state', 'VBZ'),
#    ('take', 'VBZ'),
#    ('tell', 'VBZ'),
#    ('travels', 'VBZ'),
#    ('turn', 'VBZ'),
#    ('want', 'VBZ'),
#    ('weakens', 'VBZ'),
#    ('win', 'VBZ'),
#    ('wins', 'VBZ')}),
#  (("'shifting", 'JJ'), {("'shifting", 'JJ')}),
#  (('stay', 'VBP'), {('continue', 'VBP'), ('rest', 'VBP'), ('stay', 'VBP')}),
#  (('noticible', 'JJ'), {('noticible', 'JJ')}),
#  (('data', 'NN'), {('data', 'NN'), ('info', 'NN'), ('information', 'NN')}),
#  (('vary', 'VB'),
#   {('alter', 'VB'), ('change', 'VB'), ('shift', 'VB'), ('vary', 'VB')}),
#  (('till', 'NN'), {('till', 'NN')}),
#  (('explain', 'VBG'), {('explain', 'VBG'), ('explaining', 'VBG')}),
#  (('3', 'CD'), {('3', 'CD')}),
#  (("zooxanthallae'", 'NNP'), {("zooxanthallae'", 'NNP')}),
#  (('starts', 'NNS'),
#   {('author', 'NNS'),
#    ('beginning', 'NNS'),
#    ('source', 'NNS'),
#    ('sources', 'NNS'),
#    ('starts', 'NNS')}),
#  (('states', 'NNS'),
#   {('country', 'NNS'), ('land', 'NNS'), ('state', 'NNS'), ('states', 'NNS')}),
#  (('altered', 'VBN'),
#   {('alter', 'VBN'), ('altered', 'VBN'), ('change', 'VBN'), ('vary', 'VBN')}),
#  (('"', 'NNP'), {('"', 'NNP')}),
#  (('across', 'IN'), {('across', 'IN')}),
#  (('natural', 'JJ'), {('natural', 'JJ')}),
#  (('healthy', 'NN'), {('healthy', 'NN')}),
#  (('farrenheit', 'NN'), {('farrenheit', 'NN')}),
#  (('form', 'VBG'),
#   {('act', 'VBG'),
#    ('affect', 'VBG'),
#    ('allow', 'VBG'),
#    ('asking', 'VBG'),
#    ('be', 'VBG'),
#    ('become', 'VBG'),
#    ('being', 'VBG'),
#    ('causeing', 'VBG'),
#    ('causing', 'VBG'),
#    ('chance', 'VBG'),
#    ('clear', 'VBG'),
#    ('come', 'VBG'),
#    ('depend', 'VBG'),
#    ('depending', 'VBG'),
#    ('dieing', 'VBG'),
#    ('doing', 'VBG'),
#    ('drop', 'VBG'),
#    ('droping', 'VBG'),
#    ('dying', 'VBG'),
#    ('eat', 'VBG'),
#    ('eating', 'VBG'),
#    ('feed', 'VBG'),
#    ('find', 'VBG'),
#    ('following', 'VBG'),
#    ('form', 'VBG'),
#    ('gain', 'VBG'),
#    ('go', 'VBG'),
#    ('grow', 'VBG'),
#    ('happen', 'VBG'),
#    ('happening', 'VBG'),
#    ('hurting', 'VBG'),
#    ('involve', 'VBG'),
#    ('know', 'VBG'),
#    ('knowing', 'VBG'),
#    ('leave', 'VBG'),
#    ('live', 'VBG'),
#    ('living', 'VBG'),
#    ('look', 'VBG'),
#    ('loosing', 'VBG'),
#    ('lose', 'VBG'),
#    ('losing', 'VBG'),
#    ('make', 'VBG'),
#    ('mean', 'VBG'),
#    ('meaning', 'VBG'),
#    ('move', 'VBG'),
#    ('moving', 'VBG'),
#    ('need', 'VBG'),
#    ('occur', 'VBG'),
#    ('pass', 'VBG'),
#    ('prompt', 'VBG'),
#    ('provide', 'VBG'),
#    ('providing', 'VBG'),
#    ('raising', 'VBG'),
#    ('realizing', 'VBG'),
#    ('receiving', 'VBG'),
#    ('release', 'VBG'),
#    ('resulting', 'VBG'),
#    ('reverse', 'VBG'),
#    ('rising', 'VBG'),
#    ('run', 'VBG'),
#    ('screw', 'VBG'),
#    ('see', 'VBG'),
#    ('spring', 'VBG'),
#    ('starting', 'VBG'),
#    ('suffer', 'VBG'),
#    ('take', 'VBG'),
#    ('think', 'VBG'),
#    ('throw', 'VBG'),
#    ('travel', 'VBG'),
#    ('turn', 'VBG'),
#    ('turning', 'VBG'),
#    ('understand', 'VBG'),
#    ('watch', 'VBG'),
#    ('work', 'VBG')}),
#  (('75', 'CD'), {('75', 'CD')}),
#  (('send', 'VBZ'),
#   {('air', 'VBZ'), ('place', 'VBZ'), ('send', 'VBZ'), ('sends', 'VBZ')}),
#  (('charges', 'NNS'),
#   {('amount', 'NNS'),
#    ('amounts', 'NNS'),
#    ('charges', 'NNS'),
#    ('direction', 'NNS'),
#    ('means', 'NNS'),
#    ('room', 'NNS'),
#    ('sum', 'NNS'),
#    ('way', 'NNS'),
#    ('ways', 'NNS')}),
#  (('treats', 'NNS'), {('treat', 'NNS'), ('treats', 'NNS')}),
#  (('pollution', 'NN'), {('pollution', 'NN')}),
#  (('varioustimes', 'NNS'), {('varioustimes', 'NNS')}),
#  (('either', 'NN'), {('either', 'NN')}),
#  (('more', 'JJR'), {('more', 'JJR')}),
#  (('blast', 'NN'),
#   {('blast', 'NN'),
#    ('blow', 'NN'),
#    ('carbon', 'NN'),
#    ('opposite', 'NN'),
#    ('reverse', 'NN')}),
#  (('sick', 'NN'), {('sick', 'NN')}),
#  (('contribute', 'NN'), {('contribute', 'NN')}),
#  (('phenomen', 'NN'), {('phenomen', 'NN')}),
#  (('hight', 'NN'), {('hight', 'NN')}),
#  (('corral', 'JJ'), {('corral', 'JJ')}),
#  (('"', '``'), {('"', '``')}),
#  (('nutreunts', 'VBZ'), {('nutreunts', 'VBZ')}),
#  (('%', 'NN'), {('%', 'NN')}),
#  (('organisems', 'NNS'), {('organisems', 'NNS')}),
#  (('ward', 'JJ'), {('ward', 'JJ')}),
#  (('sugars', 'NNS'), {('sugar', 'NNS'), ('sugars', 'NNS')}),
#  (('warm', 'VBP'), {('warm', 'VBP')}),
#  (('sum', 'NNS'),
#   {('amount', 'NNS'),
#    ('amounts', 'NNS'),
#    ('charges', 'NNS'),
#    ('direction', 'NNS'),
#    ('means', 'NNS'),
#    ('room', 'NNS'),
#    ('sum', 'NNS'),
#    ('way', 'NNS'),
#    ('ways', 'NNS')}),
#  (('passage', 'NN'), {('passage', 'NN')}),
#  (('kill', 'VBN'), {('down', 'VBN'), ('kill', 'VBN'), ('killed', 'VBN')}),
#  (('exist', 'VBN'),
#   {('act', 'VBN'),
#    ('affect', 'VBN'),
#    ('affected', 'VBN'),
#    ('amazed', 'VBN'),
#    ('answer', 'VBN'),
#    ('bar', 'VBN'),
#    ('be', 'VBN'),
#    ('been', 'VBN'),
#    ('blocked', 'VBN'),
#    ('break', 'VBN'),
#    ('called', 'VBN'),
#    ('cause', 'VBN'),
#    ('caused', 'VBN'),
#    ('come', 'VBN'),
#    ('controlled', 'VBN'),
#    ('course', 'VBN'),
#    ('depend', 'VBN'),
#    ('destroy', 'VBN'),
#    ('destroyed', 'VBN'),
#    ('die', 'VBN'),
#    ('died', 'VBN'),
#    ('do', 'VBN'),
#    ('done', 'VBN'),
#    ('drop', 'VBN'),
#    ('droped', 'VBN'),
#    ('eat', 'VBN'),
#    ('evidence', 'VBN'),
#    ('exist', 'VBN'),
#    ('exposed', 'VBN'),
#    ('face', 'VBN'),
#    ('feed', 'VBN'),
#    ('filled', 'VBN'),
#    ('flow', 'VBN'),
#    ('freeze', 'VBN'),
#    ('get', 'VBN'),
#    ('give', 'VBN'),
#    ('go', 'VBN'),
#    ('guess', 'VBN'),
#    ('happen', 'VBN'),
#    ('happened', 'VBN'),
#    ('hurt', 'VBN'),
#    ('impact', 'VBN'),
#    ('involve', 'VBN'),
#    ('known', 'VBN'),
#    ('lead', 'VBN'),
#    ('leave', 'VBN'),
#    ('live', 'VBN'),
#    ('located', 'VBN'),
#    ('look', 'VBN'),
#    ('looked', 'VBN'),
#    ('lose', 'VBN'),
#    ('lost', 'VBN'),
#    ('made', 'VBN'),
#    ('make', 'VBN'),
#    ('mentioned', 'VBN'),
#    ('move', 'VBN'),
#    ('name', 'VBN'),
#    ('pall', 'VBN'),
#    ('pass', 'VBN'),
#    ('picture', 'VBN'),
#    ('place', 'VBN'),
#    ('pose', 'VBN'),
#    ('predict', 'VBN'),
#    ('present', 'VBN'),
#    ('prey', 'VBN'),
#    ('read', 'VBN'),
#    ('removed', 'VBN'),
#    ('required', 'VBN'),
#    ('result', 'VBN'),
#    ('resulted', 'VBN'),
#    ('ruin', 'VBN'),
#    ('run', 'VBN'),
#    ('say', 'VBN'),
#    ('see', 'VBN'),
#    ('set', 'VBN'),
#    ('show', 'VBN'),
#    ('showed', 'VBN'),
#    ('speculate', 'VBN'),
#    ('stated', 'VBN'),
#    ('stop', 'VBN'),
#    ('stuff', 'VBN'),
#    ('suffer', 'VBN'),
#    ('supposed', 'VBN'),
#    ('take', 'VBN'),
#    ('think', 'VBN'),
#    ('throw', 'VBN'),
#    ('weaken', 'VBN')}),
#  (('reports', 'NNS'), {('report', 'NNS'), ('reports', 'NNS')}),
#  (('gluecose', 'DT'), {('gluecose', 'DT')}),
#  (('common', 'JJ'), {('common', 'JJ'), ('usual', 'JJ')}),
#  (('release', 'NN'),
#   {('decline', 'NN'),
#    ('drop', 'NN'),
#    ('fall', 'NN'),
#    ('going', 'NN'),
#    ('loss', 'NN'),
#    ('release', 'NN'),
#    ('spill', 'NN')}),
#  (('varys', 'VBZ'),
#   {('alter', 'VBZ'),
#    ('change', 'VBZ'),
#    ('shifts', 'VBZ'),
#    ('vary', 'VBZ'),
#    ('varys', 'VBZ')}),
#  (('earth', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('group', 'VBN'), {('group', 'VBN'), ('grouped', 'VBN')}),
#  (('pleasurable', 'JJ'), {('pleasurable', 'JJ')}),
#  (('when', 'WRB'), {('when', 'WRB')}),
#  (('broken', 'JJS'),
#   {('blue', 'JJS'),
#    ('broken', 'JJS'),
#    ('down', 'JJS'),
#    ('last', 'JJS'),
#    ('low', 'JJS'),
#    ('lowest', 'JJS'),
#    ('smallest', 'JJS')}),
#  (('pattern', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('object', 'NN'), {('object', 'NN')}),
#  (('happens', 'NNS'), {('happens', 'NNS')}),
#  (('some', 'VB'), {('some', 'VB')}),
#  (('bunch', 'NN'),
#   {('bunch', 'NN'),
#    ('circumstances', 'NN'),
#    ('lot', 'NN'),
#    ('mess', 'NN'),
#    ('plenty', 'NN'),
#    ('set', 'NN')}),
#  (('go', 'VBD'),
#   {('act', 'VBD'),
#    ('be', 'VBD'),
#    ('began', 'VBD'),
#    ('begin', 'VBD'),
#    ('bring', 'VBD'),
#    ('come', 'VBD'),
#    ('continue', 'VBD'),
#    ('determine', 'VBD'),
#    ('exist', 'VBD'),
#    ('find', 'VBD'),
#    ('form', 'VBD'),
#    ('function', 'VBD'),
#    ('get', 'VBD'),
#    ('go', 'VBD'),
#    ('happen', 'VBD'),
#    ('hit', 'VBD'),
#    ('keep', 'VBD'),
#    ('kept', 'VBD'),
#    ('knew', 'VBD'),
#    ('lead', 'VBD'),
#    ('learn', 'VBD'),
#    ('learned', 'VBD'),
#    ('leave', 'VBD'),
#    ('live', 'VBD'),
#    ('maintain', 'VBD'),
#    ('make', 'VBD'),
#    ('needed', 'VBD'),
#    ('notice', 'VBD'),
#    ('noticed', 'VBD'),
#    ('occur', 'VBD'),
#    ('occurred', 'VBD'),
#    ('pass', 'VBD'),
#    ('preserve', 'VBD'),
#    ('process', 'VBD'),
#    ('provided', 'VBD'),
#    ('read', 'VBD'),
#    ('result', 'VBD'),
#    ('resulted', 'VBD'),
#    ('run', 'VBD'),
#    ('said', 'VBD'),
#    ('see', 'VBD'),
#    ('showed', 'VBD'),
#    ('start', 'VBD'),
#    ('sustain', 'VBD'),
#    ('take', 'VBD'),
#    ('turn', 'VBD'),
#    ('was', 'VBD'),
#    ('watch', 'VBD'),
#    ('work', 'VBD'),
#    ('worked', 'VBD')}),
#  (('blow', 'VBZ'), {('blow', 'VBZ'), ('blows', 'VBZ'), ('gas', 'VBZ')}),
#  (('air', 'VBZ'),
#   {('air', 'VBZ'), ('place', 'VBZ'), ('send', 'VBZ'), ('sends', 'VBZ')}),
#  (('would', 'MD'), {('would', 'MD')}),
#  (('present', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (('hand', 'NN'), {('hand', 'NN')}),
#  (('barely', 'RB'),
#   {('alone', 'RB'),
#    ('barely', 'RB'),
#    ('but', 'RB'),
#    ('just', 'RB'),
#    ('only', 'RB'),
#    ('simply', 'RB')}),
#  (('temputre', 'NN'), {('temputre', 'NN')}),
#  (('plenty', 'NN'),
#   {('bunch', 'NN'),
#    ('circumstances', 'NN'),
#    ('lot', 'NN'),
#    ('mess', 'NN'),
#    ('plenty', 'NN'),
#    ('set', 'NN')}),
#  (('affect', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (('h20', 'NNP'), {('h20', 'NNP')}),
#  (('type', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('east', 'JJ'), {('east', 'JJ')}),
#  (('anchor', 'NNS'), {('anchor', 'NNS'), ('anchors', 'NNS')}),
#  (('sudden', 'JJ'), {('sudden', 'JJ')}),
#  (('zox', 'NN'), {('zox', 'NN')}),
#  (('piece', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('after', 'IN'), {('after', 'IN')}),
#  (('shift', 'NNS'),
#   {('break', 'NNS'),
#    ('disruptions', 'NNS'),
#    ('shift', 'NNS'),
#    ('shifting', 'NNS'),
#    ('shifts', 'NNS'),
#    ('switching', 'NNS')}),
#  (('practices', 'NNS'),
#   {('pattern', 'NNS'), ('patterns', 'NNS'), ('practices', 'NNS')}),
#  (('third', 'JJ'), {('third', 'JJ')}),
#  (('differ', 'VBP'), {('differ', 'VBP'), ('disagree', 'VBP')}),
#  (('ya', 'VB'), {('ya', 'VB')}),
#  (('weakest', 'JJS'), {('light', 'JJS'), ('weak', 'JJS'), ('weakest', 'JJS')}),
#  (('importantly', 'RB'), {('importantly', 'RB')}),
#  (('turn', 'NNS'),
#   {('act', 'NNS'),
#    ('bit', 'NNS'),
#    ('go', 'NNS'),
#    ('home', 'NNS'),
#    ('number', 'NNS'),
#    ('pass', 'NNS'),
#    ('passes', 'NNS'),
#    ('place', 'NNS'),
#    ('places', 'NNS'),
#    ('routine', 'NNS'),
#    ('s', 'NNS'),
#    ('second', 'NNS'),
#    ('sites', 'NNS'),
#    ('situation', 'NNS'),
#    ('south', 'NNS'),
#    ('space', 'NNS'),
#    ('spot', 'NNS'),
#    ('turn', 'NNS'),
#    ('turning', 'NNS'),
#    ('turns', 'NNS'),
#    ('walk', 'NNS'),
#    ('walking', 'NNS'),
#    ('walks', 'NNS')}),
#  (('wotter', 'NN'), {('wotter', 'NN')}),
#  (('releases', 'NNS'),
#   {('going', 'NNS'),
#    ('loss', 'NNS'),
#    ('release', 'NNS'),
#    ('releases', 'NNS'),
#    ('spill', 'NNS')}),
#  (('energy', 'NN'), {('energy', 'NN'), ('push', 'NN')}),
#  (('local', 'JJ'), {('local', 'JJ')}),
#  (('hard', 'JJ'),
#   {('bad', 'JJ'),
#    ('big', 'JJ'),
#    ('dangerous', 'JJ'),
#    ('fond', 'JJ'),
#    ('good', 'JJ'),
#    ('hard', 'JJ'),
#    ('large', 'JJ'),
#    ('right', 'JJ'),
#    ('risky', 'JJ'),
#    ('serious', 'JJ'),
#    ('severe', 'JJ'),
#    ('strong', 'JJ'),
#    ('warm', 'JJ')}),
#  (('most', 'VB'), {('most', 'VB')}),
#  (('pink', 'NN'), {('pink', 'NN')}),
#  (('sensitive', 'JJ'), {('sensitive', 'JJ')}),
#  (('endangering', 'VBG'),
#   {('endangering', 'VBG'), ('threaten', 'VBG'), ('threatening', 'VBG')}),
#  ((')', 'NN'), {(')', 'NN')}),
#  (('balance', 'VB'), {('balance', 'VB')}),
#  (('drop', 'VBN'),
#   {('act', 'VBN'),
#    ('affect', 'VBN'),
#    ('affected', 'VBN'),
#    ('amazed', 'VBN'),
#    ('answer', 'VBN'),
#    ('bar', 'VBN'),
#    ('be', 'VBN'),
#    ('been', 'VBN'),
#    ('blocked', 'VBN'),
#    ('break', 'VBN'),
#    ('called', 'VBN'),
#    ('cause', 'VBN'),
#    ('caused', 'VBN'),
#    ('come', 'VBN'),
#    ('controlled', 'VBN'),
#    ('course', 'VBN'),
#    ('depend', 'VBN'),
#    ('destroy', 'VBN'),
#    ('destroyed', 'VBN'),
#    ('die', 'VBN'),
#    ('died', 'VBN'),
#    ('do', 'VBN'),
#    ('done', 'VBN'),
#    ('drop', 'VBN'),
#    ('droped', 'VBN'),
#    ('eat', 'VBN'),
#    ('evidence', 'VBN'),
#    ('exist', 'VBN'),
#    ('exposed', 'VBN'),
#    ('face', 'VBN'),
#    ('feed', 'VBN'),
#    ('filled', 'VBN'),
#    ('flow', 'VBN'),
#    ('freeze', 'VBN'),
#    ('get', 'VBN'),
#    ('give', 'VBN'),
#    ('go', 'VBN'),
#    ('guess', 'VBN'),
#    ('happen', 'VBN'),
#    ('happened', 'VBN'),
#    ('hurt', 'VBN'),
#    ('impact', 'VBN'),
#    ('involve', 'VBN'),
#    ('known', 'VBN'),
#    ('lead', 'VBN'),
#    ('leave', 'VBN'),
#    ('live', 'VBN'),
#    ('located', 'VBN'),
#    ('look', 'VBN'),
#    ('looked', 'VBN'),
#    ('lose', 'VBN'),
#    ('lost', 'VBN'),
#    ('made', 'VBN'),
#    ('make', 'VBN'),
#    ('mentioned', 'VBN'),
#    ('move', 'VBN'),
#    ('name', 'VBN'),
#    ('pall', 'VBN'),
#    ('pass', 'VBN'),
#    ('picture', 'VBN'),
#    ('place', 'VBN'),
#    ('pose', 'VBN'),
#    ('predict', 'VBN'),
#    ('present', 'VBN'),
#    ('prey', 'VBN'),
#    ('read', 'VBN'),
#    ('removed', 'VBN'),
#    ('required', 'VBN'),
#    ('result', 'VBN'),
#    ('resulted', 'VBN'),
#    ('ruin', 'VBN'),
#    ('run', 'VBN'),
#    ('say', 'VBN'),
#    ('see', 'VBN'),
#    ('set', 'VBN'),
#    ('show', 'VBN'),
#    ('showed', 'VBN'),
#    ('speculate', 'VBN'),
#    ('stated', 'VBN'),
#    ('stop', 'VBN'),
#    ('stuff', 'VBN'),
#    ('suffer', 'VBN'),
#    ('supposed', 'VBN'),
#    ('take', 'VBN'),
#    ('think', 'VBN'),
#    ('throw', 'VBN'),
#    ('weaken', 'VBN')}),
#  (('lastly', 'RB'),
#   {('eventually', 'RB'), ('finally', 'RB'), ('last', 'RB'), ('lastly', 'RB')}),
#  (('varys', 'NNS'), {('varys', 'NNS')}),
#  (('necessary', 'NNS'), {('necessary', 'NNS'), ('requirements', 'NNS')}),
#  (('anymore', 'NN'), {('anymore', 'NN')}),
#  (('region', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('gotton', 'VBN'), {('gotton', 'VBN')}),
#  (('chance', 'VBG'),
#   {('act', 'VBG'),
#    ('affect', 'VBG'),
#    ('allow', 'VBG'),
#    ('asking', 'VBG'),
#    ('be', 'VBG'),
#    ('become', 'VBG'),
#    ('being', 'VBG'),
#    ('causeing', 'VBG'),
#    ('causing', 'VBG'),
#    ('chance', 'VBG'),
#    ('clear', 'VBG'),
#    ('come', 'VBG'),
#    ('depend', 'VBG'),
#    ('depending', 'VBG'),
#    ('dieing', 'VBG'),
#    ('doing', 'VBG'),
#    ('drop', 'VBG'),
#    ('droping', 'VBG'),
#    ('dying', 'VBG'),
#    ('eat', 'VBG'),
#    ('eating', 'VBG'),
#    ('feed', 'VBG'),
#    ('find', 'VBG'),
#    ('following', 'VBG'),
#    ('form', 'VBG'),
#    ('gain', 'VBG'),
#    ('go', 'VBG'),
#    ('grow', 'VBG'),
#    ('happen', 'VBG'),
#    ('happening', 'VBG'),
#    ('hurting', 'VBG'),
#    ('involve', 'VBG'),
#    ('know', 'VBG'),
#    ('knowing', 'VBG'),
#    ('leave', 'VBG'),
#    ('live', 'VBG'),
#    ('living', 'VBG'),
#    ('look', 'VBG'),
#    ('loosing', 'VBG'),
#    ('lose', 'VBG'),
#    ('losing', 'VBG'),
#    ('make', 'VBG'),
#    ('mean', 'VBG'),
#    ('meaning', 'VBG'),
#    ('move', 'VBG'),
#    ('moving', 'VBG'),
#    ('need', 'VBG'),
#    ('occur', 'VBG'),
#    ('pass', 'VBG'),
#    ('prompt', 'VBG'),
#    ('provide', 'VBG'),
#    ('providing', 'VBG'),
#    ('raising', 'VBG'),
#    ('realizing', 'VBG'),
#    ('receiving', 'VBG'),
#    ('release', 'VBG'),
#    ('resulting', 'VBG'),
#    ('reverse', 'VBG'),
#    ('rising', 'VBG'),
#    ('run', 'VBG'),
#    ('screw', 'VBG'),
#    ('see', 'VBG'),
#    ('spring', 'VBG'),
#    ('starting', 'VBG'),
#    ('suffer', 'VBG'),
#    ('take', 'VBG'),
#    ('think', 'VBG'),
#    ('throw', 'VBG'),
#    ('travel', 'VBG'),
#    ('turn', 'VBG'),
#    ('turning', 'VBG'),
#    ('understand', 'VBG'),
#    ('watch', 'VBG'),
#    ('work', 'VBG')}),
#  (('lose', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (('suffer', 'VBP'),
#   {('act', 'VBP'),
#    ('add', 'VBP'),
#    ('affect', 'VBP'),
#    ('are', 'VBP'),
#    ('arrive', 'VBP'),
#    ('be', 'VBP'),
#    ('become', 'VBP'),
#    ('begin', 'VBP'),
#    ('break', 'VBP'),
#    ('come', 'VBP'),
#    ('contribute', 'VBP'),
#    ('create', 'VBP'),
#    ('decrease', 'VBP'),
#    ('depend', 'VBP'),
# ...
#    ('live', 'VBD'),
#    ('maintain', 'VBD'),
#    ('make', 'VBD'),
#    ('needed', 'VBD'),
#    ('notice', 'VBD'),
#    ('noticed', 'VBD'),
#    ('occur', 'VBD'),
#    ('occurred', 'VBD'),
#    ('pass', 'VBD'),
#    ('preserve', 'VBD'),
#    ('process', 'VBD'),
#    ('provided', 'VBD'),
#    ('read', 'VBD'),
#    ('result', 'VBD'),
#    ('resulted', 'VBD'),
#    ('run', 'VBD'),
#    ('said', 'VBD'),
#    ('see', 'VBD'),
#    ('showed', 'VBD'),
#    ('start', 'VBD'),
#    ('sustain', 'VBD'),
#    ('take', 'VBD'),
#    ('turn', 'VBD'),
#    ('was', 'VBD'),
#    ('watch', 'VBD'),
#    ('work', 'VBD'),
#    ('worked', 'VBD')}),
#  (('blow', 'VBN'), {('blow', 'VBN'), ('blown', 'VBN'), ('gas', 'VBN')}),
#  (('function', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('stress', 'VBN'), {('stress', 'VBN'), ('stressed', 'VBN')}),
#  (('continue', 'VBZ'),
#   {('continue', 'VBZ'),
#    ('cover', 'VBZ'),
#    ('covers', 'VBZ'),
#    ('keeps', 'VBZ'),
#    ('report', 'VBZ'),
#    ('stays', 'VBZ'),
#    ('treat', 'VBZ')}),
#  (('anhors', 'NNS'), {('anhors', 'NNS')}),
#  (('take', 'VBD'),
#   {('act', 'VBD'),
#    ('be', 'VBD'),
#    ('began', 'VBD'),
#    ('begin', 'VBD'),
#    ('bring', 'VBD'),
#    ('come', 'VBD'),
#    ('continue', 'VBD'),
#    ('determine', 'VBD'),
#    ('exist', 'VBD'),
#    ('find', 'VBD'),
#    ('form', 'VBD'),
#    ('function', 'VBD'),
#    ('get', 'VBD'),
#    ('go', 'VBD'),
#    ('happen', 'VBD'),
#    ('hit', 'VBD'),
#    ('keep', 'VBD'),
#    ('kept', 'VBD'),
#    ('knew', 'VBD'),
#    ('lead', 'VBD'),
#    ('learn', 'VBD'),
#    ('learned', 'VBD'),
#    ('leave', 'VBD'),
#    ('live', 'VBD'),
#    ('maintain', 'VBD'),
#    ('make', 'VBD'),
#    ('needed', 'VBD'),
#    ('notice', 'VBD'),
#    ('noticed', 'VBD'),
#    ('occur', 'VBD'),
#    ('occurred', 'VBD'),
#    ('pass', 'VBD'),
#    ('preserve', 'VBD'),
#    ('process', 'VBD'),
#    ('provided', 'VBD'),
#    ('read', 'VBD'),
#    ('result', 'VBD'),
#    ('resulted', 'VBD'),
#    ('run', 'VBD'),
#    ('said', 'VBD'),
#    ('see', 'VBD'),
#    ('showed', 'VBD'),
#    ('start', 'VBD'),
#    ('sustain', 'VBD'),
#    ('take', 'VBD'),
#    ('turn', 'VBD'),
#    ('was', 'VBD'),
#    ('watch', 'VBD'),
#    ('work', 'VBD'),
#    ('worked', 'VBD')}),
#  (('yes', 'VBZ'), {('yes', 'VBZ')}),
#  (('all', 'DT'), {('all', 'DT')}),
#  (("'92t", 'JJ'), {("'92t", 'JJ')}),
#  (('whats', 'NNS'), {('whats', 'NNS')}),
#  (('chance', 'VBZ'),
#   {('act', 'VBZ'),
#    ('affects', 'VBZ'),
#    ('allow', 'VBZ'),
#    ('answer', 'VBZ'),
#    ('be', 'VBZ'),
#    ('become', 'VBZ'),
#    ('becomes', 'VBZ'),
#    ('begins', 'VBZ'),
#    ('break', 'VBZ'),
#    ('cause', 'VBZ'),
#    ('chance', 'VBZ'),
#    ('come', 'VBZ'),
#    ('contains', 'VBZ'),
#    ('course', 'VBZ'),
#    ('creates', 'VBZ'),
#    ('decrease', 'VBZ'),
#    ('decreases', 'VBZ'),
#    ('destroy', 'VBZ'),
#    ('do', 'VBZ'),
#    ('does', 'VBZ'),
#    ('eat', 'VBZ'),
#    ('essay', 'VBZ'),
#    ('evidence', 'VBZ'),
#    ('examine', 'VBZ'),
#    ('exist', 'VBZ'),
#    ('fall', 'VBZ'),
#    ('feed', 'VBZ'),
#    ('feeds', 'VBZ'),
#    ('find', 'VBZ'),
#    ('flow', 'VBZ'),
#    ('gain', 'VBZ'),
#    ('get', 'VBZ'),
#    ('give', 'VBZ'),
#    ('gives', 'VBZ'),
#    ('go', 'VBZ'),
#    ('happen', 'VBZ'),
#    ('happens', 'VBZ'),
#    ('has', 'VBZ'),
#    ('involve', 'VBZ'),
#    ('is', 'VBZ'),
#    ('knows', 'VBZ'),
#    ('leave', 'VBZ'),
#    ('live', 'VBZ'),
#    ('make', 'VBZ'),
#    ('need', 'VBZ'),
#    ('occur', 'VBZ'),
#    ('order', 'VBZ'),
#    ('pass', 'VBZ'),
#    ('prey', 'VBZ'),
#    ('proves', 'VBZ'),
#    ('provide', 'VBZ'),
#    ('provides', 'VBZ'),
#    ('rates', 'VBZ'),
#    ('read', 'VBZ'),
#    ('requires', 'VBZ'),
#    ('rise', 'VBZ'),
#    ('rises', 'VBZ'),
#    ('ruin', 'VBZ'),
#    ('ruins', 'VBZ'),
#    ('run', 'VBZ'),
#    ('say', 'VBZ'),
#    ('says', 'VBZ'),
#    ('set', 'VBZ'),
#    ('show', 'VBZ'),
#    ('shows', 'VBZ'),
#    ('smash', 'VBZ'),
#    ('state', 'VBZ'),
#    ('take', 'VBZ'),
#    ('tell', 'VBZ'),
#    ('travels', 'VBZ'),
#    ('turn', 'VBZ'),
#    ('want', 'VBZ'),
#    ('weakens', 'VBZ'),
#    ('win', 'VBZ'),
#    ('wins', 'VBZ')}),
#  (('destroy', 'NN'), {('destroy', 'NN')}),
#  (('south', 'NNS'),
#   {('act', 'NNS'),
#    ('bit', 'NNS'),
#    ('go', 'NNS'),
#    ('home', 'NNS'),
#    ('number', 'NNS'),
#    ('pass', 'NNS'),
#    ('passes', 'NNS'),
#    ('place', 'NNS'),
#    ('places', 'NNS'),
#    ('routine', 'NNS'),
#    ('s', 'NNS'),
#    ('second', 'NNS'),
#    ('sites', 'NNS'),
#    ('situation', 'NNS'),
#    ('south', 'NNS'),
#    ('space', 'NNS'),
#    ('spot', 'NNS'),
#    ('turn', 'NNS'),
#    ('turning', 'NNS'),
#    ('turns', 'NNS'),
#    ('walk', 'NNS'),
#    ('walking', 'NNS'),
#    ('walks', 'NNS')}),
#  (('h2o', 'NNP'), {('h2o', 'NNP'), ('water', 'NNP')}),
#  (('addition', 'NN'),
#   {('addition', 'NN'), ('gain', 'NN'), ('increase', 'NN')}),
#  (('country', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('rising', 'VBG'),
#   {('act', 'VBG'),
#    ('affect', 'VBG'),
#    ('allow', 'VBG'),
#    ('asking', 'VBG'),
#    ('be', 'VBG'),
#    ('become', 'VBG'),
#    ('being', 'VBG'),
#    ('causeing', 'VBG'),
#    ('causing', 'VBG'),
#    ('chance', 'VBG'),
#    ('clear', 'VBG'),
#    ('come', 'VBG'),
#    ('depend', 'VBG'),
#    ('depending', 'VBG'),
#    ('dieing', 'VBG'),
#    ('doing', 'VBG'),
#    ('drop', 'VBG'),
#    ('droping', 'VBG'),
#    ('dying', 'VBG'),
#    ('eat', 'VBG'),
#    ('eating', 'VBG'),
#    ('feed', 'VBG'),
#    ('find', 'VBG'),
#    ('following', 'VBG'),
#    ('form', 'VBG'),
#    ('gain', 'VBG'),
#    ('go', 'VBG'),
#    ('grow', 'VBG'),
#    ('happen', 'VBG'),
#    ('happening', 'VBG'),
#    ('hurting', 'VBG'),
#    ('involve', 'VBG'),
#    ('know', 'VBG'),
#    ('knowing', 'VBG'),
#    ('leave', 'VBG'),
#    ('live', 'VBG'),
#    ('living', 'VBG'),
#    ('look', 'VBG'),
#    ('loosing', 'VBG'),
#    ('lose', 'VBG'),
#    ('losing', 'VBG'),
#    ('make', 'VBG'),
#    ('mean', 'VBG'),
#    ('meaning', 'VBG'),
#    ('move', 'VBG'),
#    ('moving', 'VBG'),
#    ('need', 'VBG'),
#    ('occur', 'VBG'),
#    ('pass', 'VBG'),
#    ('prompt', 'VBG'),
#    ('provide', 'VBG'),
#    ('providing', 'VBG'),
#    ('raising', 'VBG'),
#    ('realizing', 'VBG'),
#    ('receiving', 'VBG'),
#    ('release', 'VBG'),
#    ('resulting', 'VBG'),
#    ('reverse', 'VBG'),
#    ('rising', 'VBG'),
#    ('run', 'VBG'),
#    ('screw', 'VBG'),
#    ('see', 'VBG'),
#    ('spring', 'VBG'),
#    ('starting', 'VBG'),
#    ('suffer', 'VBG'),
#    ('take', 'VBG'),
#    ('think', 'VBG'),
#    ('throw', 'VBG'),
#    ('travel', 'VBG'),
#    ('turn', 'VBG'),
#    ('turning', 'VBG'),
#    ('understand', 'VBG'),
#    ('watch', 'VBG'),
#    ('work', 'VBG')}),
#  (('blowing', 'VBG'), {('blow', 'VBG'), ('blowing', 'VBG'), ('gas', 'VBG')}),
#  (('waters', 'NNS'), {('water', 'NNS'), ('waters', 'NNS')}),
#  (('allow', 'VB'),
#   {('add', 'VB'),
#    ('affect', 'VB'),
#    ('allow', 'VB'),
#    ('be', 'VB'),
#    ('become', 'VB'),
#    ('begin', 'VB'),
#    ('break', 'VB'),
#    ('build', 'VB'),
#    ('cause', 'VB'),
#    ('continue', 'VB'),
#    ('contribute', 'VB'),
#    ('cover', 'VB'),
#    ('create', 'VB'),
#    ('decrease', 'VB'),
#    ('depend', 'VB'),
#    ('destroy', 'VB'),
#    ('die', 'VB'),
#    ('drop', 'VB'),
#    ('eat', 'VB'),
#    ('eject', 'VB'),
#    ('end', 'VB'),
#    ('evidence', 'VB'),
#    ('exist', 'VB'),
#    ('face', 'VB'),
#    ('fade', 'VB'),
#    ('fall', 'VB'),
#    ('feed', 'VB'),
#    ('feel', 'VB'),
#    ('find', 'VB'),
#    ('get', 'VB'),
#    ('give', 'VB'),
#    ('go', 'VB'),
#    ('grow', 'VB'),
#    ('happen', 'VB'),
#    ('have', 'VB'),
#    ('hit', 'VB'),
#    ('hurt', 'VB'),
#    ('impact', 'VB'),
#    ('involve', 'VB'),
#    ('know', 'VB'),
#    ('lead', 'VB'),
#    ('leave', 'VB'),
#    ('let', 'VB'),
#    ('live', 'VB'),
#    ('look', 'VB'),
#    ('lose', 'VB'),
#    ('make', 'VB'),
#    ('move', 'VB'),
#    ('order', 'VB'),
#    ('own', 'VB'),
#    ('pall', 'VB'),
#    ('pass', 'VB'),
#    ('picture', 'VB'),
#    ('place', 'VB'),
#    ('pose', 'VB'),
#    ('present', 'VB'),
#    ('preserve', 'VB'),
#    ('process', 'VB'),
#    ('put', 'VB'),
#    ('read', 'VB'),
#    ('receive', 'VB'),
#    ('recover', 'VB'),
#    ('release', 'VB'),
#    ('rest', 'VB'),
#    ('result', 'VB'),
#    ('reverse', 'VB'),
#    ('rise', 'VB'),
#    ('ruin', 'VB'),
#    ('run', 'VB'),
#    ('say', 'VB'),
#    ('screw', 'VB'),
#    ('see', 'VB'),
#    ('sense', 'VB'),
#    ('set', 'VB'),
#    ('show', 'VB'),
#    ('state', 'VB'),
#    ('stay', 'VB'),
#    ('stop', 'VB'),
#    ('suffer', 'VB'),
#    ('sustain', 'VB'),
#    ('take', 'VB'),
#    ('tell', 'VB'),
#    ('tend', 'VB'),
#    ('throw', 'VB'),
#    ('treat', 'VB'),
#    ('turn', 'VB'),
#    ('watch', 'VB'),
#    ('weaken', 'VB'),
#    ('work', 'VB')}),
#  (('setting', 'NN'),
#   {('background', 'NN'),
#    ('circumstance', 'NN'),
#    ('condition', 'NN'),
#    ('setting', 'NN')}),
#  (('tenticles', 'NNS'), {('tenticles', 'NNS')}),
#  (('current', 'NNS'),
#   {('current', 'NNS'),
#    ('currents', 'NNS'),
#    ('flow', 'NNS'),
#    ('periods', 'NNS')}),
#  (('blow', 'VBG'), {('blow', 'VBG'), ('blowing', 'VBG'), ('gas', 'VBG')}),
#  (('eventially', 'RB'), {('eventially', 'RB')}),
#  (('above', 'IN'), {('above', 'IN')}),
#  (('grow', 'VBG'),
#   {('act', 'VBG'),
#    ('affect', 'VBG'),
#    ('allow', 'VBG'),
#    ('asking', 'VBG'),
#    ('be', 'VBG'),
#    ('become', 'VBG'),
#    ('being', 'VBG'),
#    ('causeing', 'VBG'),
#    ('causing', 'VBG'),
#    ('chance', 'VBG'),
#    ('clear', 'VBG'),
#    ('come', 'VBG'),
#    ('depend', 'VBG'),
#    ('depending', 'VBG'),
#    ('dieing', 'VBG'),
#    ('doing', 'VBG'),
#    ('drop', 'VBG'),
#    ('droping', 'VBG'),
#    ('dying', 'VBG'),
#    ('eat', 'VBG'),
#    ('eating', 'VBG'),
#    ('feed', 'VBG'),
#    ('find', 'VBG'),
#    ('following', 'VBG'),
#    ('form', 'VBG'),
#    ('gain', 'VBG'),
#    ('go', 'VBG'),
#    ('grow', 'VBG'),
#    ('happen', 'VBG'),
#    ('happening', 'VBG'),
#    ('hurting', 'VBG'),
#    ('involve', 'VBG'),
#    ('know', 'VBG'),
#    ('knowing', 'VBG'),
#    ('leave', 'VBG'),
#    ('live', 'VBG'),
#    ('living', 'VBG'),
#    ('look', 'VBG'),
#    ('loosing', 'VBG'),
#    ('lose', 'VBG'),
#    ('losing', 'VBG'),
#    ('make', 'VBG'),
#    ('mean', 'VBG'),
#    ('meaning', 'VBG'),
#    ('move', 'VBG'),
#    ('moving', 'VBG'),
#    ('need', 'VBG'),
#    ('occur', 'VBG'),
#    ('pass', 'VBG'),
#    ('prompt', 'VBG'),
#    ('provide', 'VBG'),
#    ('providing', 'VBG'),
#    ('raising', 'VBG'),
#    ('realizing', 'VBG'),
#    ('receiving', 'VBG'),
#    ('release', 'VBG'),
#    ('resulting', 'VBG'),
#    ('reverse', 'VBG'),
#    ('rising', 'VBG'),
#    ('run', 'VBG'),
#    ('screw', 'VBG'),
#    ('see', 'VBG'),
#    ('spring', 'VBG'),
#    ('starting', 'VBG'),
#    ('suffer', 'VBG'),
#    ('take', 'VBG'),
#    ('think', 'VBG'),
#    ('throw', 'VBG'),
#    ('travel', 'VBG'),
#    ('turn', 'VBG'),
#    ('turning', 'VBG'),
#    ('understand', 'VBG'),
#    ('watch', 'VBG'),
#    ('work', 'VBG')}),
#  (("there's", 'NNP'), {("there's", 'NNP')}),
#  (('bad', 'JJS'),
#   {('bad', 'JJS'),
#    ('big', 'JJS'),
#    ('biggest', 'JJS'),
#    ('giving', 'JJS'),
#    ('heavy', 'JJS'),
#    ('large', 'JJS')}),
#  (('alone', 'NN'), {('alone', 'NN')}),
#  (('crush', 'VB'), {('crush', 'VB'), ('smash', 'VB')}),
#  (('release', 'VBG'),
#   {('act', 'VBG'),
#    ('affect', 'VBG'),
#    ('allow', 'VBG'),
#    ('asking', 'VBG'),
#    ('be', 'VBG'),
#    ('become', 'VBG'),
#    ('being', 'VBG'),
#    ('causeing', 'VBG'),
#    ('causing', 'VBG'),
#    ('chance', 'VBG'),
#    ('clear', 'VBG'),
#    ('come', 'VBG'),
#    ('depend', 'VBG'),
#    ('depending', 'VBG'),
#    ('dieing', 'VBG'),
#    ('doing', 'VBG'),
#    ('drop', 'VBG'),
#    ('droping', 'VBG'),
#    ('dying', 'VBG'),
#    ('eat', 'VBG'),
#    ('eating', 'VBG'),
#    ('feed', 'VBG'),
#    ('find', 'VBG'),
#    ('following', 'VBG'),
#    ('form', 'VBG'),
#    ('gain', 'VBG'),
#    ('go', 'VBG'),
#    ('grow', 'VBG'),
#    ('happen', 'VBG'),
#    ('happening', 'VBG'),
#    ('hurting', 'VBG'),
#    ('involve', 'VBG'),
#    ('know', 'VBG'),
#    ('knowing', 'VBG'),
#    ('leave', 'VBG'),
#    ('live', 'VBG'),
#    ('living', 'VBG'),
#    ('look', 'VBG'),
#    ('loosing', 'VBG'),
#    ('lose', 'VBG'),
#    ('losing', 'VBG'),
#    ('make', 'VBG'),
#    ('mean', 'VBG'),
#    ('meaning', 'VBG'),
#    ('move', 'VBG'),
#    ('moving', 'VBG'),
#    ('need', 'VBG'),
#    ('occur', 'VBG'),
#    ('pass', 'VBG'),
#    ('prompt', 'VBG'),
#    ('provide', 'VBG'),
#    ('providing', 'VBG'),
#    ('raising', 'VBG'),
#    ('realizing', 'VBG'),
#    ('receiving', 'VBG'),
#    ('release', 'VBG'),
#    ('resulting', 'VBG'),
#    ('reverse', 'VBG'),
#    ('rising', 'VBG'),
#    ('run', 'VBG'),
#    ('screw', 'VBG'),
#    ('see', 'VBG'),
#    ('spring', 'VBG'),
#    ('starting', 'VBG'),
#    ('suffer', 'VBG'),
#    ('take', 'VBG'),
#    ('think', 'VBG'),
#    ('throw', 'VBG'),
#    ('travel', 'VBG'),
#    ('turn', 'VBG'),
#    ('turning', 'VBG'),
#    ('understand', 'VBG'),
#    ('watch', 'VBG'),
#    ('work', 'VBG')}),
#  (('number', 'NN'),
#   {('act', 'NN'),
#    ('air', 'NN'),
#    ('answer', 'NN'),
#    ('area', 'NN'),
#    ('bit', 'NN'),
#    ('case', 'NN'),
#    ('cause', 'NN'),
#    ('change', 'NN'),
#    ('component', 'NN'),
#    ('country', 'NN'),
#    ('course', 'NN'),
#    ('earth', 'NN'),
#    ('event', 'NN'),
#    ('example', 'NN'),
#    ('face', 'NN'),
#    ('factor', 'NN'),
#    ('figure', 'NN'),
#    ('force', 'NN'),
#    ('function', 'NN'),
#    ('globe', 'NN'),
#    ('go', 'NN'),
#    ('home', 'NN'),
#    ('humans', 'NN'),
#    ('job', 'NN'),
#    ('kind', 'NN'),
#    ('line', 'NN'),
#    ('man', 'NN'),
#    ('map', 'NN'),
#    ('mix', 'NN'),
#    ('mixture', 'NN'),
#    ('moment', 'NN'),
#    ('move', 'NN'),
#    ('movement', 'NN'),
#    ('name', 'NN'),
#    ('number', 'NN'),
#    ('part', 'NN'),
#    ('pattern', 'NN'),
#    ('piece', 'NN'),
#    ('place', 'NN'),
#    ('problem', 'NN'),
#    ('reason', 'NN'),
#    ('region', 'NN'),
#    ('result', 'NN'),
#    ('routine', 'NN'),
#    ('section', 'NN'),
#    ('share', 'NN'),
#    ('side', 'NN'),
#    ('situation', 'NN'),
#    ('space', 'NN'),
#    ('spot', 'NN'),
#    ('state', 'NN'),
#    ('strength', 'NN'),
#    ('turn', 'NN'),
#    ('turning', 'NN'),
#    ('type', 'NN'),
#    ('use', 'NN'),
#    ('variety', 'NN'),
#    ('walk', 'NN'),
#    ('walking', 'NN'),
#    ('while', 'NN'),
#    ('world', 'NN')}),
#  (('passage', 'NNS'), {('passage', 'NNS'), ('passages', 'NNS')}),
#  (('messing', 'VBG'), {('mess', 'VBG'), ('messing', 'VBG')}),
#  (('work', 'NN'), {('work', 'NN')}),
#  (('ocors', 'NNS'), {('ocors', 'NNS')}),
#  (('harm', 'VB'), {('harm', 'VB')}),
#  ...]
