# %%
from textblob import TextBlob
import numpy as np
from gensim import matutils
from numpy import random

from Metrics import rpf1a
from Rpfa import rpfa, weighted_mean_rpfa
from BrattEssay import load_bratt_essays
from ProcessEssays import process_sentences
from Decorators import timeit, memoize

from WindowSplitter import split_into_windows

from nltk import PorterStemmer
from stanford_parser import parser
import MontyLingua

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
parser = MontyLingua.MontyLingua(trace_p=0)
# Out:
# ****** MontyLingua v.2.1 ******
# ***** by hugo@media.mit.edu *****
# Lemmatiser OK!
# Custom Lexicon Found! Now Loading!
# Fast Lexicon Found! Now Loading!
# Lexicon OK!
# LexicalRuleParser OK!
# ContextualRuleParser OK!
# Commonsense OK!
# Semantic Interpreter OK!
# Loading Morph Dictionary!
# *********************************

# %%
""" Settings """

MIN_SENTENCE_FREQ   = 0       #i.e. df. Note this is calculated BEFORE creating windows
REMOVE_INFREQUENT   = False    # if false, infrequent words are replaced with "INFREQUENT"
SPELLING_CORRECT    = True
STEM                = False
REPLACE_NUMS        = True    # 1989 -> 0000, 10 -> 00
MIN_SENTENCE_LENGTH = 3
REMOVE_STOP_WORDS   = False
REMOVE_PUNCTUATION  = True

# %%
@timeit
def load_sentences(essays):
    return process_sentences(essays, 
                              min_df = MIN_SENTENCE_FREQ, 
                              remove_infrequent = REMOVE_INFREQUENT,
                              spelling_correct = SPELLING_CORRECT, 
                              replace_nums = REPLACE_NUMS, 
                              stem=STEM,
                              remove_stop_words=REMOVE_STOP_WORDS,
                              remove_punctuation=REMOVE_PUNCTUATION)
# load from disk
essays = load_bratt_essays()
lbl_sentences = load_sentences(essays)
# Out:
# Results Dir: /Users/simon.hughes/Google Drive/Phd/Results/
# Data Dir:    /Users/simon.hughes/Google Drive/Phd/Data/
# Root Dir:    /Users/simon.hughes/GitHub/NlpResearch/
# Public Data: /Users/simon.hughes/GitHub/NlpResearch/Data/PublicDatasets/
# 297 files found
# 297 essays processed
# timeit: load_sentences(...) took 16.41 secs

# %%
sentences = []
for lbl_sentence in lbl_sentences:
    wds, tags = zip(*lbl_sentence)
    sentences.append(" ".join(wds))
print "done"
# Out:
# done

# %%
outp = parser.jist_predicates ("the coral's physical state can make it bleached.")
outp
# Out:
# (NX the/DT coral/NN 's/POS physical/JJ state/NN NX) (VX can/MD make/VB VX) (NX it/PRP NX) (NX bleached/JJ NX) ./.
# [['("make" "coral \'s physical state" "it" "bleached")']]

# %%
lst = []
for sentence in sentences[:5]:
    vsoos = parser.jist_predicates(sentence)
    lst.append((sentence, vsoos))
# Out:
# the/DT (NX coral/JJ NX) (VX bleaching/VBG is/VBZ VX) (NX a/DT different/JJ type/NN NX) (NX they/PRP NX) (VX are/VBP VX) (NX bleached/JJ NX) and/CC (NX coral/JJ NX) (VX bleaching/VBG VX)
# (NX the/DT bleached/JJ is/NNS NX) (NX plain/JJ white/JJ NX)
# (NX the/DT coral/JJ polyps/NNS NX) (VX give/VBP VX) (NX different/JJ colors/NNS NX)
# (NX the/DT skeleton/NN NX) (VX protects/VBZ VX) (NX the/DT body/NN NX) of/IN (NX polyp/NN NX)
# (NX the/DT process/NN NX) (VX requires/VBZ VX) (NX both/DT carbon/NN dioxide/NN and/CC release/NN oxygen/NN NX)

# %%
for sen, vso in lst:
    print sen
    print vso
    print ""
# Out:
# the coral bleaching is a different type they are bleached and coral bleaching
# [['("be" "coral" "different type" "they")', '("be" "they" "bleached")', '("bleach" "coral" )']]
#
# the bleached is plain white
# [[]]
#
# the coral polyps give different colors
# [['("give" "coral polyp" "different color")']]
#
# the skeleton protects the body of polyp
# [['("protect" "skeleton" "body" "of polyp")']]
#
# the process requires both carbon dioxide and release oxygen
# [['("require" "process" "carbon dioxide and release oxygen")']]

# %%
preds = parser.jist_predicates("I eat potatoes and I like to eat oranges.")
print preds
preds[0][0], type(preds[0][0])
# Out:
# (NX I/PRP NX) (VX eat/VBP VX) (NX potatoes/NNS NX) and/CC (NX I/PRP NX) like/RB to/TO (VX eat/VB VX) (NX oranges/NNS NX) ./.
# [['("eat" "I" "potato")', '("eat" "" "orange")']]
# ('("eat" "I" "potato")', str)

# %%
parser.parse_pred_arg(preds[0][0])
# Out:
# ['eat', 'I', 'potato']

# %%
jist = parser.jist("the coral's physical state can make it bleached.")
parser.pp_info(jist)
# Out:
# (NX the/DT coral/NN 's/POS physical/JJ state/NN NX) (VX can/MD make/VB VX) (NX it/PRP NX) (NX bleached/JJ NX) ./.
#
#
#    SENTENCE #1 DIGEST:
#
#          adj_phrases: ['bleached']
#   adj_phrases_tagged: ['bleached/JJ']
#            modifiers: ['physical', 'bleached']
#     modifiers_tagged: ['physical/JJ', 'bleached/JJ']
#         noun_phrases: ["coral 's physical state", 'it']
#  noun_phrases_tagged: ["coral/NN 's/POS physical/JJ state/NN", 'it/PRP']
# parameterized_predicates: [[['make', []], ["coral 's physical state", ['determiner=the']], ['it', []], ['bleached', []]]]
#         prep_phrases: []
#  prep_phrases_tagged: []
#  verb_arg_structures: [['can/MD make/VB', "the/DT coral/NN 's/POS physical/JJ state/NN", ['it/PRP', 'bleached/JJ']]]
# verb_arg_structures_concise: ['("make" "coral \'s physical state" "it" "bleached")']
#         verb_phrases: ['make']
#  verb_phrases_tagged: ['make/VB']

# %%
tokenized = parser.tokenize("I can't eat lemons, but I can eat some oranges!")
print "Tokenized:\n", tokenized, type(tokenized)
tagged = parser.tag_tokenized(tokenized)
print
print "Tagged:\n", tagged, type(tagged)
print
chunked = parser.chunk_tagged(tagged)
print "Chunked:\n", chunked, type(chunked)
print
# Out:
# Tokenized:
# I can't eat lemons , but I can eat some oranges ! <type 'str'>
#
# Tagged:
# I/PRP can't/MD eat/VB lemons/NNS ,/, but/CC I/PRP can/MD eat/VB some/DT oranges/NNS !/. <type 'str'>
#
# Chunked:
# (NX I/PRP NX) (VX can't/MD eat/VB VX) (NX lemons/NNS NX) ,/, but/CC (NX I/PRP NX) (VX can/MD eat/VB VX) (NX some/DT oranges/NNS NX) !/. <type 'str'>

# %%
for chnk in chunked.split("("):
    if len(chnk.strip()) > 0:
        ix = chnk.index(")")
        print "(" + chnk[:ix+1]
# Out:
# (NX I/PRP NX)
# (VX can't/MD eat/VB VX)
# (NX lemons/NNS NX)
# (NX I/PRP NX)
# (VX can/MD eat/VB VX)
# (NX some/DT oranges/NNS NX)

# %%
parser.extract_info(chunked)
# Out:
# (NX I/PRP NX) (VX can't/MD eat/VB VX) (NX lemons/NNS NX) ,/, but/CC (NX I/PRP NX) (VX can/MD eat/VB VX) (NX some/DT oranges/NNS NX) !/.
# {'adj_phrases': [],
#  'adj_phrases_tagged': [],
#  'modifiers': [],
#  'modifiers_tagged': [],
#  'noun_phrases': ['I', 'lemons', 'I', 'oranges'],
#  'noun_phrases_tagged': ['I/PRP', 'lemons/NNS', 'I/PRP', 'oranges/NNS'],
#  'parameterized_predicates': [[['eat', []], ['I', []], ['lemon', ['plural']]],
#   [['eat', []], ['I', []], ['orange', ['determiner=some', 'plural']]]],
#  'prep_phrases': [],
#  'prep_phrases_tagged': [],
#  'verb_arg_structures': [["can't/MD eat/VB", 'I/PRP', ['lemons/NNS']],
#   ['can/MD eat/VB', 'I/PRP', ['oranges/NNS']]],
#  'verb_arg_structures_concise': ['("eat" "I" "lemon")',
#   '("eat" "I" "orange")'],
#  'verb_phrases': ['eat', 'eat'],
#  'verb_phrases_tagged': ['eat/VB', 'eat/VB']}

# %%
class VSO(object):
    def __init__(self, pred_arg, sentence):
        self.verb = pred_arg[0]
        self.subj = pred_arg[1]
        if len(pred_arg) > 2 and len(pred_arg[2]) > 0:
            self.objs = pred_arg[2:]
        else:
            self.objs = []
        self.pred_arg = pred_arg
        self.sentence = sentence
    
    def is_triple(self):
        return len(self.subj) > 0 and len(self.verb) > 0 and len (self.objs) > 0
    
    def has_SV(self):
        return len(self.subj) > 0 and len(self.verb) > 0

    def has_VO(self):
        return len(self.verb) > 0 and len (self.objs) > 0
    
    def has_SO(self):
        return len(self.subj) > 0 and len (self.objs) > 0
    
    def __repr__(self):
        return "S(%s) V(%s) O(%s)" % (self.subj, self.verb, ",".join(self.objs)) 

    def __hash__(self):
        return str(self)
    
    def __eq__(self, other):
        return str(self) == str(other)
    
    def to_SV(self):
        return VSO([self.verb, self.subj], self.sentence)
    
    def to_VO(self):
        return VSO([self.verb, ""] + self.objs,  self.sentence)
    
    def to_SO(self):
        return VSO(["", self.subj] + self.objs,  self.sentence)

def extract_predicates(sentence):
    preds = parser.jist_predicates(sentence)
    if len(preds) >= 2:
        preds = filter(lambda l: len(l) > 0, preds)
    
    retVals = []    
    for sentence_predicates in preds:
        for sp in sentence_predicates:
            vsoos = parser.parse_pred_arg(sp)
            if len(vsoos) > 0:
                retVals.append(VSO(vsoos, sentence))
    return retVals

sent = "I ate oranges and pears."
# also lemmatizes the verbs, which is nice
print extract_predicates(sent)
# Out:
# (NX I/PRP NX) (VX ate/VBD VX) (NX oranges/NNS and/CC pears/NNS NX) ./.
# [S(I) V(eat) O(orange and pear)]

# %%
from IterableFP import flatten, compact

vsoos = map(extract_predicates, sentences)
fvsoos = flatten(vsoos)
# Out:
# the/DT (NX coral/JJ NX) (VX bleaching/VBG is/VBZ VX) (NX a/DT different/JJ type/NN NX) (NX they/PRP NX) (VX are/VBP VX) (NX bleached/JJ NX) and/CC (NX coral/JJ NX) (VX bleaching/VBG VX)
# (NX the/DT bleached/JJ is/NNS NX) (NX plain/JJ white/JJ NX)
# (NX the/DT coral/JJ polyps/NNS NX) (VX give/VBP VX) (NX different/JJ colors/NNS NX)
# (NX the/DT skeleton/NN NX) (VX protects/VBZ VX) (NX the/DT body/NN NX) of/IN (NX polyp/NN NX)
# (NX the/DT process/NN NX) (VX requires/VBZ VX) (NX both/DT carbon/NN dioxide/NN and/CC release/NN oxygen/NN NX)
# (NX they/PRP NX) (VX know/VBP VX) about/IN (NX changes/NNS NX) (VX wind/VBP VX) (NX ocean/NN currents/NNS and/CC temperature/NN NX)
# (NX this/DT event/NN NX) (VX occurred/VBD VX) in/IN (NX 0000/CD NX)
# (NX blue/JJ color/NN NX) (VX is/VBZ VX) (NX water/NN temperature/NN NX)
# (NX red/JJ color/NN NX) (VX is/VBZ VX) (NX trade/NN wind/NN strength/NN NX)
# ...

# %%
from collections import Counter

counter = Counter(map(str,filter(lambda vso: vso.is_triple(),fvsoos)))
counter.most_common(50)
# Out:
# [('S(coral) V(bleach) O(rate)', 173),
#  ('S(rate) V(vary) O(at different time)', 75),
#  ('S(tiny animal) V(call) O(polyp)', 14),
#  ('S(coral) V(be when) O(coral)', 13),
#  ('S(coral) V(vary) O(at different time)', 13),
#  ('S(coral) V(lose) O(its color)', 12),
#  ('S(coral) V(be) O(sensitive,to ocean salinity)', 12),
#  ('S(algae) V(live) O(within coral polyp)', 12),
#  ('S(that) V(cause) O(coral)', 10),
#  ('S(who) V(drop) O(anchor)', 10),
#  ('S(sugar) V(make) O(by algae)', 9),
#  ('S(coral) V(be) O(phenomenon,in which coral)', 9),
#  ('S(few year) V(trade) O(wind)', 8),
#  ('S(coral) V(lose) O(their color)', 8),
#  ('S(salinity) V(threaten) O(balance,necessary)', 8),
#  ('S(coral) V(be) O(sensitive)', 8),
#  ('S(what) V(be) O(coral)', 8),
#  ('S(delicate balance) V(keep) O(coral,healthy)', 8),
#  ('S(disruption) V(threaten) O(delicate balance)', 7),
#  ('S(rate) V(vary) O(at different time,because it)', 7),
# ...

# %%
""" Subject Verb Pairs """
filtered = filter(lambda vso: vso.has_SV(), fvsoos)
sv_counter = Counter(map(lambda svo: str(svo.to_SV()),  filtered))
sv_counter.most_common(35)
# Out:
# [('S(coral) V(bleach) O()', 459),
#  ('S(coral) V(be) O()', 193),
#  ('S(rate) V(vary) O()', 173),
#  ('S(there) V(be) O()', 137),
#  ('S(it) V(be) O()', 83),
#  ('S(coral) V(happen) O()', 43),
#  ('S(coral) V(need) O()', 43),
#  ('S(coral) V(lose) O()', 39),
#  ('S(coral) V(vary) O()', 36),
#  ('S(they) V(be) O()', 35),
#  ('S(water) V(be) O()', 34),
#  ('S(that) V(be) O()', 29),
#  ('S(coral) V(get) O()', 27),
#  ('S(which) V(be) O()', 27),
#  ('S(coral) V(be when) O()', 27),
#  ('S(they) V(have) O()', 24),
#  ('S(it) V(say) O()', 24),
#  ('S(temperature) V(be) O()', 24),
#  ('S(coral) V(turn) O()', 24),
#  ('S(coral) V(have) O()', 23),
#  ('S(coral) V(die) O()', 22),
#  ('S(coral) V(occur) O()', 22),
#  ('S(coral) V(live) O()', 22),
#  ('S(that) V(make) O()', 21),
#  ('S(different time) V(be) O()', 21),
#  ('S(that) V(affect) O()', 21),
#  ('S(it) V(cause) O()', 21),
#  ('S(water temperature) V(increase) O()', 20),
#  ('S(they) V(die) O()', 20),
#  ('S(that) V(live) O()', 20),
# ...

# %%
""" Verb Object Pairs """
filtered = filter(lambda vso: vso.has_VO(), fvsoos)
vo_counter = Counter(map(lambda svo: str(svo.to_VO()),  filtered))
vo_counter.most_common(25)
# Out:
# [('S() V(bleach) O(rate)', 181),
#  ('S() V(vary) O(at different time)', 101),
#  ('S() V(cause) O(coral)', 37),
#  ('S() V(turn) O(white)', 30),
#  ('S() V(keep) O(coral,healthy)', 23),
#  ('S() V(lose) O(its color)', 20),
#  ('S() V(drop) O(anchor)', 20),
#  ('S() V(call) O(polyp)', 19),
#  ('S() V(be) O(coral)', 18),
#  ('S() V(walk) O(on reef)', 17),
#  ('S() V(be) O(bleached)', 17),
#  ('S() V(lose) O(color)', 16),
#  ('S() V(lose) O(their color)', 16),
#  ('S() V(be) O(what)', 16),
#  ('S() V(live) O(in colony)', 15),
#  ('S() V(be when) O(coral)', 15),
#  ('S() V(be) O(sensitive,to ocean salinity)', 14),
#  ('S() V(affect) O(coral)', 14),
#  ('S() V(live) O(within coral polyp)', 13),
#  ('S() V(be) O(sensitive)', 12),
#  ('S() V(stay) O(in one place)', 12),
#  ('S() V(threaten) O(balance,necessary)', 12),
#  ('S() V(reverse) O(direction)', 12),
#  ('S() V(make) O(by algae)', 12),
#  ('S() V(trade) O(wind)', 12)]

# %%
""" Subject Object Pairs """
filtered = filter(lambda vso: vso.has_SO(), fvsoos)
so_counter = Counter(map(lambda svo: str(svo.to_SO()),  filtered))
so_counter.most_common(25)
# Out:
# [('S(coral) V() O(rate)', 173),
#  ('S(rate) V() O(at different time)', 76),
#  ('S(that) V() O(coral)', 26),
#  ('S(coral) V() O(coral)', 23),
#  ('S(coral) V() O(at different time)', 19),
#  ('S(tiny animal) V() O(polyp)', 14),
#  ('S(it) V() O(coral)', 14),
#  ('S(coral) V() O(its color)', 13),
#  ('S(coral) V() O(sensitive,to ocean salinity)', 12),
#  ('S(algae) V() O(within coral polyp)', 12),
#  ('S(coral) V() O(it)', 12),
#  ('S(coral) V() O(their color)', 12),
#  ('S(it) V() O(that coral)', 11),
#  ('S(coral) V() O(algae)', 11),
#  ('S(what) V() O(coral)', 10),
#  ('S(who) V() O(anchor)', 10),
#  ('S(which) V() O(coral)', 10),
#  ('S(coral) V() O(color)', 9),
#  ('S(that) V() O(in 0000)', 9),
#  ('S(I) V() O(it)', 9),
#  ('S(coral) V() O(white)', 9),
#  ('S(sugar) V() O(by algae)', 9),
#  ('S(coral) V() O(phenomenon,in which coral)', 9),
#  ('S(few year) V() O(wind)', 9),
#  ('S(i) V() O(coral)', 8)]

# %%
""" Subjects Only """
subj_counter = Counter(map(lambda svo: svo.subj, fvsoos))
subj_counter.most_common(25)
# Out:
# [('coral', 1281),
#  ('', 1256),
#  ('it', 509),
#  ('they', 285),
#  ('that', 230),
#  ('rate', 197),
#  ('there', 152),
#  ('algae', 112),
#  ('which', 100),
#  ('wind', 85),
#  ('water', 83),
#  ('temperature', 76),
#  ('I', 74),
#  ('water temperature', 59),
#  ('trade wind', 57),
#  ('coral reef', 49),
#  ('i', 47),
#  ('salinity', 41),
#  ('what', 40),
#  ('you', 40),
#  ('photosynthesis', 34),
#  ('different time', 31),
#  ('zooxanthella', 26),
#  ('who', 23),
#  ('ocean', 22)]

# %%
""" Verbs Only """
verb_counter = Counter(compact(map(lambda svo: svo.verb, fvsoos)))
verb_counter.most_common(25)
# Out:
# [('be', 1044),
#  ('bleach', 580),
#  ('vary', 270),
#  ('cause', 180),
#  ('make', 156),
#  ('have', 138),
#  ('happen', 137),
#  ('live', 133),
#  ('die', 127),
#  ('affect', 124),
#  ('get', 123),
#  ('change', 115),
#  ('need', 110),
#  ('lose', 91),
#  ('increase', 78),
#  ('occur', 74),
#  ('drop', 69),
#  ('go', 65),
#  ('turn', 64),
#  ('do', 64),
#  ('depend', 59),
#  ('become', 59),
#  ('give', 57),
#  ('survive', 55),
#  ('threaten', 53)]

# %%
""" Objects Only """
obj_counter = Counter(flatten(map(lambda svo: svo.objs, fvsoos)))
obj_counter.most_common(25)
# Out:
# [('coral', 298),
#  ('at different time', 228),
#  ('it', 208),
#  ('rate', 205),
#  ('that', 77),
#  ('of coral', 73),
#  ('algae', 67),
#  ('white', 64),
#  ('they', 59),
#  ('color', 53),
#  ('temperature', 51),
#  ('bleached', 51),
#  ('which', 49),
#  ('of photosynthesis', 47),
#  ('healthy', 46),
#  ('in 0000', 46),
#  ('in ocean', 45),
#  ('sensitive', 43),
#  ('photosynthesis', 42),
#  ('water', 40),
#  ('them', 38),
#  ('because it', 38),
#  ('lot', 36),
#  ('what', 36),
#  ('water temperature', 36)]

# %%
""" Subject + Objects Merged """
obj_counter = Counter(compact(flatten(map(lambda svo: svo.objs + [svo.subj], fvsoos))))
obj_counter.most_common(25)
# Out:
# [('coral', 1579),
#  ('it', 717),
#  ('rate', 402),
#  ('they', 344),
#  ('that', 307),
#  ('at different time', 228),
#  ('algae', 179),
#  ('there', 178),
#  ('which', 149),
#  ('temperature', 127),
#  ('water', 123),
#  ('wind', 118),
#  ('water temperature', 95),
#  ('I', 90),
#  ('trade wind', 83),
#  ('photosynthesis', 76),
#  ('what', 76),
#  ('of coral', 73),
#  ('coral reef', 70),
#  ('white', 69),
#  ('color', 61),
#  ('you', 54),
#  ('bleached', 54),
#  ('them', 51),
#  ('salinity', 51)]

# %%
from py_word2vec import Word2Vec

tokenized_sentences = map(lambda s: s.split(" "), sentences)
word2vec = Word2Vec(tokenized_sentences, size=10, window=5, workers=8)
sorted(word2vec.vocab.keys())
# Out:
# 2014-08-23 21:19:04,501 : INFO : 'pattern' package found; utils.lemmatize() is available for English
# 2014-08-23 21:19:04,517 : INFO : collecting all words and their counts
# 2014-08-23 21:19:04,517 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2014-08-23 21:19:04,529 : INFO : collected 1793 word types from a corpus of 39786 words and 2725 sentences
# 2014-08-23 21:19:04,530 : INFO : total 659 word types after removing those with count<5
# 2014-08-23 21:19:04,530 : INFO : constructing a huffman tree from 659 words
# 2014-08-23 21:19:04,545 : INFO : built huffman tree with maximum node depth 13
# 2014-08-23 21:19:04,546 : INFO : training model with 8 workers on 659 vocabulary and 10 features
# 2014-08-23 21:19:04,576 : INFO : reached the end of input; waiting to finish 13 outstanding jobs
# 2014-08-23 21:19:04,604 : INFO : training on 37931 words took 0.1s, 665805 words/s
# ['0',
#  '00',
#  '0000',
#  '5f',
#  '85f',
#  'a',
#  'able',
#  'about',
# ...

# %%
from gensim.models.word2vec import Word2Vec as gsWord2Vec

gsword2vec = gsWord2Vec(tokenized_sentences, size=50, window=5, workers=8, hs=0, sg=1, negative=5)
sorted(gsword2vec.vocab.keys())
# Out:
# 2014-08-23 21:31:08,529 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2014-08-23 21:31:08,530 : INFO : collecting all words and their counts
# 2014-08-23 21:31:08,530 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2014-08-23 21:31:08,544 : INFO : collected 1793 word types from a corpus of 39786 words and 2725 sentences
# 2014-08-23 21:31:08,545 : INFO : total 659 word types after removing those with count<5
# 2014-08-23 21:31:08,545 : INFO : constructing a table with noise distribution from 659 words
# 2014-08-23 21:31:33,097 : INFO : resetting layer weights
# 2014-08-23 21:31:33,102 : INFO : training model with 8 workers on 659 vocabulary and 50 features, using 'skipgram'=1 'hierarchical softmax'=0 'subsample'=0 and 'negative sampling'=5
# 2014-08-23 21:31:33,172 : INFO : reached the end of input; waiting to finish 4 outstanding jobs
# 2014-08-23 21:31:33,191 : INFO : training on 37931 words took 0.1s, 432651 words/s
# ...

# %%
from numpy.linalg import norm
from Decorators import memoize

def mean_vector(lst_vectors):
    if len(lst_vectors) == 0:
        return np.zeros(gsword2vec.layer1_size)
    sum_vec = np.asarray(lst_vectors).sum(axis=0)
    length = norm(sum_vec)
    if length == 0:
        return np.zeros(gsword2vec.layer1_size)
    return sum_vec / length

@memoize
def vectorize(phrase):
    splt = phrase.split(" ")
    vecs = []
    for item in splt:
        if item in gsword2vec.vocab:
            v = gsword2vec[item]
            length = norm(v)
            if length == 0:
                vecs.append(np.zeros(gsword2vec.layer1_size))
            else:
                vecs.append(v / length)
    return mean_vector(vecs)

def vectorize_triple(vso):
    vvect = vectorize(vso.verb)
    svect = vectorize(vso.subj)
    ovecs = []
    for obj in vso.objs:
        v = vectorize(obj)
        ovecs.append(v)
    ovect = mean_vector(ovecs)
    return np.concatenate((vvect,svect,ovect))

# %%
from datetime import datetime
print datetime.now()
# Out:
# 2014-08-23 21:48:03.940636

# %%
triples = filter(lambda vso: vso.is_triple(),fvsoos)
vectors = map(vectorize_triple, triples)
vectors = np.asarray(vectors, dtype=np.float64)

# %%
from sklearn.cluster import AffinityPropagation, KMeans

clusterer = AffinityPropagation()
labels = clusterer.fit_predict(vectors)

# %%
from collections import defaultdict

def group_clusters(cluster_labels, examples):
    clusters = defaultdict(list)
    clusters_tags = defaultdict(lambda : defaultdict(int))
    for i, lbl in enumerate(cluster_labels):
        clusters[lbl].append(examples[i])
    srtd = map(lambda v: sorted(v, key = lambda item: str(item)), clusters.values())
    # returns a list of lists of clustered documents, and the counts of the cluster tags
    return clusters

# %%
clusters = group_clusters(labels, triples)

# %%
print "#Clusters", len(clusters.values()), "#Triples", len(triples), "\n"
padding = 30

def print_triple_cluster(cluster):
    for vso in sorted(cluster, key = lambda cl: str(cl)):
        print vso.subj.ljust(padding), vso.verb.ljust(padding), str(vso.objs)

for i, cl in clusters.items():
    print i
    print_triple_cluster(cl)
    print ""
# Out:
# #Clusters 138 #Triples 4020
#
# 0
# algae                          not survive                    ['in harsh condition']
# case                           occur                          ['in 0000']
# cause                          result                         ['in 00', 'of coral death']
# degree photosynthesis          happen                         ['which']
# drastic                        happen                         ['in 0000']
# event                          occur                          ['in 0000']
# event                          occur                          ['in 0000']
# event                          result                         ['in 00', 'of coral reef']
# graph                          show                           ['in 0000']
# i                              believe                        ['that temperature']
# that                           happen                         ['in 0000']
# that                           happen                         ['in 0000']
# ...

# %%
""" K Means (30) """
kmclusterer = KMeans(n_clusters=30)
kmlabels = kmclusterer.fit_predict(vectors)

# %%
kmclusters = group_clusters(kmlabels, triples)
print "#Clusters", len(kmclusters.values()), "#Triples", len(triples), "\n"

for i, cl in kmclusters.items():
    print i, len(cl)
    print_triple_cluster(cl)
    print ""
# Out:
# #Clusters 30 #Triples 4020
#
# 0 104
# algae                          be                             ['because they']
# algae                          die                            ['because they']
# area                           be                             ['on coast']
# atlantic ocean                 have                           ['many']
# change coral                   color                          ['because it']
# color                          be                             ['because of different type', 'of algae']
# coral polyp                    give                           ['different color']
# coral polyp                    have                           ['different size', 'they']
# coral reef                     be                             ['different']
# different stressor             happen                         ['at different time', 'if coral']
# different thing                happen                         ['at different time']
# ...

# %% [raw]
# TODO
#
# For each code, group the sentences for that code. Then extract the VSO triples and examine
# Remove triples with coreferences (it, that, etc). Then look for ones that consistently predict other ones (then compute page rank for triples to determine centrality?)
# ** Use Freebase on extracted entities **
# Repeat the word2vec cluster concept, but using pre-trained vectors
