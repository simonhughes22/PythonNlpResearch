# %%
# %load_ext autoreload

# %%
from BrattEssay import load_bratt_essays
from collections import defaultdict
from IterableFP import flatten
from Settings import Settings

#target_folder = "Training"
settings = Settings()
#root_folder = settings.data_directory + "CoralBleaching/Thesis_Dataset/"
#training_folder = root_folder + target_folder + "/"

#essays = load_bratt_essays(training_folder)
# Out:
# Results Dir: /Users/simon.hughes/Google Drive/Phd/Results/
# Data Dir:    /Users/simon.hughes/Google Drive/Phd/Data/
# Root Dir:    /Users/simon.hughes/GitHub/NlpResearch/
# Public Data: /Users/simon.hughes/GitHub/NlpResearch/Data/PublicDatasets/

# %%
#from https://github.com/pytorch/examples/blob/master/word_language_model/model.py
import torch.nn as nn
from torch.autograd import Variable

class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ntarget, ninp, nhid, nlayers):
        super(RNNModel, self).__init__()
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, bias=False)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, bias=False)
        self.decoder = nn.Linear(nhid, ntarget) # changed from ntoken

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.encoder(input)
        output, hidden = self.rnn(emb, hidden)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters()).data
        if self.rnn_type == 'LSTM':
            return (Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()),
                    Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()))
        else:
            return Variable(weight.new(self.nlayers, bsz, self.nhid).zero_())

# %%
class Args(object):
    def __init__(self):
        self.model = "GRU"
        self.emsize = 100
        self.nhid = 100
        self.nlayers = 1 # default 2
        self.lr = 20
        self.clip = 0.5
        self.epochs = 200
        self.batch_size = 20
        # sequence length, what does this mean ???
        self.bptt = 30
        self.seed = 1111
        self.cuda = False  # Throws error during data load
        self.log_interval=50
        self.save = "/Users/simon.hughes/data/pytorch/models/rq1_rnn.pt"
        
args = Args()

# %%
import time
import math
import torch
import torch.nn as nn
from torch.autograd import Variable

# Set the random seed manually for reproducibility.
torch.manual_seed(args.seed)
if torch.cuda.is_available():
    if not args.cuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")
    else:
        print("CUDA Enabled")
        torch.cuda.manual_seed(args.seed)
else:
    print("CUDA is not available")
# Out:
# WARNING: You have a CUDA device, so you should probably run with --cuda

# %%
import os
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)

class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        self.labels_dictionary = Dictionary()
        self.train = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Training/inputs.txt", self.dictionary)
        self.train_lbls = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Training/output_most_freq.txt", self.labels_dictionary)
        self.valid = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Test/inputs.txt", self.dictionary)
        self.valid_lbls = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Test/output_most_freq.txt", self.labels_dictionary)
       
    def tokenize(self, path, dictionary):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r') as f:
            tokens = 0
            for line in f:
                words = line.split() + ['<eos>']
                tokens += len(words)
                for word in words:
                    dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r') as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    ids[token] = dictionary.word2idx[word]
                    token += 1

        return ids

# %%
corpus = Corpus()

def batchify(data, bsz):
    nbatch = data.size(0) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous()
    if args.cuda:
        data = data.cuda()
    return data

eval_batch_size = 10
train_data = batchify(corpus.train, args.batch_size)
train_data_lbls = batchify(corpus.train_lbls, args.batch_size)

val_data = batchify(corpus.valid, eval_batch_size)
val_data_lbls = batchify(corpus.valid_lbls, eval_batch_size)

# %% [markdown]
# ## Build The Model

# %%
ntokens = len(corpus.dictionary)
nlabels = len(corpus.labels_dictionary)
model = RNNModel(args.model, ntokens, nlabels, args.emsize, args.nhid, args.nlayers)
if args.cuda:
    model.cuda()

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train The Model

# %%
def clip_gradient(model, clip):
    """Computes a gradient clipping coefficient based on gradient norm."""
    totalnorm = 0
    for p in model.parameters():
        modulenorm = p.grad.data.norm()
        totalnorm += modulenorm ** 2
    totalnorm = math.sqrt(totalnorm)
    return min(1, clip / (totalnorm + 1e-6))


def repackage_hidden(h):
    """Wraps hidden states in new Variables, to detach them from their history."""
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)


def get_batch(source, label_source, i, evaluation=False):
    seq_len = min(args.bptt, len(source) - 1 - i)
    data = Variable(source[i:i+seq_len], volatile=evaluation)
    target = Variable(label_source[i:i+seq_len].view(-1))
    return data, target

def evaluate(data_source, label_source):
    total_loss = 0
    ntokens = len(corpus.dictionary)
    nlabels = len(corpus.labels_dictionary)
    hidden = model.init_hidden(eval_batch_size)
    for i in range(0, data_source.size(0) - 1, args.bptt):
        data, targets = get_batch(data_source, label_source, i, evaluation=True)
        output, hidden = model(data, hidden)
        output_flat = output.view(-1, nlabels)
        total_loss += len(data) * criterion(output_flat, targets).data
        hidden = repackage_hidden(hidden)
    return total_loss[0] / len(data_source)


def train():
    total_loss = 0
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    nlabels = len(corpus.labels_dictionary)
    hidden = model.init_hidden(args.batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, args.bptt)):
        data, targets = get_batch(train_data, train_data_lbls, i)
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, nlabels), targets)
        loss.backward()

        clipped_lr = lr * clip_gradient(model, args.clip)
        for p in model.parameters():
            p.data.add_(-clipped_lr, p.grad.data)

        total_loss += loss.data

        if batch % args.log_interval == 0 and batch > 0:
            cur_loss = total_loss[0] / args.log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args.bptt, lr,
                elapsed * 1000 / args.log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
# Loop over epochs.
lr = args.lr
prev_val_loss = None
for epoch in range(1, args.epochs+1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(val_data, val_data_lbls)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
            'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                       val_loss, math.exp(val_loss)))
    print('-' * 89)
    # Anneal the learning rate.
    if prev_val_loss and val_loss > prev_val_loss:
        lr /= 4
    prev_val_loss = val_loss

# Run on test data and save the model.
#test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training |')
print('=' * 89)
if args.save != '':
    with open(args.save, 'wb') as f:
        torch.save(model, f)
# Out:
# | epoch   1 |    50/  242 batches | lr 20.00 | ms/batch 20.79 | loss  3.13 | ppl    22.98
# | epoch   1 |   100/  242 batches | lr 20.00 | ms/batch 21.35 | loss  1.97 | ppl     7.18
# | epoch   1 |   150/  242 batches | lr 20.00 | ms/batch 21.97 | loss  1.15 | ppl     3.16
# | epoch   1 |   200/  242 batches | lr 20.00 | ms/batch 20.53 | loss  1.16 | ppl     3.18
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  5.67s | valid loss  3.00 | valid ppl    20.16
# -----------------------------------------------------------------------------------------
# | epoch   2 |    50/  242 batches | lr 20.00 | ms/batch 19.41 | loss  1.31 | ppl     3.71
# | epoch   2 |   100/  242 batches | lr 20.00 | ms/batch 19.67 | loss  2.00 | ppl     7.37
# | epoch   2 |   150/  242 batches | lr 20.00 | ms/batch 19.23 | loss  1.11 | ppl     3.02
# | epoch   2 |   200/  242 batches | lr 20.00 | ms/batch 19.09 | loss  1.24 | ppl     3.47
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  5.32s | valid loss  1.46 | valid ppl     4.33
# -----------------------------------------------------------------------------------------
# | epoch   3 |    50/  242 batches | lr 20.00 | ms/batch 20.01 | loss  2.02 | ppl     7.50
# | epoch   3 |   100/  242 batches | lr 20.00 | ms/batch 19.28 | loss  1.11 | ppl     3.02
# | epoch   3 |   150/  242 batches | lr 20.00 | ms/batch 19.14 | loss  1.16 | ppl     3.20
# | epoch   3 |   200/  242 batches | lr 20.00 | ms/batch 19.22 | loss  1.44 | ppl     4.20
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  5.35s | valid loss  4.84 | valid ppl   126.06
# -----------------------------------------------------------------------------------------
# | epoch   4 |    50/  242 batches | lr 5.00 | ms/batch 22.25 | loss  1.70 | ppl     5.47
# | epoch   4 |   100/  242 batches | lr 5.00 | ms/batch 22.77 | loss  1.26 | ppl     3.54
# | epoch   4 |   150/  242 batches | lr 5.00 | ms/batch 19.98 | loss  1.39 | ppl     4.02
# | epoch   4 |   200/  242 batches | lr 5.00 | ms/batch 20.09 | loss  1.46 | ppl     4.29
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  5.70s | valid loss  1.05 | valid ppl     2.87
# -----------------------------------------------------------------------------------------
# | epoch   5 |    50/  242 batches | lr 5.00 | ms/batch 20.16 | loss  1.16 | ppl     3.18
# | epoch   5 |   100/  242 batches | lr 5.00 | ms/batch 19.86 | loss  1.15 | ppl     3.14
# | epoch   5 |   150/  242 batches | lr 5.00 | ms/batch 21.20 | loss  1.15 | ppl     3.15
# | epoch   5 |   200/  242 batches | lr 5.00 | ms/batch 21.03 | loss  1.03 | ppl     2.80
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  5.68s | valid loss  0.95 | valid ppl     2.59
# -----------------------------------------------------------------------------------------
# | epoch   6 |    50/  242 batches | lr 5.00 | ms/batch 20.47 | loss  1.09 | ppl     2.97
# | epoch   6 |   100/  242 batches | lr 5.00 | ms/batch 20.63 | loss  1.03 | ppl     2.79
# | epoch   6 |   150/  242 batches | lr 5.00 | ms/batch 20.29 | loss  1.02 | ppl     2.78
# | epoch   6 |   200/  242 batches | lr 5.00 | ms/batch 20.07 | loss  1.08 | ppl     2.94
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  5.61s | valid loss  1.57 | valid ppl     4.82
# -----------------------------------------------------------------------------------------
# | epoch   7 |    50/  242 batches | lr 1.25 | ms/batch 22.35 | loss  1.01 | ppl     2.73
# | epoch   7 |   100/  242 batches | lr 1.25 | ms/batch 22.84 | loss  0.86 | ppl     2.37
# | epoch   7 |   150/  242 batches | lr 1.25 | ms/batch 21.21 | loss  0.87 | ppl     2.39
# | epoch   7 |   200/  242 batches | lr 1.25 | ms/batch 21.53 | loss  0.82 | ppl     2.28
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  6.10s | valid loss  0.86 | valid ppl     2.37
# -----------------------------------------------------------------------------------------
# | epoch   8 |    50/  242 batches | lr 1.25 | ms/batch 25.28 | loss  0.91 | ppl     2.48
# | epoch   8 |   100/  242 batches | lr 1.25 | ms/batch 23.93 | loss  0.85 | ppl     2.34
# | epoch   8 |   150/  242 batches | lr 1.25 | ms/batch 24.33 | loss  0.86 | ppl     2.35
# | epoch   8 |   200/  242 batches | lr 1.25 | ms/batch 22.33 | loss  0.80 | ppl     2.23
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  6.45s | valid loss  0.82 | valid ppl     2.28
# -----------------------------------------------------------------------------------------
# | epoch   9 |    50/  242 batches | lr 1.25 | ms/batch 22.14 | loss  0.88 | ppl     2.41
# | epoch   9 |   100/  242 batches | lr 1.25 | ms/batch 24.57 | loss  0.84 | ppl     2.31
# | epoch   9 |   150/  242 batches | lr 1.25 | ms/batch 22.82 | loss  0.84 | ppl     2.32
# | epoch   9 |   200/  242 batches | lr 1.25 | ms/batch 22.88 | loss  0.80 | ppl     2.22
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  6.30s | valid loss  0.92 | valid ppl     2.50
# -----------------------------------------------------------------------------------------
# | epoch  10 |    50/  242 batches | lr 0.31 | ms/batch 22.76 | loss  0.88 | ppl     2.41
# | epoch  10 |   100/  242 batches | lr 0.31 | ms/batch 23.65 | loss  0.81 | ppl     2.25
# | epoch  10 |   150/  242 batches | lr 0.31 | ms/batch 24.64 | loss  0.82 | ppl     2.27
# | epoch  10 |   200/  242 batches | lr 0.31 | ms/batch 22.83 | loss  0.77 | ppl     2.17
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  6.49s | valid loss  0.80 | valid ppl     2.23
# -----------------------------------------------------------------------------------------
# | epoch  11 |    50/  242 batches | lr 0.31 | ms/batch 24.07 | loss  0.86 | ppl     2.37
# | epoch  11 |   100/  242 batches | lr 0.31 | ms/batch 24.54 | loss  0.80 | ppl     2.23
# | epoch  11 |   150/  242 batches | lr 0.31 | ms/batch 22.58 | loss  0.82 | ppl     2.26
# | epoch  11 |   200/  242 batches | lr 0.31 | ms/batch 22.75 | loss  0.77 | ppl     2.15
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  6.43s | valid loss  0.79 | valid ppl     2.21
# -----------------------------------------------------------------------------------------
# | epoch  12 |    50/  242 batches | lr 0.31 | ms/batch 23.81 | loss  0.85 | ppl     2.34
# | epoch  12 |   100/  242 batches | lr 0.31 | ms/batch 24.85 | loss  0.80 | ppl     2.23
# | epoch  12 |   150/  242 batches | lr 0.31 | ms/batch 24.01 | loss  0.81 | ppl     2.25
# | epoch  12 |   200/  242 batches | lr 0.31 | ms/batch 23.23 | loss  0.76 | ppl     2.15
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time:  6.54s | valid loss  0.79 | valid ppl     2.20
# -----------------------------------------------------------------------------------------
# | epoch  13 |    50/  242 batches | lr 0.31 | ms/batch 23.67 | loss  0.84 | ppl     2.33
# | epoch  13 |   100/  242 batches | lr 0.31 | ms/batch 24.52 | loss  0.79 | ppl     2.21
# | epoch  13 |   150/  242 batches | lr 0.31 | ms/batch 23.10 | loss  0.81 | ppl     2.25
# | epoch  13 |   200/  242 batches | lr 0.31 | ms/batch 22.55 | loss  0.76 | ppl     2.14
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time:  6.44s | valid loss  0.79 | valid ppl     2.19
# -----------------------------------------------------------------------------------------
# | epoch  14 |    50/  242 batches | lr 0.31 | ms/batch 25.78 | loss  0.84 | ppl     2.33
# | epoch  14 |   100/  242 batches | lr 0.31 | ms/batch 25.09 | loss  0.79 | ppl     2.20
# | epoch  14 |   150/  242 batches | lr 0.31 | ms/batch 23.63 | loss  0.81 | ppl     2.24
# | epoch  14 |   200/  242 batches | lr 0.31 | ms/batch 23.65 | loss  0.76 | ppl     2.14
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  6.58s | valid loss  0.79 | valid ppl     2.21
# -----------------------------------------------------------------------------------------
# | epoch  15 |    50/  242 batches | lr 0.08 | ms/batch 23.10 | loss  0.84 | ppl     2.32
# | epoch  15 |   100/  242 batches | lr 0.08 | ms/batch 22.48 | loss  0.78 | ppl     2.19
# | epoch  15 |   150/  242 batches | lr 0.08 | ms/batch 26.90 | loss  0.80 | ppl     2.22
# | epoch  15 |   200/  242 batches | lr 0.08 | ms/batch 25.08 | loss  0.76 | ppl     2.13
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  6.54s | valid loss  0.78 | valid ppl     2.18
# -----------------------------------------------------------------------------------------
# | epoch  16 |    50/  242 batches | lr 0.08 | ms/batch 22.82 | loss  0.84 | ppl     2.31
# | epoch  16 |   100/  242 batches | lr 0.08 | ms/batch 24.55 | loss  0.78 | ppl     2.18
# | epoch  16 |   150/  242 batches | lr 0.08 | ms/batch 26.97 | loss  0.79 | ppl     2.21
# | epoch  16 |   200/  242 batches | lr 0.08 | ms/batch 26.00 | loss  0.75 | ppl     2.12
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time:  6.93s | valid loss  0.78 | valid ppl     2.18
# -----------------------------------------------------------------------------------------
# | epoch  17 |    50/  242 batches | lr 0.08 | ms/batch 26.38 | loss  0.83 | ppl     2.30
# | epoch  17 |   100/  242 batches | lr 0.08 | ms/batch 27.26 | loss  0.78 | ppl     2.18
# | epoch  17 |   150/  242 batches | lr 0.08 | ms/batch 24.58 | loss  0.79 | ppl     2.20
# | epoch  17 |   200/  242 batches | lr 0.08 | ms/batch 26.06 | loss  0.75 | ppl     2.13
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time:  7.06s | valid loss  0.78 | valid ppl     2.18
# -----------------------------------------------------------------------------------------
# | epoch  18 |    50/  242 batches | lr 0.02 | ms/batch 26.06 | loss  0.83 | ppl     2.30
# | epoch  18 |   100/  242 batches | lr 0.02 | ms/batch 24.73 | loss  0.78 | ppl     2.18
# | epoch  18 |   150/  242 batches | lr 0.02 | ms/batch 26.01 | loss  0.79 | ppl     2.20
# | epoch  18 |   200/  242 batches | lr 0.02 | ms/batch 27.04 | loss  0.75 | ppl     2.12
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  7.17s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  19 |    50/  242 batches | lr 0.02 | ms/batch 27.18 | loss  0.83 | ppl     2.30
# | epoch  19 |   100/  242 batches | lr 0.02 | ms/batch 24.94 | loss  0.78 | ppl     2.18
# | epoch  19 |   150/  242 batches | lr 0.02 | ms/batch 26.65 | loss  0.79 | ppl     2.20
# | epoch  19 |   200/  242 batches | lr 0.02 | ms/batch 25.57 | loss  0.75 | ppl     2.12
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  6.92s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  20 |    50/  242 batches | lr 0.00 | ms/batch 22.89 | loss  0.83 | ppl     2.29
# | epoch  20 |   100/  242 batches | lr 0.00 | ms/batch 22.67 | loss  0.78 | ppl     2.18
# | epoch  20 |   150/  242 batches | lr 0.00 | ms/batch 23.23 | loss  0.79 | ppl     2.20
# | epoch  20 |   200/  242 batches | lr 0.00 | ms/batch 25.60 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  6.56s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  21 |    50/  242 batches | lr 0.00 | ms/batch 27.45 | loss  0.83 | ppl     2.29
# | epoch  21 |   100/  242 batches | lr 0.00 | ms/batch 24.91 | loss  0.78 | ppl     2.17
# | epoch  21 |   150/  242 batches | lr 0.00 | ms/batch 24.45 | loss  0.79 | ppl     2.20
# | epoch  21 |   200/  242 batches | lr 0.00 | ms/batch 27.06 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time:  7.22s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  22 |    50/  242 batches | lr 0.00 | ms/batch 24.22 | loss  0.83 | ppl     2.29
# | epoch  22 |   100/  242 batches | lr 0.00 | ms/batch 22.35 | loss  0.78 | ppl     2.17
# | epoch  22 |   150/  242 batches | lr 0.00 | ms/batch 24.55 | loss  0.79 | ppl     2.19
# | epoch  22 |   200/  242 batches | lr 0.00 | ms/batch 26.84 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time:  6.83s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  23 |    50/  242 batches | lr 0.00 | ms/batch 23.99 | loss  0.83 | ppl     2.28
# | epoch  23 |   100/  242 batches | lr 0.00 | ms/batch 24.63 | loss  0.77 | ppl     2.17
# | epoch  23 |   150/  242 batches | lr 0.00 | ms/batch 24.30 | loss  0.79 | ppl     2.19
# | epoch  23 |   200/  242 batches | lr 0.00 | ms/batch 24.31 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time:  6.83s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  24 |    50/  242 batches | lr 0.00 | ms/batch 27.44 | loss  0.83 | ppl     2.29
# | epoch  24 |   100/  242 batches | lr 0.00 | ms/batch 27.30 | loss  0.77 | ppl     2.17
# | epoch  24 |   150/  242 batches | lr 0.00 | ms/batch 25.51 | loss  0.79 | ppl     2.19
# | epoch  24 |   200/  242 batches | lr 0.00 | ms/batch 25.14 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time:  7.23s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  25 |    50/  242 batches | lr 0.00 | ms/batch 29.52 | loss  0.83 | ppl     2.28
# | epoch  25 |   100/  242 batches | lr 0.00 | ms/batch 31.06 | loss  0.77 | ppl     2.17
# | epoch  25 |   150/  242 batches | lr 0.00 | ms/batch 29.06 | loss  0.79 | ppl     2.19
# | epoch  25 |   200/  242 batches | lr 0.00 | ms/batch 24.98 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time:  7.54s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  26 |    50/  242 batches | lr 0.00 | ms/batch 24.66 | loss  0.83 | ppl     2.28
# | epoch  26 |   100/  242 batches | lr 0.00 | ms/batch 26.36 | loss  0.77 | ppl     2.17
# | epoch  26 |   150/  242 batches | lr 0.00 | ms/batch 23.76 | loss  0.78 | ppl     2.19
# | epoch  26 |   200/  242 batches | lr 0.00 | ms/batch 22.86 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time:  6.56s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  27 |    50/  242 batches | lr 0.00 | ms/batch 23.32 | loss  0.83 | ppl     2.28
# | epoch  27 |   100/  242 batches | lr 0.00 | ms/batch 23.41 | loss  0.77 | ppl     2.17
# | epoch  27 |   150/  242 batches | lr 0.00 | ms/batch 23.81 | loss  0.79 | ppl     2.19
# | epoch  27 |   200/  242 batches | lr 0.00 | ms/batch 24.26 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time:  6.59s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  28 |    50/  242 batches | lr 0.00 | ms/batch 23.17 | loss  0.82 | ppl     2.28
# | epoch  28 |   100/  242 batches | lr 0.00 | ms/batch 23.55 | loss  0.77 | ppl     2.17
# | epoch  28 |   150/  242 batches | lr 0.00 | ms/batch 23.92 | loss  0.79 | ppl     2.20
# | epoch  28 |   200/  242 batches | lr 0.00 | ms/batch 24.66 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time:  6.45s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  29 |    50/  242 batches | lr 0.00 | ms/batch 22.94 | loss  0.83 | ppl     2.28
# | epoch  29 |   100/  242 batches | lr 0.00 | ms/batch 22.45 | loss  0.77 | ppl     2.17
# | epoch  29 |   150/  242 batches | lr 0.00 | ms/batch 23.34 | loss  0.79 | ppl     2.19
# | epoch  29 |   200/  242 batches | lr 0.00 | ms/batch 23.49 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time:  6.27s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  30 |    50/  242 batches | lr 0.00 | ms/batch 23.04 | loss  0.83 | ppl     2.28
# | epoch  30 |   100/  242 batches | lr 0.00 | ms/batch 23.52 | loss  0.77 | ppl     2.17
# | epoch  30 |   150/  242 batches | lr 0.00 | ms/batch 22.72 | loss  0.79 | ppl     2.19
# | epoch  30 |   200/  242 batches | lr 0.00 | ms/batch 22.56 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time:  6.26s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  31 |    50/  242 batches | lr 0.00 | ms/batch 23.77 | loss  0.83 | ppl     2.28
# | epoch  31 |   100/  242 batches | lr 0.00 | ms/batch 22.68 | loss  0.77 | ppl     2.17
# | epoch  31 |   150/  242 batches | lr 0.00 | ms/batch 22.53 | loss  0.79 | ppl     2.19
# | epoch  31 |   200/  242 batches | lr 0.00 | ms/batch 23.24 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time:  6.38s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  32 |    50/  242 batches | lr 0.00 | ms/batch 23.14 | loss  0.83 | ppl     2.28
# | epoch  32 |   100/  242 batches | lr 0.00 | ms/batch 22.57 | loss  0.77 | ppl     2.17
# | epoch  32 |   150/  242 batches | lr 0.00 | ms/batch 23.33 | loss  0.79 | ppl     2.19
# | epoch  32 |   200/  242 batches | lr 0.00 | ms/batch 24.09 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time:  6.38s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  33 |    50/  242 batches | lr 0.00 | ms/batch 23.09 | loss  0.83 | ppl     2.28
# | epoch  33 |   100/  242 batches | lr 0.00 | ms/batch 26.55 | loss  0.77 | ppl     2.17
# | epoch  33 |   150/  242 batches | lr 0.00 | ms/batch 27.99 | loss  0.79 | ppl     2.19
# | epoch  33 |   200/  242 batches | lr 0.00 | ms/batch 28.86 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time:  7.42s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  34 |    50/  242 batches | lr 0.00 | ms/batch 29.09 | loss  0.83 | ppl     2.28
# | epoch  34 |   100/  242 batches | lr 0.00 | ms/batch 30.13 | loss  0.77 | ppl     2.17
# | epoch  34 |   150/  242 batches | lr 0.00 | ms/batch 25.46 | loss  0.79 | ppl     2.19
# | epoch  34 |   200/  242 batches | lr 0.00 | ms/batch 24.78 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time:  7.32s | valid loss  0.77 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  35 |    50/  242 batches | lr 0.00 | ms/batch 23.13 | loss  0.83 | ppl     2.28
# | epoch  35 |   100/  242 batches | lr 0.00 | ms/batch 23.68 | loss  0.77 | ppl     2.17
# | epoch  35 |   150/  242 batches | lr 0.00 | ms/batch 23.86 | loss  0.79 | ppl     2.19
# | epoch  35 |   200/  242 batches | lr 0.00 | ms/batch 22.60 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time:  6.31s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  36 |    50/  242 batches | lr 0.00 | ms/batch 24.28 | loss  0.83 | ppl     2.28
# | epoch  36 |   100/  242 batches | lr 0.00 | ms/batch 22.35 | loss  0.77 | ppl     2.17
# | epoch  36 |   150/  242 batches | lr 0.00 | ms/batch 22.88 | loss  0.79 | ppl     2.19
# | epoch  36 |   200/  242 batches | lr 0.00 | ms/batch 22.66 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time:  6.33s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  37 |    50/  242 batches | lr 0.00 | ms/batch 24.56 | loss  0.83 | ppl     2.28
# | epoch  37 |   100/  242 batches | lr 0.00 | ms/batch 22.42 | loss  0.77 | ppl     2.17
# | epoch  37 |   150/  242 batches | lr 0.00 | ms/batch 22.31 | loss  0.79 | ppl     2.19
# | epoch  37 |   200/  242 batches | lr 0.00 | ms/batch 23.35 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time:  6.29s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  38 |    50/  242 batches | lr 0.00 | ms/batch 22.96 | loss  0.83 | ppl     2.28
# | epoch  38 |   100/  242 batches | lr 0.00 | ms/batch 23.02 | loss  0.77 | ppl     2.17
# | epoch  38 |   150/  242 batches | lr 0.00 | ms/batch 24.25 | loss  0.79 | ppl     2.19
# | epoch  38 |   200/  242 batches | lr 0.00 | ms/batch 23.04 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time:  6.32s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  39 |    50/  242 batches | lr 0.00 | ms/batch 22.96 | loss  0.83 | ppl     2.28
# | epoch  39 |   100/  242 batches | lr 0.00 | ms/batch 22.54 | loss  0.77 | ppl     2.17
# | epoch  39 |   150/  242 batches | lr 0.00 | ms/batch 23.18 | loss  0.79 | ppl     2.19
# | epoch  39 |   200/  242 batches | lr 0.00 | ms/batch 22.96 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time:  6.30s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  40 |    50/  242 batches | lr 0.00 | ms/batch 22.76 | loss  0.83 | ppl     2.28
# | epoch  40 |   100/  242 batches | lr 0.00 | ms/batch 23.29 | loss  0.77 | ppl     2.17
# | epoch  40 |   150/  242 batches | lr 0.00 | ms/batch 22.91 | loss  0.79 | ppl     2.19
# | epoch  40 |   200/  242 batches | lr 0.00 | ms/batch 23.14 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time:  6.31s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  41 |    50/  242 batches | lr 0.00 | ms/batch 23.95 | loss  0.83 | ppl     2.28
# | epoch  41 |   100/  242 batches | lr 0.00 | ms/batch 22.69 | loss  0.77 | ppl     2.17
# | epoch  41 |   150/  242 batches | lr 0.00 | ms/batch 22.40 | loss  0.79 | ppl     2.19
# | epoch  41 |   200/  242 batches | lr 0.00 | ms/batch 23.09 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time:  6.34s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  42 |    50/  242 batches | lr 0.00 | ms/batch 22.82 | loss  0.83 | ppl     2.28
# | epoch  42 |   100/  242 batches | lr 0.00 | ms/batch 22.36 | loss  0.77 | ppl     2.17
# | epoch  42 |   150/  242 batches | lr 0.00 | ms/batch 23.06 | loss  0.79 | ppl     2.19
# | epoch  42 |   200/  242 batches | lr 0.00 | ms/batch 24.23 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time:  6.32s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  43 |    50/  242 batches | lr 0.00 | ms/batch 23.04 | loss  0.83 | ppl     2.28
# | epoch  43 |   100/  242 batches | lr 0.00 | ms/batch 22.50 | loss  0.77 | ppl     2.17
# | epoch  43 |   150/  242 batches | lr 0.00 | ms/batch 24.19 | loss  0.79 | ppl     2.19
# | epoch  43 |   200/  242 batches | lr 0.00 | ms/batch 24.22 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time:  6.46s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  44 |    50/  242 batches | lr 0.00 | ms/batch 22.85 | loss  0.83 | ppl     2.28
# | epoch  44 |   100/  242 batches | lr 0.00 | ms/batch 23.30 | loss  0.77 | ppl     2.17
# | epoch  44 |   150/  242 batches | lr 0.00 | ms/batch 22.79 | loss  0.79 | ppl     2.19
# | epoch  44 |   200/  242 batches | lr 0.00 | ms/batch 23.20 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time:  6.32s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  45 |    50/  242 batches | lr 0.00 | ms/batch 24.69 | loss  0.83 | ppl     2.28
# | epoch  45 |   100/  242 batches | lr 0.00 | ms/batch 23.21 | loss  0.77 | ppl     2.17
# | epoch  45 |   150/  242 batches | lr 0.00 | ms/batch 22.67 | loss  0.79 | ppl     2.19
# | epoch  45 |   200/  242 batches | lr 0.00 | ms/batch 23.57 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time:  6.42s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  46 |    50/  242 batches | lr 0.00 | ms/batch 24.24 | loss  0.83 | ppl     2.28
# | epoch  46 |   100/  242 batches | lr 0.00 | ms/batch 22.55 | loss  0.77 | ppl     2.17
# | epoch  46 |   150/  242 batches | lr 0.00 | ms/batch 23.15 | loss  0.79 | ppl     2.19
# | epoch  46 |   200/  242 batches | lr 0.00 | ms/batch 24.15 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time:  6.40s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  47 |    50/  242 batches | lr 0.00 | ms/batch 22.94 | loss  0.83 | ppl     2.28
# | epoch  47 |   100/  242 batches | lr 0.00 | ms/batch 22.66 | loss  0.77 | ppl     2.17
# | epoch  47 |   150/  242 batches | lr 0.00 | ms/batch 23.32 | loss  0.79 | ppl     2.19
# | epoch  47 |   200/  242 batches | lr 0.00 | ms/batch 22.69 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time:  6.32s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  48 |    50/  242 batches | lr 0.00 | ms/batch 23.68 | loss  0.83 | ppl     2.28
# | epoch  48 |   100/  242 batches | lr 0.00 | ms/batch 23.80 | loss  0.77 | ppl     2.17
# | epoch  48 |   150/  242 batches | lr 0.00 | ms/batch 23.33 | loss  0.79 | ppl     2.19
# | epoch  48 |   200/  242 batches | lr 0.00 | ms/batch 22.72 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time:  6.40s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  49 |    50/  242 batches | lr 0.00 | ms/batch 23.26 | loss  0.83 | ppl     2.28
# | epoch  49 |   100/  242 batches | lr 0.00 | ms/batch 23.55 | loss  0.77 | ppl     2.17
# | epoch  49 |   150/  242 batches | lr 0.00 | ms/batch 22.61 | loss  0.79 | ppl     2.19
# | epoch  49 |   200/  242 batches | lr 0.00 | ms/batch 23.19 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time:  6.34s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  50 |    50/  242 batches | lr 0.00 | ms/batch 24.18 | loss  0.83 | ppl     2.28
# | epoch  50 |   100/  242 batches | lr 0.00 | ms/batch 22.63 | loss  0.77 | ppl     2.17
# | epoch  50 |   150/  242 batches | lr 0.00 | ms/batch 23.12 | loss  0.79 | ppl     2.19
# | epoch  50 |   200/  242 batches | lr 0.00 | ms/batch 23.25 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time:  6.39s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  51 |    50/  242 batches | lr 0.00 | ms/batch 22.84 | loss  0.83 | ppl     2.28
# | epoch  51 |   100/  242 batches | lr 0.00 | ms/batch 22.30 | loss  0.77 | ppl     2.17
# | epoch  51 |   150/  242 batches | lr 0.00 | ms/batch 22.97 | loss  0.79 | ppl     2.19
# | epoch  51 |   200/  242 batches | lr 0.00 | ms/batch 24.02 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time:  6.42s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  52 |    50/  242 batches | lr 0.00 | ms/batch 22.89 | loss  0.83 | ppl     2.28
# | epoch  52 |   100/  242 batches | lr 0.00 | ms/batch 22.36 | loss  0.77 | ppl     2.17
# | epoch  52 |   150/  242 batches | lr 0.00 | ms/batch 23.48 | loss  0.79 | ppl     2.19
# | epoch  52 |   200/  242 batches | lr 0.00 | ms/batch 23.16 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time:  6.32s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  53 |    50/  242 batches | lr 0.00 | ms/batch 23.02 | loss  0.83 | ppl     2.28
# | epoch  53 |   100/  242 batches | lr 0.00 | ms/batch 23.37 | loss  0.77 | ppl     2.17
# | epoch  53 |   150/  242 batches | lr 0.00 | ms/batch 22.96 | loss  0.79 | ppl     2.19
# | epoch  53 |   200/  242 batches | lr 0.00 | ms/batch 23.69 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time:  6.41s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  54 |    50/  242 batches | lr 0.00 | ms/batch 24.26 | loss  0.83 | ppl     2.28
# | epoch  54 |   100/  242 batches | lr 0.00 | ms/batch 23.30 | loss  0.77 | ppl     2.17
# | epoch  54 |   150/  242 batches | lr 0.00 | ms/batch 23.51 | loss  0.79 | ppl     2.19
# | epoch  54 |   200/  242 batches | lr 0.00 | ms/batch 23.78 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time:  6.48s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  55 |    50/  242 batches | lr 0.00 | ms/batch 23.82 | loss  0.83 | ppl     2.28
# | epoch  55 |   100/  242 batches | lr 0.00 | ms/batch 22.67 | loss  0.77 | ppl     2.17
# | epoch  55 |   150/  242 batches | lr 0.00 | ms/batch 22.50 | loss  0.79 | ppl     2.19
# | epoch  55 |   200/  242 batches | lr 0.00 | ms/batch 22.84 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time:  6.39s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  56 |    50/  242 batches | lr 0.00 | ms/batch 23.82 | loss  0.83 | ppl     2.28
# | epoch  56 |   100/  242 batches | lr 0.00 | ms/batch 23.21 | loss  0.77 | ppl     2.17
# | epoch  56 |   150/  242 batches | lr 0.00 | ms/batch 23.28 | loss  0.79 | ppl     2.19
# | epoch  56 |   200/  242 batches | lr 0.00 | ms/batch 24.26 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time:  6.40s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  57 |    50/  242 batches | lr 0.00 | ms/batch 22.92 | loss  0.83 | ppl     2.28
# | epoch  57 |   100/  242 batches | lr 0.00 | ms/batch 22.50 | loss  0.77 | ppl     2.17
# | epoch  57 |   150/  242 batches | lr 0.00 | ms/batch 23.44 | loss  0.79 | ppl     2.19
# | epoch  57 |   200/  242 batches | lr 0.00 | ms/batch 23.24 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time:  6.31s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  58 |    50/  242 batches | lr 0.00 | ms/batch 23.09 | loss  0.83 | ppl     2.28
# | epoch  58 |   100/  242 batches | lr 0.00 | ms/batch 23.25 | loss  0.77 | ppl     2.17
# | epoch  58 |   150/  242 batches | lr 0.00 | ms/batch 23.04 | loss  0.79 | ppl     2.19
# | epoch  58 |   200/  242 batches | lr 0.00 | ms/batch 23.62 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time:  6.37s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  59 |    50/  242 batches | lr 0.00 | ms/batch 24.41 | loss  0.83 | ppl     2.28
# | epoch  59 |   100/  242 batches | lr 0.00 | ms/batch 24.48 | loss  0.77 | ppl     2.17
# | epoch  59 |   150/  242 batches | lr 0.00 | ms/batch 28.74 | loss  0.79 | ppl     2.19
# | epoch  59 |   200/  242 batches | lr 0.00 | ms/batch 27.53 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time:  7.29s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  60 |    50/  242 batches | lr 0.00 | ms/batch 27.19 | loss  0.83 | ppl     2.28
# | epoch  60 |   100/  242 batches | lr 0.00 | ms/batch 25.80 | loss  0.77 | ppl     2.17
# | epoch  60 |   150/  242 batches | lr 0.00 | ms/batch 26.75 | loss  0.79 | ppl     2.19
# | epoch  60 |   200/  242 batches | lr 0.00 | ms/batch 26.94 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time:  7.40s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  61 |    50/  242 batches | lr 0.00 | ms/batch 26.91 | loss  0.83 | ppl     2.28
# | epoch  61 |   100/  242 batches | lr 0.00 | ms/batch 26.71 | loss  0.77 | ppl     2.17
# | epoch  61 |   150/  242 batches | lr 0.00 | ms/batch 28.06 | loss  0.79 | ppl     2.19
# | epoch  61 |   200/  242 batches | lr 0.00 | ms/batch 26.42 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time:  7.19s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# | epoch  62 |    50/  242 batches | lr 0.00 | ms/batch 24.74 | loss  0.83 | ppl     2.28
# | epoch  62 |   100/  242 batches | lr 0.00 | ms/batch 27.24 | loss  0.77 | ppl     2.17
# | epoch  62 |   150/  242 batches | lr 0.00 | ms/batch 26.04 | loss  0.79 | ppl     2.19
# | epoch  62 |   200/  242 batches | lr 0.00 | ms/batch 26.73 | loss  0.75 | ppl     2.11
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time:  7.03s | valid loss  0.78 | valid ppl     2.17
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-176-6c943b32142b> in <module>()
#       4 for epoch in range(1, args.epochs+1):
#       5     epoch_start_time = time.time()
# ----> 6     train()
#       7     val_loss = evaluate(val_data, val_data_lbls)
#       8     print('-' * 89)
#
# <ipython-input-175-839af502d1e3> in train()
#      49         output, hidden = model(data, hidden)
#      50         loss = criterion(output.view(-1, nlabels), targets)
# ---> 51         loss.backward()
#      52
#      53         clipped_lr = lr * clip_gradient(model, args.clip)
#
# /Users/simon.hughes/anaconda3/envs/pytorch_src/lib/python3.5/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_variables)
#     143                     'or with gradient w.r.t. the variable')
#     144             gradient = self.data.new().resize_as_(self.data).fill_(1)
# --> 145         self._execution_engine.run_backward((self,), (gradient,), retain_variables)
#     146
#     147     def register_hook(self, hook):
#
# /Users/simon.hughes/anaconda3/envs/pytorch_src/lib/python3.5/site-packages/torch/nn/_functions/linear.py in backward(self, grad_output)
#      20         grad_input = grad_weight = grad_bias = None
#      21         if self.needs_input_grad[0]:
# ---> 22             grad_input = torch.mm(grad_output, weight)
#      23         if self.needs_input_grad[1]:
#      24             grad_weight = torch.mm(grad_output.t(), input)
#
# KeyboardInterrupt:

# %%
def words_to_ids(sentence):
    wds = sentence.strip().split(" ")
    if(len(wds)) < args.bptt:
        diff = args.bptt - len(wds)
        sentence = sentence.strip() + (" <eos>" * (diff+1))
        wds = sentence.strip().split(" ")
    ids = torch.LongTensor(len(wds))
    #print(len(wds), "words")
    token = 0
    for word in wds:
        ids[token] = corpus.dictionary.word2idx[word]
        token += 1
    return ids

sentence = "What leads to differences in the rates of coral bleaching ."
sentence = sentence.split(" ")
for i in range(len(sentence)):
    model.zero_grad()
    up_to_this = " ".join(sentence[:i])
    ids = words_to_ids(up_to_this)# pad to length
    batch = batchify(ids, eval_batch_size)
    inputs, _ = get_batch(batch, batch, 0, True)
    hidden = model.init_hidden(eval_batch_size)
    output, hidden = model(inputs, hidden)
    output_flat = output.view(-1, nlabels)
    word_weights = output.squeeze().data.exp().cpu()
    word_idx = torch.multinomial(word_weights, 1)[-1]
    word_idxs = list(word_idx)[0]
    tag = corpus.labels_dictionary.idx2word[word_idxs]
    print(sentence[i].strip().ljust(15), tag)
# Out:
# What            11
# leads           <eos>
# to              4
# differences     None
# in              None
# the             None
# rates           3
# of              None
# coral           <eos>
# bleaching       50
# .               None

# %%
len(corpus.labels_dictionary)
# Out:
# 15

# %%
#TODO make sure eos markers not counted in accuracy metrics
