# %%
# %load_ext autoreload

# %%
from BrattEssay import load_bratt_essays
from collections import defaultdict
from IterableFP import flatten
from Settings import Settings

#target_folder = "Training"
settings = Settings()
#root_folder = settings.data_directory + "CoralBleaching/Thesis_Dataset/"
#training_folder = root_folder + target_folder + "/"

#essays = load_bratt_essays(training_folder)
# Out:
# Results Dir: /Users/simon.hughes/Google Drive/Phd/Results/
# Data Dir:    /Users/simon.hughes/Google Drive/Phd/Data/
# Root Dir:    /Users/simon.hughes/GitHub/NlpResearch/
# Public Data: /Users/simon.hughes/GitHub/NlpResearch/Data/PublicDatasets/

# %%
#from https://github.com/pytorch/examples/blob/master/word_language_model/model.py
import torch.nn as nn
from torch.autograd import Variable

class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ntarget, ninp, nhid, nlayers):
        super(RNNModel, self).__init__()
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, bias=False)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, bias=False)
        self.decoder = nn.Linear(nhid, ntarget) # changed from ntoken

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.encoder(input)
        output, hidden = self.rnn(emb, hidden)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters()).data
        if self.rnn_type == 'LSTM':
            return (Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()),
                    Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()))
        else:
            return Variable(weight.new(self.nlayers, bsz, self.nhid).zero_())

# %%
class Args(object):
    def __init__(self):
        self.model = "GRU"
        self.emsize = 100
        self.nhid = 100
        self.nlayers = 1 # default 2
        self.lr = 20
        self.clip = 0.5
        self.epochs = 200
        self.batch_size = 20
        # sequence length, what does this mean ???
        self.bptt = 30
        self.seed = 1111
        self.cuda = False  # Throws error during data load
        self.log_interval=50
        self.save = "/Users/simon.hughes/data/pytorch/models/rq1_rnn.pt"
        
args = Args()

# %%
import time
import math
import torch
import torch.nn as nn
from torch.autograd import Variable

# Set the random seed manually for reproducibility.
torch.manual_seed(args.seed)
if torch.cuda.is_available():
    if not args.cuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")
    else:
        print("CUDA Enabled")
        torch.cuda.manual_seed(args.seed)
else:
    print("CUDA is not available")
# Out:
# WARNING: You have a CUDA device, so you should probably run with --cuda

# %%
import os
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)

class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        self.labels_dictionary = Dictionary()
        self.train = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Training/inputs.txt", self.dictionary)
        self.train_lbls = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Training/output_most_freq.txt", self.labels_dictionary)
        self.valid = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Test/inputs.txt", self.dictionary)
        self.valid_lbls = self.tokenize("/Users/simon.hughes/data/tensorflow/translate/cb/Test/output_most_freq.txt", self.labels_dictionary)
       
    def tokenize(self, path, dictionary):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r') as f:
            tokens = 0
            for line in f:
                words = ['<sos>'] + line.split() + ['<eos>']
                tokens += len(words)
                for word in words:
                    dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r') as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for line in f:
                words = ['<sos>'] + line.split() + ['<eos>']
                for word in words:
                    ids[token] = dictionary.word2idx[word]
                    token += 1

        return ids

# %%
corpus = Corpus()

def batchify(data, bsz):
    nbatch = data.size(0) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous()
    if args.cuda:
        data = data.cuda()
    return data

eval_batch_size = 10
train_data = batchify(corpus.train, args.batch_size)
train_data_lbls = batchify(corpus.train_lbls, args.batch_size)

val_data = batchify(corpus.valid, eval_batch_size)
val_data_lbls = batchify(corpus.valid_lbls, eval_batch_size)

# %% [markdown]
# ## Build The Model

# %%
ntokens = len(corpus.dictionary)
nlabels = len(corpus.labels_dictionary)
model = RNNModel(args.model, ntokens, nlabels, args.emsize, args.nhid, args.nlayers)
if args.cuda:
    model.cuda()

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train The Model

# %%
def clip_gradient(model, clip):
    """Computes a gradient clipping coefficient based on gradient norm."""
    totalnorm = 0
    for p in model.parameters():
        modulenorm = p.grad.data.norm()
        totalnorm += modulenorm ** 2
    totalnorm = math.sqrt(totalnorm)
    return min(1, clip / (totalnorm + 1e-6))


def repackage_hidden(h):
    """Wraps hidden states in new Variables, to detach them from their history."""
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)


def get_batch(source, label_source, i, evaluation=False):
    seq_len = min(args.bptt, len(source) - 1 - i)
    data = Variable(source[i:i+seq_len], volatile=evaluation)
    target = Variable(label_source[i:i+seq_len].view(-1))
    return data, target

def evaluate(data_source, label_source):
    total_loss = 0
    ntokens = len(corpus.dictionary)
    nlabels = len(corpus.labels_dictionary)
    hidden = model.init_hidden(eval_batch_size)
    for i in range(0, data_source.size(0) - 1, args.bptt):
        data, targets = get_batch(data_source, label_source, i, evaluation=True)
        output, hidden = model(data, hidden)
        output_flat = output.view(-1, nlabels)
        total_loss += len(data) * criterion(output_flat, targets).data
        hidden = repackage_hidden(hidden)
    return total_loss[0] / len(data_source)


def train():
    total_loss = 0
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    nlabels = len(corpus.labels_dictionary)
    hidden = model.init_hidden(args.batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, args.bptt)):
        data, targets = get_batch(train_data, train_data_lbls, i)
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, nlabels), targets)
        loss.backward()

        clipped_lr = lr * clip_gradient(model, args.clip)
        for p in model.parameters():
            p.data.add_(-clipped_lr, p.grad.data)

        total_loss += loss.data

        if batch % args.log_interval == 0 and batch > 0:
            cur_loss = total_loss[0] / args.log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args.bptt, lr,
                elapsed * 1000 / args.log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
# Loop over epochs.
lr = args.lr
prev_val_loss = None
for epoch in range(1, args.epochs+1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(val_data, val_data_lbls)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
            'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                       val_loss, math.exp(val_loss)))
    print('-' * 89)
    # Anneal the learning rate.
    if prev_val_loss and val_loss > prev_val_loss:
        lr /= 4
    prev_val_loss = val_loss

# Run on test data and save the model.
#test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training |')
print('=' * 89)
if args.save != '':
    with open(args.save, 'wb') as f:
        torch.save(model, f)
# Out:
# | epoch   1 |    50/  256 batches | lr 20.00 | ms/batch 20.70 | loss  2.85 | ppl    17.37
# | epoch   1 |   100/  256 batches | lr 20.00 | ms/batch 21.95 | loss  1.79 | ppl     5.98
# | epoch   1 |   150/  256 batches | lr 20.00 | ms/batch 20.80 | loss  1.10 | ppl     3.01
# | epoch   1 |   200/  256 batches | lr 20.00 | ms/batch 20.11 | loss  1.36 | ppl     3.91
# | epoch   1 |   250/  256 batches | lr 20.00 | ms/batch 20.74 | loss  1.36 | ppl     3.88
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  6.05s | valid loss  4.58 | valid ppl    97.42
# -----------------------------------------------------------------------------------------
# | epoch   2 |    50/  256 batches | lr 20.00 | ms/batch 22.41 | loss  1.98 | ppl     7.24
# | epoch   2 |   100/  256 batches | lr 20.00 | ms/batch 21.42 | loss  1.28 | ppl     3.61
# | epoch   2 |   150/  256 batches | lr 20.00 | ms/batch 24.52 | loss  1.27 | ppl     3.57
# | epoch   2 |   200/  256 batches | lr 20.00 | ms/batch 21.00 | loss  1.56 | ppl     4.74
# | epoch   2 |   250/  256 batches | lr 20.00 | ms/batch 21.75 | loss  1.69 | ppl     5.43
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  6.45s | valid loss 11.44 | valid ppl 93101.84
# -----------------------------------------------------------------------------------------
# | epoch   3 |    50/  256 batches | lr 5.00 | ms/batch 22.34 | loss  6.15 | ppl   470.42
# | epoch   3 |   100/  256 batches | lr 5.00 | ms/batch 20.97 | loss  2.03 | ppl     7.60
# | epoch   3 |   150/  256 batches | lr 5.00 | ms/batch 21.15 | loss  1.18 | ppl     3.25
# | epoch   3 |   200/  256 batches | lr 5.00 | ms/batch 22.20 | loss  1.01 | ppl     2.74
# | epoch   3 |   250/  256 batches | lr 5.00 | ms/batch 20.08 | loss  0.95 | ppl     2.59
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  6.14s | valid loss  2.35 | valid ppl    10.53
# -----------------------------------------------------------------------------------------
# | epoch   4 |    50/  256 batches | lr 5.00 | ms/batch 19.65 | loss  1.13 | ppl     3.09
# | epoch   4 |   100/  256 batches | lr 5.00 | ms/batch 20.58 | loss  0.95 | ppl     2.59
# | epoch   4 |   150/  256 batches | lr 5.00 | ms/batch 20.92 | loss  0.91 | ppl     2.49
# | epoch   4 |   200/  256 batches | lr 5.00 | ms/batch 19.93 | loss  0.89 | ppl     2.44
# | epoch   4 |   250/  256 batches | lr 5.00 | ms/batch 19.71 | loss  0.91 | ppl     2.47
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  5.85s | valid loss  1.82 | valid ppl     6.19
# -----------------------------------------------------------------------------------------
# | epoch   5 |    50/  256 batches | lr 5.00 | ms/batch 20.48 | loss  1.01 | ppl     2.74
# | epoch   5 |   100/  256 batches | lr 5.00 | ms/batch 19.45 | loss  0.91 | ppl     2.49
# | epoch   5 |   150/  256 batches | lr 5.00 | ms/batch 23.53 | loss  1.00 | ppl     2.73
# | epoch   5 |   200/  256 batches | lr 5.00 | ms/batch 20.13 | loss  0.93 | ppl     2.53
# | epoch   5 |   250/  256 batches | lr 5.00 | ms/batch 21.92 | loss  0.99 | ppl     2.68
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  6.15s | valid loss  3.43 | valid ppl    30.91
# -----------------------------------------------------------------------------------------
# | epoch   6 |    50/  256 batches | lr 1.25 | ms/batch 20.16 | loss  1.10 | ppl     3.00
# | epoch   6 |   100/  256 batches | lr 1.25 | ms/batch 19.58 | loss  0.85 | ppl     2.34
# | epoch   6 |   150/  256 batches | lr 1.25 | ms/batch 19.57 | loss  0.83 | ppl     2.29
# | epoch   6 |   200/  256 batches | lr 1.25 | ms/batch 20.29 | loss  0.83 | ppl     2.29
# | epoch   6 |   250/  256 batches | lr 1.25 | ms/batch 19.83 | loss  0.80 | ppl     2.22
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  5.86s | valid loss  0.96 | valid ppl     2.61
# -----------------------------------------------------------------------------------------
# | epoch   7 |    50/  256 batches | lr 1.25 | ms/batch 23.17 | loss  0.87 | ppl     2.38
# | epoch   7 |   100/  256 batches | lr 1.25 | ms/batch 21.38 | loss  0.81 | ppl     2.25
# | epoch   7 |   150/  256 batches | lr 1.25 | ms/batch 22.14 | loss  0.81 | ppl     2.24
# | epoch   7 |   200/  256 batches | lr 1.25 | ms/batch 21.48 | loss  0.80 | ppl     2.23
# | epoch   7 |   250/  256 batches | lr 1.25 | ms/batch 21.51 | loss  0.78 | ppl     2.19
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  6.45s | valid loss  0.96 | valid ppl     2.60
# -----------------------------------------------------------------------------------------
# | epoch   8 |    50/  256 batches | lr 1.25 | ms/batch 21.82 | loss  0.85 | ppl     2.35
# | epoch   8 |   100/  256 batches | lr 1.25 | ms/batch 22.64 | loss  0.80 | ppl     2.23
# | epoch   8 |   150/  256 batches | lr 1.25 | ms/batch 21.83 | loss  0.79 | ppl     2.21
# | epoch   8 |   200/  256 batches | lr 1.25 | ms/batch 21.88 | loss  0.79 | ppl     2.21
# | epoch   8 |   250/  256 batches | lr 1.25 | ms/batch 21.88 | loss  0.77 | ppl     2.17
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  6.43s | valid loss  0.94 | valid ppl     2.56
# -----------------------------------------------------------------------------------------
# | epoch   9 |    50/  256 batches | lr 1.25 | ms/batch 23.42 | loss  0.84 | ppl     2.31
# | epoch   9 |   100/  256 batches | lr 1.25 | ms/batch 22.07 | loss  0.79 | ppl     2.21
# | epoch   9 |   150/  256 batches | lr 1.25 | ms/batch 22.21 | loss  0.79 | ppl     2.20
# | epoch   9 |   200/  256 batches | lr 1.25 | ms/batch 22.35 | loss  0.79 | ppl     2.20
# | epoch   9 |   250/  256 batches | lr 1.25 | ms/batch 22.84 | loss  0.76 | ppl     2.15
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  6.56s | valid loss  0.95 | valid ppl     2.59
# -----------------------------------------------------------------------------------------
# | epoch  10 |    50/  256 batches | lr 0.31 | ms/batch 22.64 | loss  0.84 | ppl     2.31
# | epoch  10 |   100/  256 batches | lr 0.31 | ms/batch 22.19 | loss  0.78 | ppl     2.18
# | epoch  10 |   150/  256 batches | lr 0.31 | ms/batch 23.48 | loss  0.77 | ppl     2.16
# | epoch  10 |   200/  256 batches | lr 0.31 | ms/batch 22.24 | loss  0.77 | ppl     2.15
# | epoch  10 |   250/  256 batches | lr 0.31 | ms/batch 22.90 | loss  0.74 | ppl     2.10
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  6.71s | valid loss  0.75 | valid ppl     2.13
# -----------------------------------------------------------------------------------------
# | epoch  11 |    50/  256 batches | lr 0.31 | ms/batch 22.72 | loss  0.80 | ppl     2.24
# | epoch  11 |   100/  256 batches | lr 0.31 | ms/batch 22.54 | loss  0.77 | ppl     2.16
# | epoch  11 |   150/  256 batches | lr 0.31 | ms/batch 21.10 | loss  0.77 | ppl     2.15
# | epoch  11 |   200/  256 batches | lr 0.31 | ms/batch 21.05 | loss  0.76 | ppl     2.15
# | epoch  11 |   250/  256 batches | lr 0.31 | ms/batch 21.31 | loss  0.74 | ppl     2.10
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  6.33s | valid loss  0.75 | valid ppl     2.11
# -----------------------------------------------------------------------------------------
# | epoch  12 |    50/  256 batches | lr 0.31 | ms/batch 22.25 | loss  0.80 | ppl     2.22
# | epoch  12 |   100/  256 batches | lr 0.31 | ms/batch 21.21 | loss  0.77 | ppl     2.15
# | epoch  12 |   150/  256 batches | lr 0.31 | ms/batch 21.98 | loss  0.77 | ppl     2.15
# | epoch  12 |   200/  256 batches | lr 0.31 | ms/batch 21.32 | loss  0.76 | ppl     2.14
# | epoch  12 |   250/  256 batches | lr 0.31 | ms/batch 22.10 | loss  0.74 | ppl     2.09
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time:  6.34s | valid loss  0.75 | valid ppl     2.12
# -----------------------------------------------------------------------------------------
# | epoch  13 |    50/  256 batches | lr 0.08 | ms/batch 22.00 | loss  0.80 | ppl     2.22
# | epoch  13 |   100/  256 batches | lr 0.08 | ms/batch 21.25 | loss  0.76 | ppl     2.14
# | epoch  13 |   150/  256 batches | lr 0.08 | ms/batch 21.65 | loss  0.76 | ppl     2.14
# | epoch  13 |   200/  256 batches | lr 0.08 | ms/batch 21.76 | loss  0.76 | ppl     2.13
# | epoch  13 |   250/  256 batches | lr 0.08 | ms/batch 21.66 | loss  0.73 | ppl     2.07
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time:  6.31s | valid loss  0.73 | valid ppl     2.08
# -----------------------------------------------------------------------------------------
# | epoch  14 |    50/  256 batches | lr 0.08 | ms/batch 22.98 | loss  0.79 | ppl     2.21
# | epoch  14 |   100/  256 batches | lr 0.08 | ms/batch 21.46 | loss  0.76 | ppl     2.14
# | epoch  14 |   150/  256 batches | lr 0.08 | ms/batch 22.12 | loss  0.76 | ppl     2.14
# | epoch  14 |   200/  256 batches | lr 0.08 | ms/batch 21.51 | loss  0.76 | ppl     2.13
# | epoch  14 |   250/  256 batches | lr 0.08 | ms/batch 21.05 | loss  0.73 | ppl     2.07
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  6.35s | valid loss  0.73 | valid ppl     2.08
# -----------------------------------------------------------------------------------------
# | epoch  15 |    50/  256 batches | lr 0.08 | ms/batch 22.04 | loss  0.79 | ppl     2.21
# | epoch  15 |   100/  256 batches | lr 0.08 | ms/batch 22.15 | loss  0.76 | ppl     2.13
# | epoch  15 |   150/  256 batches | lr 0.08 | ms/batch 21.34 | loss  0.76 | ppl     2.14
# | epoch  15 |   200/  256 batches | lr 0.08 | ms/batch 21.29 | loss  0.75 | ppl     2.12
# | epoch  15 |   250/  256 batches | lr 0.08 | ms/batch 21.43 | loss  0.73 | ppl     2.07
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  6.30s | valid loss  0.73 | valid ppl     2.08
# -----------------------------------------------------------------------------------------
# | epoch  16 |    50/  256 batches | lr 0.02 | ms/batch 22.46 | loss  0.79 | ppl     2.20
# | epoch  16 |   100/  256 batches | lr 0.02 | ms/batch 21.57 | loss  0.75 | ppl     2.13
# | epoch  16 |   150/  256 batches | lr 0.02 | ms/batch 21.32 | loss  0.76 | ppl     2.13
# | epoch  16 |   200/  256 batches | lr 0.02 | ms/batch 21.69 | loss  0.75 | ppl     2.12
# | epoch  16 |   250/  256 batches | lr 0.02 | ms/batch 22.34 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time:  6.36s | valid loss  0.73 | valid ppl     2.08
# -----------------------------------------------------------------------------------------
# | epoch  17 |    50/  256 batches | lr 0.02 | ms/batch 21.69 | loss  0.79 | ppl     2.20
# | epoch  17 |   100/  256 batches | lr 0.02 | ms/batch 21.95 | loss  0.75 | ppl     2.12
# | epoch  17 |   150/  256 batches | lr 0.02 | ms/batch 21.54 | loss  0.76 | ppl     2.13
# | epoch  17 |   200/  256 batches | lr 0.02 | ms/batch 22.30 | loss  0.75 | ppl     2.11
# | epoch  17 |   250/  256 batches | lr 0.02 | ms/batch 21.80 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time:  6.39s | valid loss  0.73 | valid ppl     2.08
# -----------------------------------------------------------------------------------------
# | epoch  18 |    50/  256 batches | lr 0.02 | ms/batch 21.93 | loss  0.79 | ppl     2.20
# | epoch  18 |   100/  256 batches | lr 0.02 | ms/batch 21.96 | loss  0.75 | ppl     2.12
# | epoch  18 |   150/  256 batches | lr 0.02 | ms/batch 21.37 | loss  0.75 | ppl     2.13
# | epoch  18 |   200/  256 batches | lr 0.02 | ms/batch 21.59 | loss  0.75 | ppl     2.11
# | epoch  18 |   250/  256 batches | lr 0.02 | ms/batch 21.26 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  6.30s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  19 |    50/  256 batches | lr 0.02 | ms/batch 22.58 | loss  0.79 | ppl     2.20
# | epoch  19 |   100/  256 batches | lr 0.02 | ms/batch 21.76 | loss  0.75 | ppl     2.12
# | epoch  19 |   150/  256 batches | lr 0.02 | ms/batch 21.56 | loss  0.75 | ppl     2.12
# | epoch  19 |   200/  256 batches | lr 0.02 | ms/batch 21.58 | loss  0.75 | ppl     2.12
# | epoch  19 |   250/  256 batches | lr 0.02 | ms/batch 22.27 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  6.38s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  20 |    50/  256 batches | lr 0.02 | ms/batch 21.98 | loss  0.79 | ppl     2.19
# | epoch  20 |   100/  256 batches | lr 0.02 | ms/batch 21.49 | loss  0.75 | ppl     2.12
# | epoch  20 |   150/  256 batches | lr 0.02 | ms/batch 21.76 | loss  0.75 | ppl     2.12
# | epoch  20 |   200/  256 batches | lr 0.02 | ms/batch 22.14 | loss  0.75 | ppl     2.12
# | epoch  20 |   250/  256 batches | lr 0.02 | ms/batch 21.69 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  6.36s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  21 |    50/  256 batches | lr 0.00 | ms/batch 21.94 | loss  0.79 | ppl     2.20
# | epoch  21 |   100/  256 batches | lr 0.00 | ms/batch 21.70 | loss  0.75 | ppl     2.12
# | epoch  21 |   150/  256 batches | lr 0.00 | ms/batch 22.36 | loss  0.75 | ppl     2.12
# | epoch  21 |   200/  256 batches | lr 0.00 | ms/batch 21.63 | loss  0.75 | ppl     2.11
# | epoch  21 |   250/  256 batches | lr 0.00 | ms/batch 22.46 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time:  6.46s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  22 |    50/  256 batches | lr 0.00 | ms/batch 23.81 | loss  0.79 | ppl     2.19
# | epoch  22 |   100/  256 batches | lr 0.00 | ms/batch 25.54 | loss  0.75 | ppl     2.12
# | epoch  22 |   150/  256 batches | lr 0.00 | ms/batch 24.23 | loss  0.75 | ppl     2.13
# | epoch  22 |   200/  256 batches | lr 0.00 | ms/batch 25.39 | loss  0.75 | ppl     2.11
# | epoch  22 |   250/  256 batches | lr 0.00 | ms/batch 23.63 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time:  7.18s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  23 |    50/  256 batches | lr 0.00 | ms/batch 29.68 | loss  0.79 | ppl     2.19
# | epoch  23 |   100/  256 batches | lr 0.00 | ms/batch 26.62 | loss  0.75 | ppl     2.11
# | epoch  23 |   150/  256 batches | lr 0.00 | ms/batch 27.94 | loss  0.75 | ppl     2.12
# | epoch  23 |   200/  256 batches | lr 0.00 | ms/batch 29.03 | loss  0.75 | ppl     2.11
# | epoch  23 |   250/  256 batches | lr 0.00 | ms/batch 29.38 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time:  8.32s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  24 |    50/  256 batches | lr 0.00 | ms/batch 26.90 | loss  0.78 | ppl     2.19
# | epoch  24 |   100/  256 batches | lr 0.00 | ms/batch 24.88 | loss  0.75 | ppl     2.11
# | epoch  24 |   150/  256 batches | lr 0.00 | ms/batch 26.83 | loss  0.75 | ppl     2.12
# | epoch  24 |   200/  256 batches | lr 0.00 | ms/batch 30.42 | loss  0.75 | ppl     2.11
# | epoch  24 |   250/  256 batches | lr 0.00 | ms/batch 30.59 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time:  8.13s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  25 |    50/  256 batches | lr 0.00 | ms/batch 25.66 | loss  0.78 | ppl     2.19
# | epoch  25 |   100/  256 batches | lr 0.00 | ms/batch 27.54 | loss  0.75 | ppl     2.11
# | epoch  25 |   150/  256 batches | lr 0.00 | ms/batch 29.52 | loss  0.75 | ppl     2.12
# | epoch  25 |   200/  256 batches | lr 0.00 | ms/batch 29.17 | loss  0.75 | ppl     2.11
# | epoch  25 |   250/  256 batches | lr 0.00 | ms/batch 27.03 | loss  0.72 | ppl     2.06
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time:  8.17s | valid loss  0.73 | valid ppl     2.07
# -----------------------------------------------------------------------------------------
# | epoch  26 |    50/  256 batches | lr 0.00 | ms/batch 30.42 | loss  0.78 | ppl     2.19
# | epoch  26 |   100/  256 batches | lr 0.00 | ms/batch 30.75 | loss  0.75 | ppl     2.12
# | epoch  26 |   150/  256 batches | lr 0.00 | ms/batch 28.00 | loss  0.75 | ppl     2.12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6c943b32142b> in <module>()
#       4 for epoch in range(1, args.epochs+1):
#       5     epoch_start_time = time.time()
# ----> 6     train()
#       7     val_loss = evaluate(val_data, val_data_lbls)
#       8     print('-' * 89)
#
# <ipython-input-20-839af502d1e3> in train()
#      49         output, hidden = model(data, hidden)
#      50         loss = criterion(output.view(-1, nlabels), targets)
# ---> 51         loss.backward()
#      52
#      53         clipped_lr = lr * clip_gradient(model, args.clip)
#
# /Users/simon.hughes/anaconda3/envs/pytorch_src/lib/python3.5/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_variables)
#     143                     'or with gradient w.r.t. the variable')
#     144             gradient = self.data.new().resize_as_(self.data).fill_(1)
# --> 145         self._execution_engine.run_backward((self,), (gradient,), retain_variables)
#     146
#     147     def register_hook(self, hook):
#
# /Users/simon.hughes/anaconda3/envs/pytorch_src/lib/python3.5/site-packages/torch/nn/_functions/linear.py in backward(self, grad_output)
#      22             grad_input = torch.mm(grad_output, weight)
#      23         if self.needs_input_grad[1]:
# ---> 24             grad_weight = torch.mm(grad_output.t(), input)
#      25         if bias is not None and self.needs_input_grad[2]:
#      26             grad_bias = torch.mv(grad_output.t(), self.add_buffer)
#
# KeyboardInterrupt:

# %%
def words_to_ids(sentence):
    wds = sentence.strip().split(" ")
    if(len(wds)) < args.bptt:
        diff = args.bptt - len(wds)
        sentence = sentence.strip() + (" <eos>" * (diff+1))
        wds = sentence.strip().split(" ")
    ids = torch.LongTensor(len(wds))
    #print(len(wds), "words")
    token = 0
    for word in wds:
        ids[token] = corpus.dictionary.word2idx[word]
        token += 1
    return ids

sentence = "<sos> What leads to differences in the rates of coral bleaching . <eos>"
sentence = sentence.split(" ")
#hidden = model.init_hidden(eval_batch_size)
for i in range(len(sentence)):
    #model.zero_grad()
    hidden = model.init_hidden(eval_batch_size)
    up_to_this = " ".join(sentence[:i])
    ids = words_to_ids(up_to_this)# pad to length
    batch = batchify(ids, eval_batch_size)
    inputs, _ = get_batch(batch, batch, 0, True)
    output, hidden = model(inputs, hidden)
    output_flat = output.view(-1, nlabels)
    word_weights = output.squeeze().data.exp().cpu()
    word_idx = torch.multinomial(word_weights, 1)[-1]
    word_idxs = list(word_idx)[0]
    tag = corpus.labels_dictionary.idx2word[word_idxs]
    print(sentence[i].strip().ljust(15), tag)
# Out:
# <sos>           3
# What            <sos>
# leads           <sos>
# to              <sos>
# differences     <sos>
# in              <eos>
# the             <sos>
# rates           <sos>
# of              4
# coral           <sos>
# bleaching       <sos>
# .               <sos>
# <eos>           <sos>

# %%
#TODO make sure eos markers not counted in accuracy metrics
