# %% [markdown]
# # Constants, Placeholders and Simple Arithmetic

# %% [markdown]
# ### Define Some Constants.

# %%
import tensorflow as tf
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0) # also tf.float32 implicitly
print(node1, node2)
# Out:
# Tensor("Const:0", shape=(), dtype=float32) Tensor("Const_1:0", shape=(), dtype=float32)

# %% [markdown]
# ### These Don't Have a Value unti They Are Ran in a Session

# %%
sess = tf.Session()
print(sess.run([node1, node2]))
# Out:
# [3.0, 4.0]

# %% [markdown]
# ### Addition Operator

# %%
node3 = tf.add(node1, node2)
print("node3: ", node3)
print("sess.run(node3): ",sess.run(node3))
# Out:
# node3:  Tensor("Add:0", shape=(), dtype=float32)
# sess.run(node3):  7.0

# %% [markdown]
# ### Placeholders Allow Inputs to the Graph to be Specified

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b  # + provides a shortcut for tf.add(a, b)

# %%
print(sess.run(adder_node, {a: 3, b:4.5}))
print(sess.run(adder_node, {a: [1,3], b: [2, 4]}))
# Out:
# 7.5
# [ 3.  7.]

# %%
add_and_triple = adder_node * 3.
print(sess.run(add_and_triple, {a: 3, b:4.5}))
# Out:
# 22.5

# %% [markdown]
# # Define a Linear Model
# Has Variables, which Can be Updated Within the Graph

# %%
W = tf.Variable([.3], tf.float32)
b = tf.Variable([-.3], tf.float32)
x = tf.placeholder(tf.float32)
linear_model = W * x + b

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# ### Loss Function for Linear Model

# %%
y = tf.placeholder(tf.float32)
squared_deltas = tf.square(linear_model - y)
loss = tf.reduce_sum(squared_deltas)
print(sess.run(loss, {x:[1,2,3,4], y:[0,-1,-2,-3]}))
# Out:
# 23.66

# %% [markdown]
# ### We Can Fix The Variable Values if We Like

# %%
fixW = tf.assign(W, [-1.])
fixb = tf.assign(b, [1.])
sess.run([fixW, fixb])
print(sess.run(loss, {x:[1,2,3,4], y:[0,-1,-2,-3]}))
# Out:
# 0.0

# %% [markdown]
# ## Let's Train The Model
# Use Gradient Descent to Miminimize the Loss Function

# %%
optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)

# %%
sess.run(init) # reset values to incorrect defaults.
for i in range(1000):
    sess.run(train, {x:[1,2,3,4], y:[0,-1,-2,-3]})

print(sess.run([W, b]))
# Out:
# [array([-0.9999969], dtype=float32), array([ 0.99999082], dtype=float32)]

# %% [markdown]
# # Final Linear Model Solution (All in One)

# %%
import numpy as np
import tensorflow as tf

# Model parameters
W = tf.Variable([.3], tf.float32)
b = tf.Variable([-.3], tf.float32)
# Model input and output
x = tf.placeholder(tf.float32)
linear_model = W * x + b
y = tf.placeholder(tf.float32)
# loss
loss = tf.reduce_sum(tf.square(linear_model - y)) # sum of the squares
# optimizer
optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)
# training data
x_train = [1,2,3,4]
y_train = [0,-1,-2,-3]
# training loop
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init) # reset values to wrong
for i in range(1000):
    sess.run(train, {x:x_train, y:y_train})

# evaluate training accuracy
curr_W, curr_b, curr_loss  = sess.run([W, b, loss], {x:x_train, y:y_train})
print("W: %s b: %s loss: %s"%(curr_W, curr_b, curr_loss))
# Out:
# W: [-0.9999969] b: [ 0.99999082] loss: 5.69997e-11

# %%
import tensorflow.contrib.learn
#from tensorflow.contrib.learn.models.
