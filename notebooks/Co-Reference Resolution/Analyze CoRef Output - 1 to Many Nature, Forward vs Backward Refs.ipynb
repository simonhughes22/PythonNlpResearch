# %%
import dill

#from gensim.models import Word2Vec
from window_based_tagger_config import get_config
from Rpfa import micro_rpfa

import logging
import datetime
import pickle

from CoRefHelper import parse_stanfordnlp_tagged_essays, bratt_essays_2_hash_map
from CrossValidation import cross_validation
from BrattEssay import load_bratt_essays
from load_data import load_process_essays
from collections import defaultdict
from IterableFP import flatten
from Settings import Settings
from FindFiles import find_files

CV_FOLDS = 5
DEV_SPLIT = 0.1

settings = Settings()
root_folder = settings.data_directory + "CoralBleaching/Thesis_Dataset/"
# Out:
# Results Dir: /Users/simon.hughes/Google Drive/Phd/Results/
# Data Dir:    /Users/simon.hughes/Google Drive/Phd/Data/
# Root Dir:    /Users/simon.hughes/GitHub/NlpResearch/
# Public Data: /Users/simon.hughes/GitHub/NlpResearch/Data/PublicDatasets/

# %% [markdown]
# ## Load CoRef Parsed Essays

# %%
coref_folder_train = root_folder + "CoReference/Training"
coref_files_train = find_files(coref_folder_train, ".*\.tagged")
len(coref_files_train)
# Out:
# 902

# %%
coref_folder_test = root_folder + "CoReference/Test"
coref_files_test = find_files(coref_folder_test, ".*\.tagged")
len(coref_files_test)
# Out:
# 226

# %%
essay2coref_train = parse_stanfordnlp_tagged_essays(coref_files_train)
print(len(essay2coref_train))
# Out:
# 902

# %%
essay2coref_test = parse_stanfordnlp_tagged_essays(coref_files_test)
print(len(essay2coref_test))
# Out:
# 226

# %% [markdown]
# ### Examine Data Structure

# %%
e = essay2coref_train["EBA1415_AEKD_4_CB_ES-05568"]
e[0]
# Out:
# [('what', {'NER': 'O', 'POS': 'WDT'}),
#  ('leads', {'NER': 'O', 'POS': 'VBZ'}),
#  ('to', {'NER': 'O', 'POS': 'TO'}),
#  ('differences', {'NER': 'O', 'POS': 'NNS'}),
#  ('in', {'NER': 'O', 'POS': 'IN'}),
#  ('the', {'NER': 'O', 'POS': 'DT'}),
#  ('rates', {'NER': 'O', 'POS': 'NNS'}),
#  ('of', {'NER': 'O', 'POS': 'IN'}),
#  ('coral', {'COREF_ID': '2', 'NER': 'O', 'POS': 'NN'}),
#  ('bleaching', {'COREF_ID': '2', 'NER': 'O', 'POS': 'NN'}),
#  ('.', {'NER': 'O', 'POS': '.'})]

# %% [markdown]
# ### Notes on CoRef Datastructure
# - Dictionary of esssays, keyed by name
# - Each essay is a list of sentences
# - Each sentence is a list of words
# - words are mapped to a tag dict
#   - tag dict - contains
#     - NER tag (most are O - none)
#     - POS tag
#     - If a Co-Reference such as an anaphor (mostly pronouns)
#       - COREF_PHRASE - phrase referred to by coref
#       - COREF_REF - Id of referenced phrase
#     - else if it is a phrase that is referenced:
#       - COREF_ID - id of the co-reference, referenced in the COREF_REF tag

# %%
COREF_ID = "COREF_ID"
COREF_REF = "COREF_REF"

id2coref_tally = {}
id2fwdrefs = defaultdict(int)

essays_with_dupes = defaultdict(set)

for ename, list_sent in list(essay2coref_train.items()):
    matching_ix = -1
    essay_ref_tally = defaultdict(int)
    seen_ids = set()
    for sentix, sent in enumerate(list_sent):
        
        current_ref = ""
        current_id = ""
        
        for wd, tag_dict in sent:
            if COREF_ID in tag_dict:
                idval = tag_dict[COREF_ID]
                if idval != current_id:
                    # new/changed
                    current_id = idval
                    if idval in seen_ids:
                        essays_with_dupes[ename].add(idval)
                    seen_ids.add(idval)
            else:
                current_id = ""
            if COREF_REF in tag_dict:
                refval = tag_dict[COREF_REF]
                if refval != current_ref:
                    essay_ref_tally[refval] += 1
                    # new/changed
                    current_ref = refval
            else:
                current_ref = ""
        
        for ref, cnt in sent_ref_tally.items():
            if cnt > 0:
                id2coref_tally[(ename,sentix,ref)] = cnt

# %% [markdown]
# ## How Many Mentions on Average Per Sentence?

# %%
import numpy as np
# number of references per id, ONLY for sentences that have one or more co-refs
vals = list(id2coref_tally.values())
np.mean(vals)
# Out:
# 1.2058823529411764

# %%
def print_corefs_in_essay(essay):
    sent_ixs = set()
    for sentix, sent in enumerate(essay):      
        for wd, tag_dict in sent:
            if "COREF_ID" in tag_dict:
                sent_ixs.add(sentix)
            if "COREF_REF" in tag_dict:
                sent_ixs.add(sentix)
                
    for sentix, sent in enumerate(essay):
        if sentix in sent_ixs:
            for wd, tag_dict in sent:
                copy = dict([(k,v) for k,v in tag_dict.items() if k in {"COREF_ID", "COREF_REF", "COREF_PHRASE"}])
                print(wd.ljust(20), copy if copy else "")
            print("*" * 80)

# %%
essays_with_dupes
# Out:
# defaultdict(set,
#             {'EBA1415_BLRW_3_CB_ES-05173': {'3'},
#              'EBA1415_BLRW_3_CB_ES-05185': {'1'},
#              'EBA1415_BLRW_3_CB_ES-05480': {'8'},
#              'EBA1415_BLRW_5_CB_ES-05198': {'2'},
#              'EBA1415_KYLS_5_CB_ES-05647': {'5'},
#              'EBA1415_KYNS_4_CB_ES-05393': {'1'},
#              'EBA1415_RCGJ_4a_CB_ES-04684': {'5'},
#              'EBA1415_SDLC_8_CB_ES-05920': {'9'},
#              'EBA1415_SWCT_7_CB-04891': {'3'},
#              'EBA1415_TWMD_45_CB_ES-04994': {'3'},
#              'EBA1415_WSKT_6_CB_ES-05343': {'1'},
#              'EBA1415post_TWDG_11_CB_ES-05461': {'1'}})

# %%
ename = "EBA1415_KYNS_4_CB_ES-05393"
print(essays_with_dupes[ename])
print_corefs_in_essay(essay2coref_train[ename])
# Out:
# {'1'}
# looking
# at
# the
# graph
# of
# trade
# winds
# and
# coral
# bleaching
# it
# helps
# show
# what
# leads
# to
# differences
# in
# the
# rates
# of
# coral                {'COREF_ID': '4'}
# bleaching            {'COREF_ID': '4'}
# .
# ********************************************************************************
# in
# 0000
# trade
# winds
# got
# severly
# weaker
# going
# down
# to
# -
# 0                    {'COREF_ID': '7'}
# .
# ********************************************************************************
# weaker               {'COREF_ID': '2'}
# trade                {'COREF_ID': '2'}
# winds                {'COREF_ID': '2'}
# are
# causing
# coral
# bleaching
# to
# rise
# .
# ********************************************************************************
# polyps               {'COREF_REF': '5', 'COREF_PHRASE': 'the_polyps'}
# created
# corals               {'COREF_REF': '3', 'COREF_PHRASE': 'the_corals'}
# around
# from
# us
# a
# protection
# barrier
# .
# ********************************************************************************
# coral
# reefs
# need
# co2
# from
# the                  {'COREF_ID': '1'}
# photosynthesis       {'COREF_ID': '1'}
# the                  {'COREF_ID': '5'}
# polyps               {'COREF_ID': '5'}
# go                   {'COREF_ID': '1'}
# through              {'COREF_ID': '1'}
# to                   {'COREF_ID': '1'}
# recieve              {'COREF_ID': '1'}
# energy               {'COREF_ID': '1'}
# to                   {'COREF_ID': '1'}
# give                 {'COREF_ID': '1'}
# to                   {'COREF_ID': '1'}
# the                  {'COREF_ID': '1'}
# coral                {'COREF_ID': '1'}
# which                {'COREF_ID': '1'}
# they                 {'COREF_REF': '5', 'COREF_ID': '1', 'COREF_PHRASE': 'the_polyps'}
# need                 {'COREF_ID': '1'}
# 00                   {'COREF_ID': '1'}
# %                    {'COREF_ID': '1'}
# to                   {'COREF_ID': '1'}
# 00                   {'COREF_ID': '1'}
# %                    {'COREF_ID': '1'}
# of                   {'COREF_ID': '1'}
# .
# ********************************************************************************
# the
# process
# is
# very
# sensitive
# to
# changes
# in
# enviroment
# so
# if
# the                  {'COREF_REF': '2', 'COREF_PHRASE': 'weaker_trade_winds'}
# trade                {'COREF_REF': '2', 'COREF_PHRASE': 'weaker_trade_winds'}
# winds                {'COREF_REF': '2', 'COREF_PHRASE': 'weaker_trade_winds'}
# change
# the
# temperature
# in
# the
# water
# the                  {'COREF_REF': '1', 'COREF_PHRASE': 'the_photosynthesis_the_polyps_go_through_to_recieve_energy_to_give_to_the_coral_which_they_need_00_%_to_00_%_of'}
# photosynthesis       {'COREF_REF': '1', 'COREF_PHRASE': 'the_photosynthesis_the_polyps_go_through_to_recieve_energy_to_give_to_the_coral_which_they_need_00_%_to_00_%_of'}
# will
# change
# ,
# and
# become
# incomplete
# .
# ********************************************************************************
# this                 {'COREF_REF': '2', 'COREF_PHRASE': 'weaker_trade_winds'}
# will
# cause
# not
# enough
# energy
# to
# be
# given
# to
# the
# coral
# when
# will
# lead
# to
# decoration
# or
# coral
# bleaching
# .
# ********************************************************************************
# if
# the                  {'COREF_ID': '6'}
# algae                {'COREF_ID': '6'}
# called               {'COREF_ID': '6'}
# zooxanthe            {'COREF_ID': '6'}
# can
# not
# complete
# photosynthesis
# they                 {'COREF_REF': '6', 'COREF_PHRASE': 'the_algae_called_zooxanthe'}
# wont
# be
# able
# to
# give
# the                  {'COREF_ID': '8'}
# coral                {'COREF_ID': '8'}
# it                   {'COREF_REF': '8', 'COREF_PHRASE': 'the_coral'}
# color
# .
# ********************************************************************************
# the                  {'COREF_REF': '6', 'COREF_PHRASE': 'the_algae_called_zooxanthe'}
# algae                {'COREF_REF': '6', 'COREF_PHRASE': 'the_algae_called_zooxanthe'}
# rely
# on
# the
# coral
# to
# stay
# healthy
# ,
# just
# like
# the                  {'COREF_ID': '3'}
# corals               {'COREF_ID': '3'}
# defend
# on
# the                  {'COREF_REF': '6', 'COREF_PHRASE': 'the_algae_called_zooxanthe'}
# algae                {'COREF_REF': '6', 'COREF_PHRASE': 'the_algae_called_zooxanthe'}
# for
# their                {'COREF_REF': '3', 'COREF_PHRASE': 'the_corals'}
# colors
# .
# ********************************************************************************

# %%
for ename, list_sent in list(essay2coref_train.items())[400:][:100]:
    matching_ix = -1
    for ix, sent in enumerate(list_sent):
        found_id = False
        found_ref = False
        for wd, tag_dict in sent:
            if "COREF_ID" in tag_dict:
                found_id = True
            if "COREF_REF" in tag_dict:
                found_ref = True
        if found_id and found_ref:
            matching_ix = ix
            break
            
    if found_id and found_ref:
        print(ename)
        print()
        for sent in list_sent: #[:matching_ix+1]:
            for wd, tag_dict in sent:
                copy = dict([(k,v) for k,v in tag_dict.items() if k in {"COREF_ID", "COREF_REF", "COREF_PHRASE"}])
                print(wd.ljust(20), copy if copy else "")
            print("*" * 80)
        break
# Out:
# EBA1415_SEAL_34_CB_ES-04796
#
# what
# leads
# to
# differences
# in
# the
# rate
# of
# coral                {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# bleaching            {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# ?
# ********************************************************************************
# coral                {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# bleaching            {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# is
# a
# phenomenon
# in
# which
# coral                {'COREF_REF': '3', 'COREF_PHRASE': 'the_coral'}
# lose
# it                   {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# color
# .
# ********************************************************************************
# coral                {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# bleaching            {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# is
# mostly
# noticeable
# in
# pacific              {'COREF_ID': '4'}
# ocean                {'COREF_ID': '4'}
# .
# ********************************************************************************
# the                  {'COREF_REF': '4', 'COREF_PHRASE': 'pacific_ocean'}
# ocean                {'COREF_REF': '4', 'COREF_PHRASE': 'pacific_ocean'}
# covers
# about
# 0
# 0
# of
# the
# surface
# in
# the
# global
# .
# ********************************************************************************
# if
# the                  {'COREF_ID': '1'}
# amount               {'COREF_ID': '1'}
# of                   {'COREF_ID': '1'}
# co2                  {'COREF_ID': '1'}
# is
# lower
# than
# normal
# ,
# it                   {'COREF_REF': '1', 'COREF_PHRASE': 'the_amount_of_co2'}
# can
# be
# bad
# for
# the                  {'COREF_ID': '3'}
# coral                {'COREF_ID': '3'}
# .
# ********************************************************************************
# it                   {'COREF_REF': '1', 'COREF_PHRASE': 'the_amount_of_co2'}
# is
# estimated
# that
# coral                {'COREF_REF': '3', 'COREF_PHRASE': 'the_coral'}
# recieve
# 00
# %
# -
# 00
# %
# of
# there
# energy
# from
# this
# process
# .
# ********************************************************************************
# as
# long
# as
# there
# is
# sunlight
# and
# the
# normal
# amount
# of
# co2
# the
# coral
# will
# recieve
# the
# proper
# energy
# needed
# for
# the
# coral
# .
# ********************************************************************************
# as
# the
# water
# temperature
# increase
# and
# co2
# decrease
# will
# delicate
# balance
# required
# to
# coral
# healthy
# .
# ********************************************************************************
# in
# conclusion
# the                  {'COREF_ID': '5'}
# coral                {'COREF_ID': '5'}
# bleaching            {'COREF_ID': '5'}
# is
# caused
# by
# the
# co2
# in
# the
# water
# .
# ********************************************************************************
# if
# the                  {'COREF_ID': '2'}
# coral                {'COREF_ID': '2'}
# doesnt               {'COREF_ID': '2'}
# get
# what
# is
# supposed
# to
# get
# healthy
# it                   {'COREF_REF': '2', 'COREF_PHRASE': 'the_coral_doesnt'}
# will
# die
# or
# will
# lead
# to
# bleaching
# .
# ********************************************************************************
# coral                {'COREF_REF': '3', 'COREF_PHRASE': 'the_coral'}
# is
# like
# humans
# .
# ********************************************************************************
# if
# you
# dont
# live
# in
# a
# safe
# enviroment
# it                   {'COREF_REF': '5', 'COREF_PHRASE': 'the_coral_bleaching'}
# will
# lead
# to
# coral
# bleaching
# .
# ********************************************************************************
