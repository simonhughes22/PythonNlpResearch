# %%
# !pip uninstall numpy scipy -y
# !pip uninstall scikit-learn -y

# %%
# !conda uninstall scipy -y

# %%
# !conda install numpy scipy scikit-learn -y

# %%
# !pip install pymongo

# %%
import datetime
import logging
from collections import defaultdict

import dill
import numpy as np
import pymongo
# import pandas as pd
from sklearn.linear_model import LogisticRegression
from typing import Any

from CrossValidation import cross_validation
from Settings import Settings
from cost_functions import *
from crel_helper import get_cr_tags
from function_helpers import get_function_names, get_functions_by_name
from results_procesor import ResultsProcessor, __MICRO_F1__
from searn_parser import SearnModelTemplateFeatures
from template_feature_extractor import *
from window_based_tagger_config import get_config
from wordtagginghelper import merge_dictionaries

import sys
sys.path.append("/Users/simon.hughes/GitHub/NlpResearch/PythonNlpResearch/notebooks/Co-Reference Resolution/Results")

from results_common import get_essays

# %%
client = pymongo.MongoClient()
db = client.metrics

# Data Set Partition
CV_FOLDS = 5
MIN_FEAT_FREQ = 5

# Global settings

settings = Settings()
root_folder = settings.data_directory + "CoralBleaching/Thesis_Dataset/"
training_folder = root_folder + "Training" + "/"
test_folder = root_folder + "Test" + "/"
# NOTE: These predictions are generated from the "./notebooks/SEARN/Keras 
#  - Train Tagger and Save CV Predictions For Word Tags.ipynb" notebook
# used as inputs to parsing model
coref_root = root_folder + "CoReference/"
coref_output_folder = coref_root + "CRel/"

config = get_config(training_folder)

# %%
train_fname = coref_output_folder + "training_crel_anatagged_essays_most_recent_code.dill"
with open(train_fname, "rb") as f:
    pred_tagged_essays_train = dill.load(f)

test_fname = coref_output_folder + "test_crel_anatagged_essays_most_recent_code.dill"
with open(test_fname, "rb") as f:
    pred_tagged_essays_test = dill.load(f)

len(pred_tagged_essays_train),len(pred_tagged_essays_test)

# %%
# doesn't matter with parser for this
stanford_coref_predictions_folder = root_folder + "CoReference/"

orig_pred_tagged_essays_train = get_essays(stanford_coref_predictions_folder, "Training")
orig_pred_tagged_essays_test  = get_essays(stanford_coref_predictions_folder, "Test")

# %%
# len(e.sentences), len(e.pred_corefids)

# %%
ixs = defaultdict(set)
for eix, e in enumerate(orig_pred_tagged_essays_train):
    for i in range(len(e.sentences)):
        for (wd,tags), corefs in (list(zip(e.sentences[i], e.pred_corefids[i]))):
            if corefs:
                ixs[eix].add(i)


for i in list(ixs.keys())[:20]:
    e = orig_pred_tagged_essays_train[i]
    sixs = ixs[i]
    for i in sixs:
        for (wd,tags), corefs in (list(zip(e.sentences[i], e.pred_corefids[i]))):
            stags = ",".join(tags).replace("Causer","").replace("Result","").replace(":","")
            print(wd.ljust(15), stags, "\t|", ",".join(corefs))
# Out:
# coral            	|
# is               	|
# often            	|
# mistaken         	|
# for              	|
# a                	| 1
# rock             	| 1
# but              	|
# it               	| 1
# is               	|
# made             	|
# up               	|
# of               	|
# tiny             	|
# animals          	|
# called           	|
# polyps           	|
# .                	|
# and              	|
# if               	|
# they            5->50,5,5,Anaphor[5],,Anaphor 	| 1
# dont            ,5->50,5,5 	|
# get             ,5->50,5,5 	|
# or              ,5->50,5,5 	|
# much            ,5->50,5,5 	|
# sunlight        ,5->50,5,5 	|
# they            5->50 	|
# start           5->50,explicit 	|
# to              5->50 	|
# loses           ,5->50,50,50 	|
# their           ,5->50,50,50 	| 1
# color           ,5->50,50,50 	|
# .                	|
# the              	| 2
# coral            	| 2
# also             	|
# need             	|
# special          	|
# water            	|
# temperature      	|
# because          	|
# they             	| 2
# are              	|
# sensitive        	|
# .                	|
# what             	|
# leads            	|
# to               	|
# different        	|
# in               	|
# the              	|
# rates            	|
# of               	|
# coral           50 	|
# bleaching       50 	|
# is               	|
# that             	|
# INFREQUENT       	|
# different        	|
# types            	|
# of               	|
# INFREQUENT      ,7->50,7 	|
# living          ,7->50,7 	|
# within          ,7->50,7 	|
# the             ,7->50,7 	|
# coral           ,7->50,7 	|
# polyps          7->50 	|
# gives           7->50,explicit 	|
# the             7->50 	| 1
# coral           ,7->50,50 	| 1
# their           ,7->50,50 	| 1
# varying         ,7->50,50 	|
# colors          ,7->50,50 	|
# .                	|
# coral            	| 3
# reefs            	| 3
# are              	|
# only             	|
# found            	|
# in               	|
# clear            	|
# ,                	|
# shallow          	|
# ,                	|
# tropical         	|
# waters           	|
# .                	|
# "                	|
# because          	|
# if               	|
# they             	| 3
# INFREQUENT       	|
# in               	|
# that             	|
# type             	|
# pf               	|
# water            	|
# they             	| 3
# would            	|
# die              	|
# .                	|
# coral           50 	| 2
# bleaching       50 	| 2
# is              50 	|
# a               50 	|
# phenomenon      50 	|
# in              50 	|
# which           50 	|
# loses           50 	|
# its             50 	| 2
# color           50 	|
# .                	|
# i                	|
# read             	|
# over             	|
# marine           	|
# INFREQUENT       	|
# and              	|
# has              	|
# been             	|
# discovered       	|
# that             	|
# there            	|
# are              	|
# many             	|
# different        	|
# types            	|
# of               	|
# corals           	|
# that             	|
# live             	|
# in               	|
# the              	|
# ocean            	|
# that             	|
# live             	|
# close            	|
# to               	|
# the              	| 3
# animals          	| 3
# and              	|
# loses           50 	|
# their           50 	| 3
# color           50 	|
# .                	|
# coral            	| 1
# and              	| 1
# photosynthesis   	| 1
# coral            	| 1
# is               	|
# often            	|
# mistaken         	|
# for              	|
# a                	|
# rock             	|
# or               	|
# plant            	|
# however          	|
# ,                	|
# it               	| 1
# is               	|
# really           	|
# made             	|
# up               	|
# of               	|
# tiny             	|
# animals          	|
# called           	|
# polyps           	|
# .                	|
# coral            	| 2
# and              	| 2
# zooanthallae     	| 2
# coral            	| 2
# and              	| 2
# zooxanthallae    	| 2,4
# algae            	| 2,4
# have             	|
# a                	|
# symbiotic        	|
# relationship     	|
# .                	|
# this             	|
# means            	|
# that             	|
# they             	| 2
# both             	|
# benefit          	|
# from             	|
# their            	| 2
# relationship     	|
# with             	|
# each             	|
# other            	|
# .                	|
# the              	| 4
# algae            	| 4
# rely             	|
# on               	|
# the              	|
# coral            	|
# to               	|
# stay             	|
# healthy          	|
# but              	|
# corals           	|
# can              	|
# sustain          	|
# physical         	|
# damage           	|
# from             	|
# some             	|
# destructive      	|
# practices        	|
# .                	|
# normal           	| 1
# corals           	| 1
# is               	|
# made             	|
# up               	|
# of               	|
# tiny             	|
# animals          	|
# called           	|
# polyps           	|
# .                	|
# their            	| 1
# mouth            	|
# surrounded       	|
# by               	|
# stinging         	|
# tentacles        	|
# .                	|
# polyps           	|
# use              	|
# limestone        	|
# from             	|
# seawater         	|
# to               	|
# build            	|
# a                	|
# hard             	|
# skeleton         	|
# and              	|
# protect          	|
# their            	| 1
# delicate         	|
# body             	|
# .                	|
# some             	|
# differences      	|
# will             	|
# start            	|
# INFREQUENT       	|
# ,                	|
# like             	|
# some             	| 3
# consumers        	| 3
# of               	| 3
# coral            	| 3
# reef             	| 3
# ,                	| 3
# they             	| 3
# (                	| 3
# fishes           	| 3
# consumers        	| 3
# ,                	| 3
# )                	| 3
# will             	|
# starve           	|
# to               	|
# death            	|
# because          	|
# those            	| 3
# consumers        	| 3
# is               	|
# all              	|
# they             	| 3
# eat              	|
# .                	|
# then             	|
# the              	|
# other            	|
# ,                	|
# consumers        	| 1
# will             	|
# have             	|
# trouble          	|
# INFREQUENT       	|
# or               	|
# eating           	|
# their            	| 1
# food             	|
# due              	|
# to               	|
# lack             	|
# of               	|
# energy           	|
# .                	|
# it               	|
# will             	|
# then             	|
# become           	|
# a                	|
# slight           	|
# problem          	|
# to               	|
# larger           	| 2
# consumers        	| 2
# because          	|
# they             	| 2
# cant             	|
# find             	|
# food             	|
# .                	|
# like             	|
# fisherman        	|
# ,                	|
# they             	| 2
# find             	|
# fishes           	|
# to               	|
# INFREQUENT       	|
# and              	|
# if               	|
# they             	| 2
# cant             	|
# find             	|
# fishes           	|
# ,                	|
# other            	|
# consumers        	|
# starve           	|
# .                	|
# once             	|
# the              	|
# producers        	|
# in               	|
# the              	|
# ocean            	|
# die              	|
# out              	|
# ,                	|
# there            	|
# will             	|
# be               	|
# less             	|
# food             	|
# for              	|
# everyone         	|
# in               	|
# the              	| 4
# entire           	| 4
# world            	| 4
# .                	|
# if               	|
# the              	|
# coral            	|
# reef             	|
# die              	|
# out              	|
# ,                	|
# large            	|
# changes          	|
# in               	|
# the              	| 4
# world            	| 4
# would            	|
# be               	|
# notice           	|
# like             	|
# some             	|
# fishes           	|
# INFREQUENT       	|
# out              	|
# (                	|
# extinct          	|
# )                	|
# and              	|
# we               	|
# would            	|
# even             	|
# have             	|
# less             	|
# food             	|
# to               	|
# produce          	|
# due              	|
# to               	|
# INFREQUENT       	|
# of               	|
# an               	|
# animal           	|
# .                	|
# it               	|
# is               	|
# said             	|
# there            	|
# fresh           11 	| 3
# water           11 	| 3
# animals          	| 3
# and              	|
# in               	|
# the              	|
# shallow          	|
# tropical         	|
# water            	|
# .                	|
# so               	|
# they             	| 3
# cant            13 	|
# take            13 	|
# in              13 	|
# salt            13 	| 1
# water           13 	| 1
# .                	|
# it               	|
# is               	|
# good             	|
# for              	|
# the              	| 2
# corals           	| 2
# to               	|
# take             	|
# it               	| 2
# in               	|
# .                	|
# this             	| 4
# also             	|
# causes           	|
# in               	|
# with             	|
# tropical        11 	|
# storm           11 	|
# because          	|
# it               	| 4
# could            	|
# push            13 	|
# the             13 	| 1
# salty           13 	| 1
# water           13 	| 1
# into            13 	|
# their           13 	| 1
# environment     13 	|
# .                	|
# this             	|
# is               	|
# are              	|
# things           	|
# that             	|
# could            	|
# bleach          50 	|
# them            50 	| 1
# .                	|
# what             	|
# leads            	|
# to               	|
# differences      	|
# in               	|
# the              	|
# rates            	|
# of               	|
# coral           50 	| 1
# bleaching       50 	| 1
# is               	|
# that             	|
# once             	|
# that             	|
# happens          	|
# during           	|
# bleaching       ,7->50,50,50 	|
# it              ,7->50,50,50 	| 1
# turns           ,7->50,50,50 	|
# white           ,7->50,50,50 	|
# because         7->50,explicit 	|
# of              7->50 	|
# the             7->50 	|
# ejection        ,7->50,7,7 	|
# of              ,7->50,7,7 	|
# the             ,7->50,7,7 	|
# zooxanthellae   ,7->50,7,7 	|
# algae           ,7->50,7,7 	|
# it              ,7->50,7,7 	|
# means           ,7->50,7,7 	|
# it              ,7->50,7,7 	| 1
# has             ,7->50,7,7 	|
# been            ,7->50,7,7 	|
# dead            ,7->50,7,7 	|
# which            	|
# is               	|
# why              	|
# healthy          	|
# coral            	|
# is               	|
# a                	|
# much             	|
# INFREQUENT       	|
# color            	|
# and              	|
# the              	|
# bleached        50 	|
# coral           50 	|
# is              50 	|
# just            50 	|
# white           50 	|
# that             	|
# means            	|
# it               	| 1
# dead            COMPILED 	|
# .                	|
# coral           50 	|
# bleaching       50 	|
# INFREQUENT       	|
# most             	|
# in               	|
# the              	| 1
# pacific          	| 1
# ocean            	| 1
# .                	|
# the              	|
# different        	|
# types            	|
# of               	|
# algae           ,7->50,7 	|
# living          ,7->50,7 	|
# within          ,7->50,7 	|
# the             ,7->50,7 	|
# coral           ,7->50,7 	|
# polyps          ,7->50,7 	|
# give            7->50,explicit 	|
# the             7->50 	| 2
# corals          ,7->50,50 	| 2
# their           ,7->50,50 	| 2
# varying         ,7->50,50 	|
# colors          ,7->50,50 	|
# .                	|
# coral           50 	| 3
# bleaching       50 	| 3
# is              50 	|
# a               50 	|
# phenomenon      50 	|
# in              50 	|
# which           50 	|
# coral           50 	|
# loses           50 	|
# its             50 	| 3
# color           50 	|
# .                	|
# coral           50 	|
# bleaching       50 	|
# is               	|
# most             	|
# noticeable       	|
# in               	|
# the              	| 1
# pacific          	| 1
# ocean            	| 1
# .                	|
# this             	| 1
# ocean            	| 1
# covers           	|
# about            	|
# 0                	|
# 0                	|
# of               	|
# the              	|
# surface          	|
# of               	|
# the              	|
# entire           	|
# globe            	|
# ,                	|
# and              	|
# contains         	|
# double           	|
# the              	|
# amount           	|
# of               	|
# water            	|
# found            	|
# in               	|
# the              	| 1
# atlantic         	| 1
# ocean            	| 1
# .                	|
# coral           ,6->50,50,50 	| 1
# bleaching       ,6->50,50,50 	| 1
# comes           6->50 	|
# from            6->50 	|
# changes         6->50 	|
# of              6->50 	|
# it              6->50 	| 1
# enviroment      6->50 	|
# which           6->50,explicit 	|
# puts            ,6,6->50,6 	|
# stress          ,6,6->50,6 	|
# on              ,6,6->50,6 	|
# coral           6,6->50,6,COMPILED, 	|
# .                	|
# coral           50 	| 3
# bleaching       50 	| 3
# is              50 	|
# when            50 	|
# coral           50 	|
# loses           50 	|
# it              50 	| 3
# color           50 	|
# .                	|
# they             	| 3
# usually          	|
# vary             	|
# in               	|
# many             	|
# different        	|
# colors           	|
# but              	|
# when             	|
# they             	| 3
# get             50 	|
# bleached        50 	|
# they            50 	| 3
# turn            50 	|
# white           50 	|
# .                	|
# they             	| 3
# are              	|
# only             	|
# found            	|
# in               	|
# clear            	|
# ;                	|
# shallow          	|
# ,                	|
# tropical         	|
# waters           	|
# .                	|
# coral            	| 5
# reefs            	| 5
# are              	|
# made             	|
# up               	|
# of               	|
# polyp            	|
# .                	|
# over             	|
# time             	|
# the              	|
# polyp            	|
# INFREQUENT       	|
# ,                	|
# giving           	|
# the              	| 5
# coral            	| 5
# a                	|
# protective       	|
# skeleton         	|
# .                	|
# this             	|
# is               	|
# algae            	|
# lives            	|
# in               	|
# coral            	|
# tissues          	|
# and              	|
# need             	|
# light            	|
# for              	|
# the              	| 4
# process          	| 4
# of               	| 4
# photosynthesis   	| 4
# .                	|
# salinity         	|
# also             	|
# can              	|
# cause            	|
# harm             	|
# to               	|
# the              	| 5
# coral            	| 5
# .                	|
# when             	|
# the              	| 2
# salt            13 	| 2
# level           13 	| 2
# drops           13 	|
# in              13 	|
# water           13 	|
# it               	| 2
# may              	|
# also             	|
# affect           	|
# the              	|
# corals           	|
# health           	|
# .                	|
# the              	| 5
# coral           ,7->50,50,50 	| 5
# ends            ,7->50,50,50 	|
# up              ,7->50,50,50 	|
# bleaching       ,7->50,50,50 	|
# due             7->50,explicit 	|
# to              7->50,explicit 	|
# the             7->50 	|
# ejection        ,7->50,7,7 	|
# or              ,7->50,7,7 	|
# death           ,7->50,7,7 	|
# of              ,7->50,7,7 	|
# the             ,7->50,7,7 	|
# zooxanthellae   ,7->50,7,7 	|
# algae           ,7->50,7,7 	|
# .                	|
# when             	|
# the              	| 1
# corals          50 	| 1
# bleach          50 	| 1
# they             	| 1
# are              	|
# in               	|
# risk             	|
# of               	|
# disease          	|
# and              	|
# starvation      COMPILED 	|
# .                	|
# "               50 	|
# coral           50 	| 2
# bleaching       50 	| 2
# is              50 	|
# a               50 	|
# phenomenon      50 	|
# in              50 	|
# which           50 	|
# coral           50 	|
# loses           50 	|
# it              50 	| 2
# color           50 	|
# .                	|
# "                	|
# "                	|
# events           	|
# leading          	|
# to               	|
# coral           50 	| 3
# bleaching       50 	| 3
# are              	|
# a                	| 4
# serious          	| 4
# problem          	| 4
# with             	| 4
# a                	| 4
# serious          	| 4
# impact           	| 4
# on               	| 4
# the              	| 4
# world            	| 4
# coral            	| 4
# reefs            	| 4
# .                	|
# "                	|
# this             	| 4
# problem          	| 4
# can              	|
# cause            	|
# serious          	|
# damage           	|
# to               	|
# much             	|
# corral           	|
# in               	|
# the              	| 1
# ocean            	| 1
# and              	|
# the              	|
# effects          	|
# that             	|
# it               	| 4
# suffers          	|
# from             	|
# can              	|
# lead             	|
# to               	|
# worse            	|
# things           	|
# .                	|
# the              	| 3
# coral           50 	| 3
# will            50 	|
# eventually      50 	|
# die             50 	|
# if               	|
# the              	|
# color           50 	|
# is              50 	|
# bleached        50 	|
# out             50 	|
# .                	|
# the              	| 3
# coral            	| 3
# needs            	|
# it               	| 3
# color            	|
# or               	|
# else             	|
# the              	| 3
# coral            	| 3
# will             	|
# have             	|
# no               	|
# life             	|
# INFREQUENT       	|
# left             	|
# and              	|
# will             	|
# just             	|
# end              	|
# up               	|
# dead             	|
# .                	|
# the              	|
# differences      	|
# in               	|
# the              	|
# rates            	|
# of               	|
# coral           50 	|
# bleaching       50 	|
# is               	|
# that             	|
# the              	| 3
# coral            	| 3
# needs            	|
# it               	| 3
# color            	|
# ,                	|
# so               	|
# if               	|
# it               	|
# is               	|
# ever            50 	|
# bleached        50 	|
# it               	| 3
# will             	|
# end              	|
# up               	|
# dying            	|
# .                	|
# "                	|
# coral           50 	|
# bleaching       50 	|
# is               	|
# most             	|
# noticeable       	|
# in               	|
# the              	| 1
# pacific          	| 1
# ocean            	| 1
# .                	|
# "                	|
# what             	|
# mainly           	|
# leads           explicit 	|
# to              explicit 	|
# different        	|
# rates            	|
# of               	|
# coral           ,50,1->50,50 	| 3
# bleaching       ,50,1->50,50 	| 3
# is              1->50 	|
# trade           ,1,1->50,1 	|
# winds           ,1,1->50,1 	|
# ,                	|
# when            explicit 	|
# the              	|
# water           ,3,3->1,3 	|
# temperature     ,3,3->1,3 	|
# is              ,3,3->1,3 	|
# high            ,3,3->1,3 	|
# the             3->1,explicit 	| 2
# trade           ,1,3->1,1 	| 2
# wind            ,1,3->1,1 	| 2
# is              ,1,3->1,1 	|
# low             ,1,3->1,1 	|
# .                	|
# the              	| 3
# coral           ,50,1->50,50 	| 3
# bleaching       ,50,1->50,50 	| 3
# come            1->50 	|
# from            1->50 	|
# when            1->50,explicit 	|
# the             1->50 	| 1
# trade           ,1,1->50,1 	| 1
# winds           ,1,1->50,1 	| 1
# are             ,1,1->50,1 	|
# low             ,1,1->50,1 	|
# .                	|
# in               	|
# the              	| 4
# text             	| 4
# it               	| 4
# says             	|
# ,                	|
# "                	|
# need             	|
# -                	|
# water            	|
# temperatures     	|
# between          	|
# 00               	|
# -                	|
# 00               	|
# degrees          	|
# .                	|
# "                	|
# so               	|
# that             	|
# means            	|
# the              	| 1
# winds           1 	| 1
# are             1 	|
# low             1 	|
# the              	|
# temperature     3 	|
# is              3 	|
# high            3 	|
# .                	|
# on               	|
# the              	|
# background       	|
# text             	|
# it               	|
# stated           	|
# that             	|
# inside           	|
# the              	| 4
# coral            	| 4
# polyps           	|
# give             	|
# the              	| 5
# corals           	| 5
# their            	| 5
# varying          	|
# colors           	|
# .                	|
# the              	|
# difference       	|
# in               	|
# the              	|
# trade            	|
# winds            	|
# and              	|
# the              	|
# corals          50 	|
# bleaching       50 	|
# is               	|
# the              	|
# wind            1 	|
# is              1 	|
# weaker          1 	|
# than             	|
# the              	| 3
# water           3 	| 3
# temperature     3 	| 3
# .                	|
# the              	| 1
# coral           50 	| 1
# bleach          50 	| 1
# has              	|
# increased        	|
# in               	|
# 0000             	| 2
# and              	|
# it               	| 1
# decreased        	|
# in               	|
# 0000             	|
# ,                	|
# 0000             	|
# and              	|
# in               	|
# 0000             	|
# .                	|
# as               	|
# long             	|
# as               	|
# there            	|
# is               	|
# enough           	|
# sunlight         	|
# and              	|
# a                	|
# normal          4->5,4, 	|
# amount          4->5,4, 	|
# of              4->5,4, 	|
# co2             4->5,4, 	|
# ,               explicit 	|
# the             4->5 	| 6
# algae           5,4->5, 	| 6
# will            5,4->5, 	|
# undergo         5,4->5, 	|
# photosynthesis  5,4->5, 	|
# this             	|
# is               	|
# the              	|
# most             	|
# important        	|
# because          	|
# the              	|
# chemicals        	|
# that             	|
# the              	|
# algae            	|
# make             	|
# provide          	|
# the              	|
# coral            	|
# with             	|
# the              	|
# energy           	|
# it               	| 4
# needs            	|
# to               	|
# survive          	|
# .                	|
# coral           50 	| 1
# bleaching       50 	| 1
# is              50 	|
# a               50 	|
# phenomena       50 	|
# where           50 	|
# coral           50 	|
# loses           50 	|
# its             50 	| 1
# color           50 	|
# .                	|
# what             	|
# can              	|
# cause           explicit 	|
# the              	| 4
# corals          3->50,50,,50 	| 4
# to              3->50,50,,50 	|
# change          3->50,50,,50 	|
# color           3->50,50,,50 	|
# is              3->50 	|
# the             3->50 	|
# change          3->50,3,,3 	|
# in              3->50,3,,3 	|
# temperature     3->50,3,,3 	|
# .                	|
# in               	|
# the              	|
# charts           	|
# it               	|
# shows            	|
# how              	|
# as              explicit 	|
# the              	|
# temperature     3->50,3,,3 	|
# rises           3->50,3,,3 	|
# ,               explicit 	|
# more            3->50 	|
# coral           3->50,50,,50 	| 2
# bleaching       3->50,50,,50 	| 2
# is               	|
# reported         	|
# .                	|
# salt             	| 6
# can              	|
# also             	|
# affect           	|
# how              	|
# the              	| 2
# coral            	| 2
# is               	|
# .                	|
# like             	|
# they             	| 6
# are              	|
# sensitive       13 	|
# to              13 	|
# how             13 	|
# salty           13 	|
# the             13 	| 3
# water           13 	| 3
# is              13 	|
# .                	|
# if              explicit 	|
# it              Anaphor[13],13->50,,13,Anaphor,13 	| 3
# drops           ,13,13->50,13 	|
# alot            ,13,13->50,13 	|
# then            13->50,explicit 	|
# it              13->50 	| 3
# can             13->50 	|
# really          ,13->50,50,50 	|
# affect          ,13->50,50,50 	|
# the             ,13->50,50,50 	| 2
# coral           ,13->50,50,50 	| 2
# .                	|
# so               	|
# it               	| 3
# needs            	|
# to               	|
# be               	|
# at               	|
# stable           	|
# condition        	|
# for              	|
# the              	|
# coral            	|
# to               	|
# be               	|
# healthy          	|
# .                	|
# in               	|
# order            	|
# for              	|
# coral            	|
# to               	|
# stay             	|
# healthy          	|
# they             	|
# also             	|
# need             	|
# the              	|
# help             	|
# from             	|
# zooxanthellae    	| 5
# algae            	| 5
# which            	|
# gives            	|
# them             	| 5
# their            	| 5
# color           COMPILED 	|
# .                	|
# what             	|
# leads            	|
# to               	|
# differences      	|
# in               	|
# the              	|
# rates            	|
# of               	|
# coral           50 	| 2
# bleaching       50 	| 2
# are              	|
# coral            	|
# polyps           	|
# it               	| 2
# help             	|
# give             	|
# the              	|
# corals           	|
# there            	|
# varying          	|
# color            	|
# .                	|
# another          	| 3
# difference       	| 3
# is               	|
# coral            	|
# reefs            	|
# because          	|
# it               	| 3
# is               	|
# only             	|
# found            	|
# in               	|
# clear            	|
# ,                	|
# shallow          	|
# ,                	|
# tropical         	|
# waters           	|
# .                	|
# coral           50 	| 1
# bleaching       50 	| 1
# loses           50 	|
# their           50 	| 1
# color           50 	|
# because          	|
# it               	| 1
# dont             	|
# have             	|
# enough           	|
# water            	|
# from             	|
# the              	|
# pacific          	|
# ocean           COMPILED 	|
# .                	|
# coral           50 	|
# bleaching       50 	|
# is              50 	|
# a               50 	|
# phenomenon      50 	|
# ,                	|
# that            50 	|
# means           50 	|
# that            50 	|
# that            50 	|
# the             50 	| 1
# coral           50 	| 1
# looses          50 	|
# its             50 	| 1
# color           50 	|
# .                	|
# coral           50 	| 4
# bleaching       50 	| 4
# has              	|
# led              	|
# to               	|
# serious          	|
# problems         	|
# and              	|
# serious          	|
# impact           	|
# on               	|
# the              	|
# world            	|
# .                	|
# it               	| 4
# is               	|
# mostly           	|
# noticable        	|
# in               	|
# the              	|
# pacific          	|
# ocean            	|
# (                	|
# the              	|
# coral            	|
# bleaching        	|
# )                	|
# .                	|
# in               	|
# 0000             	|
# a                	| 3
# massive          	| 3
# coral           50 	| 3
# bleaching       50 	| 3
# event            	| 3
# happened         	|
# .                	|
# it               	| 3
# was              	|
# considered       	|
# one              	|
# of               	|
# the              	|
# worst            	|
# events           	|
# observed         	|
# .                	|
# it               	| 3
# resulted         	|
# n                	|
# the              	|
# death            	|
# of               	|
# 0000             	|
# of               	|
# the              	| 2
# worlds           	| 2
# coral            	| 2
# reef             	| 2
# .                	|
# the              	| 2
# coral            	| 2
# reef             	| 2
# are              	|
# found            	|
# in               	|
# tropical         	|
# water            	|
# ,                	|
# shallow          	|
# ,                	|
# and              	|
# clear            	|
# water            	|
# .                	|
# the              	| 2
# coral            	| 2
# is               	|
# made             	|
# up               	|
# of               	|
# INFREQUENT       	|
# animals          	|
# called           	|
# polyps           	|
# .                	|
# they             	| 2
# are              	|
# usually          	|
# mistaken         	|
# by               	|
# plants           	|
# or               	|
# rocks            	|
# .                	|
# their            	| 2
# is               	|
# a                	| 5
# process          	| 5
# that             	| 5
# is               	| 5
# very             	| 5
# important        	| 5
# .                	|
# the              	| 2
# coral            	| 2
# receive          	|
# 00               	|
# %                	|
# to               	|
# 00               	|
# %                	|
# of               	|
# the              	|
# energy           	|
# from             	|
# the              	| 5
# process          	| 5
# .                	|
# both             	|
# coral            	|
# and              	|
# zooxanthellae    	|
# benefit          	|
# from             	|
# this             	| 5
# process         COMPILED 	| 5
# .                	|
# when            explicit 	|
# water           ,3->7,3,3 	|
# is              ,3->7,3,3 	|
# too             ,3->7,3,3 	|
# warm            ,3->7,3,3 	|
# ,               explicit 	|
# corals          3->7 	|
# will            3->7 	|
# expel           ,7->50,,3->7,7,7,7 	|
# the             ,7->50,,3->7,7,7,7 	| 1
# algae           ,7->50,,3->7,7,7,7 	| 1
# living          7->50 	| 1
# in              7->50 	|
# their           7->50 	| 1
# tissues         7->50 	|
# causing         7->50,explicit 	|
# the             7->50 	|
# coral           ,7->50,50,50 	|
# to              ,7->50,50,50 	|
# turn            ,7->50,50,50 	|
# completely      ,7->50,50,50 	|
# white           ,7->50,50,50 	|
# .                	|
# when             	|
# coral           50 	| 2
# bleached        50 	| 2
# it               	| 2
# is               	|
# not              	|
# dead             	|
# .                	|
# corals           	| 3
# and              	|
# survive          	|
# a                	|
# bleaching       50 	|
# event           50 	|
# ,                	|
# but              	|
# they             	| 3
# are              	|
# under           6 	|
# stress          6 	|
# and              	|
# more             	|
# INFREQUENT       	|
# to               	|
# die              	|
# .                	|
# first            	|
# coral           50 	|
# bleaching       50 	|
# is               	|
# when             	|
# a                	| 3
# healthy          	| 3
# coral            	| 3
# reef             	| 3
# leaves          50 	|
# its             50 	| 3
# color           50 	|
# and             50 	|
# turns           50 	|
# white           50 	|
# .                	|
# another          	|
# thing            	|
# is               	|
# that             	|
# changes          	| 1
# is               	|
# their            	| 1
# environment      	|
# that             	|
# out              	|
# stress          6 	|
# on              6 	|
# corals          6 	|
# .                	|
# increased       ,6,6,6->7 	|
# stress          ,6,6,6->7 	|
# on              ,6,6,6->7 	|
# corals          ,6,6,6->7 	|
# fron            6->7 	|
# the             6->7 	|
# environment     6->7 	|
# forces          6->7,explicit 	|
# the             6->7 	| 3
# coral           ,7,6->7,7 	| 3
# the             ,7,6->7,7 	|
# eject           ,7,6->7,7 	|
# their           ,7,6->7,7 	| 3
# food            ,7,6->7,7 	|
# -                	|
# producing       ,7,6->7,7 	|
# algae           ,7,6->7,7 	|
# .                	|
# these           Anaphor[7]->50,Anaphor[6]->50,Anaphor[6],,Anaphor,Anaphor->50,Anaphor,Anaphor[7] 	| 3
# two             Anaphor[7]->50,Anaphor[6]->50,Anaphor[6],,Anaphor,Anaphor->50,Anaphor,Anaphor[7] 	| 3
# are             Anaphor->50,Anaphor[7]->50,Anaphor[6]->50 	|
# the             Anaphor->50,Anaphor[7]->50,Anaphor[6]->50 	|
# main            Anaphor[7]->50,Anaphor[6]->50,rhetorical->50,rhetorical,,rhetorical,Anaphor->50 	|
# reasons         Anaphor[7]->50,Anaphor[6]->50,rhetorical->50,rhetorical,,rhetorical,Anaphor->50 	|
# why             Anaphor[7]->50,Anaphor[6]->50,rhetorical->50,Anaphor->50,explicit 	|
# corals          ,Anaphor[7]->50,Anaphor[6]->50,rhetorical->50,50,Anaphor->50,50 	|
# die             ,Anaphor[7]->50,Anaphor[6]->50,rhetorical->50,50,Anaphor->50,50 	|
# and              	|
# the              	|
# rate            ,50,50 	|
# goes            ,50,50 	|
# up              ,50,50 	|
# .                	|
# another         rhetorical,3->rhetorical,,rhetorical 	| 2
# reason          rhetorical,3->rhetorical,,rhetorical 	| 2
# is              3->rhetorical 	|
# that            3->rhetorical 	|
# when            3->rhetorical,explicit 	|
# the             3->rhetorical 	|
# temperature     ,3,3,3->rhetorical 	|
# changes         ,3,3,3->rhetorical 	|
# in              ,3,3,3->rhetorical 	|
# the             ,3,3,3->rhetorical 	|
# water           ,3,3,3->rhetorical 	|
# ,                	|
# it               	| 2
# hurts            	|
# the              	|
# corals           	|
# .                	|
# corals           	| 4
# need             	|
# a                	|
# certain          	|
# temperature      	|
# and              	|
# when             	|
# it               	| 2
# keeps            	|
# changing         	|
# up               	|
# or               	|
# down             	|
# it               	| 2
# hurts            	|
# them             	| 4
# and              	|
# it               	| 2
# leads            	|
# them             	| 4
# to               	|
# death            	|
# or               	|
# leaving         50 	|
# their           50 	| 4
# color           COMPILED,50 	|
# .                	|

# %%
EMPTY = "Empty"
from BrattEssay import ANAPHORA

def get_different_predicted_tags_by_sent(essays_a, essays_b):
    assert len(essays_a) == len(essays_b)
    diff_by_sent = []
    for ea, eb in zip(essays_a, essays_b):
        assert len(ea.sentences) == len(eb.sentences)
        assert len(ea.pred_tagged_sentences) == len(eb.pred_tagged_sentences)
        for asent, bsent in zip(ea.pred_tagged_sentences, eb.pred_tagged_sentences):
            unique_atags = set(asent)
            if EMPTY in unique_atags:
                unique_atags.remove(EMPTY)
            unique_btags = set(bsent)
            if EMPTY in unique_btags:
                unique_btags.remove(EMPTY)
            diff_by_sent.append(unique_btags - unique_atags)
    return diff_by_sent

def to_is_valid_crel(tags):
    filtered = set()
    for t in tags:
        t_lower = t.lower()
        if "rhetorical" in t_lower or "change" in t_lower or "other" in t_lower:
            continue
        if "->" in t and ANAPHORA not in t:
            filtered.add(t)
    return filtered

def get_different_crel_tags_by_sent(essays_a, essays_b):
    assert len(essays_a) == len(essays_b)
    diff_by_sent = []
    for ea, eb in zip(essays_a, essays_b):
        assert len(ea.sentences) == len(eb.sentences)
        for asent, bsent in zip(ea.sentences, eb.sentences):
            all_atags, all_btags = set(), set()
            for (awd, atags), (bwd, btags) in zip(asent, bsent):
                assert awd == bwd
                all_atags.update(to_is_valid_crel(atags))
                all_btags.update(to_is_valid_crel(btags))
            
            diff_by_sent.append(all_btags - all_atags)
    return diff_by_sent

def get_crel_tags_by_sent(essays_a):
    crels_by_sent = []
    for ea in essays_a:
        for asent in ea.sentences:
            all_atags = set()
            for awd, atags in asent:
                all_atags.update(to_is_valid_crel(atags))
            crels_by_sent.append(all_atags)
    return crels_by_sent

# %%
cr_tags = get_cr_tags(train_tagged_essays=pred_tagged_essays_train, tag_essays_test=pred_tagged_essays_test)
# cv_folds  = [(pred_tagged_essays_train, pred_tagged_essays_test)]  # type: List[Tuple[Any,Any]]
cv_folds = cross_validation(pred_tagged_essays_train, CV_FOLDS)

# cv_folds  = [(pred_tagged_essays_train, pred_tagged_essays_test)]  # type: List[Tuple[Any,Any]]

# %%
def evaluate_model(
        collection_prefix: str,
        folds: List[Tuple[Any, Any]],
        extractor_fn_names_lst: List[str],
        cost_function_name: str,
        beta: float,
        ngrams: int,
        stemmed: bool,
        max_epochs: int,
        down_sample_rate=1.0) -> float:

    if down_sample_rate < 1.0:
        new_folds = []  # type: List[Tuple[Any, Any]]
        for i, (essays_TD, essays_VD) in enumerate(folds):
            essays_TD = essays_TD[:int(down_sample_rate * len(essays_TD))]
            essays_VD = essays_VD[:int(down_sample_rate * len(essays_VD))]
            new_folds.append((essays_TD, essays_VD))
        folds = new_folds  # type: List[Tuple[Any, Any]]

    serial_results = [
        model_train_predict(essays_TD, essays_VD, extractor_fn_names_lst, cost_function_name, ngrams, stemmed, beta, max_epochs)
        for essays_TD, essays_VD in folds
    ]

    cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag = defaultdict(list), defaultdict(list)
    cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag = defaultdict(list), defaultdict(list)

    # record the number of features in each fold
    number_of_feats = []

    # Parallel is almost 5X faster!!!
    cv_td_preds_by_sent = []
    cv_vd_preds_by_sent = []
    for (num_feats,
         sent_td_ys_bycode, sent_vd_ys_bycode,
         sent_td_pred_ys_bycode, sent_vd_pred_ys_bycode, td_preds_by_sent, vd_preds_by_sent) in serial_results:
        number_of_feats.append(num_feats)

        merge_dictionaries(sent_td_ys_bycode, cv_sent_td_ys_by_tag)
        merge_dictionaries(sent_vd_ys_bycode, cv_sent_vd_ys_by_tag)
        merge_dictionaries(sent_td_pred_ys_bycode, cv_sent_td_predictions_by_tag)
        merge_dictionaries(sent_vd_pred_ys_bycode, cv_sent_vd_predictions_by_tag)
        
        cv_td_preds_by_sent.append(td_preds_by_sent)
        cv_vd_preds_by_sent.append(vd_preds_by_sent)

    # print(processor.results_to_string(sent_td_objectid, CB_SENT_TD, sent_vd_objectid, CB_SENT_VD, "SENTENCE"))
    return cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag, cv_td_preds_by_sent, cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag, cv_vd_preds_by_sent

# %%
def predict_by_sent(tagged_essays, model):
    predict_by_sent = []
    for essay_ix, essay in enumerate(tagged_essays):
        for sent_ix, taggged_sentence in enumerate(essay.sentences):
            predicted_tags = essay.pred_tagged_sentences[sent_ix]
            pred_relations = model.predict_sentence(taggged_sentence, predicted_tags)
            # Store predictions for evaluation
            predict_by_sent.append(pred_relations)
    return predict_by_sent

def model_train_predict(essays_TD, essays_VD, extractor_names, cost_function_name, ngrams, stemmed, beta, max_epochs):
    extractors = get_functions_by_name(extractor_names, all_extractor_fns)
    # get single cost function
    cost_fn = get_functions_by_name([cost_function_name], all_cost_functions)[0]
    assert cost_fn is not None, "Cost function look up failed"
    # Ensure all extractors located
    assert len(extractors) == len(extractor_names), "number of extractor functions does not match the number of names"

    template_feature_extractor = NonLocalTemplateFeatureExtractor(extractors=extractors)
    if stemmed:
        ngram_extractor = NgramExtractorStemmed(max_ngram_len=ngrams)
    else:
        ngram_extractor = NgramExtractor(max_ngram_len=ngrams)
    parse_model = SearnModelTemplateFeatures(feature_extractor=template_feature_extractor,
                                             cost_function=cost_fn,
                                             min_feature_freq=MIN_FEAT_FREQ,
                                             ngram_extractor=ngram_extractor, cr_tags=cr_tags,
                                             base_learner_fact=BASE_LEARNER_FACT,
                                             beta=beta,
                                             # log_fn=lambda s: print(s))
                                             log_fn=lambda s: None)

    parse_model.train(essays_TD, max_epochs=max_epochs)

    num_feats = template_feature_extractor.num_features()

    sent_td_ys_bycode = parse_model.get_label_data(essays_TD)
    sent_vd_ys_bycode = parse_model.get_label_data(essays_VD)

    sent_td_pred_ys_bycode = parse_model.predict(essays_TD)
    sent_vd_pred_ys_bycode = parse_model.predict(essays_VD)

    td_preds_by_sent = predict_by_sent(essays_TD, parse_model)
    vd_preds_by_sent = predict_by_sent(essays_VD, parse_model)
    
    return num_feats, sent_td_ys_bycode, sent_vd_ys_bycode, sent_td_pred_ys_bycode, sent_vd_pred_ys_bycode, td_preds_by_sent, vd_preds_by_sent

# %%
def metrics_to_df(metrics):
    import Rpfa

    rows = []
    for k,val in metrics.items():
        if type(val) == Rpfa.rpfa:
            d = dict(val.__dict__) # convert obj to dict
        elif type(val) == dict:
            d = dict(val)
        else:
            d = dict()
        d["code"] = k
        rows.append(d)
    return pd.DataFrame(rows)

def get_metrics_from_dict(act_ys_bycode, pred_ys_bycode, expected_tags):
    assert len(act_ys_bycode.keys()) == len(pred_ys_bycode.keys()) == len(expected_tags), "Miss-matched codes"
    first_tag = list(expected_tags)[0]
    last_tag  = list(expected_tags)[-1]
    assert len(act_ys_bycode[first_tag]) == len(pred_ys_bycode[first_tag]), "Different numbers of words"
    assert len(act_ys_bycode[last_tag])  == len(pred_ys_bycode[last_tag]),  "Different numbers of words"

    mean_metrics = ResultsProcessor.compute_mean_metrics(act_ys_bycode, pred_ys_bycode)
    return metrics_to_df(mean_metrics)

def compute_metrics_from_essays(tagged_esssays, expected_tags):
    act_ys_bycode  = get_wd_level_lbs(  tagged_esssays, expected_tags)
    pred_ys_bycode = get_wd_level_preds(tagged_esssays, expected_tags)
    return get_metrics_from_dict(act_ys_bycode, pred_ys_bycode, expected_tags)

def get_micro_metrics(df):
    return df[df.code == "MICRO_F1"][["accuracy", "f1_score", "recall", "precision"]]

# %%
LINE_WIDTH = 80

# other settings
DOWN_SAMPLE_RATE = 1.0  # For faster smoke testing the algorithm
BASE_LEARNER_FACT = None
COLLECTION_PREFIX = "CR_CB_SHIFT_REDUCE_PARSER_TEMPLATED_MOST_RECENT_CODE"

# some of the other extractors aren't functional if the system isn't able to do a basic parse
# so the base extractors are the MVP for getting to a basic parser, then additional 'meta' parse
# features from all_extractors can be included
base_extractors = [
    single_words,
    word_pairs,
    three_words,
    between_word_features
]

all_extractor_fns = base_extractors + [
    word_distance,
    valency,
    unigrams,
    third_order,
    label_set,
    size_features
]

all_cost_functions = [
    micro_f1_cost,
    micro_f1_cost_squared,
    micro_f1_cost_plusone,
    micro_f1_cost_plusepsilon,
    binary_cost,
    inverse_micro_f1_cost,
    uniform_cost
]

all_extractor_fn_names = get_function_names(all_extractor_fns)
base_extractor_fn_names = get_function_names(base_extractors)
all_cost_fn_names = get_function_names(all_cost_functions)

# %% [markdown]
# ### Note that these are different for Skin Cancer dataset

# %%
ngrams = 1
stemmed = True
cost_function_name = micro_f1_cost_plusepsilon.__name__
dual = True
fit_intercept = True
beta = 0.5
max_epochs = 2
C = 0.5
penalty = "l2"

# %% [markdown]
# # Train CV

# %%
# Note these also differ for SC dataset
BASE_LEARNER_FACT = lambda : LogisticRegression(dual=dual, C=C, penalty=penalty, fit_intercept=fit_intercept)
best_extractor_names = ['single_words', 'between_word_features', 'label_set',
                                    'three_words', 'third_order', 'unigrams'] # type: List[str]
result = evaluate_model(
    collection_prefix=COLLECTION_PREFIX,
    folds=cv_folds,
    extractor_fn_names_lst=best_extractor_names,
    cost_function_name=cost_function_name,
    ngrams=ngrams,
    beta=beta,
    stemmed=stemmed,
    down_sample_rate=DOWN_SAMPLE_RATE,
    max_epochs=max_epochs)

# %%
cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag, cv_td_preds_by_sent, \
    cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag, cv_vd_preds_by_sent = result

# %% [markdown]
# ### CV Metrics - All CRel Codes (Inc. Anaphora)

# %% [markdown]
# #### CV Train

# %%
mean_metrics = ResultsProcessor.compute_mean_metrics(cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag)
get_micro_metrics(metrics_to_df(mean_metrics))

# %% [markdown]
# #### CV Test

# %%
mean_metrics = ResultsProcessor.compute_mean_metrics(cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag)
get_micro_metrics(metrics_to_df(mean_metrics))

# %% [markdown]
# # Compute Anaphora CRel Accuracy

# %%
# cv_folds = cross_validation(pred_tagged_essays_train, CV_FOLDS)
orig_cv_folds = cross_validation(orig_pred_tagged_essays_train, CV_FOLDS)

# %%
def build_metrics_by_code(td_preds_by_sent, diffs_train, diffs_crel_train, ys_by_code_train, preds_by_code_train):
    for pred_crels, pred_ccodes, crels in zip(td_preds_by_sent, diffs_train, diffs_crel_train):    
        for crel in cr_tags:
            ys_by_code_train[crel].append( 1 if crel in crels else 0)

        # filter predictions to only those that were produced as a result of the ana tags
        ana_preds = set()
        for crel in pred_crels:
            l,r = crel.split("->")
            lcode = l.split(":")[-1].strip()
            rcode = r.split(":")[-1].strip()
            if lcode in pred_ccodes or rcode in pred_ccodes:
                ana_preds.add(crel)

        for crel in cr_tags:
            preds_by_code_train[crel].append( 1 if crel in ana_preds else 0)

# %%
# Predicted Concept Codes - correspond to Ana tags
preds_by_code_train = defaultdict(list)
ys_by_code_train    = defaultdict(list)

preds_by_code_test = defaultdict(list)
ys_by_code_test    = defaultdict(list)

for (orig_td, orig_vd), (td, vd), td_preds_by_sent, vd_preds_by_sent in zip(orig_cv_folds, cv_folds, cv_td_preds_by_sent, cv_vd_preds_by_sent):
    
    diffs_train = get_predicted_tags(essays=orig_td)
    diffs_test  = get_predicted_tags(essays=orig_vd)

    # Actual Ana CRels
    diffs_crel_train = get_different_crel_tags_by_sent(essays_a=orig_td, essays_b=td)
    diffs_crel_test  = get_different_crel_tags_by_sent(essays_a=orig_vd, essays_b=vd)
    
    build_metrics_by_code(td_preds_by_sent, diffs_train, diffs_crel_train, ys_by_code_train, preds_by_code_train)
    build_metrics_by_code(vd_preds_by_sent, diffs_test,  diffs_crel_test,  ys_by_code_test,  preds_by_code_test)

# %% [markdown]
# ### CV Metrics - Ana Codes Only

# %% [markdown]
# #### Train

# %%
df_train = get_metrics_from_dict(ys_by_code_train, preds_by_code_train, cr_tags)
get_micro_metrics(df_train)

# %% [markdown]
# #### Test

# %%
df_test = get_metrics_from_dict(ys_by_code_test, preds_by_code_test, cr_tags)
get_micro_metrics(df_test)

# %% [markdown]
# # Train for Test Set Eval

# %%
orig_test_folds  = [(orig_pred_tagged_essays_train, orig_pred_tagged_essays_test)]  # type: List[Tuple[Any,Any]]
test_folds     = [(pred_tagged_essays_train, pred_tagged_essays_test)]  # type: List[Tuple[Any,Any]]

# %%
result_test = evaluate_model(
    collection_prefix=COLLECTION_PREFIX,
    folds=test_folds,
    extractor_fn_names_lst=best_extractor_names,
    cost_function_name=cost_function_name,
    ngrams=ngrams,
    beta=beta,
    stemmed=stemmed,
    down_sample_rate=DOWN_SAMPLE_RATE,
    max_epochs=max_epochs)

# %% [markdown]
# ### Test Metrics (All Codes Inc. Ana)

# %% [markdown]
# #### Train

# %%
cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag, cv_td_preds_by_sent, \
    cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag, cv_vd_preds_by_sent = result_test
    
mean_metrics = ResultsProcessor.compute_mean_metrics(cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag)
get_micro_metrics(metrics_to_df(mean_metrics))

# %% [markdown]
# #### Test

# %%
cv_sent_td_ys_by_tag, cv_sent_td_predictions_by_tag, cv_td_preds_by_sent, \
    cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag, cv_vd_preds_by_sent = result_test
    
mean_metrics = ResultsProcessor.compute_mean_metrics(cv_sent_vd_ys_by_tag, cv_sent_vd_predictions_by_tag)
get_micro_metrics(metrics_to_df(mean_metrics))

# %%
# Predicted Concept Codes - correspond to Ana tags
preds_by_code_train = defaultdict(list)
ys_by_code_train    = defaultdict(list)

preds_by_code_test = defaultdict(list)
ys_by_code_test    = defaultdict(list)

for (orig_td, orig_vd), (td, vd), td_preds_by_sent, vd_preds_by_sent in zip(orig_test_folds, test_folds, cv_td_preds_by_sent, cv_vd_preds_by_sent):
    
    diffs_train = get_predicted_tags(essays=orig_td)
    diffs_test  = get_predicted_tags(essays=orig_vd)

    # Actual Ana CRels
    diffs_crel_train = get_different_crel_tags_by_sent(essays_a=orig_td, essays_b=td)
    diffs_crel_test  = get_different_crel_tags_by_sent(essays_a=orig_vd, essays_b=vd)
    
    build_metrics_by_code(td_preds_by_sent, diffs_train, diffs_crel_train, ys_by_code_train, preds_by_code_train)
    build_metrics_by_code(vd_preds_by_sent, diffs_test,  diffs_crel_test,  ys_by_code_test,  preds_by_code_test)

# %% [markdown]
# ### Test Metrics - Ana Codes Only

# %% [markdown]
# #### Train

# %%
df_train2 = get_metrics_from_dict(ys_by_code_train, preds_by_code_train, cr_tags)
get_micro_metrics(df_train2)

# %% [markdown]
# #### Test

# %%
df_test2 = get_metrics_from_dict(ys_by_code_test, preds_by_code_test, cr_tags)
get_micro_metrics(df_test2)
