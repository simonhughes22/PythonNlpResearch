# %%
import numpy as np
import dill

#from gensim.models import Word2Vec
from window_based_tagger_config import get_config
from Rpfa import micro_rpfa

import logging
import datetime
import pickle

from CrossValidation import cross_validation
from BrattEssay import load_bratt_essays
from load_data import load_process_essays
from collections import defaultdict
from IterableFP import flatten
from Settings import Settings

CV_FOLDS = 5
DEV_SPLIT = 0.1

settings = Settings()
root_folder = settings.data_directory + "CoralBleaching/Thesis_Dataset/"
training_folder = root_folder + "Training" + "/"
training_pickled = settings.data_directory + "CoralBleaching/Thesis_Dataset/training.pl"
# Out:
# Results Dir: /Users/simon.hughes/Google Drive/Phd/Results/
# Data Dir:    /Users/simon.hughes/Google Drive/Phd/Data/
# Root Dir:    /Users/simon.hughes/GitHub/NlpResearch/
# Public Data: /Users/simon.hughes/GitHub/NlpResearch/Data/PublicDatasets/

# %%
config = get_config(training_folder)
# override this so we don't replace INFREQUENT words
config["min_df"] = 0
tagged_essays2 = load_process_essays(**config)
#config
# Out:
# 902 files found
# 902 essays processed

# %%
len(tagged_essays2)
# Out:
# 902

# %%
#coref_folder = root_folder + "CoReference/Training_Old"
coref_folder = root_folder + "CoReference/Training"
coref_folder
# Out:
# '/Users/simon.hughes/Google Drive/Phd/Data/CoralBleaching/Thesis_Dataset/CoReference/Training'

# %%
from FindFiles import find_files
coref_files = find_files(coref_folder, ".*\.tagged")
len(coref_files)
# Out:
# 902

# %%
from pprint import pprint

DELIM = "->"
DELIM_TAG = "|||"

essay2tagged = {}
for fname in coref_files:
    with open(fname) as f:
        lines = f.readlines()
    
    tagged_lines = []    
    for line in lines:
        tagged_words = []
        line = line.strip()
        wds = []
        for t_token in line.split(" "):
            ##print(t_token)
            splt = t_token.split(DELIM)
            word, tags = t_token.split(DELIM)
            wds.append(word)
            tag_dict = {}
            for tag in tags.split(DELIM_TAG):
                if not tag:
                    continue
                splt = tag.split(":")
                if len(splt) == 2:
                    key,val = splt
                    tag_dict[key] = val
                else:
                    raise Exception("Error")
            tagged_words.append((word, tag_dict))
        tagged_lines.append(tagged_words)
    essay2tagged[fname.split("/")[-1].split(".")[0]] = tagged_lines
print(len(essay2tagged))
# Out:
# 902

# %%
mentions = []
mention_lens = []

current_ph_len = 0
current_mention = ""
prev_phrase = ""

mention2replace = []

def change_in_phrase():
    global mentions, mention_lens, current_ph_len, current_mention, prev_phrase, mention2replace 
    if current_ph_len > 0:
        mention_lens.append(current_ph_len)
        mentions.append(current_mention.strip())
        mention2replace.append((current_mention.strip(), prev_phrase))
    current_mention = ""
    current_ph_len = 0
    prev_phrase = ""

for ename, tagged_lines in essay2tagged.items():
    #print(ename)
    for line in tagged_lines:
        current_ph_len = 0
        current_mention = ""
        prev_phrase = ""
        for wd, tag_dict in line:
            if "COREF_PHRASE" in tag_dict:
                current_phrase = tag_dict["COREF_PHRASE"]
                if prev_phrase != current_phrase:
                    change_in_phrase()
                current_ph_len+=1
                current_mention += " " + wd
                prev_phrase = tag_dict["COREF_PHRASE"]
            else:
                change_in_phrase()
        change_in_phrase()
len(mention_lens), len(mentions), len(mention2replace)
# Out:
# (5125, 5125, 5125)

# %%
import numpy as np
np.mean(mention_lens), np.max(mention_lens), np.min(mention_lens)
# Out:
# (1.5473170731707317, 20, 1)

# %%
lens = list(map(lambda s: len(s.strip().split(" ")), mentions))
np.mean(lens), np.max(lens), np.min(lens)
# Out:
# (1.5473170731707317, 20, 1)

# %%
[m for m in mentions if len(m.strip().split(" ")) >= 3]
# Out:
# ['producers -lrb- things that create food using sunlight like coral reef -rrb-',
#  'the salty water',
#  'the pacific ocean',
#  'corals living in the oceans',
#  'the atlantic ocean',
#  'the amount of carbon dioxide',
#  'the amount of co2',
#  'the coral reef',
#  'the amount of fresh water',
#  'the zooxanthallae algae',
#  'the trade winds',
#  'the warm waters',
#  'the amount of co2',
#  'the amounts of dioxide',
#  'the coral reef',
#  'the coral reef',
#  'the coral reefs',
#  'the coral reefs',
#  'the coral reefs',
#  'a report of coral bleaching',
#  'the balance for',
#  'the corals health',
#  'the trade winds',
#  'the coral reefs',
#  'the trade winds',
#  'the trade winds',
#  'the weaker trade winds',
#  'the rates of color bleaching',
#  'this shifting winds',
#  'the shifting winds',
#  'the western pacific ocean',
#  'this kind of balance',
#  'algae , called zooxantellae',
#  'the temperature the water needs to be at for coral reefs to survive',
#  'the atlantic ocean',
#  'the pacific trade winds',
#  'the ocean with water -lrb- h20 -rrb-',
#  'a algae with a different color and living with the coral',
#  'the temperature of',
#  'the temperature of the water',
#  'the worst ever observed event',
#  'the eastern pacific waters',
#  'types of algae living in the corals polyps',
#  'the hard skeleton',
#  'the zooxanthellae algae',
#  'the energy it needs to survive',
#  'the atlantic ocean',
#  'the earth coral',
#  'these coral reefs',
#  'the ocean with water',
#  'the temperature in the water',
#  'the atlantic ocean',
#  'the atlantic ocean',
#  'the trade wind',
#  'the pacific ocean',
#  'coral bleaching reports',
#  'the rates of bleaching',
#  'the water temperatures',
#  'the water temperature',
#  'the ocean with water',
#  'the amount of co2',
#  'the amount of co2',
#  'the amount of salt in',
#  'coral and zooxanthellae algae',
#  'carbon dioxide -lrb- co2 -rrb-',
#  'the amount of co2',
#  'the water temperature',
#  'the water temperature',
#  'higher temp in the water',
#  'the temperature of the water',
#  'the pacific ocean',
#  'the normal temperature',
#  'the atlantic ocean',
#  'a coral which it can be damage',
#  'many factor which leads to differences in the rates of coral bleaching',
#  'the trade winds',
#  'the second factor',
#  'algae that was ejected from the coral',
#  'these changes in the environment',
#  'the stress on the coral',
#  'more coral bleaching',
#  'the trade winds',
#  'the trade winds',
#  'the trade winds',
#  'some coral reefs',
#  'the coral population',
#  'the amount of co2',
#  'the process of',
#  'water temperature increasing',
#  'the atlantic ocean',
#  'the atlantic ocean',
#  'the algae color bleached',
#  'the dead , algae',
#  'the definition of upwelling',
#  'more coral bleaching',
#  'the environment of corals and these action',
#  'coral bleaching i found',
#  'the cause of the temperature change in waters',
#  'many factor that cause coral bleaching',
#  'the wind strength',
#  'zooxanthellae , algae',
#  'the coral reef',
#  'number of countries reporting coral bleaching',
#  'the stress they have caused by fishes and humans',
#  'the trade winds',
#  'storms that cause excessive rainfall',
#  'the ocean with water',
#  'of the temperature',
#  'the hard skeleton',
#  'the water of a certain temperature',
#  'their process of photosynthesis',
#  'the zooxanthellae algae the coral',
#  'eastern pacific waters',
#  'the water temperature',
#  'the world coral reefs',
#  'the water temperature',
#  'carbon dioxide -lrb- co2 -rrb- in water decreases',
#  'the rates of coral bleaching',
#  'the amount of co2',
#  'the worlds coral reefs',
#  'the wind strength',
#  'the atlantic ocean',
#  'the coral bleaching',
#  'the water temperature',
#  'the rates of coral bleaching',
#  'the death of',
#  'the amount of co2',
#  'these coral polyps',
#  'the things that can cause coral bleaching',
#  'with the coral',
#  'the coral which causes the bleaching process',
#  'the amount of salinity in the water',
#  'zooxanthelae that live on the coral to survive',
#  'some variables that may lead to changes in coral bleaching',
#  'the winds altering',
#  'the algae photosynthesizing',
#  'then the polyps',
#  'these climate shifts',
#  'the trade winds',
#  'the trade winds',
#  'the trade winds',
#  'this type of algae',
#  'many different types of corals living in the oceans',
#  'a change in environment',
#  'this hard skeleton',
#  'the rates of coral reefs',
#  'the zooxanthellae algae',
#  'corals in the ocean',
#  'the water temperature',
#  'algae -lrb- zooxanthellae -rrb-',
#  'algae that live in corals',
#  'corals living in the ocean or sea',
#  'coral reef bleaching',
#  'the strengths and water temperature',
#  'the trade winds',
#  'the water temperature',
#  'the water temperature',
#  'the water temperature',
#  'the change in trade winds',
#  'the amount of co2',
#  'the balance necessary for',
#  'another factor for coral bleaching',
#  'a large amount of',
#  'damage from blast fishing , or tourists walking or dropping anchors on to the coral',
#  'the changes in the environment',
#  'these trade winds',
#  'the water temperature',
#  'the balance of saltwater',
#  'the water temperature',
#  'the coral its',
#  'the trade winds',
#  'corals from the environment',
#  'our coral reefs',
#  'the warmer water',
#  'the temperature of',
#  'the bad relationship',
#  'the balance of salt in',
#  'changes in the enviroment like temperature increase or water level increase or decrease',
#  'algae that lives in it',
#  'the bleaching of coral',
#  'glucose for the coral',
#  'the years of weaker trade winds the water temperature rises',
#  'the world coral reefs',
#  'these trade winds',
#  'coral , zooxanthallae',
#  'the coral reefs',
#  'the salinity of the water',
#  'the amount of temperature',
#  'the amount of co2',
#  'the rate of coral bleaching',
#  'the ocean with water',
#  'the temperature of the water',
#  'this temperature change',
#  'coral its color',
#  'the cooler water',
#  'the warm water',
#  'the form of glucose',
#  'the rates of coral bleaching',
#  'the temperature of the wind effects the temperature of the ocean',
#  'the amount of algae',
#  'trade wind strength',
#  'the second largest outbreak',
#  'many different ways that leads to coral bleaching',
#  'the amount of co2',
#  'the water temperatures',
#  'the water temperature',
#  'the bleached coral',
#  'the algae inside the coral',
#  'the problem that makes coral bleach',
#  'this hard skeleton',
#  'algae called zooxanthellae',
#  'the amount of co2',
#  'the rates of coral',
#  'the pacific ocean',
#  'the climate system',
#  'the zooxanthellae algae',
#  'the world reef',
#  'the trade winds',
#  'the ocean for the corals',
#  'the amount of fresh water in the ocean',
#  'many different types of corals living in the oceans',
#  'bleaching in coral',
#  'the temperature for coral reef',
#  'the rates of coral bleaching',
#  'the trade winds',
#  'this change in co2',
#  'the amount of co2',
#  'the amount of fresh water',
#  'the atlantic ocean',
#  'several different reasons',
#  'this warm water',
#  'the trade winds',
#  'the amount of co2',
#  'the balance of corals health',
#  'the temperature of the water',
#  'the temperature of the water',
#  'the first graph',
#  'the amount of co2',
#  'the the coral',
#  'the atlantic ocean',
#  'algae called zooxanthellae',
#  'the temperatures of the water',
#  'the water temperature',
#  'the sea temperature',
#  'the rates of coral bleaching',
#  'the rates of coral bleaching',
#  'the amount of co2',
#  'the coral reefs',
#  'the ocean in the entire globe',
#  'the coral bleaching',
#  'the water in the eastern pacific',
#  "the text '' coral",
#  'the temperature in the water',
#  'the hard skeleton',
#  'the amount of co2',
#  'the amount of co2',
#  'the balance necessary for coral health',
#  'the perfect temperature',
#  'the surface of',
#  'the warm water',
#  'those years listed',
#  'the rates of coral bleaching',
#  'reasons for coral bleaching',
#  'the water temperature',
#  'the pacific ocean',
#  'stress that is put on',
#  'the pacific ocean which contains double the amount of water of the atlantic',
#  'photosynthesis which is how',
#  'the rates of coral bleaching',
#  'the death rates',
#  'the balance neccessary for coral health',
#  'trade winds which leads to differences in',
#  'these trade winds',
#  'the differences in rates',
#  'corals from the enviroment',
#  'a healthy coral',
#  'the coral bleaching',
#  'the process of photosynthesis',
#  'the coral cant',
#  'the process of photosynthesis it wont have energy',
#  'this the coral',
#  'algae called zooxanthallae',
#  'the cooler water',
#  'the reports for coral bleaching',
#  'the coral reefs',
#  'the process of photosynthesis',
#  'the worlds coral',
#  'many types of coral',
#  'corals living in the oceans',
#  'the third lead',
#  'the fourth lead',
#  'the hard skeleton',
#  'the hard skeletons',
#  'the atlantic ocean',
#  'the hard skeleton',
#  'the hard skeleton',
#  'algae called zooxanthelle',
#  'the ocean with -lrb- h20 -rrb-',
#  'the trade winds',
#  'the trade winds',
#  'the cold surface water',
#  'corals living in the ocean',
#  'many different types of corals living in the oceans',
#  'the amount of co2',
#  'this hard skeleton',
#  'the hard skeletons',
#  'the amount of co2',
#  'the zooxanthellae algae',
#  'the coral bleaching',
#  'this hard skeleton',
#  'the hard skeletons',
#  'the zooxanthellae algae',
#  'the climate changes',
#  'that hard skeleton',
#  'the hard skeleton',
#  'the healthy coral on the right',
#  'this movement of warm water',
#  'the coral bleaching',
#  'the coral bleaching',
#  'the atlantic ocean',
#  'corals living in',
#  'the atlantic ocean',
#  'the trade winds',
#  'the coral reef',
#  'the coral reef',
#  'corals living in the oceans',
#  'process of photosynthesis',
#  'the coral reefs',
#  'the changes in',
#  'a group i have created',
#  'the atlantic ocean',
#  'the amount of co2',
#  'many different types of corals living in the ocean',
#  'the coral that is called the coral bleaching',
#  'many different types of corals living in the oceans',
#  'the world coral reefs',
#  'the coral reefs',
#  'the amount of co2',
#  'the begining corals',
#  'the healthy coral',
#  'the bleached coral',
#  'the process of photosynthesis',
#  'the process of photosynthesis',
#  'corals living in the oceans',
#  'the algae cant',
#  'these warmer waters',
#  'the last rate',
#  'the pacific ocean',
#  'rates of coral bleaching',
#  'the pacific ocean',
#  'different types of corals living in the oceans',
#  'the atlantic ocean',
#  'these warm waters',
#  '0000 coral bleaching',
#  '0000 coral bleaching',
#  'passage about coral it begins to talk about how the coral got or get their colors in the first place',
#  'algae , also called zooxanthellae',
#  'the same waters',
#  'the healthy coral',
#  'algae called zooxanthellae',
#  'this spike in temperature',
#  'the temperature rate',
#  'the coral bleaching',
#  'the atlantic ocean',
#  'a bleaching event that make corals vulnerable to disease and starvation',
#  'the coral bleaching',
#  'temperature in the water',
#  'the ocean they are at',
#  'the atlantic ocean',
#  'the atlantic ocean',
#  'the world coral reef',
#  'the world coral reefs',
#  'rates of coral bleaching',
#  'reef building coral',
#  'the background passage it said',
#  'the reports of coral bleaching',
#  'the amount of coral bleaching',
#  'the amount of corals',
#  'corals from the enviroment forces then the coral eject the food producing',
#  'the relationship between the coral and zooxanthallae',
#  'the different types of algae living within the coral polyps',
#  'the body of the coral',
#  'the high temps',
#  "the process called '' photosynthesis",
#  'the coral bleaching',
#  'the atlantic ocean',
#  'algae , called zooxanthellae',
#  'the shifting trade winds',
#  'the amount of carbon dioxide',
#  'a necessary balance in coral reefs',
#  'the process of photosynthesis',
#  'rates of coral bleaching',
#  'the balance necessary for coral health',
#  'the atlantic ocean',
#  'the trade winds',
#  'process of photosynthesis',
#  'these warm waters',
#  'the amount of co2',
#  'the amount of co2',
#  'the temperature of the water',
#  'the coral reefs',
#  'the environment which',
#  'the color of there',
#  'the coral bleaching',
#  'the weaker trade winds',
#  'the trade winds',
#  'the trade winds',
#  'the trade winds',
#  'the coral bleaching',
#  'the coral bleaching',
#  'the coral bleaching',
#  'algae , called zooxanthellae',
#  'surface waters to be colder than those in the western pacific',
#  'different organisms called polyps',
#  'the hard skeleton',
#  'the more reefs',
#  'the algae that makes the coral bleach',
#  'increased stress on corals from the environment',
#  'the algae that feeds them',
#  'an unbalanced relationship between the two',
#  'the relationship between algae and coral',
#  'rates of coral bleaching',
#  'storms like hurricanes',
#  'the right temperature',
#  'trade wind strength',
#  'the coral bleaching',
#  'the shifting winds',
#  'the temperature increases',
#  'the trade winds']

# %%
sorted(mention2replace, key = lambda s: -len(s[1].split("_")))[:35]
# Out:
# [('the winds',
#   'the_trade_winds_that_go_through_upwelling_which_can_increase_the_temperature_from_3of_to_5of_and_in_some_places_they_increase_over_10of'),
#  ('the trade winds',
#   'the_trade_winds_that_go_through_upwelling_which_can_increase_the_temperature_from_3of_to_5of_and_in_some_places_they_increase_over_10of'),
#  ('the photosynthesis',
#   'the_photosynthesis_the_polyps_go_through_to_recieve_energy_to_give_to_the_coral_which_they_need_00_%_to_00_%_of'),
#  ('the ways',
#   'many_ways_to_explain_the_rates_in_coral_bleaching_like_trade_winds_,_a_balanced_environment_,_and_physical_damage'),
#  ('it',
#   'the_change_in_carbon_dioxide_which_is_a_cause_of_different_temperatures_and_extreme_storms_coral_how_salty_the_water'),
#  ('it',
#   'the_change_in_carbon_dioxide_which_is_a_cause_of_different_temperatures_and_extreme_storms_coral_how_salty_the_water'),
#  ('the algae',
#   'the_algae_,_called_zooxanthellae_,_that_lives_in_the_tissues_of_the_coral_need_sunlight_for_photosynthesis'),
#  ('the algae',
#   'the_algae_,_called_zooxanthellae_,_that_lives_in_the_tissues_of_the_coral_need_sunlight_for_photosynthesis'),
#  ('this algae',
#   'the_algae_,_called_zooxanthellae_,_that_lives_in_the_tissues_of_the_coral_need_sunlight_for_photosynthesis'),
#  ('the coral',
#   'the_coral_which_is_in_the_pacific_ocean_and_also_because_how_the_people_affect_the_coral_bleaching'),
#  ('the coral',
#   'the_coral_which_is_in_the_pacific_ocean_and_also_because_how_the_people_affect_the_coral_bleaching'),
#  ('the coral',
#   'the_coral_which_is_in_the_pacific_ocean_and_also_because_how_the_people_affect_the_coral_bleaching'),
#  ('it',
#   'this_mostly_in_the_pacific_ocean_which_is_good_for_corals_reefs_to_live_in_shifting_the_wind'),
#  ('the salinity',
#   'water_salinity_-lrb-_how_salty_the_water_is_-rrb-_salt_levels_can_decrease_during_storms_with_excessive_rainfall'),
#  ('the environment',
#   'a_nutrient_-_rich_environment_for_the_algae_,_the_zooxanthellae_pass_food_to_the_coral_with_color'),
#  ('itself',
#   'the_coral_itself_,_coral_is_not_what_people_think_it_is_,_it_an_animal_like_polyps'),
#  ('it',
#   'the_coral_itself_,_coral_is_not_what_people_think_it_is_,_it_an_animal_like_polyps'),
#  ('this event',
#   'a_bleaching_event_in_0000_,_which_is_considered_to_be_one_of_the_worst_ever_observed'),
#  ('itself',
#   'a_massive_effect_not_only_on_the_coral_itself_,_but_on_the_world_many_coral_reefs'),
#  ('the energy it needs to survive',
#   'the_photosynthesis_zooxanthellae_use_energy_from_sunlight_to_combine_carbon_dioxide_in_the_ocean_with_water'),
#  ('the water temperature',
#   'the_water_temperature_,_upwelling_,_movement_of_water_,_the_amount_and_severity_of_storms'),
#  ('the algae',
#   'the_algae_that_has_not_been_ejected_most_likely_dies_because_it_can_not_preform_photosynthesis'),
#  ('it',
#   'the_algae_that_has_not_been_ejected_most_likely_dies_because_it_can_not_preform_photosynthesis'),
#  ('it',
#   'the_algae_that_has_not_been_ejected_most_likely_dies_because_it_can_not_preform_photosynthesis'),
#  ('it',
#   'the_algae_that_has_not_been_ejected_most_likely_dies_because_it_can_not_preform_photosynthesis'),
#  ('that',
#   "some_things_that_can_happen_to_coral_that_may_lead_to_''_coral_bleaching_''"),
#  ('this phenomenon',
#   'a_phenomenon_with_coral_that_causes_it_to_loose_it_color_and_turn_plain_white'),
#  ('the water temperatures',
#   'the_highest_water_temperatures_recorded_,_which_was_a_result_of_weaker_trade_winds'),
#  ('these changes in the environment',
#   'some_changes_in_the_environment_that_can_threaten_the_process_between_coral_and_algae'),
#  ('the event',
#   'a_massive_coral_bleaching_event_that_was_considered_one_of_the_worst_ones_observed'),
#  ('this event',
#   'a_massive_coral_bleaching_event_in_0000_considered_one_of_the_worst_ever_observed'),
#  ('the coral',
#   'the_coral_like_blast_fishing_,_anchors_or_people_walking_dropping_on_the_corals'),
#  ('it',
#   'the_coral_like_blast_fishing_,_anchors_or_people_walking_dropping_on_the_corals'),
#  ('it',
#   'the_coral_like_blast_fishing_,_anchors_or_people_walking_dropping_on_the_corals'),
#  ('the water',
#   'the_water_their_in_to_be_between_seventy_and_eighty_-_five_degrees_farinheight')]

# %%
for m,h in mention2replace:
    if len(m.split(" ")) > len(h.split("_")):
        print(m)
        print(h)
        print("")
# Out:
# producers -lrb- things that create food using sunlight like coral reef -rrb-
# the_producers_in_the_ocean
#
# corals living in the oceans
# the_corals
#
# a report of coral bleaching
# the_coral_bleaching_reports
#
# algae , called zooxantellae
# the_algae
#
# the temperature the water needs to be at for coral reefs to survive
# the_water_temperature
#
# the ocean with water -lrb- h20 -rrb-
# the_pacific_ocean
#
# a algae with a different color and living with the coral
# the_color_algae
#
# the temperature of the water
# the_higher_temperature
#
# types of algae living in the corals polyps
# the_types_of_algae
#
# the ocean with water
# the_pacific_ocean
#
# the temperature in the water
# the_water_temperature
#
# the ocean with water
# the_tropical_ocean
#
# coral and zooxanthellae algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# carbon dioxide -lrb- co2 -rrb-
# the_carbon_dioxide
#
# the temperature of the water
# the_water_temperature
#
# a coral which it can be damage
# the_coral_and_algae_coral
#
# many factor which leads to differences in the rates of coral bleaching
# the_first_factor
#
# algae that was ejected from the coral
# the_algae
#
# the stress on the coral
# the_coral_stress
#
# the zooxanthallae
# zooxanthallae
#
# the zooxanthallae
# zooxanthallae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the definition of upwelling
# the_pacific_ocean
#
# the environment of corals and these action
# the_corals_environment
#
# coral bleaching i found
# the_coral_bleaching
#
# the cause of the temperature change in waters
# the_main_cause_for_bleaching
#
# many factor that cause coral bleaching
# these_different_factor
#
# zooxanthellae , algae
# the_zooxanthellae
#
# the algae
# algae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the zooxanthellae
# zooxanthellae
#
# the stress they have caused by fishes and humans
# this_cause_stress
#
# storms that cause excessive rainfall
# these_storms
#
# the ocean with water
# the_ocean_water
#
# the water of a certain temperature
# coral_bleaching_water
#
# the algae
# algae
#
# the algae
# algae
#
# the zooxanthellae algae the coral
# the_coral_zooxanthellae
#
# the algae
# algae
#
# carbon dioxide -lrb- co2 -rrb- in water decreases
# the_less_carbon_dioxide
#
# the coral which causes the bleaching process
# the_reading_''_coral
#
# the amount of salinity in the water
# the_less_co2_amount
#
# zooxanthelae that live on the coral to survive
# the_zooxanthelae
#
# some variables that may lead to changes in coral bleaching
# the_two_variables
#
# the algae
# algae
#
# corals in the ocean
# the_corals
#
# algae -lrb- zooxanthellae -rrb-
# the_algae
#
# these algae
# algae
#
# the algae
# algae
#
# algae that live in corals
# the_algae
#
# the zooxanthellae
# zooxanthellae
#
# corals living in the ocean or sea
# the_corals
#
# the zooxanthellae
# zooxanthellae
#
# another factor for coral bleaching
# the_biggest_factor
#
# damage from blast fishing , or tourists walking or dropping anchors on to the coral
# the_coral_damage
#
# the changes in the environment
# these_environmental_changes
#
# corals from the environment
# the_corals
#
# changes in the enviroment like temperature increase or water level increase or decrease
# the_changes
#
# algae that lives in it
# the_algae
#
# glucose for the coral
# the_glucose
#
# the years of weaker trade winds the water temperature rises
# those_same_years_coral_bleaching_reports_rise
#
# coral , zooxanthallae
# the_coral
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the ocean with water
# the_pacific_ocean
#
# the temperature of the water
# the_water_temperature
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# coral its color
# the_coral
#
# the temperature of the wind effects the temperature of the ocean
# the_wind_temperature
#
# the amount of algae
# the_necessary_amount
#
# the problem that makes coral bleach
# the_coral_bleaching_problem
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# algae called zooxanthellae
# the_algae
#
# the algae
# algae
#
# the zooxanthellae algae
# algae
#
# the ocean for the corals
# the_tropical_ocean
#
# the zooxanthallae
# zooxanthallae
#
# they all
# corals
#
# the temperature of the water
# the_ocean_temperature
#
# the temperature of the water
# the_ocean_temperature
#
# the amount of co2
# the_right_amount
#
# algae called zooxanthellae
# the_algae
#
# the temperatures of the water
# the_water_temperatures
#
# the alpi
# algae
#
# the alpi
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the alpi
# algae
#
# it its
# food
#
# the ocean in the entire globe
# the_tropical_ocean
#
# the water in the eastern pacific
# the_eastern_pacific_water
#
# the algae
# algae
#
# the temperature in the water
# the_water_temperature
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# reasons for coral bleaching
# the_big_reasons
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# the pacific ocean
# ocean
#
# the algae
# algae
#
# the algae
# algae
#
# the algae
# algae
#
# stress that is put on
# this_stress
#
# the pacific ocean which contains double the amount of water of the atlantic
# the_eastern_pacific_ocean
#
# photosynthesis which is how
# the_photosynthesis
#
# the rates of coral bleaching
# the_coral_bleaching_rates
#
# trade winds which leads to differences in
# the_trade_winds
#
# corals from the enviroment
# the_corals
#
# them their
# they
#
# the process of photosynthesis
# their_food_process
#
# the process of photosynthesis it wont have energy
# their_food_process
#
# the salinity
# salinity
#
# corals living in the oceans
# the_corals
#
# algae called zooxanthelle
# the_algae
#
# the ocean with -lrb- h20 -rrb-
# the_pacific_ocean
#
# corals living in the ocean
# the_corals
#
# this movement of warm water
# movement
#
# corals living in
# the_corals
#
# corals living in the oceans
# the_corals
#
# a group i have created
# just_like_my_group
#
# the coral that is called the coral bleaching
# the_living_coral
#
# them they
# corals
#
# corals living in the oceans
# the_corals
#
# the algae
# algae
#
# the algae
# algae
#
# passage about coral it begins to talk about how the coral got or get their colors in the first place
# the_passage
#
# algae , also called zooxanthellae
# the_algae
#
# algae called zooxanthellae
# these_algae
#
# a bleaching event that make corals vulnerable to disease and starvation
# the_most_massive_coral_bleaching_event
#
# temperature in the water
# the_temperature
#
# the ocean they are at
# the_pacific_ocean
#
# the reports of coral bleaching
# coral_bleaching_reports
#
# corals from the enviroment forces then the coral eject the food producing
# the_corals
#
# the algae
# algae
#
# the algae
# algae
#
# the different types of algae living within the coral polyps
# the_coral_different_types_of_colors
#
# the zooxanthallae
# zooxanthallae
#
# algae , called zooxanthellae
# the_algae
#
# the balance necessary for coral health
# the_salinity_balance
#
# process of photosynthesis
# the_process
#
# the temperature of the water
# the_lowest_water_temperature
#
# the algae
# algae
#
# algae , called zooxanthellae
# the_algae
#
# surface waters to be colder than those in the western pacific
# these_warm_waters
#
# different organisms called polyps
# these_two_organisms
#
# the algae that makes the coral bleach
# either_the_algae
#
# increased stress on corals from the environment
# the_corals_stress
#
# storms like hurricanes
# these_storms

# %%
essay2parsed = {}
for e in tagged_essays2:
    essay2parsed[e.name.split(".")[0]] = e
len(essay2parsed)
# Out:
# 902

# %%
list(essay2parsed.keys())[0:10]
# Out:
# ['EBA1415_AEKD_4_CB_ES-05568',
#  'EBA1415_AEKD_4_CB_ES-05572',
#  'EBA1415_AEKD_4_CB_ES-05902',
#  'EBA1415_AEKD_5_CB_ES-05579',
#  'EBA1415_AEKD_5_CB_ES-05582',
#  'EBA1415_AEKD_5_CB_ES-05586',
#  'EBA1415_BGJD_1_CB_ES-05726',
#  'EBA1415_BGJD_1_CB_ES-05727',
#  'EBA1415_BGJD_1_CB_ES-05728',
#  'EBA1415_BGJD_1_CB_ES-05732']

# %%
list(essay2tagged.keys())[0:10]
# Out:
# ['EBA1415_AEKD_4_CB_ES-05568',
#  'EBA1415_AEKD_4_CB_ES-05902',
#  'EBA1415_AEKD_5_CB_ES-05579',
#  'EBA1415_AEKD_5_CB_ES-05582',
#  'EBA1415_AEKD_5_CB_ES-05586',
#  'EBA1415_BGJD_1_CB_ES-05726',
#  'EBA1415_BGJD_1_CB_ES-05727',
#  'EBA1415_BGJD_1_CB_ES-05728',
#  'EBA1415_BGJD_1_CB_ES-05732',
#  'EBA1415_BGJD_2_CB_ES-05735']

# %%
wds = 0
for sent in essay.sentences:
    for wd,tags in sent:
        wds += 1
wds
# Out:
# 174

# %%
wds2 = 0
for sent in tagged_essay:
    for wd in sent:
        wds2 += 1
wds2
# Out:
# 175

# %%
diffs = 0
for ename, tagged_essay in essay2tagged.items():
    assert ename in essay2parsed
    essay = essay2parsed[ename]
    
        
    wds1 = 0
    for sent in essay.sentences:
        for wd,tags in sent:
            wds1 += 1

    wds2 = 0
    for sent in tagged_essay:
        for wd in sent:
            wds2 += 1
    if wds1 != wds2:
        diffs+=1
        print(ename,  len(essay.sentences), len(tagged_essay), wds1, wds2, wds2>=wds1)
# Out:
# EBA1415_AEKD_5_CB_ES-05579 15 12 233 234 True
# EBA1415_BGJD_2_CB_ES-05747 2 1 15 13 False
# EBA1415_BLRW_3_CB_ES-05168 11 10 156 154 False
# EBA1415_BLRW_3_CB_ES-05174 16 16 262 263 True
# EBA1415_BLRW_3_CB_ES-05180 12 12 171 172 True
# EBA1415_ERAP_7_CB_ES-05464 15 15 225 226 True
# EBA1415_ERSK_7_CB_ES-05793 10 10 143 141 False
# EBA1415_ERSK_7_CB_ES-06271 4 5 67 63 False
# EBA1415_HNJD_4_CB_ES-05810 29 29 386 387 True
# EBA1415_KNKC_3_CB_ES-05590 13 13 270 268 False
# EBA1415_KYLS_6_CB_ES-05682 6 5 83 81 False
# EBA1415_KYNS_4_CB_ES-05400 10 10 248 250 True
# EBA1415_KYNS_4_CB_ES-05403 11 12 206 204 False
# EBA1415_LRBL_4_CB_ES-05164 8 6 104 105 True
# EBA1415_LRJE_7_CB_ES-05138 19 19 216 217 True
# EBA1415_LZBA_4_CB_ES-05530 16 16 286 287 True
# EBA1415_RDJK_5_CB_ES-04725 14 14 240 241 True
# EBA1415_RHSG_1_CB_ES-05072 9 9 166 167 True
# EBA1415_SDMK_4_CB_ES-04764 12 12 268 269 True
# EBA1415_SDMK_6_CB_ES-04777 15 15 256 257 True
# EBA1415_SEAL_34_CB_ES-04798 13 15 230 228 False
# EBA1415_SEAL_34_CB_ES-05695 13 13 203 204 True
# EBA1415_SEAL_78_CB-04800 16 16 226 227 True
# EBA1415_SEKL_23_CB_ES-04827 10 10 115 116 True
# EBA1415_SERS_1314_CB-05100 11 11 282 280 False
# EBA1415_SERS_1314_CB-05930 10 10 161 162 True
# EBA1415_SERS_1314_CB_ES-05107 15 15 167 168 True
# EBA1415_SERS_1314_CB_ES-05108 11 11 159 160 True
# EBA1415_SWCT_7_CB_ES-04897 18 18 297 298 True
# EBA1415_SWSP_4_CB_ES-04856 6 6 96 97 True
# EBA1415_TFBM_2_CB_ES-05554 8 8 147 148 True
# EBA1415_TFBM_2_CB_ES-05557 17 17 267 268 True
# EBA1415_TFHC_1_CB_ES-05947 19 19 341 342 True
# EBA1415_TFMV_3_CB_ES-05846 16 15 298 296 False
# EBA1415_TRJB_2_CB_ES-06119 7 6 81 79 False
# EBA1415_TTCM_910_CB_ES-06150 10 10 166 162 False
# EBA1415_TTFW_2_CB_ES-04910 3 3 143 141 False
# EBA1415_TTKP_45_CB_ES-04921 4 3 56 54 False
# EBA1415_TTKP_45_CB_ES-6159 6 6 111 112 True
# EBA1415_TWNB_3_CB_ES-04980 6 6 167 168 True
# EBA1415_WSAL_1_CB_ES-05350 9 8 162 158 False
# EBA1415_WSAL_1_CB_ES-05354 5 5 124 125 True
# EBA1415_WSKT_1_CB_ES-05315 26 26 349 350 True
# EBA1415post_TWMD_67_CB_ES-06192 8 8 151 152 True
# EBA1415post_TWPK_3_CB_ES-06195 11 11 197 198 True
# EBA1415post_WSKT_6_CB_ES-05347 10 10 174 175 True

# %%
diffs, len(essay2tagged)
# Out:
# (46, 622)

# %%
len(tagged_essay), len(essay.sentences)
# Out:
# (10, 10)

# %%
key = "EBA1415_WSAL_1_CB_ES-05354"
essay = essay2parsed[key]
tessay = essay2tagged[key]

wds1, wds2 = [],[]
for sent in essay.sentences:
    for wd,tags in sent:
        wds1.append(wd)
        
for sent in tessay:
    for wd,tags in sent:
        wds2.append(wd)
ix = 0
for a,b in zip(wds1,wds2):
    if a != b:
        break
    ix += 1
list(zip(wds1[ix-3:ix+10],wds2[ix-3:ix+10]))
# Out:
# [('animals', 'animals'),
#  ('particles', 'particles'),
#  ('are', 'are'),
#  ('gonna', 'gon'),
#  ('begin', 'na'),
#  ('to', 'begin'),
#  ('die', 'to'),
#  ('out', 'die'),
#  (',', 'out'),
#  ('because', ','),
#  ('they', 'because'),
#  ('cant', 'they'),
#  ('gain', 'cant')]

# %%
key = "EBA1415_BLRW_3_CB_ES-05168"
essay = essay2parsed[key]
tessay = essay2tagged[key]

wds1, wds2 = [],[]
for sent in essay.sentences:
    for wd,tags in sent:
        wds1.append(wd)
        
for sent in tessay:
    for wd,tags in sent:
        wds2.append(wd)
        
ix_a, ix_b = 0,0
scan_length = 5
print_wds = True
while ix_a < len(wds1) and ix_b < len(wds2):
    a = wds1[ix_a]
    b = wds2[ix_b]
    if print_wds:
        print(a,b)
    if a != b:
        
        print_wds = True
        print("*" * 10 + "miss match" + "*" * 10)        
        next_a = wds1[ix_a+1]
        next_b = wds2[ix_b+1]
        # look ahead in wds2 for item that matches next a
        found_match = False
        for offseta, aa in enumerate(wds1[ix_a:ix_a+1+scan_length]):
            for offsetb, bb in enumerate(wds2[ix_b:ix_b+1+scan_length]):
                if aa == bb:
                    ix_a = ix_a + offseta
                    ix_b = ix_b + offsetb
                    found_match = True
                    print("Found:", aa,bb,ix_a,ix_b)
                    break
            if found_match:
                break
                
        if found_match:
            break
        else:
            print("Failed: ", a, b)
    else:            
        ix_a += 1
        ix_b += 1
    
###list(zip(wds1[ix-3:ix+10],wds2[ix-3:ix+10]))
# Out:
# the the
# differences differences
# in in
# the the
# rates rates
# of of
# coral coral
# bleaching bleaching
# is is
# that that
# first first
# it it
# started started
# out out
# not not
# so so
# major major
# in in
# 0000 0000
# , ,
# but but
# than than
# it it
# started started
# increasing increasing
# . .
# the the
# highest highest
# rate rate
# was was
# in in
# 0000 0000
# it it
# reached reached
# up up
# to to
# more more
# than than
# 00 00
# countries countries
# making making
# a a
# report report
# of of
# coral coral
# bleaching bleaching
# . .
# so so
# on on
# it it
# started started
# decreasing decreasing
# from from
# there there
# . .
# than than
# again again
# who who
# knows knows
# how how
# bad bad
# it it
# is is
# now now
# 0000 0000
# . .
# the the
# coral coral
# bleaching bleaching
# reports reports
# only only
# went went
# from from
# 0000 0000
# - -
# 0000 0000
# . .
# " ''
# **********miss match**********
# Found: also also 78 78

# %%
found_match
# Out:
# True

# %%
diffs = 0
failed_cnt = 0
for ename, tagged_essay in essay2tagged.items():
    assert ename in essay2parsed
    essay = essay2parsed[ename]
         
    wds1 = []
    for sent in essay.sentences:
        for wd,tags in sent:
            wds1.append(wd)

    wds2 = []
    for sent in tagged_essay:
        for wd,tag_dict in sent:
            wds2.append(wd)
            
    ix_a, ix_b = 0,0

    scan_length = 5
    while ix_a < len(wds1) and ix_b < len(wds2):
        a = wds1[ix_a]
        b = wds2[ix_b]
#         print(a,b)
        if a != b:
#             print("*" * 10 + "miss match" + "*" * 10)            
            # look ahead in wds2 for item that matches next a
            found_match = False
            for offseta, aa in enumerate(wds1[ix_a:ix_a+1+scan_length]):
                for offsetb, bb in enumerate(wds2[ix_b:ix_b+1+scan_length]):
                    if aa == bb:
                        ix_a = ix_a + offseta
                        ix_b = ix_b + offsetb
                        found_match = True
                        #print("Found:", aa,bb,ix_a,ix_b)
                        break
                if found_match:
                    break
            if not found_match:
                print("Failed: " + ename, a, b)
                failed_cnt +=1
                break
        else:            
            ix_a += 1
            ix_b += 1
failed_cnt
# Out:
# Failed: EBA1415_KYNS_3_CB_ES-05384 " ''
# Failed: EBA1415_LRJE_7_CB_ES-05143 . ...
# Failed: EBA1415_RCGJ_6_CB_ES-04692 " ''
# Failed: EBA1415_RDJK_5_CB_ES-4730 " ''
# Failed: EBA1415_SEAL_34_CB_ES-04798 " ''
# Failed: EBA1415_SEKL_2_CB-06037 " ''
# Failed: EBA1415_SWCT_7_CB-04885 " ''
# Failed: EBA1415_TFBM_1_CB_ES-05442 " ''
# Failed: EBA1415_TFBM_2_CB_ES-05550 " ''
# Failed: EBA1415_TFHC_4_CB_ES-05829 " ''
# Failed: EBA1415post_TWJB_5_CB_ES-06221 ) -rrb-
# Failed: EBA1415post_TWNB_3_CB_ES-04981 . ...
# Failed: EBA1415post_TWPK_3_CB_ES-05052 ) -rrb-
# 13
