# %%
import pandas as pd

fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions.txt"
#fname = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/predictions_causal_and_codes.txt"
#fname = "/Users/simon.hughes/Google Drive/PhD/Data/SkinCancer/Results/sc_cause_effect_labels_predictions.txt"

#fout = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/Results/cb_essay_categories.csv"
#fout = "/Users/simon.hughes/Google Drive/PhD/Data/SkinCancer/Results/sc_essay_categories.csv"

data = pd.read_csv(fname, sep="|")

# %%
def group_by(df, bycols, agg_map):
    """

    @param df:      DataFrame
    @param bycols:  str or list
                        Column(s) to group by
    @param agg_map: dictionary or list of 2-tuples
                        Mapping from column to aggregate function e.g. [("city", "count"), ("salary", "mean"]
    @return:        DataFrame
                        Flattened dataframe, with multi-level index removed
    """
    grps = []
    if type(bycols) == str:
        bycols = [bycols]

    if type(agg_map) == dict:
        agg_map = agg_map.items()
    for k,v in agg_map:
        grp = df[bycols + [k]].groupby(bycols).agg(v)
        grp.reset_index(inplace=True)
        grps.append(grp)

    m = grps[0]
    for grp in grps[1:]:
        m = pd.merge(m, grp, on=bycols, how="inner")
    return m

# %%
data["Concept Codes"] = data["Concept Codes"].astype("str")
data["Concept Codes"] = data["Concept Codes"].apply(lambda s: "" if s == "nan" else s)
data["Predictions"] = data["Predictions"].astype("str")
data["Predictions"] = data["Predictions"].apply(lambda s: "" if s == "nan" else s)
data.head(10)
# Out:
#                             Essay  Sent Number  \
# 0  EBA1415_AEKD_4_CB_ES-05568.ann            1
# 1  EBA1415_AEKD_4_CB_ES-05568.ann            2
# 2  EBA1415_AEKD_4_CB_ES-05568.ann            3
# 3  EBA1415_AEKD_4_CB_ES-05568.ann            4
# 4  EBA1415_AEKD_4_CB_ES-05572.ann            1
# 5  EBA1415_AEKD_4_CB_ES-05572.ann            2
# 6  EBA1415_AEKD_4_CB_ES-05572.ann            3
# 7  EBA1415_AEKD_4_CB_ES-05572.ann            4
# 8  EBA1415_AEKD_4_CB_ES-05572.ann            5
# 9  EBA1415_AEKD_4_CB_ES-05572.ann            6
#
#                                   Processed Sentence  \
# 0  What leads to differences in the rates of cora...
# 1  Coral is often mistaken for a rock but it is m...
# 2  Coral bleaching shows bleaching and healthy bl...
# 3  Coral bleaching is almost noticeable in the pa...
# 4  The part of coral called " zooanthellae " are ...
# 5  And if they dont get or much sunlight they sta...
# 6  The reason why is because the " zooanthellae ....
# 7  The coral also need special water temperature ...
# 8  Also its a threats for us because means that m...
# 9               Also the water us getting to salty .
#
#                                        Concept Codes Predictions
# 0                                                 50          50
# 1
# 2                                                 50          50
# 3                                                 50          50
# 4                                                  5
# 5  5,50,_C->R,_CRel,_RRel,Causer,Result,explicit,...          50
# 6                                                  4
# 7
# 8                                                 11          11
# 9                                                 13

# %%
def concat(lst):
    return ",".join(lst)

def make_unique(s):
    joined = s
    splt = joined.split(",")
    if len(splt) == 0:
        return ""
    un = set(splt)
    if "" in un:
        un.remove("")
    return ",".join(sorted(un))

def codes_only(s):
    splt = s.split(",")
    return ",".join([t for t in splt if len(t.strip()) > 0 and t[0].isdigit()])

def causal_only(s):
    splt = s.split(",")
    causal = ",".join([t for t in splt if len(t.strip()) > 0 and "->" in t and "Causer" in t and "Result" in t])
    return causal.replace("Causer:","").replace("Result:","")

grpd = group_by(data, "Essay", {"Concept Codes": concat, "Predictions": concat})
grpd["Concept Codes"] = grpd["Concept Codes"].apply(make_unique)
grpd["Predictions"] = grpd["Predictions"].apply(make_unique)

grpd["Ys_codes"] = grpd["Concept Codes"].apply(codes_only)
grpd["Pred_codes"] = grpd["Predictions"].apply(codes_only)

grpd["Ys_causal"] = grpd["Concept Codes"].apply(causal_only)
grpd["Pred_causal"] = grpd["Predictions"].apply(causal_only)
#Re-order cols
grpd = grpd[["Essay", "Concept Codes", "Ys_codes", "Ys_causal", "Predictions", "Pred_codes", "Pred_causal"]]
grpd.head(10)
# Out:
#                             Essay  \
# 0  EBA1415_AEKD_4_CB_ES-05568.ann
# 1  EBA1415_AEKD_4_CB_ES-05572.ann
# 2  EBA1415_AEKD_4_CB_ES-05574.ann
# 3  EBA1415_AEKD_4_CB_ES-05902.ann
# 4     EBA1415_AEKD_5_CB-06232.ann
# 5  EBA1415_AEKD_5_CB_ES-05575.ann
# 6  EBA1415_AEKD_5_CB_ES-05579.ann
# 7  EBA1415_AEKD_5_CB_ES-05582.ann
# 8  EBA1415_AEKD_5_CB_ES-05586.ann
# 9  EBA1415_BGJD_1_CB_ES-05725.ann
#
#                                        Concept Codes      Ys_codes  \
# 0                                                 50            50
# 1  11,13,4,5,50,Causer,Causer:5->Result:50,Result...  11,13,4,5,50
# 2                                              13,50         13,50
# 3  3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...      3,4,50,7
# 4  50,Causer,Causer:7->Result:50,Result,_C->R,_CR...            50
# 5  50,Causer,Causer:7->Result:50,Result,_C->R,_CR...            50
# 6                                               1,50          1,50
# 7  50,7,Causer,Causer:7->Result:50,Result,_C->R,_...          50,7
# 8                                                 50            50
# 9  3,50,Causer,Causer:3->Result:50,Causer:5->Resu...          3,50
#
#     Ys_causal                                        Predictions Pred_codes  \
# 0                                                             50         50
# 1       5->50                                              11,50      11,50
# 2                                                             50         50
# 3  3->4,7->50  3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...   3,4,50,7
# 4       7->50  50,7,Causer,Causer:7->Result:50,Result,_C->R,_...       50,7
# 5       7->50  50,Causer,Causer:7->Result:50,Result,_C->R,_CR...         50
# 6              1,14,50,6,Causer,Causer:6->Result:14,Result,_C...  1,14,50,6
# 7       7->50  50,7,Causer,Causer:7->Result:50,Result,_C->R,_...       50,7
# 8                  50,7,Causer,Result,_C->R,_CRel,_RRel,explicit       50,7
# 9  3->50,5->7  3,50,Causer,Causer:3->Result:50,Result,_C->R,_...       3,50
#
#   Pred_causal
# 0
# 1
# 2
# 3  3->4,7->50
# 4       7->50
# 5       7->50
# 6       6->14
# 7       7->50
# 8
# 9       3->50

# %%
def friendly_tag(tag):
    return tag.replace("Causer:", "").replace("Result:", "")

def sort_key(cr):
    cr = cr.replace("5b", "5.5")
    # _'s last
    if cr[0] == "_":
        return (99999999, cr, cr, cr)
    # Casual second to last, ordered by the order of the cause then the effect
    if "->" in cr:
        cr = friendly_tag(cr)
        a,b = cr.split("->")
        if a.isdigit():
            a = float(a)
        if b.isdigit():
            b = float(b)
        return (9000, a,b, cr)
    # order causer's before results
    elif "Result:" in cr:
        cr = friendly_tag(cr)
        return (-1, float(cr),-1,cr)
    elif "Causer:" in cr:
        cr = friendly_tag(cr)
        return (-2, float(cr),-1,cr)
    else:
        #place regular tags first, numbers ahead of words
        if cr[0].isdigit():
            return (-10, float(cr),-1,cr)
        else:
            return (-10, 9999.9   ,-1,cr.lower())
    return (float(cr.split("->")[0]), cr) if cr.split("->")[0][0].isdigit() else (99999, cr)

def category(s):
    if not s or s =="" or s == "nan":
        return 1
    splt = s.strip().split(",")
    splt = filter(lambda s: len(s.strip()) > 0, splt)
    regular = [t.strip() for t in splt if t[0].isdigit()]
    any_causal  = [t.strip() for t in splt if "->" in t and (("Causer" in t and "Result" in t) or "C->R" in t) ]
    causal  = [t.strip() for t in splt if "->" in t and "Causer" in t and "Result" in t]
    if len(regular) == 0 and len(any_causal) == 0:
        return 1
    if len(any_causal) == 0: #i.e. by this point regular must have some
        return 2 # no causal
    # if only one causal then must be 3
    elif len(any_causal) == 1 or len(causal) == 1:
        return 3
    #Map to Num->Num, e.g. Causer:3->Results:50 becomes 3->5
    # Also map 6 to 16 and 7 to 17 to enforce the relative size relationship
    
    def map_cb(code):
        return code.replace("6","16").replace("7","17")
    
    def map_sc(code):
        return code.replace("4","14").replace("5","15").replace("6","16").replace("150","50")
    
    if "Coral" in fname:
        crels = sorted(map(lambda t: map_cb(t.replace("Causer:","").replace("Result:","")).strip(),causal), 
                       key=sort_key)
    elif "Skin" in fname:
        crels = sorted(map(lambda t: map_sc(t.replace("Causer:","").replace("Result:","")).strip(),\
                       causal), 
                       key=sort_key)
    else:
        raise Exception("Unrecognized filename")
    
    un_results = set()
    # For each unique pairwise combination
    for a in crels:
        for b in crels:
            if sort_key(b) >= sort_key(a): # don't compare each pair twice (a,b) == (b,a)
                break
            # b is always the smaller of the two
            bc,br = b.split("->")
            ac,ar = a.split("->")
            # if result from b is causer for a
            if br.strip() == ac.strip():
                un_results.add((b,a))
    
    if len(un_results) >=1:
        
        # To be a 4 or a 5, at least one relation needs to end in a 50
        joined = ",".join(map(str, un_results))
        if "->50" not in joined:
            return 3
        
        #CB and 6->7->50 ONLY
        if len(un_results) == 1 and "Coral" in fname and ("16->17", "17->50") in un_results:
            return 4
        if len(un_results) <=2 and "Skin" in fname:
            #4->5->6->50
            codes = set("14,15,16,50".split(","))
            un_results_cp = set(un_results)
            for a,b in un_results:
                alhs, arhs = a.split("->")
                blhs, brhs = b.split("->")
                if alhs in codes and arhs in codes and blhs in codes and brhs in codes:
                    un_results_cp.remove((a,b))
            if len(un_results_cp) == 0:
                return 4
        return 5
    else:
        return 3

# %%
def check(inp, expected):
    actual = category(inp)
    assert actual == expected, "Inp: %s Actual:%i Expected:%i" % (inp, actual, expected)

check("" , 1)
check(" ", 1)

check("1", 2)
check("1,3", 2)
check("1,,,,4,7,50,1289", 2)

check("Causer:1->Result:3", 3)
check("Causer:1->Result:3,Causer:4->Result:5", 3)
#Multiple going to 50 is a 3
check("Causer:1->Result:50,Causer:3->Result:50,Causer:5->Result:50", 3)
check("Causer:1->Result:3, Causer:4->Result:5", 3)

check("_C->R", 3)
check("3,4,5,_C->R", 3)

check("Causer:6->Result:7", 3)
check("Causer:5->Result:5b", 3)

check("Causer:3->Result:4, Causer:1->Result:4, Causer:3->Result:50", 3)
#no intervening
check("Causer:1->Result:4,Causer:6->Result:7", 3)
check("Causer:4->Result:5,Causer:1->Result:3", 3)
check("Causer:1->Result:50, Causer:2->Result:50, Causer:6->Result:50, Causer:7->Result:50", 3)

#Chains not going to 50
check("Causer:1->Result:3, Causer:5->Result:7, Causer:3->Result:6", 3)
check("Causer:1->Result:3, Causer:3->Result:4, Causer:4->Result:6", 3)

#universal 5's
check("Causer:5b->Result:50,Causer:5->Result:5b", 5) #Test 5b's
check("Causer:1->Result:3,Causer:3->Result:50", 5)
check("Causer:1->Result:3, Causer:5->Result:7, Causer:3->Result:50", 5)


if "Skin" in fname:
    print "Skin Cancer"
    check("Causer:11->Result:4,Causer:4->Result:6", 3)
    
    check("Causer:4->Result:5,Causer:5->Result:6,Causer:6->Result:50,", 4)
    check("Causer:4->Result:5,Causer:5->Result:50,", 4)
    check("Causer:4->Result:5,Causer:5->Result:50", 4)
    check("Causer:5->Result:50,Causer:4->Result:5", 4)
    check("Causer:5->Result:6,Causer:6->Result:50,", 4)
    check("Causer:4->Result:6,Causer:6->Result:50,", 4)
    check("1,Causer:4->Result:5,Causer:5->Result:6,Causer:6->Result:50,", 4)
    check("Causer:4->Result:5,Causer:5->Result:6,Causer:6->Result:50,Causer:1->Result:2", 4)

    check("Causer:1->Result:2,Causer:2->Result:50", 5)
    check("Causer:4->Result:5,Causer:5->Result:6,Causer:6->Result:50,Causer:2->Result:4", 5)
    
elif "Coral" in fname:
    print "Coral Bleaching"
    check("Causer:6->Result:7", 3)
    check("Causer:7->Result:50", 3)

    check("Causer:6->Result:7,Causer:7->Result:50", 4)
    check("Causer:7->Result:50,Causer:6->Result:7", 4)
    check("Causer:7->Result:50,Causer:6->Result:7,Causer:3->Result:4", 4)

    check("Causer:7->Result:50,Causer:6->Result:7,Causer:3->Result:6", 5)
    check("Causer:1->Result:6,Causer:6->Result:7,Causer:7->Result:50", 5)
    check("Causer:13->Result:6,Causer:6->Result:50", 5)

print "Tests passed!"
# Out:
# Coral Bleaching
# Tests passed!

# %%
grpd
# Out:
#                                    Essay  \
# 0         EBA1415_AEKD_4_CB_ES-05568.ann
# 1         EBA1415_AEKD_4_CB_ES-05572.ann
# 2         EBA1415_AEKD_4_CB_ES-05574.ann
# 3         EBA1415_AEKD_4_CB_ES-05902.ann
# 4            EBA1415_AEKD_5_CB-06232.ann
# 5         EBA1415_AEKD_5_CB_ES-05575.ann
# 6         EBA1415_AEKD_5_CB_ES-05579.ann
# 7         EBA1415_AEKD_5_CB_ES-05582.ann
# 8         EBA1415_AEKD_5_CB_ES-05586.ann
# 9         EBA1415_BGJD_1_CB_ES-05725.ann
# 10        EBA1415_BGJD_1_CB_ES-05726.ann
# 11        EBA1415_BGJD_1_CB_ES-05727.ann
# 12        EBA1415_BGJD_1_CB_ES-05728.ann
# 13        EBA1415_BGJD_1_CB_ES-05730.ann
# 14        EBA1415_BGJD_1_CB_ES-05732.ann
# 15        EBA1415_BGJD_1_CB_ES-05975.ann
# 16        EBA1415_BGJD_2_CB_ES-05735.ann
# 17        EBA1415_BGJD_2_CB_ES-05736.ann
# 18        EBA1415_BGJD_2_CB_ES-05738.ann
# 19        EBA1415_BGJD_2_CB_ES-05740.ann
# 20        EBA1415_BGJD_2_CB_ES-05744.ann
# 21        EBA1415_BGJD_2_CB_ES-05747.ann
# 22        EBA1415_BGJD_2_CB_ES-05751.ann
# 23        EBA1415_BGJD_2_CB_ES-05752.ann
# 24        EBA1415_BGJD_2_CB_ES-05753.ann
# 25        EBA1415_BGJD_2_CB_ES-05754.ann
# 26        EBA1415_BGJD_2_CB_ES-05756.ann
# 27         EBA1415_BGJD_2_CB_ES-5746.ann
# 28        EBA1415_BLHT_5_CB_ES-05201.ann
# 29        EBA1415_BLHT_5_CB_ES-05202.ann
# ...                                  ...
# 1058  EBA1415post_TWPK_3_CB_ES-06198.ann
# 1059  EBA1415post_UTKZ_1_CB_ES-05760.ann
# 1060  EBA1415post_WSAL_1_CB_ES-05348.ann
# 1061  EBA1415post_WSAL_1_CB_ES-05349.ann
# 1062  EBA1415post_WSAL_1_CB_ES-05351.ann
# 1063  EBA1415post_WSAL_1_CB_ES-05353.ann
# 1064  EBA1415post_WSAL_1_CB_ES-05488.ann
# 1065  EBA1415post_WSAL_1_CB_ES-05961.ann
# 1066  EBA1415post_WSAL_2_CB_ES-05356.ann
# 1067  EBA1415post_WSAL_2_CB_ES-05364.ann
# 1068  EBA1415post_WSAL_2_CB_ES-05365.ann
# 1069  EBA1415post_WSAL_2_CB_ES-05369.ann
# 1070  EBA1415post_WSAL_2_CB_ES-05370.ann
# 1071  EBA1415post_WSAL_2_CB_ES-05962.ann
# 1072  EBA1415post_WSKT_1_CB_ES-05318.ann
# 1073  EBA1415post_WSKT_1_CB_ES-05319.ann
# 1074  EBA1415post_WSKT_1_CB_ES-05321.ann
# 1075  EBA1415post_WSKT_1_CB_ES-05323.ann
# 1076  EBA1415post_WSKT_1_CB_ES-05324.ann
# 1077  EBA1415post_WSKT_1_CB_ES-05326.ann
# 1078  EBA1415post_WSKT_1_CB_ES-05327.ann
# 1079  EBA1415post_WSKT_1_CB_ES-05328.ann
# 1080  EBA1415post_WSKT_1_CB_ES-05331.ann
# 1081  EBA1415post_WSKT_1_CB_ES-05486.ann
# 1082  EBA1415post_WSKT_6_CB_ES-05334.ann
# 1083  EBA1415post_WSKT_6_CB_ES-05335.ann
# 1084  EBA1415post_WSKT_6_CB_ES-05339.ann
# 1085  EBA1415post_WSKT_6_CB_ES-05345.ann
# 1086  EBA1415post_WSKT_6_CB_ES-05346.ann
# 1087  EBA1415post_WSKT_6_CB_ES-05347.ann
#
#                                           Concept Codes  \
# 0                                                    50
# 1     11,13,4,5,50,Causer,Causer:5->Result:50,Result...
# 2                                                 13,50
# 3     3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...
# 4     50,Causer,Causer:7->Result:50,Result,_C->R,_CR...
# 5     50,Causer,Causer:7->Result:50,Result,_C->R,_CR...
# 6                                                  1,50
# 7     50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 8                                                    50
# 9     3,50,Causer,Causer:3->Result:50,Causer:5->Resu...
# 10
# 11    1,11,13,50,Causer,Causer:1->Result:50,Causer:1...
# 12    50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 13    1,3,50,Causer,Causer:1->Result:3,Causer:3->Res...
# 14                                                   50
# 15    50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 16    50,6,Causer,Causer:6->Result:50,Result,_C->R,_...
# 17    1,13,14,3,4,50,7,Causer,Causer:1->Result:50,Ca...
# 18                                                   50
# 19    1,13,3,50,Causer,Causer:1->Result:3,Causer:1->...
# 20
# 21                                                   50
# 22    1,14,3,4,50,Causer,Causer:3->Result:4,Causer:4...
# 23    13,3,50,Causer,Causer:13->Result:50,Causer:3->...
# 24                                                   50
# 25    50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 26    3,50,6,7,Causer,Causer:3->Result:50,Causer:3->...
# 27          50,Causer,Result,_C->R,_CRel,_RRel,explicit
# 28    3,50,6,7,Causer,Causer:6->Result:7,Result,_C->...
# 29    1,11,12,13,2,3,50,7,Causer,Causer:1->Result:50...
# ...                                                 ...
# 1058
# 1059  14,4,50,6,7,Causer,Causer:4->Result:5,Causer:4...
# 1060  1,3,50,Causer,Causer:1->Result:2,Causer:1->Res...
# 1061  1,3,50,7,Causer,Causer:1->Result:50,Causer:3->...
# 1062  50,6,7,Causer,Causer:6->Result:7,Causer:7->Res...
# 1063                                               50,7
# 1064  50,6,7,Causer,Causer:6->Result:7,Causer:7->Res...
# 1065  1,14,3,50,6,Causer,Causer:1->Result:50,Causer:...
# 1066  1,11,12,13,14,2,4,50,Causer,Causer:1->Result:2...
# 1067  1,14,50,6,7,Causer,Causer:1->Result:50,Causer:...
# 1068  1,2,50,6,7,Causer,Causer:6->Result:7,Causer:7-...
# 1069  1,11,13,14,3,50,7,Causer,Causer:1->Result:3,Ca...
# 1070  11,12,13,14,3,4,50,7,Causer,Causer:11->Result:...
# 1071  1,11,12,13,3,4,50,Causer,Causer:1->Result:3,Ca...
# 1072  1,3,50,7,Causer,Causer:1->Result:3,Causer:1->R...
# 1073  1,3,50,6,7,Causer,Causer:1->Result:3,Causer:6-...
# 1074  1,11,12,13,14,3,50,6,7,Causer,Causer:1->Result...
# 1075  1,3,4,50,Causer,Causer:1->Result:3,Causer:1->R...
# 1076  1,3,4,50,6,7,Causer,Causer:1->Result:3,Causer:...
# 1077  3,4,5,50,Causer,Causer:3->Result:4,Causer:4->R...
# 1078  1,3,50,6,7,Causer,Causer:1->Result:3,Causer:4-...
# 1079                                                 50
# 1080  1,12,13,3,50,7,Causer,Causer:13->Result:50,Cau...
# 1081  1,3,4,50,Causer,Causer:3->Result:1,Causer:3->R...
# 1082  1,3,50,Causer,Causer:1->Result:3,Causer:1->Res...
# 1083  1,3,5,50,Causer,Causer:5->Result:50,Result,_C-...
# 1084  1,11,13,14,3,4,50,6,7,Causer,Causer:1->Result:...
# 1085                                         1,2,3,50,7
# 1086  1,3,50,Causer,Causer:1->Result:50,Causer:3->Re...
# 1087  1,14,3,50,6,7,Causer,Causer:1->Result:50,Cause...
#
#                     Ys_codes  \
# 0                         50
# 1               11,13,4,5,50
# 2                      13,50
# 3                   3,4,50,7
# 4                         50
# 5                         50
# 6                       1,50
# 7                       50,7
# 8                         50
# 9                       3,50
# 10
# 11                1,11,13,50
# 12                      50,7
# 13                    1,3,50
# 14                        50
# 15                      50,7
# 16                      50,6
# 17          1,13,14,3,4,50,7
# 18                        50
# 19                 1,13,3,50
# 20
# 21                        50
# 22               1,14,3,4,50
# 23                   13,3,50
# 24                        50
# 25                      50,7
# 26                  3,50,6,7
# 27                        50
# 28                  3,50,6,7
# 29       1,11,12,13,2,3,50,7
# ...                      ...
# 1058
# 1059             14,4,50,6,7
# 1060                  1,3,50
# 1061                1,3,50,7
# 1062                  50,6,7
# 1063                    50,7
# 1064                  50,6,7
# 1065             1,14,3,50,6
# 1066    1,11,12,13,14,2,4,50
# 1067             1,14,50,6,7
# 1068              1,2,50,6,7
# 1069       1,11,13,14,3,50,7
# 1070    11,12,13,14,3,4,50,7
# 1071       1,11,12,13,3,4,50
# 1072                1,3,50,7
# 1073              1,3,50,6,7
# 1074  1,11,12,13,14,3,50,6,7
# 1075                1,3,4,50
# 1076            1,3,4,50,6,7
# 1077                3,4,5,50
# 1078              1,3,50,6,7
# 1079                      50
# 1080          1,12,13,3,50,7
# 1081                1,3,4,50
# 1082                  1,3,50
# 1083                1,3,5,50
# 1084   1,11,13,14,3,4,50,6,7
# 1085              1,2,3,50,7
# 1086                  1,3,50
# 1087           1,14,3,50,6,7
#
#                                               Ys_causal  \
# 0
# 1                                                 5->50
# 2
# 3                                            3->4,7->50
# 4                                                 7->50
# 5                                                 7->50
# 6
# 7                                                 7->50
# 8
# 9                                            3->50,5->7
# 10
# 11                                  1->50,11->50,13->50
# 12                                                7->50
# 13                                      1->3,3->50,4->5
# 14
# 15                                                7->50
# 16                                                6->50
# 17                          1->50,3->4,3->5,4->14,7->50
# 18
# 19                         1->3,1->50,13->50,3->1,3->50
# 20
# 21
# 22                                      3->4,4->14,4->5
# 23                                         13->50,3->50
# 24
# 25                                                7->50
# 26                                     3->50,3->7,7->50
# 27
# 28                                                 6->7
# 29               1->50,11->12,12->13,13->50,3->50,7->50
# ...                                                 ...
# 1058
# 1059                              4->5,4->50,6->50,6->7
# 1060                              1->2,1->3,1->50,3->50
# 1061                             1->50,3->50,3->7,7->50
# 1062                                         6->7,7->50
# 1063
# 1064                                         6->7,7->50
# 1065                                        1->50,3->50
# 1066  1->2,1->50,11->12,11->13,12->13,13->50,4->14,4...
# 1067                            1->50,6->14,6->50,7->50
# 1068                                         6->7,7->50
# 1069        1->3,1->50,11->13,13->14,14->50,3->50,7->50
# 1070        11->12,12->13,13->14,3->4,3->50,4->14,7->50
# 1071               1->3,11->12,12->13,13->50,3->4,4->50
# 1072                                   1->3,1->50,3->50
# 1073                                    1->3,6->7,7->50
# 1074    1->3,1->50,13->14,13->50,3->50,6->50,6->7,7->50
# 1075                        1->3,1->50,3->4,3->50,4->50
# 1076                     1->3,3->4,3->5,3->6,6->7,7->50
# 1077                                   3->4,4->50,5->50
# 1078                                   1->3,4->50,7->50
# 1079
# 1080                                        13->50,3->1
# 1081                               3->1,3->4,3->50,4->5
# 1082                                   1->3,1->50,3->50
# 1083                                              5->50
# 1084                             1->50,4->14,6->7,7->50
# 1085
# 1086                                   1->50,3->1,3->50
# 1087                     1->50,14->50,3->50,6->14,7->50
#
#                                             Predictions  \
# 0                                                    50
# 1                                                 11,50
# 2                                                    50
# 3     3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...
# 4     50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 5     50,Causer,Causer:7->Result:50,Result,_C->R,_CR...
# 6     1,14,50,6,Causer,Causer:6->Result:14,Result,_C...
# 7     50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 8         50,7,Causer,Result,_C->R,_CRel,_RRel,explicit
# 9     3,50,Causer,Causer:3->Result:50,Result,_C->R,_...
# 10
# 11    1,11,12,13,50,Causer,Causer:1->Result:50,Cause...
# 12    50,7,Causer,Causer:7->Result:50,Result,_C->R,_...
# 13    1,3,50,6,Causer,Causer:4->Result:5,Result,_C->...
# 14                                                   50
# 15    14,50,6,7,Causer,Causer:14->Result:50,Causer:6...
# 16                                                 50,6
# 17    1,13,14,3,4,50,7,Causer,Causer:1->Result:50,Ca...
# 18                                                   50
# 19    1,13,3,50,Causer,Causer:1->Result:3,Causer:1->...
# 20
# 21                                                   50
# 22    1,14,3,4,50,6,Causer,Causer:1->Result:3,Causer...
# 23    13,3,50,Causer,Causer:3->Result:50,Result,_C->...
# 24          50,Causer,Result,_C->R,_CRel,_RRel,explicit
# 25    14,50,6,7,Causer,Causer:6->Result:14,Causer:7-...
# 26    3,50,6,Causer,Causer:3->Result:50,Result,_C->R...
# 27                                            50,Causer
# 28    3,50,6,7,Causer,Causer:3->Result:50,Causer:6->...
# 29    1,11,12,13,14,3,50,6,7,Causer,Causer:1->Result...
# ...                                                 ...
# 1058
# 1059  4,50,6,7,Causer,Causer:4->Result:5,Causer:4->R...
# 1060  1,3,50,Causer,Causer:1->Result:2,Causer:1->Res...
# 1061  1,3,50,7,Causer,Causer:1->Result:3,Causer:1->R...
# 1062  50,6,7,Causer,Causer:6->Result:7,Causer:7->Res...
# 1063                                               50,7
# 1064  50,6,7,Causer,Causer:6->Result:7,Causer:7->Res...
# 1065  1,3,50,Causer,Causer:1->Result:50,Causer:3->Re...
# 1066  1,11,12,13,14,2,4,50,Causer,Causer:1->Result:2...
# 1067  1,14,50,6,7,Causer,Causer:1->Result:50,Causer:...
# 1068  1,2,3,50,6,7,Causer,Causer:2->Result:3,Causer:...
# 1069  1,11,13,14,3,50,Causer,Causer:1->Result:3,Caus...
# 1070  1,11,12,13,14,3,4,50,7,Causer,Causer:11->Resul...
# 1071  1,11,12,13,14,3,4,50,Causer,Causer:1->Result:3...
# 1072  1,3,50,Causer,Causer:1->Result:50,Causer:3->Re...
# 1073  1,3,50,6,7,Causer,Causer:1->Result:3,Causer:1-...
# 1074  1,11,12,13,14,3,50,6,7,Causer,Causer:1->Result...
# 1075  1,3,4,50,Causer,Causer:1->Result:50,Causer:3->...
# 1076  1,3,4,50,6,7,Causer,Causer:1->Result:3,Causer:...
# 1077  3,5,50,Causer,Causer:5->Result:50,Result,_C->R...
# 1078  1,3,50,6,7,Causer,Causer:1->Result:3,Causer:4-...
# 1079                                                 50
# 1080  1,12,13,14,3,50,7,Causer,Causer:1->Result:3,Ca...
# 1081  1,3,4,5,50,Causer,Causer:1->Result:3,Causer:1-...
# 1082  1,3,50,Causer,Causer:1->Result:3,Causer:1->Res...
# 1083                    1,3,50,Causer,_C->R,_CRel,_RRel
# 1084  1,11,13,14,3,4,50,6,7,Causer,Causer:1->Result:...
# 1085  1,2,3,50,7,Causer,Causer:1->Result:50,Causer:3...
# 1086  1,3,50,Causer,Causer:1->Result:50,Result,_C->R...
# 1087  1,14,3,50,6,7,Causer,Causer:1->Result:50,Cause...
#
#                   Pred_codes  \
# 0                         50
# 1                      11,50
# 2                         50
# 3                   3,4,50,7
# 4                       50,7
# 5                         50
# 6                  1,14,50,6
# 7                       50,7
# 8                       50,7
# 9                       3,50
# 10
# 11             1,11,12,13,50
# 12                      50,7
# 13                  1,3,50,6
# 14                        50
# 15                 14,50,6,7
# 16                      50,6
# 17          1,13,14,3,4,50,7
# 18                        50
# 19                 1,13,3,50
# 20
# 21                        50
# 22             1,14,3,4,50,6
# 23                   13,3,50
# 24                        50
# 25                 14,50,6,7
# 26                    3,50,6
# 27                        50
# 28                  3,50,6,7
# 29    1,11,12,13,14,3,50,6,7
# ...                      ...
# 1058
# 1059                4,50,6,7
# 1060                  1,3,50
# 1061                1,3,50,7
# 1062                  50,6,7
# 1063                    50,7
# 1064                  50,6,7
# 1065                  1,3,50
# 1066    1,11,12,13,14,2,4,50
# 1067             1,14,50,6,7
# 1068            1,2,3,50,6,7
# 1069         1,11,13,14,3,50
# 1070  1,11,12,13,14,3,4,50,7
# 1071    1,11,12,13,14,3,4,50
# 1072                  1,3,50
# 1073              1,3,50,6,7
# 1074  1,11,12,13,14,3,50,6,7
# 1075                1,3,4,50
# 1076            1,3,4,50,6,7
# 1077                  3,5,50
# 1078              1,3,50,6,7
# 1079                      50
# 1080       1,12,13,14,3,50,7
# 1081              1,3,4,5,50
# 1082                  1,3,50
# 1083                  1,3,50
# 1084   1,11,13,14,3,4,50,6,7
# 1085              1,2,3,50,7
# 1086                  1,3,50
# 1087           1,14,3,50,6,7
#
#                                             Pred_causal
# 0
# 1
# 2
# 3                                            3->4,7->50
# 4                                                 7->50
# 5                                                 7->50
# 6                                                 6->14
# 7                                                 7->50
# 8
# 9                                                 3->50
# 10
# 11                                         1->50,11->50
# 12                                                7->50
# 13                                                 4->5
# 14
# 15                                   14->50,6->14,7->50
# 16
# 17            1->50,13->14,13->50,3->4,3->5,4->14,7->50
# 18
# 19                                     1->3,1->50,3->50
# 20
# 21
# 22               1->3,3->4,3->50,4->14,4->5,6->14,7->50
# 23                                                3->50
# 24
# 25                                          6->14,7->50
# 26                                                3->50
# 27
# 28                                           3->50,6->7
# 29         1->50,11->12,12->13,13->50,3->50,6->14,7->50
# ...                                                 ...
# 1058
# 1059                                    4->5,4->50,6->7
# 1060                              1->2,1->3,1->50,3->50
# 1061                              1->3,1->50,3->50,3->7
# 1062                                         6->7,7->50
# 1063
# 1064                                         6->7,7->50
# 1065                                        1->50,3->50
# 1066  1->2,1->50,11->12,11->13,12->13,13->50,4->14,4...
# 1067                                        1->50,7->50
# 1068                                    2->3,6->7,7->50
# 1069              1->3,1->50,11->13,13->14,13->50,3->50
# 1070  11->12,11->13,12->13,13->14,3->4,3->50,4->14,7...
# 1071                          1->3,11->12,12->13,13->14
# 1072                                        1->50,3->50
# 1073                        1->3,1->50,3->50,6->50,6->7
# 1074  1->3,1->50,11->12,11->14,12->13,13->14,13->50,...
# 1075                                   1->50,3->4,3->50
# 1076                   1->3,1->50,3->4,3->50,6->7,7->50
# 1077                                              5->50
# 1078                                    1->3,4->5,7->50
# 1079
# 1080                      1->3,12->13,13->14,3->1,7->50
# 1081                              1->3,1->50,3->5,3->50
# 1082                                   1->3,1->50,3->50
# 1083
# 1084                             1->50,4->14,6->7,7->50
# 1085                                        1->50,3->50
# 1086                                              1->50
# 1087                     1->50,14->50,3->50,6->14,7->50
#
# [1088 rows x 7 columns]

# %%
grpd["Ys_cat"] = grpd["Concept Codes"].apply(category)
grpd["Pred_cat"] = grpd["Predictions"].apply(category)

# %%
grpd["Diff"] = grpd["Ys_cat"] - grpd["Pred_cat"]
grpd["Diff"] = grpd["Diff"].abs()
abbrev = grpd[["Ys_codes","Ys_causal", "Ys_cat", "Pred_codes", "Pred_causal", "Pred_cat", "Diff"]]
abbrev.head(20)
# Out:
#             Ys_codes                     Ys_causal  Ys_cat        Pred_codes  \
# 0                 50                                     2                50
# 1       11,13,4,5,50                         5->50       3             11,50
# 2              13,50                                     2                50
# 3           3,4,50,7                    3->4,7->50       3          3,4,50,7
# 4                 50                         7->50       3              50,7
# 5                 50                         7->50       3                50
# 6               1,50                                     2         1,14,50,6
# 7               50,7                         7->50       3              50,7
# 8                 50                                     2              50,7
# 9               3,50                    3->50,5->7       3              3,50
# 10                                                       1
# 11        1,11,13,50           1->50,11->50,13->50       3     1,11,12,13,50
# 12              50,7                         7->50       3              50,7
# 13            1,3,50               1->3,3->50,4->5       5          1,3,50,6
# 14                50                                     2                50
# 15              50,7                         7->50       3         14,50,6,7
# 16              50,6                         6->50       3              50,6
# 17  1,13,14,3,4,50,7   1->50,3->4,3->5,4->14,7->50       3  1,13,14,3,4,50,7
# 18                50                                     2                50
# 19         1,13,3,50  1->3,1->50,13->50,3->1,3->50       5         1,13,3,50
#
#                                   Pred_causal  Pred_cat  Diff
# 0                                                     2     0
# 1                                                     2     1
# 2                                                     2     0
# 3                                  3->4,7->50         3     0
# 4                                       7->50         3     0
# 5                                       7->50         3     0
# 6                                       6->14         3     1
# 7                                       7->50         3     0
# 8                                                     3     1
# 9                                       3->50         3     0
# 10                                                    1     0
# 11                               1->50,11->50         3     0
# 12                                      7->50         3     0
# 13                                       4->5         3     2
# 14                                                    2     0
# 15                         14->50,6->14,7->50         3     0
# 16                                                    2     1
# 17  1->50,13->14,13->50,3->4,3->5,4->14,7->50         3     0
# 18                                                    2     0
# 19                           1->3,1->50,3->50         5     0

# %%
abbrev[abbrev["Ys_cat"] == 4][["Ys_codes","Ys_causal", "Ys_cat"]].head(20)
# Out:
#                   Ys_codes                            Ys_causal  Ys_cat
# 58                  50,6,7                           6->7,7->50       4
# 80              1,3,50,6,7                      1->3,6->7,7->50       4
# 87              2,3,50,6,7               3->50,6->50,6->7,7->50       4
# 128  1,11,13,14,3,4,50,6,7  1->3,11->14,13->14,4->50,6->7,7->50       4
# 135              14,50,6,7              14->50,6->14,6->7,7->50       4
# 144              14,50,6,7              14->50,6->14,6->7,7->50       4
# 155               2,50,6,7                           6->7,7->50       4
# 205    11,13,14,3,4,50,6,7       11->14,13->14,4->14,6->7,7->50       4
# 227        12,13,14,50,6,7                           6->7,7->50       4
# 253              14,50,6,7              14->50,6->14,6->7,7->50       4
# 270          1,13,3,50,6,7              1->50,13->50,6->7,7->50       4
# 321           1,2,3,50,6,7                1->2,3->50,6->7,7->50       4
# 323            1,13,50,6,7              1->50,13->50,6->7,7->50       4
# 354             1,4,50,6,7               1->50,4->50,6->7,7->50       4
# 414         1,2,3,5,50,6,7     1->2,1->3,1->50,5->50,6->7,7->50       4
# 445                 50,6,7                           6->7,7->50       4
# 459           1,2,3,50,6,7                      1->2,6->7,7->50       4
# 502                 50,6,7                     5->50,6->7,7->50       4
# 510             3,4,50,6,7                           6->7,7->50       4
# 557                 50,6,7                           6->7,7->50       4

# %%
def is_inverted(s):
    if "->" not in s:
        return False
    a,b = s.split("->")
    if int(a) > int(b):
        return True
    return False

def any_inverted(s):
    if not s.strip():
        return ""
    splt = s.split(",")
    fltd = filter(is_inverted, splt)
    if not fltd:
        return ""
    return ",".join(fltd)

grpd["Ys_inverted"] = grpd["Ys_causal"].apply(any_inverted)
grpd[grpd["Ys_inverted"].str.strip() != ""][["Essay","Ys_causal","Ys_inverted"]].head(10)
# Out:
#                                Essay  \
# 19    EBA1415_BGJD_2_CB_ES-05740.ann
# 147   EBA1415_KNKC_1_CB_ES-05410.ann
# 207   EBA1415_KYLS_5_CB_ES-05662.ann
# 287      EBA1415_LRBL_4_CB-05167.ann
# 305   EBA1415_LRJE_7_CB_ES-05135.ann
# 344  EBA1415_RCGJ_4a_CB_ES-04678.ann
# 361      EBA1415_RDCS_2_CB-04715.ann
# 479   EBA1415_SDMK_7_CB_ES-04782.ann
# 516   EBA1415_SEKL_1_CB_ES-04818.ann
# 609      EBA1415_SWCT_6_CB-04879.ann
#
#                                           Ys_causal Ys_inverted
# 19                     1->3,1->50,13->50,3->1,3->50        3->1
# 147                                1->50,3->1,7->50        3->1
# 207  1->2,1->50,11->13,13->14,3->1,3->50,6->7,7->50        3->1
# 287                                       3->1,6->7        3->1
# 305         1->50,14->50,3->1,3->4,3->5,4->14,7->50        3->1
# 344                                 3->1,4->5,7->50        3->1
# 361                                      3->1,3->50        3->1
# 479                   1->50,14->50,3->1,6->14,7->50        3->1
# 516                                 1->50,3->1,4->5        3->1
# 609                           1->50,2->3,3->1,7->50        3->1

# %%
grpd["Ys_inverted"].unique()
# Out:
# array(['', '3->1'], dtype=object)

# %%
data[data["Concept Codes"].str.contains("Causer:3->Result:1")][["Essay", "Sent Number"]]
# Out:
#                                    Essay  Sent Number
# 125       EBA1415_BGJD_2_CB_ES-05740.ann            1
# 1365      EBA1415_KNKC_1_CB_ES-05410.ann            5
# 1973      EBA1415_KYLS_5_CB_ES-05662.ann            2
# 2746         EBA1415_LRBL_4_CB-05167.ann            6
# 2907      EBA1415_LRJE_7_CB_ES-05135.ann            4
# 3308     EBA1415_RCGJ_4a_CB_ES-04678.ann            6
# 3438         EBA1415_RDCS_2_CB-04715.ann            3
# 4587      EBA1415_SDMK_7_CB_ES-04782.ann           10
# 4984      EBA1415_SEKL_1_CB_ES-04818.ann            4
# 5802         EBA1415_SWCT_6_CB-04879.ann            1
# 6141      EBA1415_SWCT_7_CB_ES-05957.ann            3
# 6266      EBA1415_SWSP_4_CB_ES-04860.ann           10
# 7156     EBA1415_TRJA_11_CB_ES-06102.ann            1
# 9325  EBA1415post_TWNB_3_CB_ES-04986.ann            9
# 9685  EBA1415post_WSKT_1_CB_ES-05331.ann            5
# 9701  EBA1415post_WSKT_1_CB_ES-05486.ann           10
# 9750  EBA1415post_WSKT_6_CB_ES-05346.ann            3

# %% [markdown]
# ## Accuracy

# %%
print "Accuracy", round(len(grpd[grpd["Ys_cat"] == grpd["Pred_cat"]]) / float(len(grpd)),4)
print "Adj     ", round(len(grpd[grpd["Diff"] <=1]) / float(len(grpd)),4)
print len(grpd), "essays"
# Out:
# Accuracy 0.7831
# Adj      0.8722
# 1088 essays

# %% [raw]
# CB
# Accuracy 0.7713
# Adj      0.8679
# 1128 essays
#
# SC
# Accuracy 0.7583
# Adj      0.8621
# 1088 essays

# %% [markdown]
# ## Accuracy Per Category

# %%
for cat in sorted(grpd["Ys_cat"].unique()):
    filtered = grpd[grpd["Ys_cat"] == cat]
    print cat
    print "Accuracy", round(len(filtered[filtered["Ys_cat"] == filtered["Pred_cat"]]) / float(len(filtered)),4)
    print "Adj     ", round(len(filtered[filtered["Diff"] <=1]) / float(len(filtered)),4)
    print len(filtered), "essays"
    print ""
# Out:
# 1
# Accuracy 0.963
# Adj      1.0
# 27 essays
#
# 2
# Accuracy 0.7919
# Adj      1.0
# 173 essays
#
# 3
# Accuracy 0.8772
# Adj      0.9354
# 619 essays
#
# 4
# Accuracy 0.5854
# Adj      1.0
# 41 essays
#
# 5
# Accuracy 0.5351
# Adj      0.5658
# 228 essays

# %% [markdown]
# ## Output Processed Results

# %%
outp = grpd.copy(deep=True)

#Strip the .ann prefix
outp["Essay"] = outp["Essay"].apply(lambda s: s[:-4])
outp["Manual_Codes"] = outp["Ys_codes"]
outp["Manual_Causal"] = outp["Ys_causal"]

outp["Manual_Category"] = outp["Ys_cat"]

outp["Predicted_Codes"] = outp["Pred_codes"]
outp["Predicted_Causal"] = outp["Pred_causal"]

outp["Predicted_Category"] = outp["Pred_cat"]

outp["All_Manual_Codes"] = outp["Concept Codes"]
outp["All_Predictions"] = outp["Predictions"]

outp = outp[["Essay", "Manual_Codes", "Manual_Causal", "Manual_Category", "Predicted_Codes", "Predicted_Causal", "Predicted_Category", "All_Manual_Codes", "All_Predictions"]]

outp.head()
# Out:
#                         Essay  Manual_Codes Manual_Causal  Manual_Category  \
# 0  EBA1415_AEKD_4_CB_ES-05568            50                              2
# 1  EBA1415_AEKD_4_CB_ES-05572  11,13,4,5,50         5->50                3
# 2  EBA1415_AEKD_4_CB_ES-05574         13,50                              2
# 3  EBA1415_AEKD_4_CB_ES-05902      3,4,50,7    3->4,7->50                3
# 4     EBA1415_AEKD_5_CB-06232            50         7->50                3
#
#   Predicted_Codes Predicted_Causal  Predicted_Category  \
# 0              50                                    2
# 1           11,50                                    2
# 2              50                                    2
# 3        3,4,50,7       3->4,7->50                   3
# 4            50,7            7->50                   3
#
#                                     All_Manual_Codes  \
# 0                                                 50
# 1  11,13,4,5,50,Causer,Causer:5->Result:50,Result...
# 2                                              13,50
# 3  3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...
# 4  50,Causer,Causer:7->Result:50,Result,_C->R,_CR...
#
#                                      All_Predictions
# 0                                                 50
# 1                                              11,50
# 2                                                 50
# 3  3,4,50,7,Causer,Causer:3->Result:4,Causer:7->R...
# 4  50,7,Causer,Causer:7->Result:50,Result,_C->R,_...

# %%
outp.to_csv(fout)

# %%
group_by(grpd, "Pred_cat", {"Essay": "count"})
# Out:
#    Pred_cat  Essay
# 0         1     28
# 1         2    166
# 2         3    690
# 3         4     39
# 4         5    165

# %%
group_by(grpd, "Ys_cat", {"Essay": "count"})
# Out:
#    Ys_cat  Essay
# 0       1     27
# 1       2    173
# 2       3    619
# 3       4     41
# 4       5    228
