# %%
# Settings
ROOT_FOLDER = "/Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/PhraseExtractionAnalysis"

DOCS_FOLDER     = "%s/ProcessedDocs" % ROOT_FOLDER
STOP_WORDS_FILE = "%s/minor_en_stop_words.txt" % ROOT_FOLDER
PHRASES_FILE    = "%s/Phrases.txt" % ROOT_FOLDER
KEY_WORDS_FILE  = None

MODEL_FILE = "%s/model.w2v" % ROOT_FOLDER
FILE_MASK = ".*\.txt"
MIN_SENT_LENGTH = 5

# W2vec settings
MIN_WD_COUNT = 3 #for word2vec model # setting to 10 seems to remove some of the noise
WINDOW_SIZE  = 5
VECTOR_SIZE  = 300
WORKERS = 8
TRAINING_ITERATIONS = 300

# %%
# Shared
import re
from collections import defaultdict

def load_stop_words(stop_words_file):
    stop_words = set()
    with open(stop_words_file) as f:
            for line in f:
                word = line.strip()
                if word[0] != "#":
                    word = word.lower()
                    stop_words.add(word)
    return stop_words

re_collapse_spaces = re.compile("\s+")
def collapse_spaces(s):
    return re_collapse_spaces.sub(" ", s)

re1 = re.compile("[;:\'\"\*/\),\(\|\s]+")
def clean_str(s):
    s = str(s).replace("'s"," ")
    #doesn't work in regex
    s = s.replace("-", " ").replace("\\"," ")
    s = re1.sub(" ",s).strip()
    return collapse_spaces(s)

# is a valid token
__bad_chars__ = "<>{}[]~@"
__punct__ = set(".?!,;:")
def is_valid_term(term):
    # remove single char entries and only numeric
    if len(term) == 0:
        return False
    if len(term) == 1:
        #else misses c and r
        if term.isalpha():
            return True
        return False
    # no html or js terms
    for c in __bad_chars__:
        if c in term:
            return False
    if term[-1] in __punct__:
        return False
    if "function(" in term:
        return False
    if "!" in term or "?" in term:
        return False
    digit_chars = 0.0
    for c in term:
        if c.isdigit() or not c.isalnum():
            digit_chars += 1.0
    # 60% digits?
    if (digit_chars / len(term)) >= 0.75:
        return False
    return True

def find_files(folder, regex, remove_empty = False):
    """
    Find all files matching the [regex] pattern in [folder]

    folder  :   string
                    folder to search (not recursive)
    regex   :   string (NOT regex object)
                    pattern to match
    """
    files = os.listdir(folder)
    matches = [os.path.abspath(os.path.join(folder, f))
               for f in files
               if re.search(regex, f, re.IGNORECASE)]

    if remove_empty:
        matches = [f for f in matches if os.path.getsize(f) > 0]
    matches.sort()
    return matches

# %%
from collections import defaultdict

class SynonymMapper(object):
    def __init__(self, mapper, nested, case_sensitive=False):
        self.case_sensitive = case_sensitive
        self.mapper = mapper
        self.nested = nested
        self.synonyms = set()
        for rhs in self.mapper.values():
            for syn in rhs:
                self.synonyms.add(syn)
        
    def is_synonym(self, term):
        return term in self.synonyms
        
    def map_synonyms(self, tokens, debug=False):
        mapped = []
        size = len(tokens)
        if not self.case_sensitive:
            tmp_tokens = map(lambda s: s.lower(), tokens)
        else:
            tmp_tokens = tokens
        ix = 0
        while ix < size:
            if debug:
                print "ix", ix
            best, best_key = None, None
            tmp_ix = ix        
            max_ix = ix
            current = ""
            d = self.nested
            while tmp_ix < size and tmp_tokens[tmp_ix] in d:
                current += tmp_tokens[tmp_ix] + " "
                key = current.strip()
                if key in self.mapper:
                    if debug:
                        if best is not None:
                            print(ix, tmp_ix, "new best:", key, "=>", self.mapper[key])
                        else:
                            print(ix, tmp_ix, "best:", key, "=>", self.mapper[key])
                    best = self.mapper[key]
                    best_key = key
                    max_ix = tmp_ix                    
                d = d[tmp_tokens[tmp_ix]]
                tmp_ix += 1
            if not best:
                #retain original casing
                mapped.append(tokens[ix])
            else:
                ix = max_ix
                #yields a set
                for item in sorted(best):
                    mapped.append(item)
            ix += 1
        return mapped

    def __repr__(self):
        return "Synonym Mapper: %i synonyms mapped" % len(self.mapper)

def build_synonym_filter(files, case_sensitive=False):
    # recursively define a defaultdict generator
    mapper = defaultdict(set)
    def dd():
        return defaultdict(dd)
    nested_map = defaultdict(dd)
    file_locn = dict()
    if type(files) == str:
        files = [files]
    for f in files:
        with open(f, "r+") as fin:
            for line in fin:
                line = line.strip()
                if len(line) > 0 and not line[0] == "#":
                    if "=>" in line:
                        left, right = line.split("=>")
                        right = set(right.split(","))
                        left_parts = left.split(",")
                    else:
                        left_parts = line.split(",")
                        right = set(left_parts)

                    for syn in left_parts:
                        for rhs in right:
                            mapper[syn].add(rhs)
                        file_locn[syn] = f

                        tokens = syn.split(" ")
                        prev = tokens[0]
                        d = nested_map[prev]
                        for token in tokens[1:]:
                            d = d[token]
                            prev = token                        
    return SynonymMapper(mapper, nested_map, case_sensitive)

# %%
#String processing
def white_space_tokenize(s):
    return s.split(" ")

__punct__ = set(".?!,;:")
def remove_punct_at_end(s):
    while len(s) > 1 and s[-1] in __punct__:
        s = s[:-1]
    return s

#Token Filters
def fact_len_filter(max_len):
    def len_filter(tokens):
        return filter(lambda s: len(s) >= max_len, tokens)
    return len_filter

remove_empty_tokens_filter = fact_len_filter(1)

def lower_case_filter(tokens):
    if type(tokens) == str:
        return tokens.lower()
    return map(lambda t: t.lower(), tokens)

__punct__ = set(".?!,;:")

def remove_punct_at_end_filter(tokens):
    return map(remove_punct_at_end, tokens)

def fact_is_synonym_filter(syn_mapper):
    def is_synonym_filter(tokens):
        return filter(syn_mapper.is_synonym, tokens)
    return is_synonym_filter

def valid_term_filter(tokens):
    return filter(is_valid_term, tokens)

# %%
def fact_stop_word_filter(case_sensitive, stop_words_file):
    stop_words = set()
    with open(stop_words_file) as f:
        for line in f:
            word = line.strip()
            if word[0] != "#":
                if not case_sensitive:
                    word = word.lower()
                stop_words.add(word)

    def cs_stop_filter(tokens):
        return [tok for tok in tokens if tok not in stop_words]

    def stop_filter(tokens):
        return [tok for tok in tokens if tok.lower() not in stop_words]

    if case_sensitive:
        return cs_stop_filter
    else:
        return stop_filter

stop_filter = fact_stop_word_filter(False, STOP_WORDS_FILE)

# %%
def analyze(s, filters):
    temp = s
    for f in filters:
        temp = f(temp)
    return temp

def debug_analyze(s, filters):
    temp = s
    pad = 20
    print "START".ljust(pad), temp
    for f in filters:
        temp = f(temp)
        if type(temp) == list:
            s_temp = "|".join(map(str,temp))
        else:
            s_temp = str(temp)
        print f.func_name.ljust(pad), s_temp
    return temp

# %%
if KEY_WORDS_FILE:
    syn_mapper = build_synonym_filter([PHRASES_FILE, KEY_WORDS_FILE], False)
else:
    syn_mapper = build_synonym_filter([PHRASES_FILE], False)
syn_mapper
# Out:
# Synonym Mapper: 1194 synonyms mapped

# %%
#Skills from text
is_a_synonym_filter = fact_is_synonym_filter(syn_mapper)
analysis_chain = [clean_str,
                  white_space_tokenize,
                  remove_punct_at_end_filter,
                  #valid_term_filter,
                  lower_case_filter,
                  stop_filter,
                  syn_mapper.map_synonyms, 
                  remove_empty_tokens_filter]
                  #, is_a_synonym_filter] - just train the model longer

#Test
rslt = debug_analyze("$150k as400 Sr.\ Java/j2ee and the C#.! developer. FIT \"HOT\" dev. -IBM's business, sql server management", 
                     analysis_chain)
# Out:
# START                $150k as400 Sr.\ Java/j2ee and the C#.! developer. FIT "HOT" dev. -IBM's business, sql server management
# clean_str            $150k as400 Sr. Java j2ee and the C#.! developer. FIT HOT dev. IBM business sql server management
# white_space_tokenize $150k|as400|Sr.|Java|j2ee|and|the|C#.!|developer.|FIT|HOT|dev.|IBM|business|sql|server|management
# remove_punct_at_end_filter $150k|as400|Sr|Java|j2ee|and|the|C#|developer|FIT|HOT|dev|IBM|business|sql|server|management
# lower_case_filter    $150k|as400|sr|java|j2ee|and|the|c#|developer|fit|hot|dev|ibm|business|sql|server|management
# stop_filter          $150k|as400|sr|java|j2ee|c#|developer|fit|hot|dev|ibm|business|sql|server|management
# map_synonyms         $150k|as400|sr|java|j2ee|c#|developer|fit|hot|dev|ibm|business|sql|server|management
# len_filter           $150k|as400|sr|java|j2ee|c#|developer|fit|hot|dev|ibm|business|sql|server|management

# %%
import os, re, time
start = time.time()

sentences = []
files = find_files(DOCS_FOLDER, FILE_MASK, True)
print("%s files found in %s" % (len(files), DOCS_FOLDER))

documents = []
for i, fname in enumerate(files):
    with open(fname) as f:
        contents = f.read()
        sentences.extend(contents.split("\n"))
end = time.time()
print("Loading %i sentences took %s seconds" % (len(sentences), str(end - start)))
# Out:
# 1093 files found in /Users/simon.hughes/Google Drive/PhD/Data/CoralBleaching/PhraseExtractionAnalysis/ProcessedDocs
# Loading 10112 sentences took 0.185217142105 seconds

# %%
print len(sentences)
tokenized = []
print("Tokenizing sentences")
for i, sent in enumerate(sentences):
    tokens = analyze(sent, analysis_chain)
    if len(tokens) >= MIN_SENT_LENGTH:
        tokenized.append(tokens)
    if i % 1000 == 0:
        print(i)
# Out:
# 10112
# Tokenizing sentences
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
for t in tokenized[0:100]:
    print "|".join(t)
# Out:
# what leads|to|differences|in|rates|of|coral bleaching
# coral|is|often mistaken|for|rock|it|is|made up|of|tiny animals called polyps
# coral bleaching|shows|bleaching|healthy|bleaching event|that|makes coral vulnerable|to|disease starvation
# coral bleaching|is|almost|noticeable|in|pacific ocean
# part|of|coral|called|zooanthellae|are|not|getting|sunlight
# if|they|get|much|sunlight|they|start|to|loses|their|color
# reason why|is|because|zooanthellae|if|not|getting|up|with|carbon dioxide
# coral|also|need water temperature|because|they|are|sensitive
# also|its|threats|for|us|because|means|that|more|extreme storms|are|most|likely|to|occurs
# also|water|us|getting|to|salty
# well|based|on|what|i|read|corals|are|their|colors|coral bleaching|are|serious problem|with|serious impact|on|worlds coral reefs
# this|is|serious problem|because|coral bleaching|is|most noticeable|in|pacific ocean|ocean covers about|0|0|of|entire globe|some|corals|are|sensitive|to|how|salty|water|us
# massive coral bleaching event|in|0000|is|one|of|worst ever|event resulted|in|death|of|00|of|worlds coral reefs|thus|very serious|it|killed|lot|of|coral reefs
# what leads|to|different|in|rates|of|coral bleaching|is|that|different types|of|living within|coral polyps|gives|coral|their|varying colors
# it|states|that|coral|is|often mistaken|for|rock|plant
# coral reefs|are|only found|in|clear shallow tropical waters
# because|if|they|in|that|type|water|they|would|die
# coral|with|energy|it|needs|to|survive
# as|water increases|amount|of|carbon dioxide|in|water decreases
# also|coral turns white due|to|ejection|death|of|algae
# coral bleaching|is|phenomenon|in|which|loses|its|color
# coral bleaching|is|most noticeable|in|pacific ocean
# biologists|different types|of|corals living|in|oceans|these|invertebrate animals live together|in|colonies|tend|to|stay|in|one place
# different types|of|algae|of|algae living within|coral polyps give|corals|their|varying colors|see|figure|0
# some|coral bleaching|bleached|plain white|coral bleaching|is|phenomenon|in|white|coral loses|its|color
# events leading|to|coral bleaching|are|serious problem|with|serious impact|on|coral reefs
# coral bleaching|has|many|differences|types|living|in|oceans|different types|of|algae living within|coral polyps give|corals|their|varying|color
# coral bleaching|is|phenomenon|in|which|coral loses|its|color
# coral bleaching|is|most noticeable|in|pacific ocean
# i|read|over|marine|has|been|discovered|that|there|are|many different types|of|corals|that|live|in|ocean|that|live|close|to|animals|loses|their|color
# about|when|wind|changes|direction|affects|world|ocean
# trade winds|were|originally used|to|guide boat navigation|were|later recognized|as|important|for|merchant trading|in
# coral|is|often mistaken|for|rock|plant|however|it|is|really made up|of|tiny animals called polyps
# coral polyps range|in|size|tiny|size|of|pinhead|up|to|foot|in|diameter
# this|means|that|they|both benefit|from|their|relationship|with|each|other
# in|fact|most|zooxanthallae|cannot live outside|of|coral|animals|body
# algae rely|on|coral|to|stay healthy|corals|can|sustain physical damage|from|some|destructive practices
# examples|of|this|include|blast fishing tourists who drop anchors|walk|on|reefs
# coral bleaching|figure|0|shows|bleached|healthy coral|is|one example|of|how|environmental stressors|can|negatively affect|balanced relationship|between|are|coral|zooanthallae|algae|see|figure
# difference|between|normal|coral bleached|coral|is|that|bleached coral|is|plain white|coral bleaching|is|most noticeable|in|pacific ocean|about|0|0|of|surface|of|entire globe
# also|during|turn white due|to|ejection|death|of|zooanthellae|algae
# also|in|result|of|bleaching coral|vulnerable|to|disease starvation
# in|0000|00|of|coral reefs
# normal|corals|is|made up|of|tiny animals called polyps|their|mouth surrounded|by|stinging tentacles
# polyps|use|limestone|from|seawater|to|build|hard skeleton|protect|their|delicate body
# coral reefs|are|only found|in|clear shallow tropical waters
# what leads|to|differences|in|rates|of|coral bleaching
# some|differences|will|start|like|some|of|coral reef|they|fishes|will|starve|to|death|because|those|is|all|they|eat
# then|other|will|have|trouble|their|food|due|to|lack|of|energy
# it|will|then|become|problem|to|because|they|find|food
# like|they|find|fishes|to|if|they|find|fishes|other|starve
# things|that|create|food|using|sunlight|like|coral reef|will|be|more|quickly|than|produce|more|food|for|itself|others
# once|in|ocean|die|out|there|will|be|less|food|for|in|entire|world
# it|will|be|notice|of|differences|in|food|will|be|made
# if|coral reef|die|out|large|changes|in|world|would|be|notice|like|some|fishes|out|we|would|even|have|less|food|to|produce|due|to|of|animal
# this|leads|big|difference|in|coral bleaching|soon|we|will|loose|that|creates|food|energy|for|animals
# in|conclusion|difference|in|rates|of|coral bleaching|can|cause|by|food|production|of|animals
# difference|in|rates|of|coral bleaching|are|cause|by|water temperature|diseases|even|to|starvation
# corals|zooanthellae|can|be|benefit|their|relationship|with|each|other
# corals|depend|on|clear shallow tropical waters|coral tissues|algae called zooxanthellae|need light|for|process|of|photosynthesis
# corals need|chemicals|co2|that|provide|coral|with|energy|it|needs|to|survive
# scientist|estimate|that|coral|recieve|00|to|00|of|their|energy|from|this|process
# things|that|lead|to|coral bleaching could|be|salt|that|near|there|trade winds|tropical storms
# it|is|said|fresh water|animals|in|shallow tropical|water
# so|they|take|in|salt water
# it|is|good|for|corals|to|take|it|in
# this|also|causes|in|with|tropical|storm|because|it|could|push|salty|water|into|their|environment
# this|is|are|things|that|could|bleach|them
# trade winds|could|could|be|reason|because|corals|are|being|disturbed
# what leads|to|differences|in|rates|of|coral bleaching|is|that|once|that|happens|during bleaching|it|turns white|because|of|ejection|of|zooxanthellae algae|it|means|it|has|been|dead|which|is|why|healthy coral|is|much|color|bleached coral|is|just|white|that|means|dead
# first|i|will|like|to|tell|you|what coral bleaching|is|it|is|phenomenon|in|which|coral loses color
# these|invertebrate animals live together|in|colonies|tend|to|stay|in|one place
# some|differences|would|be|water temps|trade winds
# in|graph|it|shows|as|weaker trade winds|are|water temps|would|be
# as|you look|at|both|graphs|in|0000|as|weaker|trade wind|was|higher water temps|was|can|see|that|this|year|has|highest|coral bleaching|in|that|year
# coral reefs|are|only found|in|clear shallow tropical|water
# this|is|partly|because|of|algae|as|long|as|there|is|enough sunlight|normal amount|of|co2|algae|will|undergo photosynthesis
# important|because|chemicals|algae makes|provide|coral|with|energy|it|needs|to|survive|so|if|it|get|these|it|will|die
# coral bleaching|is|one example|on|how|environment|stressors|can|negative|affect|towards|coral|zooanthellae
# coral bleaching|is|most|noticable|in|pacific ocean
# their|are|many different|type|of|corals living|in|oceans
# different types|of|algae living within|coral polyps give|corals|their|varying colors
# some|coral|have|been bleached|plain white
# coral bleaching|is|phenomenon|in|which|coral loses|its|color
# coral bleaching|is|most noticeable|in|pacific ocean
# this|ocean covers about|0|0|of|surface|of|entire globe|contains double|amount|of|water found|in|atlantic ocean
# coral bleaching|is|how|environmental stressors|can|negatively affect|balanced relationship|between|coral zooxanthellae
# during bleaching corals turn white due|to|ejection|death|of|zooxanthellae
# this|results|in|bleaching event|that|makes corals vulnerable|to|disease starvation
# while|some|dying|reefs recover|from|such|events|many do|not
# for|example|massive coral bleaching event|in|0000|is|considered one|of|worst|events|observed
# this|resulted|in|death|of|00|of|coral reefs
# coral bleaching|is|mostly|noticeable|in|pacific ocean
# they|usually|vary|in|many different|colors|when|they|get bleached|they|turn white
# they|are|only found|in|clear shallow tropical waters
# coral reefs|are|made up|of|polyp
# over time|polyp|giving|coral|skeleton
# this|is|algae lives|in|coral tissues|need light|for|process|of|photosynthesis
# reef building corals need water temperatures|between|00|00|degrees f|because|process|of|photosynthesis|is|sensitive|to|change|in|water temperature
# when|water temp|rises|amount|of|carbon dioxide decreases

# %% [markdown]
# # Train Model

# %%
import gensim, time
from gensim.models.word2vec import Word2Vec

start = time.time()

print("Training Model. This could take a while (10-60 mins for moderate collections). Get a coffee")
model = Word2Vec(tokenized, iter=TRAINING_ITERATIONS, size=VECTOR_SIZE, window=WINDOW_SIZE, min_count=MIN_WD_COUNT, workers=WORKERS, sample=1e-5, hs=0, negative=20)
model.save(MODEL_FILE)
end = time.time()
print "Took %s seconds" % (end - start)
# Out:
# Training Model. This could take a while (10-60 mins for moderate collections). Get a coffee
# Took 1335.32123804 seconds

# %%
tokens = map(lambda s: s.strip(), "coral, bleaching, coral bleaching, white, trade winds, salinity, death, dying, fresh water, storms, rainfall, water temperatures, temps".split(","))
for token in tokens:
    print token
    if token not in model.vocab:
        print "Token not in vocab\n"
        continue
    freq = 0
    for pair in model.most_similar(positive=[token], topn=100):
        if syn_mapper.is_synonym(pair[0]):
            print "\t", pair
            freq += 1
            if freq >= 20:
                break
    print ""
# Out:
# coral
# 	('algae', 0.8424152135848999)
# 	('corals', 0.8412076234817505)
# 	('off', 0.788943886756897)
# 	('finally', 0.7392733097076416)
# 	('zooxanthellae', 0.7365037798881531)
# 	('so', 0.7308151721954346)
# 	('coral gets', 0.7219845056533813)
# 	('being', 0.7218189835548401)
# 	('out', 0.7132343649864197)
# 	('food', 0.7000315189361572)
# 	('relies', 0.6980425715446472)
# 	('nutrient rich environment', 0.6968252658843994)
# 	('survival', 0.6960312128067017)
# 	('stay healthy', 0.6959972381591797)
# 	('algae provides', 0.6952272653579712)
# 	('like', 0.6939720511436462)
# 	('get', 0.6934082508087158)
# 	('reason why', 0.6928682327270508)
# 	('coral so', 0.6912604570388794)
# 	('any', 0.6900298595428467)
#
# bleaching
# 	('conclusion coral', 0.8251010179519653)
# 	('coral bleaching occurs', 0.7763916254043579)
# 	('likely', 0.767128050327301)
# 	('big problem', 0.7635579109191895)
# 	('result', 0.7597436904907227)
# 	('takes place', 0.7582629919052124)
# 	('alot', 0.7567083239555359)
# 	('makes coral', 0.7540161609649658)
# 	('event', 0.7535668611526489)
# 	('temperature change', 0.7476861476898193)
# 	('happen', 0.7457984089851379)
# 	('more', 0.7444592118263245)
# 	('population', 0.7427119016647339)
# 	('makes coral vulnerable', 0.7407967448234558)
# 	('worse', 0.740709662437439)
# 	('reason', 0.7366577982902527)
# 	('coral bleaching event', 0.7344974875450134)
# 	('sudden', 0.7334334850311279)
# 	('coral turn white', 0.729628324508667)
# 	('occurs', 0.7261474132537842)
#
# coral bleaching
# 	('rates', 0.8133920431137085)
# 	('difference', 0.8015445470809937)
# 	('differences', 0.7809247970581055)
# 	('what leads', 0.7747219800949097)
# 	('several', 0.7558979988098145)
# 	('rate', 0.7553632259368896)
# 	('leads', 0.7510894536972046)
# 	('many reasons', 0.7491286396980286)
# 	('lead', 0.7479717135429382)
# 	('coral bleaching rates', 0.7434888482093811)
# 	('location', 0.7410769462585449)
# 	('different rates', 0.7388367652893066)
# 	('first off', 0.7363966703414917)
# 	('mostly', 0.7361087799072266)
# 	('many ways', 0.7350485324859619)
# 	('many things', 0.7321619987487793)
# 	('located', 0.7300821542739868)
# 	('one way', 0.7265051603317261)
# 	('well', 0.7251006364822388)
# 	('why coral bleaching', 0.721108078956604)
#
# white
# 	('turning white', 0.9011688828468323)
# 	('red', 0.8896522521972656)
# 	('turns', 0.8768612146377563)
# 	('turn white', 0.8681599497795105)
# 	('turns white', 0.8673593997955322)
# 	('white color', 0.8634498119354248)
# 	('coral starts', 0.8628175854682922)
# 	('color', 0.859734296798706)
# 	('losing', 0.8591669201850891)
# 	('loses color', 0.8584964275360107)
# 	('coral dies', 0.8497792482376099)
# 	('once', 0.8462064862251282)
# 	('bright', 0.8452837467193604)
# 	('coral looses', 0.8443484306335449)
# 	('dead', 0.8425899744033813)
# 	('turn', 0.8421169519424438)
# 	('turning', 0.8396381735801697)
# 	('lost', 0.8302267789840698)
# 	('called coral bleaching', 0.8280973434448242)
# 	('plain white', 0.8264373540878296)
#
# trade winds
# 	('versus trade winds', 0.8228609561920166)
# 	('leading', 0.8195599913597107)
# 	('strength', 0.8070131540298462)
# 	('shifting', 0.7997063398361206)
# 	('merchant', 0.7996677160263062)
# 	('high water temperatures', 0.7995109558105469)
# 	('recognized', 0.7993959188461304)
# 	('water temperature rises', 0.7984129190444946)
# 	('water temperatures', 0.7956588268280029)
# 	('very weak', 0.7930784225463867)
# 	('guide', 0.7872403264045715)
# 	('weak', 0.78522789478302)
# 	('navigation', 0.784640371799469)
# 	('later recognized', 0.7842010259628296)
# 	('higher water temperatures', 0.7821922898292542)
# 	('being important', 0.7816594839096069)
# 	('shifting trade winds', 0.7785733938217163)
# 	('tradewinds', 0.7772105932235718)
# 	('winds go', 0.7707942128181458)
# 	('originally used', 0.7694680690765381)
#
# salinity
# 	('during storms', 0.95281982421875)
# 	('excessive rainfall', 0.9468363523483276)
# 	('excessive rainfall like hurricanes', 0.9339079856872559)
# 	('fresh water', 0.9325052499771118)
# 	('rain', 0.931276798248291)
# 	('shallow coastal regions', 0.9289814233779907)
# 	('upset', 0.9216805100440979)
# 	('tropical storms', 0.9207525253295898)
# 	('rainfall', 0.9143242239952087)
# 	('corals health', 0.9130167961120605)
# 	('storms increase', 0.9130138158798218)
# 	('shallow coastal regions during storms', 0.9094444513320923)
# 	('regions during storms', 0.8989773988723755)
# 	('decrease', 0.8961570858955383)
# 	('salinity drops', 0.8955734968185425)
# 	('decreases', 0.8954538702964783)
# 	('upsets', 0.8936583995819092)
# 	('like hurricanes', 0.8936440348625183)
# 	('more fresh', 0.8923100233078003)
# 	('more fresh water', 0.8864681720733643)
#
# death
# 	('white due', 0.9367979764938354)
# 	('ejection', 0.9235453605651855)
# 	('during bleaching corals turn white due', 0.9223437905311584)
# 	('corals turn white due', 0.921512246131897)
# 	('turns white due', 0.9166345596313477)
# 	('during bleaching', 0.9139635562896729)
# 	('zooxanthellae algae', 0.904430627822876)
# 	('coral turn white', 0.9042158722877502)
# 	('event resulted', 0.8840720057487488)
# 	('coral turns white due', 0.8733959794044495)
# 	('event', 0.8639152646064758)
# 	('resulted', 0.8585358262062073)
# 	('coral vulnerable', 0.8496224880218506)
# 	('worst ever', 0.8352383375167847)
# 	('massive coral bleaching', 0.8345924019813538)
# 	('died', 0.8315995931625366)
# 	('coral turns white', 0.8285364508628845)
# 	('makes corals vulnerable', 0.8188223838806152)
# 	('bleaching makes', 0.8160483837127686)
# 	('coral bleaching event', 0.8154866695404053)
#
# dying
# 	('many do', 0.9238991141319275)
# 	('reefs recover', 0.9112368822097778)
# 	('recover', 0.8945242762565613)
# 	('events', 0.8830375075340271)
# 	('bleaching makes', 0.8278310298919678)
# 	('corals vulnerable', 0.801284670829773)
# 	('many', 0.7886976003646851)
# 	('while', 0.7837539911270142)
# 	('makes coral vulnerable', 0.773914635181427)
# 	('occur', 0.7627017498016357)
# 	('coral vulnerable', 0.7420746684074402)
# 	('disease starvation', 0.7396246790885925)
# 	('lost', 0.7392953038215637)
# 	('through', 0.7338619828224182)
# 	('starvation', 0.7307739853858948)
# 	('result', 0.7302728891372681)
# 	('problems', 0.7283995151519775)
# 	('die off', 0.7268566489219666)
# 	('becoming', 0.7248971462249756)
# 	('diseases', 0.7231236696243286)
#
# fresh water
# 	('storms increase', 0.956997811794281)
# 	('salinity', 0.9325053095817566)
# 	('during storms', 0.9134523868560791)
# 	('rain', 0.9032279253005981)
# 	('hurricane', 0.8906940817832947)
# 	('upset', 0.8892799019813538)
# 	('storm', 0.8871139883995056)
# 	('more fresh water', 0.8836911916732788)
# 	('decreases', 0.8785626888275146)
# 	('drop', 0.8761087656021118)
# 	('excessive rainfall', 0.8729895353317261)
# 	('corals health', 0.8715901374816895)
# 	('salt', 0.8683663606643677)
# 	('salinity upsets', 0.8653188943862915)
# 	('storms', 0.8650954961776733)
# 	('rainfall', 0.8617534041404724)
# 	('upsets', 0.86161208152771)
# 	('balance necessary', 0.8566757440567017)
# 	('coral health', 0.8516489267349243)
# 	('salinity drops', 0.8509844541549683)
#
# storms
# 	('rain', 0.9277427792549133)
# 	('like hurricanes', 0.9217115640640259)
# 	('hurricanes', 0.9204037189483643)
# 	('rainfall', 0.9141466617584229)
# 	('add', 0.907633364200592)
# 	('corals health', 0.9016585946083069)
# 	('excessive rainfall', 0.8921704292297363)
# 	('more fresh', 0.8892829418182373)
# 	('hurricane', 0.8888227939605713)
# 	('during storms', 0.8862802982330322)
# 	('salt', 0.8850756883621216)
# 	('more fresh water', 0.8840655088424683)
# 	('salinity', 0.883683443069458)
# 	('shallow coastal regions', 0.8800923824310303)
# 	('tropical storms', 0.8759577870368958)
# 	('extreme storms', 0.8702695369720459)
# 	('fresh water', 0.8650954961776733)
# 	('salinity drops', 0.8637453317642212)
# 	('storm', 0.8554247617721558)
# 	('occur', 0.8548171520233154)
#
# rainfall
# 	('rain', 0.9494540691375732)
# 	('excessive rainfall', 0.9407850503921509)
# 	('shallow coastal regions', 0.9307758212089539)
# 	('storm', 0.9289612770080566)
# 	('tropical storms', 0.9229729175567627)
# 	('like hurricanes', 0.9153351783752441)
# 	('during storms', 0.9151452779769897)
# 	('more fresh water', 0.9148452877998352)
# 	('salinity', 0.9143242239952087)
# 	('storms', 0.9141467809677124)
# 	('hurricanes', 0.9103376865386963)
# 	('upset', 0.8965537548065186)
# 	('excessive rainfall like hurricanes', 0.8947281837463379)
# 	('shallow coastal regions during storms', 0.8897502422332764)
# 	('regions during storms', 0.8892727494239807)
# 	('hurricane', 0.8891572952270508)
# 	('salt', 0.8882738351821899)
# 	('corals health', 0.864507794380188)
# 	('fresh water', 0.8617534041404724)
# 	('tropical', 0.8597063422203064)
#
# water temperatures
# 	('water temperature', 0.9085139036178589)
# 	('trade winds shift', 0.8617820739746094)
# 	('temperature', 0.8601317405700684)
# 	('increased', 0.8265608549118042)
# 	('trade wind strength', 0.8257580995559692)
# 	('water temps', 0.8250358700752258)
# 	('change', 0.8234061002731323)
# 	('higher than', 0.813495934009552)
# 	('water temp', 0.813448429107666)
# 	('reef building corals need water temperature', 0.8046064972877502)
# 	('very weak', 0.801755428314209)
# 	('least', 0.8003126978874207)
# 	('reef building corals need', 0.8000079989433289)
# 	('trade winds', 0.7956588268280029)
# 	('needs water', 0.7916842103004456)
# 	('reef building', 0.7910329103469849)
# 	('degrees f', 0.7873681783676147)
# 	('trade winds affect', 0.7790552377700806)
# 	('reporting coral bleaching', 0.7761414051055908)
# 	('85of', 0.774351954460144)
#
# temps
# 	('water temp', 0.8343009948730469)
# 	('certain temperature', 0.807810366153717)
# 	('high water', 0.8063804507255554)
# 	('corals need water', 0.8048496842384338)
# 	('need water', 0.7896385192871094)
# 	('water temps', 0.7837706208229065)
# 	('temp', 0.7829992771148682)
# 	('waters shift eastward ocean water', 0.7810471057891846)
# 	('temperature', 0.7740940451622009)
# 	('increased', 0.7737958431243896)
# 	('water changes', 0.7674767971038818)
# 	('5of', 0.7645201683044434)
# 	('3of', 0.7640975117683411)
# 	('high', 0.7632213830947876)
# 	('reef building', 0.7626864314079285)
# 	('needs water', 0.7597126960754395)
# 	('increase', 0.7548746466636658)
# 	('co2 decreases', 0.7501924633979797)
# 	('coral needs', 0.7470659017562866)
# 	('reef building corals need water temperature', 0.7454872131347656)
